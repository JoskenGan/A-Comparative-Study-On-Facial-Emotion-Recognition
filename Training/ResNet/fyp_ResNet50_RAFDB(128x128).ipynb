# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.resnet import ResNet50
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-02 15:34:18.833019: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 15:34:18.833128: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 15:34:19.009998: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (128, 128))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (128,128,3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 64
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 128, 128, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

# https://www.tensorflow.org/guide/keras/transfer_learning#train_the_top_layer

# Load pre-trained ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Define the dropout rate and batch normalization momentum
dropout_rate = 0.3
batch_norm_momentum = 0.99  # Adjust this value as needed

# Build model on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)

# Add convolutional layers, pooling layers, etc., to build your model architecture
x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = BatchNormalization(momentum=batch_norm_momentum)(x)  # Add batch normalization
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = BatchNormalization(momentum=batch_norm_momentum)(x)  # Add batch normalization
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization(momentum=batch_norm_momentum)(x)  # Add batch normalization
x = Dropout(dropout_rate)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 61, 61, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,394,119 (28.21 MB)
#  Trainable params: 7,393,671 (28.20 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 41:43 13s/step - accuracy: 0.1719 - loss: 2.7505
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712072178.311080     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712072178.334559     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 63s 262ms/step - accuracy: 0.3573 - loss: 2.1509 - val_accuracy: 0.4120 - val_loss: 1.6022 - learning_rate: 0.0010
# Epoch 2/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.4688 - loss: 1.2914
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4688 - loss: 1.2914 - val_accuracy: 0.3654 - val_loss: 1.8199 - learning_rate: 0.0010
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.4929 - loss: 1.4563 - val_accuracy: 0.5372 - val_loss: 1.2969 - learning_rate: 0.0010
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5156 - loss: 1.3759 - val_accuracy: 0.5460 - val_loss: 1.2863 - learning_rate: 0.0010
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.5356 - loss: 1.2867 - val_accuracy: 0.5147 - val_loss: 1.2835 - learning_rate: 0.0010
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5000 - loss: 1.5507 - val_accuracy: 0.4892 - val_loss: 1.3793 - learning_rate: 0.0010
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 215ms/step - accuracy: 0.5670 - loss: 1.2023 - val_accuracy: 0.6196 - val_loss: 1.0578 - learning_rate: 0.0010
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5781 - loss: 1.1599 - val_accuracy: 0.6183 - val_loss: 1.0624 - learning_rate: 0.0010
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.6065 - loss: 1.0920 - val_accuracy: 0.6186 - val_loss: 1.0042 - learning_rate: 0.0010
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6562 - loss: 1.1106 - val_accuracy: 0.6222 - val_loss: 0.9958 - learning_rate: 0.0010
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.6279 - loss: 1.0223 - val_accuracy: 0.5248 - val_loss: 1.2119 - learning_rate: 0.0010
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5781 - loss: 1.2077 - val_accuracy: 0.5355 - val_loss: 1.1840 - learning_rate: 0.0010
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 215ms/step - accuracy: 0.6363 - loss: 1.0014 - val_accuracy: 0.6281 - val_loss: 1.0027 - learning_rate: 0.0010
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.8209 - val_accuracy: 0.6131 - val_loss: 1.0458 - learning_rate: 0.0010
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.6584 - loss: 0.9571 - val_accuracy: 0.6949 - val_loss: 0.8549 - learning_rate: 0.0010
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.7584 - val_accuracy: 0.6881 - val_loss: 0.8556 - learning_rate: 0.0010
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - accuracy: 0.6701 - loss: 0.9034 - val_accuracy: 0.6767 - val_loss: 0.9193 - learning_rate: 0.0010
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.8942 - val_accuracy: 0.6718 - val_loss: 0.9190 - learning_rate: 0.0010
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6787 - loss: 0.8786
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.6787 - loss: 0.8787 - val_accuracy: 0.6565 - val_loss: 0.9222 - learning_rate: 0.0010
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6406 - loss: 0.9105 - val_accuracy: 0.6561 - val_loss: 0.9195 - learning_rate: 1.0000e-04
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.7033 - loss: 0.8375 - val_accuracy: 0.7438 - val_loss: 0.7142 - learning_rate: 1.0000e-04
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.9252 - val_accuracy: 0.7428 - val_loss: 0.7144 - learning_rate: 1.0000e-04
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 40s 204ms/step - accuracy: 0.7119 - loss: 0.8036 - val_accuracy: 0.7477 - val_loss: 0.6996 - learning_rate: 1.0000e-04
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.7970 - val_accuracy: 0.7487 - val_loss: 0.6977 - learning_rate: 1.0000e-04
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 207ms/step - accuracy: 0.7201 - loss: 0.7788 - val_accuracy: 0.7441 - val_loss: 0.6996 - learning_rate: 1.0000e-04
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6250 - loss: 1.0428 - val_accuracy: 0.7425 - val_loss: 0.7015 - learning_rate: 1.0000e-04
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 207ms/step - accuracy: 0.7221 - loss: 0.7803 - val_accuracy: 0.7611 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.7299 - val_accuracy: 0.7595 - val_loss: 0.6746 - learning_rate: 1.0000e-04
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.7231 - loss: 0.7775 - val_accuracy: 0.7598 - val_loss: 0.6664 - learning_rate: 1.0000e-04
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.8401 - val_accuracy: 0.7598 - val_loss: 0.6659 - learning_rate: 1.0000e-04
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - accuracy: 0.7306 - loss: 0.7642 - val_accuracy: 0.7663 - val_loss: 0.6638 - learning_rate: 1.0000e-04
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.6550 - val_accuracy: 0.7637 - val_loss: 0.6648 - learning_rate: 1.0000e-04
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 46s 233ms/step - accuracy: 0.7333 - loss: 0.7449 - val_accuracy: 0.7578 - val_loss: 0.6775 - learning_rate: 1.0000e-04
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.8719 - val_accuracy: 0.7575 - val_loss: 0.6778 - learning_rate: 1.0000e-04
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7395 - loss: 0.7383
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 45s 226ms/step - accuracy: 0.7395 - loss: 0.7383 - val_accuracy: 0.7650 - val_loss: 0.6662 - learning_rate: 1.0000e-04
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6719 - loss: 0.8755 - val_accuracy: 0.7643 - val_loss: 0.6663 - learning_rate: 1.0000e-05
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 46s 234ms/step - accuracy: 0.7395 - loss: 0.7281 - val_accuracy: 0.7666 - val_loss: 0.6567 - learning_rate: 1.0000e-05
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.8476 - val_accuracy: 0.7660 - val_loss: 0.6568 - learning_rate: 1.0000e-05
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 47s 237ms/step - accuracy: 0.7357 - loss: 0.7397 - val_accuracy: 0.7669 - val_loss: 0.6537 - learning_rate: 1.0000e-05
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8281 - loss: 0.6150 - val_accuracy: 0.7669 - val_loss: 0.6537 - learning_rate: 1.0000e-05
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 46s 230ms/step - accuracy: 0.7348 - loss: 0.7526 - val_accuracy: 0.7656 - val_loss: 0.6550 - learning_rate: 1.0000e-05
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6094 - loss: 0.9606 - val_accuracy: 0.7656 - val_loss: 0.6549 - learning_rate: 1.0000e-05
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7415 - loss: 0.7182
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 221ms/step - accuracy: 0.7415 - loss: 0.7182 - val_accuracy: 0.7660 - val_loss: 0.6543 - learning_rate: 1.0000e-05
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.7366 - val_accuracy: 0.7663 - val_loss: 0.6542 - learning_rate: 1.0000e-06
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 218ms/step - accuracy: 0.7418 - loss: 0.7229 - val_accuracy: 0.7683 - val_loss: 0.6520 - learning_rate: 1.0000e-06
# Epoch 46/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.6903 - val_accuracy: 0.7676 - val_loss: 0.6516 - learning_rate: 1.0000e-06
# Epoch 47/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.7494 - loss: 0.7178 - val_accuracy: 0.7656 - val_loss: 0.6532 - learning_rate: 1.0000e-06
# Epoch 48/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.7419 - val_accuracy: 0.7660 - val_loss: 0.6531 - learning_rate: 1.0000e-06
# Epoch 49/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7408 - loss: 0.7279
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - accuracy: 0.7408 - loss: 0.7279 - val_accuracy: 0.7660 - val_loss: 0.6528 - learning_rate: 1.0000e-06
# Epoch 50/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.8049 - val_accuracy: 0.7656 - val_loss: 0.6530 - learning_rate: 1.0000e-07
# Epoch 51/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.7466 - loss: 0.7372 - val_accuracy: 0.7683 - val_loss: 0.6524 - learning_rate: 1.0000e-07
# Epoch 52/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.6163 - val_accuracy: 0.7686 - val_loss: 0.6524 - learning_rate: 1.0000e-07
# Epoch 53/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 214ms/step - accuracy: 0.7521 - loss: 0.7072 - val_accuracy: 0.7656 - val_loss: 0.6520 - learning_rate: 1.0000e-07
# Epoch 54/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.7408 - val_accuracy: 0.7666 - val_loss: 0.6520 - learning_rate: 1.0000e-07
# Epoch 55/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 221ms/step - accuracy: 0.7464 - loss: 0.7231 - val_accuracy: 0.7673 - val_loss: 0.6523 - learning_rate: 1.0000e-07
# Epoch 56/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7031 - loss: 0.8737
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.8737 - val_accuracy: 0.7669 - val_loss: 0.6522 - learning_rate: 1.0000e-07
# Epoch 57/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 220ms/step - accuracy: 0.7396 - loss: 0.7219 - val_accuracy: 0.7663 - val_loss: 0.6523 - learning_rate: 1.0000e-07
# Epoch 58/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.7186 - val_accuracy: 0.7666 - val_loss: 0.6522 - learning_rate: 1.0000e-07
# Epoch 59/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 221ms/step - accuracy: 0.7494 - loss: 0.7140 - val_accuracy: 0.7669 - val_loss: 0.6526 - learning_rate: 1.0000e-07
# Epoch 60/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.6045 - val_accuracy: 0.7673 - val_loss: 0.6527 - learning_rate: 1.0000e-07
# Epoch 61/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 218ms/step - accuracy: 0.7498 - loss: 0.7149 - val_accuracy: 0.7673 - val_loss: 0.6520 - learning_rate: 1.0000e-07
# Epoch 62/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.7454 - val_accuracy: 0.7673 - val_loss: 0.6519 - learning_rate: 1.0000e-07
# Epoch 63/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.7449 - loss: 0.7207 - val_accuracy: 0.7679 - val_loss: 0.6526 - learning_rate: 1.0000e-07
# Epoch 64/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.7650 - val_accuracy: 0.7679 - val_loss: 0.6526 - learning_rate: 1.0000e-07
# Epoch 65/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 220ms/step - accuracy: 0.7356 - loss: 0.7490 - val_accuracy: 0.7673 - val_loss: 0.6523 - learning_rate: 1.0000e-07
# Epoch 66/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.8010 - val_accuracy: 0.7673 - val_loss: 0.6522 - learning_rate: 1.0000e-07
# Epoch 67/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 219ms/step - accuracy: 0.7406 - loss: 0.7304 - val_accuracy: 0.7666 - val_loss: 0.6527 - learning_rate: 1.0000e-07
# Epoch 68/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.6718 - val_accuracy: 0.7663 - val_loss: 0.6529 - learning_rate: 1.0000e-07
# Epoch 69/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 220ms/step - accuracy: 0.7428 - loss: 0.7305 - val_accuracy: 0.7669 - val_loss: 0.6520 - learning_rate: 1.0000e-07
# Epoch 70/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.7549 - val_accuracy: 0.7669 - val_loss: 0.6519 - learning_rate: 1.0000e-07
# Epoch 71/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - accuracy: 0.7441 - loss: 0.7167 - val_accuracy: 0.7676 - val_loss: 0.6518 - learning_rate: 1.0000e-07
# Epoch 72/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6562 - loss: 0.9327 - val_accuracy: 0.7676 - val_loss: 0.6519 - learning_rate: 1.0000e-07
# Epoch 73/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.7435 - loss: 0.7272 - val_accuracy: 0.7673 - val_loss: 0.6514 - learning_rate: 1.0000e-07
# Epoch 74/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8281 - loss: 0.5521 - val_accuracy: 0.7673 - val_loss: 0.6515 - learning_rate: 1.0000e-07
# Epoch 75/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - accuracy: 0.7437 - loss: 0.7202 - val_accuracy: 0.7673 - val_loss: 0.6520 - learning_rate: 1.0000e-07
# Epoch 76/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.7521 - val_accuracy: 0.7673 - val_loss: 0.6521 - learning_rate: 1.0000e-07
# Epoch 77/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7394 - loss: 0.7375Epoch 76: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 51.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.7395 - loss: 0.7374 - val_accuracy: 0.7656 - val_loss: 0.6520 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.403621  1.820675      0.411995  1.602170   1.000000e-03
# 1   0.468750  1.291395      0.365385  1.819900   1.000000e-03
# 2   0.499795  1.425891      0.537158  1.296910   1.000000e-03
# 3   0.515625  1.375890      0.545958  1.286330   1.000000e-03
# 4   0.540346  1.278626      0.514668  1.283508   1.000000e-03
# ..       ...       ...           ...       ...            ...
# 72  0.742279  0.727494      0.767275  0.651394   1.000000e-07
# 73  0.828125  0.552128      0.767275  0.651452   1.000000e-07
# 74  0.741624  0.724843      0.767275  0.652016   1.000000e-07
# 75  0.718750  0.752127      0.767275  0.652065   1.000000e-07
# 76  0.743590  0.725261      0.765645  0.651958   1.000000e-07
#
# [77 rows x 5 columns]

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 61, 61, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,394,119 (28.21 MB)
#  Trainable params: 7,393,671 (28.20 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 21:07 7s/step - accuracy: 0.7969 - loss: 0.5967
# W0000 00:00:1712073887.531205     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 51s 235ms/step - accuracy: 0.7422 - loss: 0.7185 - val_accuracy: 0.7689 - val_loss: 0.6503 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8125 - loss: 0.5875
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8125 - loss: 0.5875 - val_accuracy: 0.7686 - val_loss: 0.6503 - learning_rate: 1.0000e-05
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 44s 220ms/step - accuracy: 0.7401 - loss: 0.7320 - val_accuracy: 0.7696 - val_loss: 0.6494 - learning_rate: 1.0000e-05
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.6162 - val_accuracy: 0.7689 - val_loss: 0.6494 - learning_rate: 1.0000e-05
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 218ms/step - accuracy: 0.7414 - loss: 0.7385 - val_accuracy: 0.7673 - val_loss: 0.6470 - learning_rate: 1.0000e-05
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.7225 - val_accuracy: 0.7673 - val_loss: 0.6472 - learning_rate: 1.0000e-05
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7428 - loss: 0.7290
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - accuracy: 0.7428 - loss: 0.7290 - val_accuracy: 0.7679 - val_loss: 0.6495 - learning_rate: 1.0000e-05
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.5690 - val_accuracy: 0.7679 - val_loss: 0.6495 - learning_rate: 1.0000e-06
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.7349 - loss: 0.7336 - val_accuracy: 0.7692 - val_loss: 0.6483 - learning_rate: 1.0000e-06
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.6658 - val_accuracy: 0.7692 - val_loss: 0.6483 - learning_rate: 1.0000e-06
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7457 - loss: 0.7241
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 215ms/step - accuracy: 0.7457 - loss: 0.7241 - val_accuracy: 0.7692 - val_loss: 0.6477 - learning_rate: 1.0000e-06
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.6603 - val_accuracy: 0.7692 - val_loss: 0.6476 - learning_rate: 1.0000e-07
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 217ms/step - accuracy: 0.7490 - loss: 0.7171 - val_accuracy: 0.7686 - val_loss: 0.6475 - learning_rate: 1.0000e-07
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6562 - loss: 0.9240 - val_accuracy: 0.7686 - val_loss: 0.6474 - learning_rate: 1.0000e-07
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 215ms/step - accuracy: 0.7505 - loss: 0.7164 - val_accuracy: 0.7683 - val_loss: 0.6477 - learning_rate: 1.0000e-07
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6719 - loss: 0.7852 - val_accuracy: 0.7689 - val_loss: 0.6478 - learning_rate: 1.0000e-07
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 42s 213ms/step - accuracy: 0.7372 - loss: 0.7332 - val_accuracy: 0.7689 - val_loss: 0.6478 - learning_rate: 1.0000e-07
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.5475 - val_accuracy: 0.7692 - val_loss: 0.6478 - learning_rate: 1.0000e-07
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.7325 - loss: 0.7303 - val_accuracy: 0.7689 - val_loss: 0.6477 - learning_rate: 1.0000e-07
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.6509 - val_accuracy: 0.7692 - val_loss: 0.6477 - learning_rate: 1.0000e-07
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 206ms/step - accuracy: 0.7478 - loss: 0.6985 - val_accuracy: 0.7683 - val_loss: 0.6472 - learning_rate: 1.0000e-07
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7812 - loss: 0.6647 - val_accuracy: 0.7676 - val_loss: 0.6473 - learning_rate: 1.0000e-07
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.7394 - loss: 0.7268 - val_accuracy: 0.7669 - val_loss: 0.6473 - learning_rate: 1.0000e-07
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.7882 - val_accuracy: 0.7673 - val_loss: 0.6473 - learning_rate: 1.0000e-07
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 207ms/step - accuracy: 0.7482 - loss: 0.7194 - val_accuracy: 0.7683 - val_loss: 0.6476 - learning_rate: 1.0000e-07
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.7439 - val_accuracy: 0.7689 - val_loss: 0.6476 - learning_rate: 1.0000e-07
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.7518 - loss: 0.7222 - val_accuracy: 0.7676 - val_loss: 0.6474 - learning_rate: 1.0000e-07
# Epoch 28/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.6719 - loss: 0.8220Epoch 27: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 2.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6719 - loss: 0.8220 - val_accuracy: 0.7673 - val_loss: 0.6474 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.740723  0.728491      0.768905  0.650270   1.000000e-05
# 1   0.812500  0.587548      0.768579  0.650311   1.000000e-05
# 2   0.742033  0.727946      0.769557  0.649435   1.000000e-05
# 3   0.750000  0.616200      0.768905  0.649447   1.000000e-05
# 4   0.740559  0.731703      0.767275  0.647045   1.000000e-05
# 5   0.765625  0.722522      0.767275  0.647184   1.000000e-05
# 6   0.742934  0.720821      0.767927  0.649516   1.000000e-05
# 7   0.875000  0.568971      0.767927  0.649523   1.000000e-06
# 8   0.742607  0.729114      0.769231  0.648274   1.000000e-06
# 9   0.718750  0.665757      0.769231  0.648294   1.000000e-06
# 10  0.743672  0.721290      0.769231  0.647654   1.000000e-06
# 11  0.734375  0.660265      0.769231  0.647632   1.000000e-07
# 12  0.743917  0.720878      0.768579  0.647494   1.000000e-07
# 13  0.656250  0.924014      0.768579  0.647426   1.000000e-07
# 14  0.744655  0.723704      0.768253  0.647679   1.000000e-07
# 15  0.671875  0.785177      0.768905  0.647782   1.000000e-07
# 16  0.742852  0.719369      0.768905  0.647754   1.000000e-07
# 17  0.781250  0.547501      0.769231  0.647802   1.000000e-07
# 18  0.737282  0.725143      0.768905  0.647670   1.000000e-07
# 19  0.796875  0.650885      0.769231  0.647714   1.000000e-07
# 20  0.744737  0.718216      0.768253  0.647192   1.000000e-07
# 21  0.781250  0.664718      0.767601  0.647289   1.000000e-07
# 22  0.743672  0.723917      0.766949  0.647291   1.000000e-07
# 23  0.734375  0.788231      0.767275  0.647282   1.000000e-07
# 24  0.742443  0.729370      0.768253  0.647562   1.000000e-07
# 25  0.703125  0.743937      0.768905  0.647577   1.000000e-07
# 26  0.743508  0.730283      0.767601  0.647432   1.000000e-07
# 27  0.671875  0.821972      0.767275  0.647362   1.000000e-07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 2s - 6ms/step - accuracy: 0.8034 - loss: 0.5638
#
# train Accuracy: 0.8033574819564819
# 96/96 - 0s - 4ms/step - accuracy: 0.7696 - loss: 0.6494
#
# Test Accuracy: 0.7695567011833191
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.81      0.75      0.78       329
#      disgust       0.70      0.45      0.55        74
#         fear       0.71      0.64      0.68       162
#        happy       0.70      0.75      0.72       680
#      neutral       0.64      0.74      0.69       478
#          sad       0.53      0.29      0.37       160
#     surprise       0.89      0.90      0.89      1185
#
#     accuracy                           0.77      3068
#    macro avg       0.71      0.64      0.67      3068
# weighted avg       0.77      0.77      0.76      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
