# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-24 08:52:49.953949: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 08:52:49.954110: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 08:52:50.074143: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (128, 128))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (128, 128, 3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 32
EPOCHS = 50

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 128, 128, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 4, 4, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 263,175 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/383 ━━━━━━━━━━━━━━━━━━━━ 24s 65ms/step - accuracy: 0.0859 - loss: 22.1717
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711270698.132330      89 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711270698.166415      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 177/383 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.2839 - loss: 7.1351
# W0000 00:00:1711270723.001899      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3124 - loss: 4.9615
# W0000 00:00:1711270748.750367      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 74s 157ms/step - accuracy: 0.3125 - loss: 4.9555 - val_accuracy: 0.4162 - val_loss: 1.5699 - learning_rate: 0.0010
# Epoch 2/50
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.2500 - loss: 1.6830
# W0000 00:00:1711270758.041907      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.2500 - loss: 1.6830 - val_accuracy: 0.3647 - val_loss: 1.6426 - learning_rate: 0.0010
# Epoch 3/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 119ms/step - accuracy: 0.3758 - loss: 1.6361 - val_accuracy: 0.3999 - val_loss: 1.5144 - learning_rate: 0.0010
# Epoch 4/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.2357 - val_accuracy: 0.3977 - val_loss: 1.5262 - learning_rate: 0.0010
# Epoch 5/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4079 - loss: 1.5572
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 47s 120ms/step - accuracy: 0.4079 - loss: 1.5572 - val_accuracy: 0.3331 - val_loss: 1.6003 - learning_rate: 0.0010
# Epoch 6/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.1875 - loss: 1.6889 - val_accuracy: 0.3334 - val_loss: 1.5968 - learning_rate: 1.0000e-04
# Epoch 7/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 47s 119ms/step - accuracy: 0.4021 - loss: 1.5291 - val_accuracy: 0.4488 - val_loss: 1.4829 - learning_rate: 1.0000e-04
# Epoch 8/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.5285 - val_accuracy: 0.4537 - val_loss: 1.4795 - learning_rate: 1.0000e-04
# Epoch 9/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 47s 119ms/step - accuracy: 0.4383 - loss: 1.4832 - val_accuracy: 0.4625 - val_loss: 1.4633 - learning_rate: 1.0000e-04
# Epoch 10/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.3890 - val_accuracy: 0.4622 - val_loss: 1.4647 - learning_rate: 1.0000e-04
# Epoch 11/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 119ms/step - accuracy: 0.4452 - loss: 1.4812 - val_accuracy: 0.4684 - val_loss: 1.4590 - learning_rate: 1.0000e-04
# Epoch 12/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5938 - loss: 1.2751 - val_accuracy: 0.4684 - val_loss: 1.4589 - learning_rate: 1.0000e-04
# Epoch 13/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4487 - loss: 1.4750 - val_accuracy: 0.4664 - val_loss: 1.4569 - learning_rate: 1.0000e-04
# Epoch 14/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4375 - loss: 1.6104 - val_accuracy: 0.4674 - val_loss: 1.4558 - learning_rate: 1.0000e-04
# Epoch 15/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4467 - loss: 1.4797 - val_accuracy: 0.4687 - val_loss: 1.4549 - learning_rate: 1.0000e-04
# Epoch 16/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5938 - loss: 1.2595 - val_accuracy: 0.4684 - val_loss: 1.4559 - learning_rate: 1.0000e-04
# Epoch 17/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4504 - loss: 1.4733 - val_accuracy: 0.4671 - val_loss: 1.4491 - learning_rate: 1.0000e-04
# Epoch 18/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5312 - loss: 1.3090 - val_accuracy: 0.4671 - val_loss: 1.4500 - learning_rate: 1.0000e-04
# Epoch 19/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4596 - loss: 1.4596 - val_accuracy: 0.4694 - val_loss: 1.4550 - learning_rate: 1.0000e-04
# Epoch 20/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.4633 - val_accuracy: 0.4716 - val_loss: 1.4526 - learning_rate: 1.0000e-04
# Epoch 21/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4508 - loss: 1.4556 - val_accuracy: 0.4700 - val_loss: 1.4437 - learning_rate: 1.0000e-04
# Epoch 22/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.3707 - val_accuracy: 0.4707 - val_loss: 1.4418 - learning_rate: 1.0000e-04
# Epoch 23/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 117ms/step - accuracy: 0.4468 - loss: 1.4752 - val_accuracy: 0.4694 - val_loss: 1.4436 - learning_rate: 1.0000e-04
# Epoch 24/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4062 - loss: 1.5247 - val_accuracy: 0.4726 - val_loss: 1.4414 - learning_rate: 1.0000e-04
# Epoch 25/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4542 - loss: 1.4570 - val_accuracy: 0.4775 - val_loss: 1.4341 - learning_rate: 1.0000e-04
# Epoch 26/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5000 - loss: 1.2920 - val_accuracy: 0.4765 - val_loss: 1.4331 - learning_rate: 1.0000e-04
# Epoch 27/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 117ms/step - accuracy: 0.4474 - loss: 1.4734 - val_accuracy: 0.4720 - val_loss: 1.4432 - learning_rate: 1.0000e-04
# Epoch 28/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5000 - loss: 1.4464 - val_accuracy: 0.4739 - val_loss: 1.4418 - learning_rate: 1.0000e-04
# Epoch 29/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4560 - loss: 1.4650
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4560 - loss: 1.4650 - val_accuracy: 0.4746 - val_loss: 1.4418 - learning_rate: 1.0000e-04
# Epoch 30/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4062 - loss: 1.6930 - val_accuracy: 0.4746 - val_loss: 1.4419 - learning_rate: 1.0000e-05
# Epoch 31/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 119ms/step - accuracy: 0.4581 - loss: 1.4607 - val_accuracy: 0.4814 - val_loss: 1.4266 - learning_rate: 1.0000e-05
# Epoch 32/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.5080 - val_accuracy: 0.4811 - val_loss: 1.4267 - learning_rate: 1.0000e-05
# Epoch 33/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 119ms/step - accuracy: 0.4620 - loss: 1.4450 - val_accuracy: 0.4798 - val_loss: 1.4259 - learning_rate: 1.0000e-05
# Epoch 34/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.6180 - val_accuracy: 0.4798 - val_loss: 1.4258 - learning_rate: 1.0000e-05
# Epoch 35/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 119ms/step - accuracy: 0.4562 - loss: 1.4587 - val_accuracy: 0.4821 - val_loss: 1.4241 - learning_rate: 1.0000e-05
# Epoch 36/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5000 - loss: 1.3825 - val_accuracy: 0.4824 - val_loss: 1.4241 - learning_rate: 1.0000e-05
# Epoch 37/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 117ms/step - accuracy: 0.4617 - loss: 1.4423 - val_accuracy: 0.4788 - val_loss: 1.4274 - learning_rate: 1.0000e-05
# Epoch 38/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4062 - loss: 1.4415 - val_accuracy: 0.4785 - val_loss: 1.4275 - learning_rate: 1.0000e-05
# Epoch 39/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4561 - loss: 1.4482 - val_accuracy: 0.4798 - val_loss: 1.4277 - learning_rate: 1.0000e-05
# Epoch 40/50
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.4688 - loss: 1.3744
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.3744 - val_accuracy: 0.4808 - val_loss: 1.4277 - learning_rate: 1.0000e-05
# Epoch 41/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 78s 117ms/step - accuracy: 0.4623 - loss: 1.4395 - val_accuracy: 0.4811 - val_loss: 1.4263 - learning_rate: 1.0000e-06
# Epoch 42/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5312 - loss: 1.3294 - val_accuracy: 0.4811 - val_loss: 1.4263 - learning_rate: 1.0000e-06
# Epoch 43/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 117ms/step - accuracy: 0.4571 - loss: 1.4415 - val_accuracy: 0.4808 - val_loss: 1.4258 - learning_rate: 1.0000e-06
# Epoch 44/50
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.5938 - loss: 1.2343
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5938 - loss: 1.2343 - val_accuracy: 0.4808 - val_loss: 1.4258 - learning_rate: 1.0000e-06
# Epoch 45/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4707 - loss: 1.4460 - val_accuracy: 0.4808 - val_loss: 1.4258 - learning_rate: 1.0000e-07
# Epoch 46/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4375 - loss: 1.3838 - val_accuracy: 0.4808 - val_loss: 1.4258 - learning_rate: 1.0000e-07
# Epoch 47/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 117ms/step - accuracy: 0.4638 - loss: 1.4489 - val_accuracy: 0.4814 - val_loss: 1.4257 - learning_rate: 1.0000e-07
# Epoch 48/50
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.5000 - loss: 1.4212
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5000 - loss: 1.4212 - val_accuracy: 0.4814 - val_loss: 1.4257 - learning_rate: 1.0000e-07
# Epoch 49/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 46s 118ms/step - accuracy: 0.4720 - loss: 1.4316 - val_accuracy: 0.4814 - val_loss: 1.4258 - learning_rate: 1.0000e-07
# Epoch 50/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6562 - loss: 1.2620 - val_accuracy: 0.4814 - val_loss: 1.4258 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.350437  2.659904      0.416232  1.569868   1.000000e-03
# 1   0.250000  1.682981      0.364733  1.642617   1.000000e-03
# 2   0.384835  1.605844      0.399935  1.514406   1.000000e-03
# 3   0.468750  1.235664      0.397653  1.526218   1.000000e-03
# 4   0.407876  1.555961      0.333116  1.600271   1.000000e-03
# 5   0.187500  1.688926      0.333442  1.596827   1.000000e-04
# 6   0.426179  1.507023      0.448827  1.482887   1.000000e-04
# 7   0.468750  1.528484      0.453716  1.479451   1.000000e-04
# 8   0.438435  1.487889      0.462516  1.463328   1.000000e-04
# 9   0.468750  1.388989      0.462190  1.464690   1.000000e-04
# 10  0.447912  1.485183      0.468383  1.458979   1.000000e-04
# 11  0.593750  1.275102      0.468383  1.458895   1.000000e-04
# 12  0.448811  1.479494      0.466428  1.456856   1.000000e-04
# 13  0.437500  1.610380      0.467405  1.455762   1.000000e-04
# 14  0.449710  1.478171      0.468709  1.454878   1.000000e-04
# 15  0.593750  1.259519      0.468383  1.455897   1.000000e-04
# 16  0.449138  1.473443      0.467080  1.449147   1.000000e-04
# 17  0.531250  1.308995      0.467080  1.449987   1.000000e-04
# 18  0.451344  1.471263      0.469361  1.455048   1.000000e-04
# 19  0.468750  1.463335      0.471643  1.452567   1.000000e-04
# 20  0.448975  1.470720      0.470013  1.443717   1.000000e-04
# 21  0.468750  1.370723      0.470665  1.441753   1.000000e-04
# 22  0.453714  1.464647      0.469361  1.443607   1.000000e-04
# 23  0.406250  1.524716      0.472621  1.441424   1.000000e-04
# 24  0.450936  1.460260      0.477510  1.434080   1.000000e-04
# 25  0.500000  1.291951      0.476532  1.433072   1.000000e-04
# 26  0.453060  1.468360      0.471969  1.443158   1.000000e-04
# 27  0.500000  1.446389      0.473924  1.441783   1.000000e-04
# 28  0.456900  1.459765      0.474576  1.441757   1.000000e-04
# 29  0.406250  1.692965      0.474576  1.441857   1.000000e-05
# 30  0.463682  1.445202      0.481421  1.426646   1.000000e-05
# 31  0.468750  1.507980      0.481095  1.426744   1.000000e-05
# 32  0.460985  1.446103      0.479791  1.425896   1.000000e-05
# 33  0.468750  1.618008      0.479791  1.425797   1.000000e-05
# 34  0.456492  1.448028      0.482073  1.424051   1.000000e-05
# 35  0.500000  1.382462      0.482399  1.424054   1.000000e-05
# 36  0.462211  1.444171      0.478814  1.427444   1.000000e-05
# 37  0.406250  1.441520      0.478488  1.427509   1.000000e-05
# 38  0.461394  1.442051      0.479791  1.427746   1.000000e-05
# 39  0.468750  1.374378      0.480769  1.427689   1.000000e-05
# 40  0.463763  1.444759      0.481095  1.426328   1.000000e-06
# 41  0.531250  1.329449      0.481095  1.426322   1.000000e-06
# 42  0.459270  1.445084      0.480769  1.425792   1.000000e-06
# 43  0.593750  1.234347      0.480769  1.425787   1.000000e-06
# 44  0.465398  1.444914      0.480769  1.425771   1.000000e-07
# 45  0.437500  1.383808      0.480769  1.425770   1.000000e-07
# 46  0.466950  1.446235      0.481421  1.425745   1.000000e-07
# 47  0.500000  1.421249      0.481421  1.425745   1.000000e-07
# 48  0.462129  1.445292      0.481421  1.425753   1.000000e-07
# 49  0.656250  1.262015      0.481421  1.425753   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 4, 4, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 21,070,127 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 5:19:01 50s/step - accuracy: 0.2812 - loss: 1.8264
# W0000 00:00:1711272051.561777      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 284/383 ━━━━━━━━━━━━━━━━━━━━ 22s 232ms/step - accuracy: 0.2889 - loss: 1.8160
# W0000 00:00:1711272117.329626      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.3043 - loss: 1.8014
# W0000 00:00:1711272135.699164      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1711272141.030251      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 143s 242ms/step - accuracy: 0.3044 - loss: 1.8012 - val_accuracy: 0.4449 - val_loss: 1.4611 - learning_rate: 1.0000e-05
# Epoch 2/50
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 1:24 221ms/step - accuracy: 0.4688 - loss: 1.5194
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4688 - loss: 1.5194 - val_accuracy: 0.4459 - val_loss: 1.4598 - learning_rate: 1.0000e-05
# Epoch 3/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.4695 - loss: 1.4361 - val_accuracy: 0.5385 - val_loss: 1.2209 - learning_rate: 1.0000e-05
# Epoch 4/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5312 - loss: 1.2299 - val_accuracy: 0.5394 - val_loss: 1.2204 - learning_rate: 1.0000e-05
# Epoch 5/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.5445 - loss: 1.2251 - val_accuracy: 0.6170 - val_loss: 1.0783 - learning_rate: 1.0000e-05
# Epoch 6/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6562 - loss: 1.0996 - val_accuracy: 0.6151 - val_loss: 1.0779 - learning_rate: 1.0000e-05
# Epoch 7/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.6161 - loss: 1.0646 - val_accuracy: 0.6653 - val_loss: 0.9669 - learning_rate: 1.0000e-05
# Epoch 8/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5312 - loss: 1.0716 - val_accuracy: 0.6649 - val_loss: 0.9670 - learning_rate: 1.0000e-05
# Epoch 9/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.6555 - loss: 0.9738 - val_accuracy: 0.6904 - val_loss: 0.8853 - learning_rate: 1.0000e-05
# Epoch 10/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5625 - loss: 1.0766 - val_accuracy: 0.6913 - val_loss: 0.8849 - learning_rate: 1.0000e-05
# Epoch 11/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.6800 - loss: 0.8905 - val_accuracy: 0.7057 - val_loss: 0.8331 - learning_rate: 1.0000e-05
# Epoch 12/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.8424 - val_accuracy: 0.7060 - val_loss: 0.8334 - learning_rate: 1.0000e-05
# Epoch 13/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.7171 - loss: 0.7942 - val_accuracy: 0.7223 - val_loss: 0.7877 - learning_rate: 1.0000e-05
# Epoch 14/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6562 - loss: 0.7318 - val_accuracy: 0.7236 - val_loss: 0.7875 - learning_rate: 1.0000e-05
# Epoch 15/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.7311 - loss: 0.7540 - val_accuracy: 0.7347 - val_loss: 0.7529 - learning_rate: 1.0000e-05
# Epoch 16/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6250 - loss: 1.1023 - val_accuracy: 0.7340 - val_loss: 0.7526 - learning_rate: 1.0000e-05
# Epoch 17/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.7437 - loss: 0.7068 - val_accuracy: 0.7464 - val_loss: 0.7409 - learning_rate: 1.0000e-05
# Epoch 18/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6250 - loss: 0.7072 - val_accuracy: 0.7454 - val_loss: 0.7402 - learning_rate: 1.0000e-05
# Epoch 19/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.7668 - loss: 0.6516 - val_accuracy: 0.7536 - val_loss: 0.7109 - learning_rate: 1.0000e-05
# Epoch 20/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8750 - loss: 0.4475 - val_accuracy: 0.7539 - val_loss: 0.7110 - learning_rate: 1.0000e-05
# Epoch 21/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.7845 - loss: 0.6139 - val_accuracy: 0.7608 - val_loss: 0.6932 - learning_rate: 1.0000e-05
# Epoch 22/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.5830 - val_accuracy: 0.7611 - val_loss: 0.6929 - learning_rate: 1.0000e-05
# Epoch 23/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.7890 - loss: 0.5835 - val_accuracy: 0.7666 - val_loss: 0.6759 - learning_rate: 1.0000e-05
# Epoch 24/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.6349 - val_accuracy: 0.7663 - val_loss: 0.6758 - learning_rate: 1.0000e-05
# Epoch 25/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8139 - loss: 0.5386 - val_accuracy: 0.7748 - val_loss: 0.6545 - learning_rate: 1.0000e-05
# Epoch 26/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8125 - loss: 0.4918 - val_accuracy: 0.7748 - val_loss: 0.6545 - learning_rate: 1.0000e-05
# Epoch 27/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8261 - loss: 0.5063 - val_accuracy: 0.7683 - val_loss: 0.6606 - learning_rate: 1.0000e-05
# Epoch 28/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8750 - loss: 0.3529 - val_accuracy: 0.7683 - val_loss: 0.6607 - learning_rate: 1.0000e-05
# Epoch 29/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8320 - loss: 0.4789 - val_accuracy: 0.7780 - val_loss: 0.6524 - learning_rate: 1.0000e-05
# Epoch 30/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.6473 - val_accuracy: 0.7777 - val_loss: 0.6514 - learning_rate: 1.0000e-05
# Epoch 31/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8446 - loss: 0.4424 - val_accuracy: 0.7777 - val_loss: 0.6441 - learning_rate: 1.0000e-05
# Epoch 32/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.4388 - val_accuracy: 0.7784 - val_loss: 0.6442 - learning_rate: 1.0000e-05
# Epoch 33/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 63s 161ms/step - accuracy: 0.8531 - loss: 0.4120 - val_accuracy: 0.7823 - val_loss: 0.6394 - learning_rate: 1.0000e-05
# Epoch 34/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.2422 - val_accuracy: 0.7826 - val_loss: 0.6401 - learning_rate: 1.0000e-05
# Epoch 35/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 78s 162ms/step - accuracy: 0.8628 - loss: 0.3995 - val_accuracy: 0.7839 - val_loss: 0.6403 - learning_rate: 1.0000e-05
# Epoch 36/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.4547 - val_accuracy: 0.7849 - val_loss: 0.6392 - learning_rate: 1.0000e-05
# Epoch 37/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8661 - loss: 0.3772 - val_accuracy: 0.7901 - val_loss: 0.6348 - learning_rate: 1.0000e-05
# Epoch 38/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7500 - loss: 0.5826 - val_accuracy: 0.7898 - val_loss: 0.6354 - learning_rate: 1.0000e-05
# Epoch 39/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8719 - loss: 0.3572 - val_accuracy: 0.7872 - val_loss: 0.6347 - learning_rate: 1.0000e-05
# Epoch 40/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.3874 - val_accuracy: 0.7878 - val_loss: 0.6345 - learning_rate: 1.0000e-05
# Epoch 41/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8856 - loss: 0.3288
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8856 - loss: 0.3289 - val_accuracy: 0.7836 - val_loss: 0.6476 - learning_rate: 1.0000e-05
# Epoch 42/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.3007 - val_accuracy: 0.7846 - val_loss: 0.6479 - learning_rate: 1.0000e-06
# Epoch 43/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8915 - loss: 0.3163 - val_accuracy: 0.7934 - val_loss: 0.6314 - learning_rate: 1.0000e-06
# Epoch 44/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.4906 - val_accuracy: 0.7937 - val_loss: 0.6318 - learning_rate: 1.0000e-06
# Epoch 45/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8889 - loss: 0.3129 - val_accuracy: 0.7924 - val_loss: 0.6344 - learning_rate: 1.0000e-06
# Epoch 46/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.2411 - val_accuracy: 0.7927 - val_loss: 0.6344 - learning_rate: 1.0000e-06
# Epoch 47/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8974 - loss: 0.2956 - val_accuracy: 0.7940 - val_loss: 0.6315 - learning_rate: 1.0000e-06
# Epoch 48/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8750 - loss: 0.3196 - val_accuracy: 0.7930 - val_loss: 0.6321 - learning_rate: 1.0000e-06
# Epoch 49/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.8971 - loss: 0.2962 - val_accuracy: 0.7917 - val_loss: 0.6294 - learning_rate: 1.0000e-06
# Epoch 50/50
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9062 - loss: 0.2752 - val_accuracy: 0.7917 - val_loss: 0.6294 - learning_rate: 1.0000e-06

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.360650  1.733860      0.444915  1.461090   1.000000e-05
# 1   0.468750  1.519438      0.445893  1.459831   1.000000e-05
# 2   0.487948  1.377572      0.538462  1.220916   1.000000e-05
# 3   0.531250  1.229853      0.539439  1.220389   1.000000e-05
# 4   0.564017  1.184065      0.617014  1.078303   1.000000e-05
# 5   0.656250  1.099627      0.615059  1.077854   1.000000e-05
# 6   0.626195  1.050233      0.665254  0.966937   1.000000e-05
# 7   0.531250  1.071635      0.664928  0.966974   1.000000e-05
# 8   0.664188  0.946578      0.690352  0.885324   1.000000e-05
# 9   0.562500  1.076572      0.691330  0.884924   1.000000e-05
# 10  0.690743  0.865698      0.705671  0.833148   1.000000e-05
# 11  0.687500  0.842386      0.705997  0.833449   1.000000e-05
# 12  0.721301  0.788476      0.722295  0.787701   1.000000e-05
# 13  0.656250  0.731769      0.723598  0.787462   1.000000e-05
# 14  0.736988  0.739670      0.734681  0.752876   1.000000e-05
# 15  0.625000  1.102302      0.734029  0.752563   1.000000e-05
# 16  0.750960  0.696374      0.746415  0.740878   1.000000e-05
# 17  0.625000  0.707194      0.745437  0.740204   1.000000e-05
# 18  0.770651  0.640790      0.753585  0.710876   1.000000e-05
# 19  0.875000  0.447472      0.753911  0.711026   1.000000e-05
# 20  0.784378  0.606739      0.760756  0.693173   1.000000e-05
# 21  0.781250  0.582970      0.761082  0.692868   1.000000e-05
# 22  0.794428  0.572056      0.766623  0.675915   1.000000e-05
# 23  0.687500  0.634853      0.766297  0.675841   1.000000e-05
# 24  0.811586  0.539902      0.774772  0.654479   1.000000e-05
# 25  0.812500  0.491755      0.774772  0.654534   1.000000e-05
# 26  0.821881  0.512525      0.768253  0.660596   1.000000e-05
# 27  0.875000  0.352921      0.768253  0.660718   1.000000e-05
# 28  0.830787  0.478223      0.778031  0.652397   1.000000e-05
# 29  0.781250  0.647278      0.777705  0.651354   1.000000e-05
# 30  0.840837  0.451120      0.777705  0.644144   1.000000e-05
# 31  0.843750  0.438788      0.778357  0.644199   1.000000e-05
# 32  0.850233  0.423620      0.782269  0.639370   1.000000e-05
# 33  0.937500  0.242224      0.782595  0.640075   1.000000e-05
# 34  0.859629  0.402007      0.783898  0.640263   1.000000e-05
# 35  0.781250  0.454734      0.784876  0.639196   1.000000e-05
# 36  0.866819  0.375921      0.790091  0.634846   1.000000e-05
# 37  0.750000  0.582647      0.789765  0.635442   1.000000e-05
# 38  0.871558  0.355231      0.787158  0.634746   1.000000e-05
# 39  0.843750  0.387410      0.787810  0.634523   1.000000e-05
# 40  0.882588  0.332343      0.783572  0.647590   1.000000e-05
# 41  0.937500  0.300694      0.784550  0.647897   1.000000e-06
# 42  0.891331  0.311059      0.793351  0.631443   1.000000e-06
# 43  0.843750  0.490618      0.793677  0.631775   1.000000e-06
# 44  0.891903  0.305766      0.792373  0.634390   1.000000e-06
# 45  0.937500  0.241117      0.792699  0.634449   1.000000e-06
# 46  0.894681  0.299178      0.794003  0.631460   1.000000e-06
# 47  0.875000  0.319648      0.793025  0.632082   1.000000e-06
# 48  0.895988  0.302811      0.791721  0.629365   1.000000e-06
# 49  0.906250  0.275159      0.791721  0.629429   1.000000e-06

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 17s - 45ms/step - accuracy: 0.9333 - loss: 0.2057
# W0000 00:00:1711273855.519263      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.9332572817802429
# 96/96 - 4s - 40ms/step - accuracy: 0.7917 - loss: 0.6294
#
# Test Accuracy: 0.791720986366272
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.80      0.77      0.79       329
#      disgust       0.61      0.51      0.56        74
#         fear       0.71      0.68      0.69       162
#        happy       0.73      0.78      0.75       680
#      neutral       0.71      0.79      0.75       478
#          sad       0.47      0.34      0.40       160
#     surprise       0.92      0.90      0.91      1185
#
#     accuracy                           0.79      3068
#    macro avg       0.71      0.68      0.69      3068
# weighted avg       0.79      0.79      0.79      3068

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rgb_img = cv2.cvtColor(img_arr_test[i], cv2.COLOR_BGR2RGB)
    plt.imshow(rgb_img)
    plt.title(label_to_text_test[predicted_labels[i]])
    plt.axis("off")

plt.show()
