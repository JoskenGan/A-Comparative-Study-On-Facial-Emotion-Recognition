# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-20 09:16:23.508587: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-20 09:16:23.508669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-20 09:16:23.668548: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(os.path.join(data_dir, dir_)):
                img = cv2.imread(os.path.join(data_dir, dir_, f), cv2.IMREAD_GRAYSCALE)
                img = cv2.resize(img, (48, 48))  # Resize the image to 48x48
                img_arr.append(np.expand_dims(img, axis=2))
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (48,48,1)
NUM_CLASSES = len(target_names)
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(48, 48), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype(int),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)

    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1

    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=4, layers_per_block=4, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=4, layers_per_block=4, growth_rate=16, show_summary=True)

plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ in_layer            │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_0 (Conv2D)   │ (None, 46, 46,    │        120 │ in_layer[0][0]    │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn1          │ (None, 46, 46,    │         48 │ conv2d_0[0][0]    │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv1        │ (None, 46, 46,    │          0 │ block1_bn1[0][0]  │
# │ (Activation)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad1         │ (None, 48, 48,    │          0 │ block1_actv1[0][… │
# │ (ZeroPadding2D)     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d1      │ (None, 46, 46,    │      1,308 │ block1_pad1[0][0] │
# │ (Conv2D)            │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat1      │ (None, 46, 46,    │          0 │ block1_conv2d1[0… │
# │ (Concatenate)       │ 24)               │            │ conv2d_0[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn2          │ (None, 46, 46,    │         96 │ block1_concat1[0… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv2        │ (None, 46, 46,    │          0 │ block1_bn2[0][0]  │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad2         │ (None, 48, 48,    │          0 │ block1_actv2[0][… │
# │ (ZeroPadding2D)     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d2      │ (None, 46, 46,    │      6,076 │ block1_pad2[0][0] │
# │ (Conv2D)            │ 28)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat2      │ (None, 46, 46,    │          0 │ block1_conv2d2[0… │
# │ (Concatenate)       │ 52)               │            │ block1_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn3          │ (None, 46, 46,    │        208 │ block1_concat2[0… │
# │ (BatchNormalizatio… │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv3        │ (None, 46, 46,    │          0 │ block1_bn3[0][0]  │
# │ (Activation)        │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad3         │ (None, 48, 48,    │          0 │ block1_actv3[0][… │
# │ (ZeroPadding2D)     │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d3      │ (None, 46, 46,    │     20,636 │ block1_pad3[0][0] │
# │ (Conv2D)            │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat3      │ (None, 46, 46,    │          0 │ block1_conv2d3[0… │
# │ (Concatenate)       │ 96)               │            │ block1_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn4          │ (None, 46, 46,    │        384 │ block1_concat3[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv4        │ (None, 46, 46,    │          0 │ block1_bn4[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad4         │ (None, 48, 48,    │          0 │ block1_actv4[0][… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d4      │ (None, 46, 46,    │     51,900 │ block1_pad4[0][0] │
# │ (Conv2D)            │ 60)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat4      │ (None, 46, 46,    │          0 │ block1_conv2d4[0… │
# │ (Concatenate)       │ 156)              │            │ block1_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_bn      │ (None, 46, 46,    │        624 │ block1_concat4[0… │
# │ (BatchNormalizatio… │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_actv    │ (None, 46, 46,    │          0 │ transition1_bn[0… │
# │ (Activation)        │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_conv2d  │ (None, 46, 46,    │      3,611 │ transition1_actv… │
# │ (Conv2D)            │ 23)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_pool2d  │ (None, 23, 23,    │          0 │ transition1_conv… │
# │ (AveragePooling2D)  │ 23)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn1          │ (None, 23, 23,    │         92 │ transition1_pool… │
# │ (BatchNormalizatio… │ 23)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv1        │ (None, 23, 23,    │          0 │ block2_bn1[0][0]  │
# │ (Activation)        │ 23)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad1         │ (None, 25, 25,    │          0 │ block2_actv1[0][… │
# │ (ZeroPadding2D)     │ 23)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d1      │ (None, 23, 23,    │     15,808 │ block2_pad1[0][0] │
# │ (Conv2D)            │ 76)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat1      │ (None, 23, 23,    │          0 │ block2_conv2d1[0… │
# │ (Concatenate)       │ 99)               │            │ transition1_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn2          │ (None, 23, 23,    │        396 │ block2_concat1[0… │
# │ (BatchNormalizatio… │ 99)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv2        │ (None, 23, 23,    │          0 │ block2_bn2[0][0]  │
# │ (Activation)        │ 99)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad2         │ (None, 25, 25,    │          0 │ block2_actv2[0][… │
# │ (ZeroPadding2D)     │ 99)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d2      │ (None, 23, 23,    │     82,064 │ block2_pad2[0][0] │
# │ (Conv2D)            │ 92)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat2      │ (None, 23, 23,    │          0 │ block2_conv2d2[0… │
# │ (Concatenate)       │ 191)              │            │ block2_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn3          │ (None, 23, 23,    │        764 │ block2_concat2[0… │
# │ (BatchNormalizatio… │ 191)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv3        │ (None, 23, 23,    │          0 │ block2_bn3[0][0]  │
# │ (Activation)        │ 191)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad3         │ (None, 25, 25,    │          0 │ block2_actv3[0][… │
# │ (ZeroPadding2D)     │ 191)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d3      │ (None, 23, 23,    │    185,760 │ block2_pad3[0][0] │
# │ (Conv2D)            │ 108)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat3      │ (None, 23, 23,    │          0 │ block2_conv2d3[0… │
# │ (Concatenate)       │ 299)              │            │ block2_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn4          │ (None, 23, 23,    │      1,196 │ block2_concat3[0… │
# │ (BatchNormalizatio… │ 299)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv4        │ (None, 23, 23,    │          0 │ block2_bn4[0][0]  │
# │ (Activation)        │ 299)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad4         │ (None, 25, 25,    │          0 │ block2_actv4[0][… │
# │ (ZeroPadding2D)     │ 299)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d4      │ (None, 23, 23,    │    333,808 │ block2_pad4[0][0] │
# │ (Conv2D)            │ 124)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat4      │ (None, 23, 23,    │          0 │ block2_conv2d4[0… │
# │ (Concatenate)       │ 423)              │            │ block2_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_bn      │ (None, 23, 23,    │      1,692 │ block2_concat4[0… │
# │ (BatchNormalizatio… │ 423)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_actv    │ (None, 23, 23,    │          0 │ transition2_bn[0… │
# │ (Activation)        │ 423)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_conv2d  │ (None, 23, 23,    │      4,664 │ transition2_actv… │
# │ (Conv2D)            │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_pool2d  │ (None, 11, 11,    │          0 │ transition2_conv… │
# │ (AveragePooling2D)  │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn1          │ (None, 11, 11,    │         44 │ transition2_pool… │
# │ (BatchNormalizatio… │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv1        │ (None, 11, 11,    │          0 │ block3_bn1[0][0]  │
# │ (Activation)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad1         │ (None, 13, 13,    │          0 │ block3_actv1[0][… │
# │ (ZeroPadding2D)     │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d1      │ (None, 11, 11,    │     14,000 │ block3_pad1[0][0] │
# │ (Conv2D)            │ 140)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat1      │ (None, 11, 11,    │          0 │ block3_conv2d1[0… │
# │ (Concatenate)       │ 151)              │            │ transition2_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn2          │ (None, 11, 11,    │        604 │ block3_concat1[0… │
# │ (BatchNormalizatio… │ 151)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv2        │ (None, 11, 11,    │          0 │ block3_bn2[0][0]  │
# │ (Activation)        │ 151)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad2         │ (None, 13, 13,    │          0 │ block3_actv2[0][… │
# │ (ZeroPadding2D)     │ 151)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d2      │ (None, 11, 11,    │    212,160 │ block3_pad2[0][0] │
# │ (Conv2D)            │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat2      │ (None, 11, 11,    │          0 │ block3_conv2d2[0… │
# │ (Concatenate)       │ 307)              │            │ block3_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn3          │ (None, 11, 11,    │      1,228 │ block3_concat2[0… │
# │ (BatchNormalizatio… │ 307)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv3        │ (None, 11, 11,    │          0 │ block3_bn3[0][0]  │
# │ (Activation)        │ 307)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad3         │ (None, 13, 13,    │          0 │ block3_actv3[0][… │
# │ (ZeroPadding2D)     │ 307)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d3      │ (None, 11, 11,    │    475,408 │ block3_pad3[0][0] │
# │ (Conv2D)            │ 172)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat3      │ (None, 11, 11,    │          0 │ block3_conv2d3[0… │
# │ (Concatenate)       │ 479)              │            │ block3_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn4          │ (None, 11, 11,    │      1,916 │ block3_concat3[0… │
# │ (BatchNormalizatio… │ 479)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv4        │ (None, 11, 11,    │          0 │ block3_bn4[0][0]  │
# │ (Activation)        │ 479)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad4         │ (None, 13, 13,    │          0 │ block3_actv4[0][… │
# │ (ZeroPadding2D)     │ 479)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d4      │ (None, 11, 11,    │    810,656 │ block3_pad4[0][0] │
# │ (Conv2D)            │ 188)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat4      │ (None, 11, 11,    │          0 │ block3_conv2d4[0… │
# │ (Concatenate)       │ 667)              │            │ block3_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_bn      │ (None, 11, 11,    │      2,668 │ block3_concat4[0… │
# │ (BatchNormalizatio… │ 667)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_actv    │ (None, 11, 11,    │          0 │ transition3_bn[0… │
# │ (Activation)        │ 667)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_conv2d  │ (None, 11, 11, 5) │      3,340 │ transition3_actv… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_pool2d  │ (None, 5, 5, 5)   │          0 │ transition3_conv… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn1          │ (None, 5, 5, 5)   │         20 │ transition3_pool… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv1        │ (None, 5, 5, 5)   │          0 │ block4_bn1[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad1         │ (None, 7, 7, 5)   │          0 │ block4_actv1[0][… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d1      │ (None, 5, 5, 204) │      9,384 │ block4_pad1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat1      │ (None, 5, 5, 209) │          0 │ block4_conv2d1[0… │
# │ (Concatenate)       │                   │            │ transition3_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn2          │ (None, 5, 5, 209) │        836 │ block4_concat1[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv2        │ (None, 5, 5, 209) │          0 │ block4_bn2[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad2         │ (None, 7, 7, 209) │          0 │ block4_actv2[0][… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d2      │ (None, 5, 5, 220) │    414,040 │ block4_pad2[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat2      │ (None, 5, 5, 429) │          0 │ block4_conv2d2[0… │
# │ (Concatenate)       │                   │            │ block4_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn3          │ (None, 5, 5, 429) │      1,716 │ block4_concat2[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv3        │ (None, 5, 5, 429) │          0 │ block4_bn3[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad3         │ (None, 7, 7, 429) │          0 │ block4_actv3[0][… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d3      │ (None, 5, 5, 236) │    911,432 │ block4_pad3[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat3      │ (None, 5, 5, 665) │          0 │ block4_conv2d3[0… │
# │ (Concatenate)       │                   │            │ block4_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn4          │ (None, 5, 5, 665) │      2,660 │ block4_concat3[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv4        │ (None, 5, 5, 665) │          0 │ block4_bn4[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad4         │ (None, 7, 7, 665) │          0 │ block4_actv4[0][… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d4      │ (None, 5, 5, 252) │  1,508,472 │ block4_pad4[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat4      │ (None, 5, 5, 917) │          0 │ block4_conv2d4[0… │
# │ (Concatenate)       │                   │            │ block4_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_bn      │ (None, 5, 5, 917) │      3,668 │ block4_concat4[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_actv    │ (None, 5, 5, 917) │          0 │ transition4_bn[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_conv2d  │ (None, 5, 5, 2)   │      1,836 │ transition4_actv… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_pool2d  │ (None, 2, 2, 2)   │          0 │ transition4_conv… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2)         │          0 │ transition4_pool… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2)         │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 128)       │        384 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1_bn           │ (None, 128)       │        512 │ dense1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1_actv         │ (None, 128)       │          0 │ dense1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 7)         │        903 │ dense1_actv[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,089,142 (19.41 MB)
#  Trainable params: 5,078,456 (19.37 MB)
#  Non-trainable params: 10,686 (41.74 KB)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(img_arr_train)

# Training the model
custom_early_stopping = CustomEarlyStopping(patience=15)
history_DenseNet = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=batch_size),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / batch_size),
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 4:24:02 41s/step - accuracy: 0.0938 - loss: 2.1259
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710926356.503808     109 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 139s 254ms/step - accuracy: 0.3669 - loss: 1.6946 - val_accuracy: 0.3742 - val_loss: 1.7105 - learning_rate: 0.0010
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.3750 - loss: 1.6922
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3750 - loss: 1.6922 - val_accuracy: 0.3739 - val_loss: 1.7552 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3886 - loss: 1.6070 - val_accuracy: 0.3859 - val_loss: 1.5588 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 1.4584 - val_accuracy: 0.3843 - val_loss: 1.5658 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.4317 - loss: 1.5111 - val_accuracy: 0.4909 - val_loss: 1.4329 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3750 - loss: 1.6275 - val_accuracy: 0.4876 - val_loss: 1.4095 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.5258 - loss: 1.2960 - val_accuracy: 0.4022 - val_loss: 1.6496 - learning_rate: 0.0010
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.1314 - val_accuracy: 0.3963 - val_loss: 1.6709 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 61ms/step - accuracy: 0.5691 - loss: 1.1676 - val_accuracy: 0.5935 - val_loss: 1.1708 - learning_rate: 0.0010
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.1132 - val_accuracy: 0.5922 - val_loss: 1.1585 - learning_rate: 0.0010
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.5990 - loss: 1.1023 - val_accuracy: 0.6186 - val_loss: 1.1110 - learning_rate: 0.0010
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.8749 - val_accuracy: 0.6239 - val_loss: 1.0981 - learning_rate: 0.0010
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6283 - loss: 1.0406 - val_accuracy: 0.6359 - val_loss: 1.0627 - learning_rate: 0.0010
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.8988 - val_accuracy: 0.6379 - val_loss: 1.0694 - learning_rate: 0.0010
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6389 - loss: 1.0164 - val_accuracy: 0.6659 - val_loss: 0.9917 - learning_rate: 0.0010
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.1860 - val_accuracy: 0.6617 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6508 - loss: 0.9823 - val_accuracy: 0.5975 - val_loss: 1.0801 - learning_rate: 0.0010
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9899 - val_accuracy: 0.6023 - val_loss: 1.0620 - learning_rate: 0.0010
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6669 - loss: 0.9510
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6669 - loss: 0.9510 - val_accuracy: 0.6050 - val_loss: 1.0855 - learning_rate: 0.0010
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.8659 - val_accuracy: 0.6056 - val_loss: 1.0835 - learning_rate: 1.0000e-04
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6850 - loss: 0.9020 - val_accuracy: 0.7145 - val_loss: 0.8192 - learning_rate: 1.0000e-04
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.7471 - val_accuracy: 0.7158 - val_loss: 0.8188 - learning_rate: 1.0000e-04
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7105 - loss: 0.8389 - val_accuracy: 0.7288 - val_loss: 0.8139 - learning_rate: 1.0000e-04
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7812 - loss: 0.7348 - val_accuracy: 0.7285 - val_loss: 0.8139 - learning_rate: 1.0000e-04
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7099 - loss: 0.8322 - val_accuracy: 0.7288 - val_loss: 0.7962 - learning_rate: 1.0000e-04
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8750 - loss: 0.5675 - val_accuracy: 0.7282 - val_loss: 0.7962 - learning_rate: 1.0000e-04
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7231 - loss: 0.8121 - val_accuracy: 0.7334 - val_loss: 0.8004 - learning_rate: 1.0000e-04
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 1.1321 - val_accuracy: 0.7337 - val_loss: 0.8001 - learning_rate: 1.0000e-04
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7292 - loss: 0.8022 - val_accuracy: 0.7357 - val_loss: 0.7834 - learning_rate: 1.0000e-04
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.6858 - val_accuracy: 0.7366 - val_loss: 0.7844 - learning_rate: 1.0000e-04
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7314 - loss: 0.7950 - val_accuracy: 0.7467 - val_loss: 0.7653 - learning_rate: 1.0000e-04
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.5071 - val_accuracy: 0.7471 - val_loss: 0.7652 - learning_rate: 1.0000e-04
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7341 - loss: 0.7796 - val_accuracy: 0.7533 - val_loss: 0.7554 - learning_rate: 1.0000e-04
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.6527 - val_accuracy: 0.7523 - val_loss: 0.7557 - learning_rate: 1.0000e-04
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7432 - loss: 0.7660 - val_accuracy: 0.7454 - val_loss: 0.7679 - learning_rate: 1.0000e-04
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.6895 - val_accuracy: 0.7471 - val_loss: 0.7679 - learning_rate: 1.0000e-04
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7344 - loss: 0.7853
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7345 - loss: 0.7853 - val_accuracy: 0.7516 - val_loss: 0.7588 - learning_rate: 1.0000e-04
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8125 - loss: 0.7043 - val_accuracy: 0.7516 - val_loss: 0.7588 - learning_rate: 1.0000e-05
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7440 - loss: 0.7479 - val_accuracy: 0.7500 - val_loss: 0.7526 - learning_rate: 1.0000e-05
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 0.8359 - val_accuracy: 0.7500 - val_loss: 0.7527 - learning_rate: 1.0000e-05
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7427 - loss: 0.7546
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7427 - loss: 0.7546 - val_accuracy: 0.7516 - val_loss: 0.7489 - learning_rate: 1.0000e-05
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.6266 - val_accuracy: 0.7510 - val_loss: 0.7491 - learning_rate: 1.0000e-06
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7504 - loss: 0.7457 - val_accuracy: 0.7503 - val_loss: 0.7469 - learning_rate: 1.0000e-06
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.5959 - val_accuracy: 0.7503 - val_loss: 0.7471 - learning_rate: 1.0000e-06
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7546 - loss: 0.7333
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7546 - loss: 0.7333 - val_accuracy: 0.7516 - val_loss: 0.7484 - learning_rate: 1.0000e-06
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.8591 - val_accuracy: 0.7516 - val_loss: 0.7481 - learning_rate: 1.0000e-07
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.7431 - loss: 0.7371 - val_accuracy: 0.7497 - val_loss: 0.7472 - learning_rate: 1.0000e-07
# Epoch 48/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.5312 - loss: 1.0354Epoch 47: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 32.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5312 - loss: 1.0354 - val_accuracy: 0.7497 - val_loss: 0.7468 - learning_rate: 1.0000e-07

# %%
history = pd.DataFrame(history_DenseNet.history)
history
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.384835  1.634883      0.374185  1.710510   1.000000e-03
# 1   0.375000  1.692165      0.373859  1.755237   1.000000e-03
# 2   0.391208  1.592363      0.385919  1.558827   1.000000e-03
# 3   0.531250  1.458360      0.384289  1.565826   1.000000e-03
# 4   0.452733  1.467493      0.490874  1.432928   1.000000e-03
# 5   0.375000  1.627494      0.487614  1.409521   1.000000e-03
# 6   0.538688  1.255335      0.402216  1.649574   1.000000e-03
# 7   0.468750  1.131386      0.396349  1.670910   1.000000e-03
# 8   0.581747  1.158782      0.593546  1.170827   1.000000e-03
# 9   0.562500  1.113158      0.592242  1.158492   1.000000e-03
# 10  0.604543  1.092890      0.618644  1.111038   1.000000e-03
# 11  0.656250  0.874916      0.623859  1.098140   1.000000e-03
# 12  0.629300  1.038829      0.635919  1.062717   1.000000e-03
# 13  0.687500  0.898783      0.637875  1.069421   1.000000e-03
# 14  0.640248  1.012748      0.665906  0.991670   1.000000e-03
# 15  0.625000  1.186028      0.661669  0.990255   1.000000e-03
# 16  0.654057  0.979240      0.597458  1.080146   1.000000e-03
# 17  0.656250  0.989867      0.602347  1.061952   1.000000e-03
# 18  0.669417  0.951909      0.604954  1.085475   1.000000e-03
# 19  0.718750  0.865904      0.605606  1.083547   1.000000e-04
# 20  0.697034  0.873158      0.714472  0.819188   1.000000e-04
# 21  0.750000  0.747144      0.715776  0.818753   1.000000e-04
# 22  0.711006  0.838039      0.728814  0.813865   1.000000e-04
# 23  0.781250  0.734834      0.728488  0.813879   1.000000e-04
# 24  0.713620  0.827317      0.728814  0.796151   1.000000e-04
# 25  0.875000  0.567522      0.728162  0.796211   1.000000e-04
# 26  0.722853  0.810972      0.733377  0.800355   1.000000e-04
# 27  0.656250  1.132130      0.733703  0.800131   1.000000e-04
# 28  0.730452  0.793036      0.735658  0.783388   1.000000e-04
# 29  0.718750  0.685765      0.736636  0.784358   1.000000e-04
# 30  0.732494  0.792096      0.746741  0.765264   1.000000e-04
# 31  0.843750  0.507072      0.747066  0.765195   1.000000e-04
# 32  0.731514  0.780600      0.753259  0.755408   1.000000e-04
# 33  0.750000  0.652659      0.752282  0.755699   1.000000e-04
# 34  0.736580  0.772488      0.745437  0.767901   1.000000e-04
# 35  0.687500  0.689508      0.747066  0.767893   1.000000e-04
# 36  0.740420  0.775737      0.751630  0.758814   1.000000e-04
# 37  0.812500  0.704262      0.751630  0.758752   1.000000e-05
# 38  0.744914  0.750793      0.750000  0.752599   1.000000e-05
# 39  0.625000  0.835945      0.750000  0.752679   1.000000e-05
# 40  0.746793  0.751275      0.751630  0.748932   1.000000e-05
# 41  0.781250  0.626625      0.750978  0.749115   1.000000e-06
# 42  0.748345  0.741976      0.750326  0.746881   1.000000e-06
# 43  0.843750  0.595865      0.750326  0.747110   1.000000e-06
# 44  0.750306  0.740054      0.751630  0.748407   1.000000e-06
# 45  0.687500  0.859105      0.751630  0.748107   1.000000e-07
# 46  0.744750  0.740232      0.749674  0.747227   1.000000e-07
# 47  0.531250  1.035398      0.749674  0.746793   1.000000e-07

# %%
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['accuracy'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['loss'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 8s - 20ms/step - accuracy: 0.7550 - loss: 0.7166
#
# train Accuracy: 0.7549507021903992
# 96/96 - 2s - 17ms/step - accuracy: 0.7533 - loss: 0.7554
#
# Test Accuracy: 0.7532594799995422
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.81      0.76      0.78       329
#      disgust       0.67      0.03      0.05        74
#         fear       0.62      0.72      0.66       162
#        happy       0.71      0.80      0.76       680
#      neutral       0.52      0.63      0.57       478
#          sad       0.00      0.00      0.00       160
#     surprise       0.90      0.93      0.91      1185
#
#     accuracy                           0.75      3068
#    macro avg       0.60      0.55      0.53      3068
# weighted avg       0.72      0.75      0.73      3068
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rgb_img = cv2.cvtColor(img_arr_test[i], cv2.COLOR_BGR2RGB)
    plt.imshow(rgb_img)
    plt.title(label_to_text_test[predicted_labels[i]])
    plt.axis("off")

plt.show()
