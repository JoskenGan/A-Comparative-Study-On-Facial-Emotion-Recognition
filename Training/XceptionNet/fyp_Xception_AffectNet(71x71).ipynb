# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-24 13:06:13.171028: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 13:06:13.171136: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 13:06:13.340988: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/AffectNet/"
TOP_EMOTIONS = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# Define constants
TRAIN_SIZE = 0.80
INPUT_SHAPE = (71, 71, 3) # input size must 71 x 71
NUM_CLASSES = len(TOP_EMOTIONS)
BATCH_SIZE = 32
EPOCHS = 100

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# surprise has 1851 number of images
# fear has 1839 number of images
# neutral has 1880 number of images
# sad has 1821 number of images
# disgust has 1740 number of images
# contempt has 1833 number of images
# happy has 1862 number of images
# anger has 1822 number of images
#
# total images are 14648

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f)
            img = cv2.resize(img, (71, 71))

            # Convert image to RGB format if it's grayscale
            if img.shape[-1] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

            img_arr.append(img)
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded contempt images to numpy arrays...
# loaded happy images to numpy arrays...
# loaded anger images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((14648, 71, 71, 3),
#  (14648, 8),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'neutral',
#   3: 'sad',
#   4: 'disgust',
#   5: 'contempt',
#   6: 'happy',
#   7: 'anger'})

# %%
# Memory cleanup
del img
del dir_
del f

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols * 2, num_emotions * 2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11718, 71, 71, 3), (2930, 71, 71, 3), (11718, 8), (2930, 8))

# %%
# Memory cleanup
del img_arr
del img_label

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(X_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,784 (80.58 MB)
#  Trainable params: 263,304 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/366 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.1597 - loss: 2.2681
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711285999.833092      88 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711285999.868514      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 360/366 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2247 - loss: 2.0399
# W0000 00:00:1711286022.844938      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2251 - loss: 2.0381
# W0000 00:00:1711286026.854264      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 45s 89ms/step - accuracy: 0.2252 - loss: 2.0378 - val_accuracy: 0.2857 - val_loss: 1.8275 - learning_rate: 0.0010
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.2500 - loss: 1.8000
# W0000 00:00:1711286032.380646      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2500 - loss: 1.8000 - val_accuracy: 0.2918 - val_loss: 1.8146 - learning_rate: 0.0010
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.2994 - loss: 1.8134 - val_accuracy: 0.3027 - val_loss: 1.7906 - learning_rate: 0.0010
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.6640 - val_accuracy: 0.3072 - val_loss: 1.7897 - learning_rate: 0.0010
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3160 - loss: 1.7572 - val_accuracy: 0.3167 - val_loss: 1.7592 - learning_rate: 0.0010
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3750 - loss: 1.6553 - val_accuracy: 0.3229 - val_loss: 1.7510 - learning_rate: 0.0010
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3411 - loss: 1.7194 - val_accuracy: 0.2993 - val_loss: 1.7931 - learning_rate: 0.0010
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.6440 - val_accuracy: 0.3048 - val_loss: 1.7745 - learning_rate: 0.0010
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3422 - loss: 1.7050 - val_accuracy: 0.3113 - val_loss: 1.7739 - learning_rate: 0.0010
# Epoch 10/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.4375 - loss: 1.7661
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.7661 - val_accuracy: 0.3208 - val_loss: 1.7566 - learning_rate: 0.0010
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3757 - loss: 1.6578 - val_accuracy: 0.3290 - val_loss: 1.7124 - learning_rate: 1.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.6238 - val_accuracy: 0.3287 - val_loss: 1.7124 - learning_rate: 1.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3772 - loss: 1.6383 - val_accuracy: 0.3420 - val_loss: 1.7049 - learning_rate: 1.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.4388 - val_accuracy: 0.3410 - val_loss: 1.7049 - learning_rate: 1.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3838 - loss: 1.6400 - val_accuracy: 0.3369 - val_loss: 1.7027 - learning_rate: 1.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.6435 - val_accuracy: 0.3355 - val_loss: 1.7040 - learning_rate: 1.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3781 - loss: 1.6306
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.3781 - loss: 1.6306 - val_accuracy: 0.3362 - val_loss: 1.7239 - learning_rate: 1.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.4469 - val_accuracy: 0.3365 - val_loss: 1.7238 - learning_rate: 1.0000e-05
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3850 - loss: 1.6142 - val_accuracy: 0.3447 - val_loss: 1.7026 - learning_rate: 1.0000e-05
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.4240 - val_accuracy: 0.3447 - val_loss: 1.7026 - learning_rate: 1.0000e-05
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3897 - loss: 1.6139 - val_accuracy: 0.3444 - val_loss: 1.6963 - learning_rate: 1.0000e-05
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.5653 - val_accuracy: 0.3444 - val_loss: 1.6963 - learning_rate: 1.0000e-05
# Epoch 23/100
# 364/366 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3951 - loss: 1.6132
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3951 - loss: 1.6132 - val_accuracy: 0.3420 - val_loss: 1.7016 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3125 - loss: 1.5924 - val_accuracy: 0.3420 - val_loss: 1.7016 - learning_rate: 1.0000e-06
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3776 - loss: 1.6204 - val_accuracy: 0.3430 - val_loss: 1.7010 - learning_rate: 1.0000e-06
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2188 - loss: 1.8247 - val_accuracy: 0.3430 - val_loss: 1.7010 - learning_rate: 1.0000e-06
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3963 - loss: 1.6248
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3963 - loss: 1.6247 - val_accuracy: 0.3427 - val_loss: 1.7006 - learning_rate: 1.0000e-06
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3125 - loss: 1.7375 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3892 - loss: 1.6217 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.6631 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3821 - loss: 1.6277
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3821 - loss: 1.6277 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3750 - loss: 1.6783 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3891 - loss: 1.6226 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2500 - loss: 1.7799 - val_accuracy: 0.3423 - val_loss: 1.7006 - learning_rate: 1.0000e-07
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3959 - loss: 1.6149 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2188 - loss: 1.8180 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3805 - loss: 1.6187 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2500 - loss: 1.7914 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3882 - loss: 1.6125 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.5915 - val_accuracy: 0.3420 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3815 - loss: 1.6203 - val_accuracy: 0.3420 - val_loss: 1.7004 - learning_rate: 1.0000e-07
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3125 - loss: 1.6761 - val_accuracy: 0.3420 - val_loss: 1.7004 - learning_rate: 1.0000e-07
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3954 - loss: 1.6127 - val_accuracy: 0.3416 - val_loss: 1.7005 - learning_rate: 1.0000e-07
# Epoch 44/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.3125 - loss: 1.7102Epoch 43: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 18.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3125 - loss: 1.7102 - val_accuracy: 0.3416 - val_loss: 1.7005 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.253380  1.932240      0.285666  1.827536   1.000000e-03
# 1   0.250000  1.799992      0.291809  1.814573   1.000000e-03
# 2   0.308403  1.802736      0.302730  1.790632   1.000000e-03
# 3   0.437500  1.664012      0.307167  1.789748   1.000000e-03
# 4   0.320469  1.752599      0.316724  1.759170   1.000000e-03
# 5   0.375000  1.655278      0.322867  1.750967   1.000000e-03
# 6   0.334845  1.728734      0.299317  1.793075   1.000000e-03
# 7   0.343750  1.644041      0.304778  1.774535   1.000000e-03
# 8   0.344173  1.707383      0.311263  1.773922   1.000000e-03
# 9   0.437500  1.766112      0.320819  1.756601   1.000000e-03
# 10  0.375064  1.652614      0.329010  1.712376   1.000000e-04
# 11  0.500000  1.623822      0.328669  1.712359   1.000000e-04
# 12  0.377118  1.638742      0.341980  1.704880   1.000000e-04
# 13  0.500000  1.438797      0.340956  1.704889   1.000000e-04
# 14  0.381824  1.635712      0.336860  1.702736   1.000000e-04
# 15  0.406250  1.643520      0.335495  1.703977   1.000000e-04
# 16  0.379685  1.631859      0.336177  1.723883   1.000000e-04
# 17  0.625000  1.446866      0.336519  1.723779   1.000000e-05
# 18  0.382595  1.617925      0.344710  1.702572   1.000000e-05
# 19  0.500000  1.423988      0.344710  1.702624   1.000000e-05
# 20  0.393120  1.617403      0.344369  1.696305   1.000000e-05
# 21  0.437500  1.565259      0.344369  1.696325   1.000000e-05
# 22  0.393805  1.614312      0.341980  1.701578   1.000000e-05
# 23  0.312500  1.592430      0.341980  1.701578   1.000000e-06
# 24  0.383194  1.614024      0.343003  1.701041   1.000000e-06
# 25  0.218750  1.824722      0.343003  1.701042   1.000000e-06
# 26  0.394575  1.614722      0.342662  1.700632   1.000000e-06
# 27  0.312500  1.737525      0.342321  1.700632   1.000000e-07
# 28  0.386360  1.621025      0.342321  1.700621   1.000000e-07
# 29  0.468750  1.663146      0.342321  1.700621   1.000000e-07
# 30  0.382595  1.621722      0.342321  1.700589   1.000000e-07
# 31  0.375000  1.678334      0.342321  1.700589   1.000000e-07
# 32  0.395345  1.612553      0.342321  1.700568   1.000000e-07
# 33  0.250000  1.779860      0.342321  1.700570   1.000000e-07
# 34  0.393805  1.612087      0.341980  1.700529   1.000000e-07
# 35  0.218750  1.817957      0.341980  1.700529   1.000000e-07
# 36  0.387900  1.612709      0.341980  1.700516   1.000000e-07
# 37  0.250000  1.791353      0.341980  1.700515   1.000000e-07
# 38  0.387215  1.618307      0.341980  1.700478   1.000000e-07
# 39  0.468750  1.591475      0.341980  1.700480   1.000000e-07
# 40  0.386017  1.619285      0.341980  1.700430   1.000000e-07
# 41  0.312500  1.676122      0.341980  1.700430   1.000000e-07
# 42  0.385675  1.616781      0.341638  1.700467   1.000000e-07
# 43  0.312500  1.710216      0.341638  1.700468   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,784 (80.58 MB)
#  Trainable params: 21,070,256 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/366 ━━━━━━━━━━━━━━━━━━━━ 33s 92ms/step - accuracy: 0.2031 - loss: 2.0416
# W0000 00:00:1711286555.012574      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 250/366 ━━━━━━━━━━━━━━━━━━━━ 19s 166ms/step - accuracy: 0.1956 - loss: 2.0194
# W0000 00:00:1711286596.237045      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.2050 - loss: 2.0043
# W0000 00:00:1711286608.067492      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 104s 154ms/step - accuracy: 0.2051 - loss: 2.0042 - val_accuracy: 0.2891 - val_loss: 1.8246 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.2812 - loss: 1.7674
# W0000 00:00:1711286611.318805      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2812 - loss: 1.7674 - val_accuracy: 0.2894 - val_loss: 1.8242 - learning_rate: 1.0000e-05
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.2904 - loss: 1.8235 - val_accuracy: 0.3290 - val_loss: 1.7012 - learning_rate: 1.0000e-05
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.6394 - val_accuracy: 0.3294 - val_loss: 1.7009 - learning_rate: 1.0000e-05
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.3390 - loss: 1.7153 - val_accuracy: 0.3580 - val_loss: 1.6609 - learning_rate: 1.0000e-05
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.6314 - val_accuracy: 0.3577 - val_loss: 1.6607 - learning_rate: 1.0000e-05
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.3589 - loss: 1.6322 - val_accuracy: 0.3751 - val_loss: 1.6170 - learning_rate: 1.0000e-05
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.5998 - val_accuracy: 0.3747 - val_loss: 1.6177 - learning_rate: 1.0000e-05
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.3762 - loss: 1.5725 - val_accuracy: 0.3911 - val_loss: 1.5784 - learning_rate: 1.0000e-05
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4375 - loss: 1.5864 - val_accuracy: 0.3918 - val_loss: 1.5792 - learning_rate: 1.0000e-05
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.3949 - loss: 1.5365 - val_accuracy: 0.4048 - val_loss: 1.5259 - learning_rate: 1.0000e-05
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2812 - loss: 1.7444 - val_accuracy: 0.4048 - val_loss: 1.5256 - learning_rate: 1.0000e-05
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4150 - loss: 1.4970 - val_accuracy: 0.4191 - val_loss: 1.4951 - learning_rate: 1.0000e-05
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2812 - loss: 1.6794 - val_accuracy: 0.4201 - val_loss: 1.4949 - learning_rate: 1.0000e-05
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4376 - loss: 1.4554 - val_accuracy: 0.4314 - val_loss: 1.4766 - learning_rate: 1.0000e-05
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.5500 - val_accuracy: 0.4307 - val_loss: 1.4772 - learning_rate: 1.0000e-05
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4494 - loss: 1.4164 - val_accuracy: 0.4420 - val_loss: 1.4665 - learning_rate: 1.0000e-05
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6250 - loss: 1.3330 - val_accuracy: 0.4427 - val_loss: 1.4661 - learning_rate: 1.0000e-05
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4645 - loss: 1.3942 - val_accuracy: 0.4539 - val_loss: 1.4453 - learning_rate: 1.0000e-05
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5000 - loss: 1.2661 - val_accuracy: 0.4553 - val_loss: 1.4455 - learning_rate: 1.0000e-05
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4684 - loss: 1.3697 - val_accuracy: 0.4631 - val_loss: 1.4236 - learning_rate: 1.0000e-05
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3125 - loss: 1.2964 - val_accuracy: 0.4642 - val_loss: 1.4242 - learning_rate: 1.0000e-05
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.4917 - loss: 1.3283 - val_accuracy: 0.4669 - val_loss: 1.4098 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3438 - loss: 1.5108 - val_accuracy: 0.4676 - val_loss: 1.4108 - learning_rate: 1.0000e-05
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5041 - loss: 1.2957 - val_accuracy: 0.4717 - val_loss: 1.4033 - learning_rate: 1.0000e-05
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5938 - loss: 1.0743 - val_accuracy: 0.4724 - val_loss: 1.4033 - learning_rate: 1.0000e-05
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5170 - loss: 1.2696 - val_accuracy: 0.4765 - val_loss: 1.3975 - learning_rate: 1.0000e-05
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.3712 - val_accuracy: 0.4751 - val_loss: 1.3969 - learning_rate: 1.0000e-05
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5280 - loss: 1.2474 - val_accuracy: 0.4744 - val_loss: 1.3874 - learning_rate: 1.0000e-05
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.2424 - val_accuracy: 0.4741 - val_loss: 1.3881 - learning_rate: 1.0000e-05
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5358 - loss: 1.2200 - val_accuracy: 0.4802 - val_loss: 1.3836 - learning_rate: 1.0000e-05
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3438 - loss: 1.5057 - val_accuracy: 0.4812 - val_loss: 1.3840 - learning_rate: 1.0000e-05
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5664 - loss: 1.1645 - val_accuracy: 0.4877 - val_loss: 1.3859 - learning_rate: 1.0000e-05
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.0221 - val_accuracy: 0.4877 - val_loss: 1.3852 - learning_rate: 1.0000e-05
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5467 - loss: 1.1859 - val_accuracy: 0.4928 - val_loss: 1.3864 - learning_rate: 1.0000e-05
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.3037 - val_accuracy: 0.4925 - val_loss: 1.3885 - learning_rate: 1.0000e-05
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5704 - loss: 1.1298 - val_accuracy: 0.4891 - val_loss: 1.3878 - learning_rate: 1.0000e-05
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.4551 - val_accuracy: 0.4891 - val_loss: 1.3884 - learning_rate: 1.0000e-05
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5872 - loss: 1.1004 - val_accuracy: 0.4945 - val_loss: 1.4480 - learning_rate: 1.0000e-05
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.2255 - val_accuracy: 0.4928 - val_loss: 1.4513 - learning_rate: 1.0000e-05
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.5817 - loss: 1.1152 - val_accuracy: 0.4857 - val_loss: 1.4314 - learning_rate: 1.0000e-05
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.0559 - val_accuracy: 0.4863 - val_loss: 1.4284 - learning_rate: 1.0000e-05
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6031 - loss: 1.0725 - val_accuracy: 0.4966 - val_loss: 1.3992 - learning_rate: 1.0000e-05
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5625 - loss: 1.0341 - val_accuracy: 0.4973 - val_loss: 1.4006 - learning_rate: 1.0000e-05
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6111 - loss: 1.0283 - val_accuracy: 0.4939 - val_loss: 1.3749 - learning_rate: 1.0000e-05
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.9097 - val_accuracy: 0.4942 - val_loss: 1.3749 - learning_rate: 1.0000e-05
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6163 - loss: 1.0269 - val_accuracy: 0.5020 - val_loss: 1.3824 - learning_rate: 1.0000e-05
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 0.9102 - val_accuracy: 0.5003 - val_loss: 1.3824 - learning_rate: 1.0000e-05
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6244 - loss: 0.9939 - val_accuracy: 0.5082 - val_loss: 1.3873 - learning_rate: 1.0000e-05
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 0.8456 - val_accuracy: 0.5075 - val_loss: 1.3866 - learning_rate: 1.0000e-05
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6435 - loss: 0.9864 - val_accuracy: 0.5065 - val_loss: 1.3876 - learning_rate: 1.0000e-05
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9128 - val_accuracy: 0.5075 - val_loss: 1.3883 - learning_rate: 1.0000e-05
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6543 - loss: 0.9308
# Epoch 53: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6543 - loss: 0.9308 - val_accuracy: 0.5031 - val_loss: 1.3991 - learning_rate: 1.0000e-05
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5625 - loss: 1.1409 - val_accuracy: 0.5038 - val_loss: 1.3995 - learning_rate: 1.0000e-06
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6653 - loss: 0.9240 - val_accuracy: 0.5072 - val_loss: 1.3892 - learning_rate: 1.0000e-06
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.0555 - val_accuracy: 0.5078 - val_loss: 1.3888 - learning_rate: 1.0000e-06
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6576 - loss: 0.9225
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6576 - loss: 0.9225 - val_accuracy: 0.5068 - val_loss: 1.4038 - learning_rate: 1.0000e-06
# Epoch 58/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9330 - val_accuracy: 0.5061 - val_loss: 1.4054 - learning_rate: 1.0000e-07
# Epoch 59/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6611 - loss: 0.9051 - val_accuracy: 0.5082 - val_loss: 1.4076 - learning_rate: 1.0000e-07
# Epoch 60/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9678 - val_accuracy: 0.5065 - val_loss: 1.4056 - learning_rate: 1.0000e-07
# Epoch 61/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6720 - loss: 0.9080 - val_accuracy: 0.5038 - val_loss: 1.4118 - learning_rate: 1.0000e-07
# Epoch 62/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9007 - val_accuracy: 0.5044 - val_loss: 1.4098 - learning_rate: 1.0000e-07
# Epoch 63/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6667 - loss: 0.9115 - val_accuracy: 0.5072 - val_loss: 1.3979 - learning_rate: 1.0000e-07
# Epoch 64/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.9252 - val_accuracy: 0.5075 - val_loss: 1.3979 - learning_rate: 1.0000e-07
# Epoch 65/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6661 - loss: 0.9196 - val_accuracy: 0.5078 - val_loss: 1.3953 - learning_rate: 1.0000e-07
# Epoch 66/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.8640 - val_accuracy: 0.5082 - val_loss: 1.3959 - learning_rate: 1.0000e-07
# Epoch 67/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6730 - loss: 0.9266 - val_accuracy: 0.5092 - val_loss: 1.3901 - learning_rate: 1.0000e-07
# Epoch 68/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 0.8260 - val_accuracy: 0.5078 - val_loss: 1.3910 - learning_rate: 1.0000e-07
# Epoch 69/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6609 - loss: 0.9131 - val_accuracy: 0.5085 - val_loss: 1.3877 - learning_rate: 1.0000e-07
# Epoch 70/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.0847 - val_accuracy: 0.5082 - val_loss: 1.3871 - learning_rate: 1.0000e-07
# Epoch 71/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6620 - loss: 0.9120 - val_accuracy: 0.5061 - val_loss: 1.3942 - learning_rate: 1.0000e-07
# Epoch 72/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.9841 - val_accuracy: 0.5078 - val_loss: 1.3955 - learning_rate: 1.0000e-07
# Epoch 73/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6648 - loss: 0.9110 - val_accuracy: 0.5078 - val_loss: 1.3910 - learning_rate: 1.0000e-07
# Epoch 74/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.7583 - val_accuracy: 0.5078 - val_loss: 1.3930 - learning_rate: 1.0000e-07
# Epoch 75/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6686 - loss: 0.9117 - val_accuracy: 0.5068 - val_loss: 1.3846 - learning_rate: 1.0000e-07
# Epoch 76/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.7201 - val_accuracy: 0.5075 - val_loss: 1.3845 - learning_rate: 1.0000e-07
# Epoch 77/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6717 - loss: 0.9067 - val_accuracy: 0.5075 - val_loss: 1.3877 - learning_rate: 1.0000e-07
# Epoch 78/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.7652 - val_accuracy: 0.5072 - val_loss: 1.3875 - learning_rate: 1.0000e-07
# Epoch 79/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6733 - loss: 0.9070 - val_accuracy: 0.5089 - val_loss: 1.3929 - learning_rate: 1.0000e-07
# Epoch 80/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 1.0761 - val_accuracy: 0.5092 - val_loss: 1.3917 - learning_rate: 1.0000e-07
# Epoch 81/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6788 - loss: 0.8823 - val_accuracy: 0.5061 - val_loss: 1.3873 - learning_rate: 1.0000e-07
# Epoch 82/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.7244 - val_accuracy: 0.5068 - val_loss: 1.3875 - learning_rate: 1.0000e-07
# Epoch 83/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6709 - loss: 0.8966 - val_accuracy: 0.5068 - val_loss: 1.3918 - learning_rate: 1.0000e-07
# Epoch 84/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 1.1476 - val_accuracy: 0.5075 - val_loss: 1.3906 - learning_rate: 1.0000e-07
# Epoch 85/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6730 - loss: 0.9024 - val_accuracy: 0.5078 - val_loss: 1.3955 - learning_rate: 1.0000e-07
# Epoch 86/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.7621 - val_accuracy: 0.5085 - val_loss: 1.3947 - learning_rate: 1.0000e-07
# Epoch 87/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6661 - loss: 0.8907 - val_accuracy: 0.5065 - val_loss: 1.4022 - learning_rate: 1.0000e-07
# Epoch 88/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 0.8596 - val_accuracy: 0.5065 - val_loss: 1.4007 - learning_rate: 1.0000e-07
# Epoch 89/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6705 - loss: 0.9058 - val_accuracy: 0.5109 - val_loss: 1.3928 - learning_rate: 1.0000e-07
# Epoch 90/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7812 - loss: 0.8079 - val_accuracy: 0.5116 - val_loss: 1.3934 - learning_rate: 1.0000e-07
# Epoch 91/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6781 - loss: 0.8946 - val_accuracy: 0.5109 - val_loss: 1.3988 - learning_rate: 1.0000e-07
# Epoch 92/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.8035 - val_accuracy: 0.5089 - val_loss: 1.3976 - learning_rate: 1.0000e-07
# Epoch 93/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6665 - loss: 0.9133 - val_accuracy: 0.5072 - val_loss: 1.3927 - learning_rate: 1.0000e-07
# Epoch 94/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.9119 - val_accuracy: 0.5075 - val_loss: 1.3935 - learning_rate: 1.0000e-07
# Epoch 95/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6712 - loss: 0.8958 - val_accuracy: 0.5109 - val_loss: 1.3874 - learning_rate: 1.0000e-07
# Epoch 96/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 0.9822 - val_accuracy: 0.5102 - val_loss: 1.3864 - learning_rate: 1.0000e-07
# Epoch 97/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 76ms/step - accuracy: 0.6549 - loss: 0.9281 - val_accuracy: 0.5089 - val_loss: 1.3856 - learning_rate: 1.0000e-07
# Epoch 98/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.8891 - val_accuracy: 0.5096 - val_loss: 1.3878 - learning_rate: 1.0000e-07
# Epoch 99/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 28s 75ms/step - accuracy: 0.6687 - loss: 0.9043 - val_accuracy: 0.5096 - val_loss: 1.3862 - learning_rate: 1.0000e-07
# Epoch 100/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.8498 - val_accuracy: 0.5099 - val_loss: 1.3861 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.230960  1.959118      0.289079  1.824604   1.000000e-05
# 1   0.281250  1.767444      0.289420  1.824244   1.000000e-05
# 2   0.302755  1.793482      0.329010  1.701212   1.000000e-05
# 3   0.406250  1.639409      0.329352  1.700926   1.000000e-05
# 4   0.348366  1.693786      0.358020  1.660930   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 95  0.593750  0.982169      0.510239  1.386381   1.000000e-07
# 96  0.667123  0.903245      0.508874  1.385574   1.000000e-07
# 97  0.781250  0.889143      0.509556  1.387764   1.000000e-07
# 98  0.663615  0.911606      0.509556  1.386209   1.000000e-07
# 99  0.750000  0.849814      0.509898  1.386119   1.000000e-07
#
# [100 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 367/367 - 8s - 23ms/step - accuracy: 0.7274 - loss: 0.7750
# W0000 00:00:1711288086.130846      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.7274278998374939
# 92/92 - 2s - 18ms/step - accuracy: 0.5099 - loss: 1.3861
#
# Test Accuracy: 0.5098975896835327
#  9/92 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# W0000 00:00:1711288091.857756      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step
# W0000 00:00:1711288096.271403      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.43      0.36      0.39       370
#     contempt       0.44      0.47      0.45       368
#      disgust       0.74      0.76      0.75       376
#         fear       0.37      0.28      0.32       364
#        happy       0.34      0.43      0.38       348
#      neutral       0.54      0.56      0.55       367
#          sad       0.82      0.80      0.81       373
#     surprise       0.39      0.41      0.40       364
#
#     accuracy                           0.51      2930
#    macro avg       0.51      0.51      0.51      2930
# weighted avg       0.51      0.51      0.51      2930

# %%
label_to_text
# Out:
# {0: 'surprise',
#  1: 'fear',
#  2: 'neutral',
#  3: 'sad',
#  4: 'disgust',
#  5: 'contempt',
#  6: 'happy',
#  7: 'anger'}

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_test[i])
    plt.title(label_to_text[predicted_labels[i]])
    plt.axis("off")

plt.show()
