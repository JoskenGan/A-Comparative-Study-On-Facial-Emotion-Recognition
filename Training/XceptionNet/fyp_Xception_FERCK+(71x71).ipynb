# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-24 10:30:12.313131: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 10:30:12.313223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 10:30:12.420657: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feralignedck/feraligned+ck/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness", "Surprise"]

# Define constants
TRAIN_SIZE = 0.80
INPUT_SHAPE = (71, 71, 3) # input size must 71 x 71
NUM_CLASSES = len(TOP_EMOTIONS)
BATCH_SIZE = 32
EPOCHS = 100

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Surprise has 249 number of images
# Fear has 728 number of images
# Angry has 938 number of images
# Neutral has 1230 number of images
# Sadness has 1153 number of images
# Happy has 2203 number of images
#
# total images are 6501

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f)
            img = cv2.resize(img, (71, 71))

            # Convert image to RGB format if it's grayscale
            if img.shape[-1] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

            img_arr.append(img)
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Surprise images to numpy arrays...
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((6501, 71, 71, 3),
#  (6501, 6),
#  {0: 'Surprise',
#   1: 'Fear',
#   2: 'Angry',
#   3: 'Neutral',
#   4: 'Sadness',
#   5: 'Happy'})

# %%
# Memory cleanup
del img
del dir_
del f

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols * 2, num_emotions * 2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5200, 71, 71, 3), (1301, 71, 71, 3), (5200, 6), (1301, 6))

# %%
# Memory cleanup
del img_arr
del img_label

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(X_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,526 (80.58 MB)
#  Trainable params: 263,046 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   4/162 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.1849 - loss: 2.2125
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711276290.254391      91 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711276290.285792      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  98/162 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.3305 - loss: 1.7074
# W0000 00:00:1711276299.520782      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3491 - loss: 1.6407
# W0000 00:00:1711276306.100273      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 32s 129ms/step - accuracy: 0.3493 - loss: 1.6400 - val_accuracy: 0.4473 - val_loss: 1.3692 - learning_rate: 0.0010
# Epoch 2/100
# W0000 00:00:1711276310.915190      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4688 - loss: 1.4534
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4688 - loss: 1.4534 - val_accuracy: 0.4573 - val_loss: 1.3662 - learning_rate: 0.0010
# Epoch 3/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.4539 - loss: 1.3481 - val_accuracy: 0.4666 - val_loss: 1.3341 - learning_rate: 0.0010
# Epoch 4/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.2643 - val_accuracy: 0.4612 - val_loss: 1.3352 - learning_rate: 0.0010
# Epoch 5/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.4679 - loss: 1.3083 - val_accuracy: 0.4796 - val_loss: 1.3281 - learning_rate: 0.0010
# Epoch 6/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.3613 - val_accuracy: 0.4819 - val_loss: 1.3088 - learning_rate: 0.0010
# Epoch 7/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.4931 - loss: 1.2533 - val_accuracy: 0.4735 - val_loss: 1.2687 - learning_rate: 0.0010
# Epoch 8/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.3791 - val_accuracy: 0.4712 - val_loss: 1.2721 - learning_rate: 0.0010
# Epoch 9/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5013 - loss: 1.2514 - val_accuracy: 0.5173 - val_loss: 1.2199 - learning_rate: 0.0010
# Epoch 10/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 1.1395 - val_accuracy: 0.5119 - val_loss: 1.2248 - learning_rate: 0.0010
# Epoch 11/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5215 - loss: 1.2023 - val_accuracy: 0.5004 - val_loss: 1.2469 - learning_rate: 0.0010
# Epoch 12/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5312 - loss: 1.2443 - val_accuracy: 0.5073 - val_loss: 1.2382 - learning_rate: 0.0010
# Epoch 13/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5292 - loss: 1.1973
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5292 - loss: 1.1972 - val_accuracy: 0.4988 - val_loss: 1.2253 - learning_rate: 0.0010
# Epoch 14/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4375 - loss: 1.3102 - val_accuracy: 0.4996 - val_loss: 1.2254 - learning_rate: 1.0000e-04
# Epoch 15/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5508 - loss: 1.1286 - val_accuracy: 0.5281 - val_loss: 1.1906 - learning_rate: 1.0000e-04
# Epoch 16/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4688 - loss: 1.2170 - val_accuracy: 0.5265 - val_loss: 1.1904 - learning_rate: 1.0000e-04
# Epoch 17/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.5652 - loss: 1.1195 - val_accuracy: 0.5296 - val_loss: 1.1863 - learning_rate: 1.0000e-04
# Epoch 18/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.0911 - val_accuracy: 0.5304 - val_loss: 1.1863 - learning_rate: 1.0000e-04
# Epoch 19/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5644 - loss: 1.1111 - val_accuracy: 0.5288 - val_loss: 1.1857 - learning_rate: 1.0000e-04
# Epoch 20/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 1.2895 - val_accuracy: 0.5281 - val_loss: 1.1851 - learning_rate: 1.0000e-04
# Epoch 21/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5800 - loss: 1.0970 - val_accuracy: 0.5311 - val_loss: 1.1773 - learning_rate: 1.0000e-04
# Epoch 22/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 1.2188 - val_accuracy: 0.5327 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 23/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5726 - loss: 1.1130 - val_accuracy: 0.5281 - val_loss: 1.1786 - learning_rate: 1.0000e-04
# Epoch 24/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 1.3137 - val_accuracy: 0.5288 - val_loss: 1.1785 - learning_rate: 1.0000e-04
# Epoch 25/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5591 - loss: 1.1090 - val_accuracy: 0.5334 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 26/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.2117 - val_accuracy: 0.5342 - val_loss: 1.1772 - learning_rate: 1.0000e-04
# Epoch 27/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5645 - loss: 1.0940 - val_accuracy: 0.5296 - val_loss: 1.1740 - learning_rate: 1.0000e-04
# Epoch 28/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5312 - loss: 1.2163 - val_accuracy: 0.5311 - val_loss: 1.1735 - learning_rate: 1.0000e-04
# Epoch 29/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5847 - loss: 1.0864 - val_accuracy: 0.5296 - val_loss: 1.1723 - learning_rate: 1.0000e-04
# Epoch 30/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.4688 - loss: 1.1529
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4688 - loss: 1.1529 - val_accuracy: 0.5319 - val_loss: 1.1724 - learning_rate: 1.0000e-04
# Epoch 31/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5760 - loss: 1.0928 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-05
# Epoch 32/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 0.9389 - val_accuracy: 0.5357 - val_loss: 1.1715 - learning_rate: 1.0000e-05
# Epoch 33/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5788 - loss: 1.0841 - val_accuracy: 0.5357 - val_loss: 1.1720 - learning_rate: 1.0000e-05
# Epoch 34/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.2110 - val_accuracy: 0.5357 - val_loss: 1.1720 - learning_rate: 1.0000e-05
# Epoch 35/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 0.5767 - loss: 1.0919 - val_accuracy: 0.5334 - val_loss: 1.1715 - learning_rate: 1.0000e-05
# Epoch 36/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5312 - loss: 1.3095
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 1.3095 - val_accuracy: 0.5334 - val_loss: 1.1715 - learning_rate: 1.0000e-05
# Epoch 37/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5824 - loss: 1.0882 - val_accuracy: 0.5357 - val_loss: 1.1715 - learning_rate: 1.0000e-06
# Epoch 38/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.0596 - val_accuracy: 0.5357 - val_loss: 1.1715 - learning_rate: 1.0000e-06
# Epoch 39/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5697 - loss: 1.0859 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-06
# Epoch 40/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5938 - loss: 1.0012
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5938 - loss: 1.0012 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-06
# Epoch 41/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5772 - loss: 1.0831 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 42/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7188 - loss: 0.9942 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 43/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5943 - loss: 1.0740 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 44/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5938 - loss: 1.1571
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-07.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5938 - loss: 1.1571 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 45/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 0.5738 - loss: 1.0989 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 46/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6250 - loss: 1.1561 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 47/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - accuracy: 0.5738 - loss: 1.1049 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 48/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 0.9555 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 49/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5788 - loss: 1.0841 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 50/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.2300 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 51/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5852 - loss: 1.0792 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 52/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.1144 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 53/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.5831 - loss: 1.0738 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 54/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 1.1355 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 55/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.5668 - loss: 1.0832 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 56/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 0.9224 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07
# Epoch 57/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5742 - loss: 1.0824Epoch 56: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 31.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.5742 - loss: 1.0824 - val_accuracy: 0.5350 - val_loss: 1.1715 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.384675  1.520205      0.447348  1.369184   1.000000e-03
# 1   0.468750  1.453385      0.457341  1.366197   1.000000e-03
# 2   0.454915  1.350631      0.466564  1.334105   1.000000e-03
# 3   0.562500  1.264295      0.461184  1.335246   1.000000e-03
# 4   0.474845  1.299305      0.479631  1.328134   1.000000e-03
# 5   0.437500  1.361279      0.481937  1.308820   1.000000e-03
# 6   0.488003  1.269089      0.473482  1.268650   1.000000e-03
# 7   0.406250  1.379086      0.471176  1.272125   1.000000e-03
# 8   0.509094  1.239898      0.517294  1.219884   1.000000e-03
# 9   0.500000  1.139519      0.511914  1.224777   1.000000e-03
# 10  0.516447  1.215758      0.500384  1.246885   1.000000e-03
# 11  0.531250  1.244288      0.507302  1.238234   1.000000e-03
# 12  0.533475  1.185378      0.498847  1.225348   1.000000e-03
# 13  0.437500  1.310155      0.499616  1.225413   1.000000e-04
# 14  0.556695  1.128908      0.528055  1.190607   1.000000e-04
# 15  0.468750  1.217018      0.526518  1.190444   1.000000e-04
# 16  0.559017  1.124146      0.529593  1.186295   1.000000e-04
# 17  0.500000  1.091129      0.530361  1.186310   1.000000e-04
# 18  0.568498  1.108890      0.528824  1.185669   1.000000e-04
# 19  0.500000  1.289502      0.528055  1.185135   1.000000e-04
# 20  0.565209  1.110760      0.531130  1.177286   1.000000e-04
# 21  0.531250  1.218785      0.532667  1.177171   1.000000e-04
# 22  0.569853  1.109798      0.528055  1.178586   1.000000e-04
# 23  0.500000  1.313706      0.528824  1.178542   1.000000e-04
# 24  0.564435  1.107157      0.533436  1.177173   1.000000e-04
# 25  0.500000  1.211739      0.534204  1.177184   1.000000e-04
# 26  0.564628  1.107123      0.529593  1.173993   1.000000e-04
# 27  0.531250  1.216263      0.531130  1.173541   1.000000e-04
# 28  0.575464  1.101633      0.529593  1.172256   1.000000e-04
# 29  0.468750  1.152932      0.531899  1.172395   1.000000e-04
# 30  0.575271  1.092625      0.534973  1.171493   1.000000e-05
# 31  0.562500  0.938870      0.535742  1.171505   1.000000e-05
# 32  0.579915  1.081183      0.535742  1.172009   1.000000e-05
# 33  0.500000  1.210982      0.535742  1.172011   1.000000e-05
# 34  0.574690  1.086318      0.533436  1.171523   1.000000e-05
# 35  0.531250  1.309482      0.533436  1.171518   1.000000e-05
# 36  0.580495  1.085202      0.535742  1.171548   1.000000e-06
# 37  0.562500  1.059570      0.535742  1.171548   1.000000e-06
# 38  0.569659  1.088849      0.534973  1.171511   1.000000e-06
# 39  0.593750  1.001216      0.534973  1.171510   1.000000e-06
# 40  0.572755  1.083727      0.534973  1.171499   1.000000e-07
# 41  0.718750  0.994193      0.534973  1.171499   1.000000e-07
# 42  0.590944  1.078891      0.534973  1.171497   1.000000e-07
# 43  0.593750  1.157137      0.534973  1.171497   1.000000e-07
# 44  0.581656  1.091293      0.534973  1.171493   1.000000e-07
# 45  0.625000  1.156080      0.534973  1.171494   1.000000e-07
# 46  0.580302  1.085921      0.534973  1.171491   1.000000e-07
# 47  0.562500  0.955515      0.534973  1.171491   1.000000e-07
# 48  0.577593  1.084766      0.534973  1.171486   1.000000e-07
# 49  0.500000  1.230015      0.534973  1.171486   1.000000e-07
# 50  0.580302  1.080815      0.534973  1.171483   1.000000e-07
# 51  0.562500  1.114390      0.534973  1.171483   1.000000e-07
# 52  0.571981  1.095322      0.534973  1.171486   1.000000e-07
# 53  0.593750  1.135454      0.534973  1.171485   1.000000e-07
# 54  0.570046  1.091730      0.534973  1.171486   1.000000e-07
# 55  0.625000  0.922420      0.534973  1.171486   1.000000e-07
# 56  0.574884  1.085328      0.534973  1.171482   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,526 (80.58 MB)
#  Trainable params: 21,069,998 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/162 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - accuracy: 0.3359 - loss: 1.6437
# W0000 00:00:1711276627.667600      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  26/162 ━━━━━━━━━━━━━━━━━━━━ 2:03 908ms/step - accuracy: 0.2912 - loss: 1.6900
# W0000 00:00:1711276650.303464      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.3365 - loss: 1.6273
# W0000 00:00:1711276663.164585      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 84s 235ms/step - accuracy: 0.3367 - loss: 1.6270 - val_accuracy: 0.3897 - val_loss: 1.5554 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.5625 - loss: 1.3804
# W0000 00:00:1711276665.615502      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.3804 - val_accuracy: 0.3905 - val_loss: 1.5553 - learning_rate: 1.0000e-05
# Epoch 3/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.4428 - loss: 1.4563 - val_accuracy: 0.3912 - val_loss: 1.5002 - learning_rate: 1.0000e-05
# Epoch 4/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.4930 - val_accuracy: 0.3920 - val_loss: 1.4998 - learning_rate: 1.0000e-05
# Epoch 5/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.4658 - loss: 1.3468 - val_accuracy: 0.4443 - val_loss: 1.4142 - learning_rate: 1.0000e-05
# Epoch 6/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4688 - loss: 1.1998 - val_accuracy: 0.4450 - val_loss: 1.4141 - learning_rate: 1.0000e-05
# Epoch 7/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.5025 - loss: 1.2575 - val_accuracy: 0.4896 - val_loss: 1.2907 - learning_rate: 1.0000e-05
# Epoch 8/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 1.2127 - val_accuracy: 0.4919 - val_loss: 1.2891 - learning_rate: 1.0000e-05
# Epoch 9/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.5297 - loss: 1.1919 - val_accuracy: 0.5557 - val_loss: 1.1656 - learning_rate: 1.0000e-05
# Epoch 10/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4688 - loss: 1.2019 - val_accuracy: 0.5565 - val_loss: 1.1654 - learning_rate: 1.0000e-05
# Epoch 11/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.5760 - loss: 1.1184 - val_accuracy: 0.5796 - val_loss: 1.1200 - learning_rate: 1.0000e-05
# Epoch 12/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.8608 - val_accuracy: 0.5796 - val_loss: 1.1217 - learning_rate: 1.0000e-05
# Epoch 13/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.5895 - loss: 1.0602 - val_accuracy: 0.6018 - val_loss: 1.0779 - learning_rate: 1.0000e-05
# Epoch 14/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 0.9446 - val_accuracy: 0.6026 - val_loss: 1.0758 - learning_rate: 1.0000e-05
# Epoch 15/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6003 - loss: 1.0444 - val_accuracy: 0.6157 - val_loss: 1.0348 - learning_rate: 1.0000e-05
# Epoch 16/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 1.0716 - val_accuracy: 0.6188 - val_loss: 1.0345 - learning_rate: 1.0000e-05
# Epoch 17/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6133 - loss: 0.9807 - val_accuracy: 0.6295 - val_loss: 1.0033 - learning_rate: 1.0000e-05
# Epoch 18/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 1.0550 - val_accuracy: 0.6303 - val_loss: 1.0039 - learning_rate: 1.0000e-05
# Epoch 19/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6381 - loss: 0.9312 - val_accuracy: 0.6387 - val_loss: 1.0205 - learning_rate: 1.0000e-05
# Epoch 20/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.9332 - val_accuracy: 0.6395 - val_loss: 1.0199 - learning_rate: 1.0000e-05
# Epoch 21/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6435 - loss: 0.9229 - val_accuracy: 0.6464 - val_loss: 0.9490 - learning_rate: 1.0000e-05
# Epoch 22/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6854 - val_accuracy: 0.6472 - val_loss: 0.9519 - learning_rate: 1.0000e-05
# Epoch 23/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6709 - loss: 0.8787 - val_accuracy: 0.6541 - val_loss: 0.9525 - learning_rate: 1.0000e-05
# Epoch 24/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.0132 - val_accuracy: 0.6549 - val_loss: 0.9500 - learning_rate: 1.0000e-05
# Epoch 25/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 77ms/step - accuracy: 0.6703 - loss: 0.8474 - val_accuracy: 0.6572 - val_loss: 0.9579 - learning_rate: 1.0000e-05
# Epoch 26/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 1.0217 - val_accuracy: 0.6580 - val_loss: 0.9610 - learning_rate: 1.0000e-05
# Epoch 27/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7067 - loss: 0.7945 - val_accuracy: 0.6610 - val_loss: 0.9217 - learning_rate: 1.0000e-05
# Epoch 28/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 0.8760 - val_accuracy: 0.6603 - val_loss: 0.9215 - learning_rate: 1.0000e-05
# Epoch 29/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.6828 - loss: 0.8146 - val_accuracy: 0.6718 - val_loss: 0.9116 - learning_rate: 1.0000e-05
# Epoch 30/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 0.9002 - val_accuracy: 0.6726 - val_loss: 0.9112 - learning_rate: 1.0000e-05
# Epoch 31/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7063 - loss: 0.7723 - val_accuracy: 0.6772 - val_loss: 0.8825 - learning_rate: 1.0000e-05
# Epoch 32/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.9037 - val_accuracy: 0.6795 - val_loss: 0.8834 - learning_rate: 1.0000e-05
# Epoch 33/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7010 - loss: 0.7778 - val_accuracy: 0.6810 - val_loss: 0.8647 - learning_rate: 1.0000e-05
# Epoch 34/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 0.8755 - val_accuracy: 0.6833 - val_loss: 0.8650 - learning_rate: 1.0000e-05
# Epoch 35/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7196 - loss: 0.7430 - val_accuracy: 0.6795 - val_loss: 0.9016 - learning_rate: 1.0000e-05
# Epoch 36/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 0.6926 - val_accuracy: 0.6787 - val_loss: 0.9070 - learning_rate: 1.0000e-05
# Epoch 37/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7318 - loss: 0.7264 - val_accuracy: 0.6872 - val_loss: 0.8554 - learning_rate: 1.0000e-05
# Epoch 38/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6055 - val_accuracy: 0.6872 - val_loss: 0.8556 - learning_rate: 1.0000e-05
# Epoch 39/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7401 - loss: 0.6965 - val_accuracy: 0.6956 - val_loss: 0.8450 - learning_rate: 1.0000e-05
# Epoch 40/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7812 - loss: 0.5602 - val_accuracy: 0.6964 - val_loss: 0.8444 - learning_rate: 1.0000e-05
# Epoch 41/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7427 - loss: 0.6880 - val_accuracy: 0.6918 - val_loss: 0.8549 - learning_rate: 1.0000e-05
# Epoch 42/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.4876 - val_accuracy: 0.6910 - val_loss: 0.8556 - learning_rate: 1.0000e-05
# Epoch 43/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7436 - loss: 0.6682 - val_accuracy: 0.6949 - val_loss: 0.8396 - learning_rate: 1.0000e-05
# Epoch 44/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.6562 - loss: 0.7773
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.7773 - val_accuracy: 0.6941 - val_loss: 0.8396 - learning_rate: 1.0000e-05
# Epoch 45/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7535 - loss: 0.6538 - val_accuracy: 0.6972 - val_loss: 0.8323 - learning_rate: 1.0000e-06
# Epoch 46/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6242 - val_accuracy: 0.6972 - val_loss: 0.8330 - learning_rate: 1.0000e-06
# Epoch 47/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7687 - loss: 0.6352 - val_accuracy: 0.7002 - val_loss: 0.8283 - learning_rate: 1.0000e-06
# Epoch 48/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.4234 - val_accuracy: 0.7002 - val_loss: 0.8281 - learning_rate: 1.0000e-06
# Epoch 49/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7557 - loss: 0.6541 - val_accuracy: 0.6987 - val_loss: 0.8298 - learning_rate: 1.0000e-06
# Epoch 50/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.5081 - val_accuracy: 0.6979 - val_loss: 0.8300 - learning_rate: 1.0000e-06
# Epoch 51/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 20s 76ms/step - accuracy: 0.7509 - loss: 0.6500 - val_accuracy: 0.7010 - val_loss: 0.8297 - learning_rate: 1.0000e-06
# Epoch 52/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6692 - val_accuracy: 0.7002 - val_loss: 0.8301 - learning_rate: 1.0000e-06
# Epoch 53/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7654 - loss: 0.6406 - val_accuracy: 0.6979 - val_loss: 0.8272 - learning_rate: 1.0000e-06
# Epoch 54/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.5832 - val_accuracy: 0.6979 - val_loss: 0.8272 - learning_rate: 1.0000e-06
# Epoch 55/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7589 - loss: 0.6311
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1e-07.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7589 - loss: 0.6311 - val_accuracy: 0.6987 - val_loss: 0.8254 - learning_rate: 1.0000e-06
# Epoch 56/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.4828 - val_accuracy: 0.6995 - val_loss: 0.8246 - learning_rate: 1.0000e-07
# Epoch 57/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7614 - loss: 0.6357 - val_accuracy: 0.6995 - val_loss: 0.8208 - learning_rate: 1.0000e-07
# Epoch 58/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.6133 - val_accuracy: 0.6987 - val_loss: 0.8198 - learning_rate: 1.0000e-07
# Epoch 59/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7586 - loss: 0.6359 - val_accuracy: 0.6987 - val_loss: 0.8256 - learning_rate: 1.0000e-07
# Epoch 60/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.7156 - val_accuracy: 0.6972 - val_loss: 0.8259 - learning_rate: 1.0000e-07
# Epoch 61/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7648 - loss: 0.6257 - val_accuracy: 0.6995 - val_loss: 0.8252 - learning_rate: 1.0000e-07
# Epoch 62/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.5327 - val_accuracy: 0.6995 - val_loss: 0.8251 - learning_rate: 1.0000e-07
# Epoch 63/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7625 - loss: 0.6427 - val_accuracy: 0.7033 - val_loss: 0.8267 - learning_rate: 1.0000e-07
# Epoch 64/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.6262 - val_accuracy: 0.7018 - val_loss: 0.8283 - learning_rate: 1.0000e-07
# Epoch 65/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7532 - loss: 0.6539 - val_accuracy: 0.7018 - val_loss: 0.8222 - learning_rate: 1.0000e-07
# Epoch 66/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.7870 - val_accuracy: 0.7018 - val_loss: 0.8220 - learning_rate: 1.0000e-07
# Epoch 67/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7659 - loss: 0.6216 - val_accuracy: 0.7025 - val_loss: 0.8223 - learning_rate: 1.0000e-07
# Epoch 68/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.9235 - val_accuracy: 0.7033 - val_loss: 0.8221 - learning_rate: 1.0000e-07
# Epoch 69/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7612 - loss: 0.6295 - val_accuracy: 0.7041 - val_loss: 0.8278 - learning_rate: 1.0000e-07
# Epoch 70/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.5723 - val_accuracy: 0.7010 - val_loss: 0.8273 - learning_rate: 1.0000e-07
# Epoch 71/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7743 - loss: 0.6214 - val_accuracy: 0.7010 - val_loss: 0.8276 - learning_rate: 1.0000e-07
# Epoch 72/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6082 - val_accuracy: 0.7010 - val_loss: 0.8276 - learning_rate: 1.0000e-07
# Epoch 73/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7693 - loss: 0.6198 - val_accuracy: 0.6995 - val_loss: 0.8199 - learning_rate: 1.0000e-07
# Epoch 74/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.6175 - val_accuracy: 0.6995 - val_loss: 0.8209 - learning_rate: 1.0000e-07
# Epoch 75/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7650 - loss: 0.6328 - val_accuracy: 0.6979 - val_loss: 0.8279 - learning_rate: 1.0000e-07
# Epoch 76/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6354 - val_accuracy: 0.6972 - val_loss: 0.8285 - learning_rate: 1.0000e-07
# Epoch 77/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7709 - loss: 0.6119 - val_accuracy: 0.6979 - val_loss: 0.8221 - learning_rate: 1.0000e-07
# Epoch 78/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.4439 - val_accuracy: 0.6987 - val_loss: 0.8217 - learning_rate: 1.0000e-07
# Epoch 79/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7694 - loss: 0.6104 - val_accuracy: 0.6979 - val_loss: 0.8292 - learning_rate: 1.0000e-07
# Epoch 80/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.5226 - val_accuracy: 0.6995 - val_loss: 0.8282 - learning_rate: 1.0000e-07
# Epoch 81/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7654 - loss: 0.6124 - val_accuracy: 0.6987 - val_loss: 0.8176 - learning_rate: 1.0000e-07
# Epoch 82/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6029 - val_accuracy: 0.6979 - val_loss: 0.8186 - learning_rate: 1.0000e-07
# Epoch 83/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7706 - loss: 0.6175 - val_accuracy: 0.7002 - val_loss: 0.8162 - learning_rate: 1.0000e-07
# Epoch 84/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6040 - val_accuracy: 0.7018 - val_loss: 0.8159 - learning_rate: 1.0000e-07
# Epoch 85/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.7574 - loss: 0.6289 - val_accuracy: 0.7002 - val_loss: 0.8202 - learning_rate: 1.0000e-07
# Epoch 86/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.6878 - val_accuracy: 0.6995 - val_loss: 0.8202 - learning_rate: 1.0000e-07
# Epoch 87/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7748 - loss: 0.6179 - val_accuracy: 0.7010 - val_loss: 0.8173 - learning_rate: 1.0000e-07
# Epoch 88/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7812 - loss: 0.5241 - val_accuracy: 0.7002 - val_loss: 0.8179 - learning_rate: 1.0000e-07
# Epoch 89/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7573 - loss: 0.6421 - val_accuracy: 0.7041 - val_loss: 0.8152 - learning_rate: 1.0000e-07
# Epoch 90/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.4547 - val_accuracy: 0.7010 - val_loss: 0.8163 - learning_rate: 1.0000e-07
# Epoch 91/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7643 - loss: 0.6323 - val_accuracy: 0.7033 - val_loss: 0.8191 - learning_rate: 1.0000e-07
# Epoch 92/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.5979 - val_accuracy: 0.7033 - val_loss: 0.8187 - learning_rate: 1.0000e-07
# Epoch 93/100
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.7685 - loss: 0.6195 - val_accuracy: 0.7025 - val_loss: 0.8230 - learning_rate: 1.0000e-07
# Epoch 94/100
#   1/162 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7188 - loss: 0.6632Epoch 93: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 68.
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.6632 - val_accuracy: 0.7025 - val_loss: 0.8218 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.369969  1.580729      0.389700  1.555419   1.000000e-05
# 1   0.562500  1.380381      0.390469  1.555335   1.000000e-05
# 2   0.443111  1.427747      0.391237  1.500225   1.000000e-05
# 3   0.437500  1.492982      0.392006  1.499849   1.000000e-05
# 4   0.474845  1.326074      0.444274  1.414179   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 89  0.812500  0.454708      0.700999  0.816266   1.000000e-07
# 90  0.764319  0.629953      0.703305  0.819105   1.000000e-07
# 91  0.812500  0.597937      0.703305  0.818708   1.000000e-07
# 92  0.769156  0.627643      0.702537  0.823017   1.000000e-07
# 93  0.718750  0.663248      0.702537  0.821823   1.000000e-07
#
# [94 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 163/163 - 5s - 29ms/step - accuracy: 0.8079 - loss: 0.5765
# W0000 00:00:1711277313.100135      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.8078846335411072
# 41/41 - 1s - 20ms/step - accuracy: 0.7041 - loss: 0.8278
#
# Test Accuracy: 0.7040737867355347
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00        50
#         Fear       0.64      0.54      0.59       145
#        Happy       0.69      0.72      0.70       188
#      Neutral       0.59      0.69      0.64       246
#      Sadness       0.51      0.43      0.47       231
#     Surprise       0.86      0.87      0.86       441
#
#     accuracy                           0.70      1301
#    macro avg       0.71      0.71      0.71      1301
# weighted avg       0.70      0.70      0.70      1301

# %%
label_to_text
# Out:
# {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Neutral', 4: 'Sadness', 5: 'Happy'}

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_test[i])
    plt.title(label_to_text[predicted_labels[i]])
    plt.axis("off")

plt.show()
