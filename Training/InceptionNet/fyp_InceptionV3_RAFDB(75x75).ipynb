# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.utils import plot_model

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (75, 75))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (75, 75, 3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 32
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 75, 75, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
    rescale=1./255  # Normalization
)

val_datagen = ImageDataGenerator(rescale=1./255)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# Fit the data generator on validation data
val_datagen.fit(img_arr_test)

# %%
# Load the InceptionV3 model
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 1, 1, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,065,959 (84.17 MB)
#  Trainable params: 263,175 (1.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    min_delta=0.0001,
    factor=0.7,
    patience=3,
    min_lr=1e-6,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

# %%
# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=val_datagen.flow(img_arr_test, img_label_test, batch_size=BATCH_SIZE),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   4/383 ━━━━━━━━━━━━━━━━━━━━ 16s 43ms/step - accuracy: 0.2090 - loss: 2.1113
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711471206.789720      90 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711471206.839889      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 354/383 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.4065 - loss: 1.6160
# W0000 00:00:1711471233.604685      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4093 - loss: 1.6073
# W0000 00:00:1711471241.261033      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1711471249.654840      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 61s 113ms/step - accuracy: 0.4094 - loss: 1.6071 - val_accuracy: 0.4756 - val_loss: 1.4132 - learning_rate: 0.0010
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.4062 - loss: 1.4638
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.4638 - val_accuracy: 0.4765 - val_loss: 1.4104 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.4734 - loss: 1.4182 - val_accuracy: 0.4654 - val_loss: 1.4167 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.6140 - val_accuracy: 0.4677 - val_loss: 1.4147 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.4948 - loss: 1.3548 - val_accuracy: 0.4883 - val_loss: 1.3691 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 1.1056 - val_accuracy: 0.4876 - val_loss: 1.3713 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5011 - loss: 1.3283 - val_accuracy: 0.5010 - val_loss: 1.3417 - learning_rate: 0.0010
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.2787 - val_accuracy: 0.5003 - val_loss: 1.3408 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5126 - loss: 1.2902 - val_accuracy: 0.5065 - val_loss: 1.3507 - learning_rate: 0.0010
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.3557 - val_accuracy: 0.5075 - val_loss: 1.3469 - learning_rate: 0.0010
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5160 - loss: 1.2953
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5160 - loss: 1.2953 - val_accuracy: 0.5010 - val_loss: 1.3480 - learning_rate: 0.0010
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.1388 - val_accuracy: 0.5039 - val_loss: 1.3382 - learning_rate: 7.0000e-04
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5206 - loss: 1.2700 - val_accuracy: 0.5052 - val_loss: 1.3390 - learning_rate: 7.0000e-04
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.3116 - val_accuracy: 0.5039 - val_loss: 1.3371 - learning_rate: 7.0000e-04
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5348 - loss: 1.2445 - val_accuracy: 0.5007 - val_loss: 1.3271 - learning_rate: 7.0000e-04
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.2386 - val_accuracy: 0.5033 - val_loss: 1.3278 - learning_rate: 7.0000e-04
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5335 - loss: 1.2343 - val_accuracy: 0.5186 - val_loss: 1.3135 - learning_rate: 7.0000e-04
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.5120 - val_accuracy: 0.5186 - val_loss: 1.3123 - learning_rate: 7.0000e-04
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5454 - loss: 1.2316 - val_accuracy: 0.5081 - val_loss: 1.3241 - learning_rate: 7.0000e-04
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.3507 - val_accuracy: 0.5104 - val_loss: 1.3234 - learning_rate: 7.0000e-04
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5509 - loss: 1.2086
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5509 - loss: 1.2086 - val_accuracy: 0.5130 - val_loss: 1.3304 - learning_rate: 7.0000e-04
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.1107 - val_accuracy: 0.5127 - val_loss: 1.3292 - learning_rate: 4.9000e-04
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.5519 - loss: 1.1962 - val_accuracy: 0.5166 - val_loss: 1.3229 - learning_rate: 4.9000e-04
# Epoch 24/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6562 - loss: 0.9230
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6562 - loss: 0.9230 - val_accuracy: 0.5150 - val_loss: 1.3211 - learning_rate: 4.9000e-04
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5640 - loss: 1.1607 - val_accuracy: 0.5108 - val_loss: 1.3163 - learning_rate: 3.4300e-04
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.3957 - val_accuracy: 0.5091 - val_loss: 1.3161 - learning_rate: 3.4300e-04
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5600 - loss: 1.1704
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5601 - loss: 1.1704 - val_accuracy: 0.5173 - val_loss: 1.3165 - learning_rate: 3.4300e-04
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.4740 - val_accuracy: 0.5169 - val_loss: 1.3170 - learning_rate: 2.4010e-04
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5786 - loss: 1.1456 - val_accuracy: 0.5183 - val_loss: 1.3090 - learning_rate: 2.4010e-04
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.9165 - val_accuracy: 0.5176 - val_loss: 1.3092 - learning_rate: 2.4010e-04
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5764 - loss: 1.1368 - val_accuracy: 0.5104 - val_loss: 1.3176 - learning_rate: 2.4010e-04
# Epoch 32/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.4688 - loss: 1.3218
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.3218 - val_accuracy: 0.5108 - val_loss: 1.3173 - learning_rate: 2.4010e-04
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5802 - loss: 1.1325 - val_accuracy: 0.5124 - val_loss: 1.3175 - learning_rate: 1.6807e-04
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.9564 - val_accuracy: 0.5127 - val_loss: 1.3172 - learning_rate: 1.6807e-04
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5879 - loss: 1.1277
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5879 - loss: 1.1277 - val_accuracy: 0.5156 - val_loss: 1.3114 - learning_rate: 1.6807e-04
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.4753 - val_accuracy: 0.5160 - val_loss: 1.3108 - learning_rate: 1.1765e-04
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5870 - loss: 1.1233 - val_accuracy: 0.5166 - val_loss: 1.3147 - learning_rate: 1.1765e-04
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.444889  1.499103      0.475554  1.413213       0.001000
# 1   0.406250  1.463762      0.476532  1.410427       0.001000
# 2   0.480922  1.394962      0.465450  1.416712       0.001000
# 3   0.312500  1.614007      0.467731  1.414697       0.001000
# 4   0.492932  1.358754      0.488266  1.369139       0.001000
# 5   0.687500  1.105586      0.487614  1.371299       0.001000
# 6   0.503146  1.336155      0.500978  1.341665       0.001000
# 7   0.468750  1.278721      0.500326  1.340778       0.001000
# 8   0.509846  1.309170      0.506519  1.350714       0.001000
# 9   0.531250  1.355692      0.507497  1.346863       0.001000
# 10  0.520794  1.293948      0.500978  1.347980       0.001000
# 11  0.593750  1.138775      0.503911  1.338187       0.000700
# 12  0.527412  1.264256      0.505215  1.339037       0.000700
# 13  0.468750  1.311577      0.503911  1.337099       0.000700
# 14  0.535828  1.250155      0.500652  1.327134       0.000700
# 15  0.468750  1.238636      0.503259  1.327811       0.000700
# 16  0.540077  1.231632      0.518579  1.313511       0.000700
# 17  0.437500  1.512002      0.518579  1.312308       0.000700
# 18  0.545551  1.229550      0.508149  1.324075       0.000700
# 19  0.562500  1.350727      0.510430  1.323418       0.000700
# 20  0.548493  1.213677      0.513038  1.330359       0.000700
# 21  0.531250  1.110697      0.512712  1.329171       0.000490
# 22  0.556418  1.190965      0.516623  1.322903       0.000490
# 23  0.656250  0.923019      0.514993  1.321101       0.000490
# 24  0.565161  1.173417      0.510756  1.316343       0.000343
# 25  0.562500  1.395653      0.509126  1.316146       0.000343
# 26  0.562137  1.168055      0.517275  1.316548       0.000343
# 27  0.468750  1.474021      0.516949  1.316975       0.000240
# 28  0.571452  1.157449      0.518253  1.309003       0.000240
# 29  0.750000  0.916501      0.517601  1.309234       0.000240
# 30  0.574720  1.144057      0.510430  1.317586       0.000240
# 31  0.468750  1.321777      0.510756  1.317318       0.000240
# 32  0.578315  1.135665      0.512386  1.317453       0.000168
# 33  0.687500  0.956352      0.512712  1.317167       0.000168
# 34  0.581257  1.134380      0.515645  1.311446       0.000168
# 35  0.500000  1.475264      0.515971  1.310755       0.000118
# 36  0.583708  1.117181      0.516623  1.314721       0.000118

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 1, 1, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,065,959 (84.17 MB)
#  Trainable params: 22,031,527 (84.04 MB)
#  Non-trainable params: 34,432 (134.50 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=val_datagen.flow(img_arr_test, img_label_test, batch_size=BATCH_SIZE),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/383 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 0.2882 - loss: 2.5135
# W0000 00:00:1711471741.566269      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  89/383 ━━━━━━━━━━━━━━━━━━━━ 2:14 459ms/step - accuracy: 0.2714 - loss: 2.3652
# W0000 00:00:1711471781.872801      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.2836 - loss: 2.0574
# W0000 00:00:1711471804.283634      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 140s 175ms/step - accuracy: 0.2837 - loss: 2.0569 - val_accuracy: 0.3892 - val_loss: 1.6491 - learning_rate: 1.0000e-05
# Epoch 2/100
# W0000 00:00:1711471808.482513      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 29s 78ms/step - accuracy: 0.3438 - loss: 1.7096
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.7096 - val_accuracy: 0.3915 - val_loss: 1.6494 - learning_rate: 1.0000e-05
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.3795 - loss: 1.6324 - val_accuracy: 0.4306 - val_loss: 1.5915 - learning_rate: 1.0000e-05
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.6262 - val_accuracy: 0.4289 - val_loss: 1.5845 - learning_rate: 1.0000e-05
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.4234 - loss: 1.5533 - val_accuracy: 0.4540 - val_loss: 1.5563 - learning_rate: 1.0000e-05
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.3213 - val_accuracy: 0.4531 - val_loss: 1.5588 - learning_rate: 1.0000e-05
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.4510 - loss: 1.4753 - val_accuracy: 0.4772 - val_loss: 1.4983 - learning_rate: 1.0000e-05
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.3583 - val_accuracy: 0.4782 - val_loss: 1.4972 - learning_rate: 1.0000e-05
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.4707 - loss: 1.4169 - val_accuracy: 0.5062 - val_loss: 1.4619 - learning_rate: 1.0000e-05
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.3722 - val_accuracy: 0.5075 - val_loss: 1.4619 - learning_rate: 1.0000e-05
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.4884 - loss: 1.3798 - val_accuracy: 0.5274 - val_loss: 1.3794 - learning_rate: 1.0000e-05
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.6114 - val_accuracy: 0.5264 - val_loss: 1.3812 - learning_rate: 1.0000e-05
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.5039 - loss: 1.3390 - val_accuracy: 0.5476 - val_loss: 1.3733 - learning_rate: 1.0000e-05
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.1703 - val_accuracy: 0.5476 - val_loss: 1.3781 - learning_rate: 1.0000e-05
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.5232 - loss: 1.3003 - val_accuracy: 0.5675 - val_loss: 1.3632 - learning_rate: 1.0000e-05
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 1.0910 - val_accuracy: 0.5655 - val_loss: 1.3696 - learning_rate: 1.0000e-05
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.5337 - loss: 1.2539 - val_accuracy: 0.5942 - val_loss: 1.2771 - learning_rate: 1.0000e-05
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 1.5273 - val_accuracy: 0.5949 - val_loss: 1.2769 - learning_rate: 1.0000e-05
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.5475 - loss: 1.2158 - val_accuracy: 0.5900 - val_loss: 1.2829 - learning_rate: 1.0000e-05
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.4624 - val_accuracy: 0.5906 - val_loss: 1.2812 - learning_rate: 1.0000e-05
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5758 - loss: 1.1829
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.9999998231651255e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.5758 - loss: 1.1829 - val_accuracy: 0.5935 - val_loss: 1.4517 - learning_rate: 1.0000e-05
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.3623 - val_accuracy: 0.5916 - val_loss: 1.4546 - learning_rate: 7.0000e-06
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.5841 - loss: 1.1531 - val_accuracy: 0.5994 - val_loss: 1.3328 - learning_rate: 7.0000e-06
# Epoch 24/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.6875 - loss: 0.9567
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.899999748886329e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.9567 - val_accuracy: 0.6007 - val_loss: 1.3322 - learning_rate: 7.0000e-06
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.5962 - loss: 1.1120 - val_accuracy: 0.6098 - val_loss: 1.2731 - learning_rate: 4.9000e-06
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.2460 - val_accuracy: 0.6092 - val_loss: 1.2746 - learning_rate: 4.9000e-06
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - accuracy: 0.5985 - loss: 1.1058 - val_accuracy: 0.6177 - val_loss: 1.1955 - learning_rate: 4.9000e-06
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.2240 - val_accuracy: 0.6167 - val_loss: 1.1935 - learning_rate: 4.9000e-06
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6030 - loss: 1.0992 - val_accuracy: 0.6239 - val_loss: 1.3428 - learning_rate: 4.9000e-06
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6562 - loss: 1.0109 - val_accuracy: 0.6248 - val_loss: 1.3482 - learning_rate: 4.9000e-06
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6031 - loss: 1.0910 - val_accuracy: 0.6281 - val_loss: 1.1578 - learning_rate: 4.9000e-06
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.1383 - val_accuracy: 0.6284 - val_loss: 1.1504 - learning_rate: 4.9000e-06
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6178 - loss: 1.0651 - val_accuracy: 0.6343 - val_loss: 1.1674 - learning_rate: 4.9000e-06
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.8347 - val_accuracy: 0.6343 - val_loss: 1.1696 - learning_rate: 4.9000e-06
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6224 - loss: 1.0593
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.4299996968911726e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6224 - loss: 1.0593 - val_accuracy: 0.6444 - val_loss: 1.1770 - learning_rate: 4.9000e-06
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.2921 - val_accuracy: 0.6431 - val_loss: 1.1773 - learning_rate: 3.4300e-06
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6281 - loss: 1.0316 - val_accuracy: 0.6450 - val_loss: 1.1463 - learning_rate: 3.4300e-06
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8438 - loss: 0.5725 - val_accuracy: 0.6447 - val_loss: 1.1482 - learning_rate: 3.4300e-06
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6425 - loss: 1.0148 - val_accuracy: 0.6486 - val_loss: 1.1668 - learning_rate: 3.4300e-06
# Epoch 40/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.5000 - loss: 1.2475
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.4009997559915063e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.2475 - val_accuracy: 0.6486 - val_loss: 1.1715 - learning_rate: 3.4300e-06
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6355 - loss: 1.0136 - val_accuracy: 0.6454 - val_loss: 1.1093 - learning_rate: 2.4010e-06
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 1.0010 - val_accuracy: 0.6457 - val_loss: 1.1104 - learning_rate: 2.4010e-06
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6297 - loss: 1.0103 - val_accuracy: 0.6473 - val_loss: 1.0975 - learning_rate: 2.4010e-06
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.0431 - val_accuracy: 0.6473 - val_loss: 1.0990 - learning_rate: 2.4010e-06
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6350 - loss: 1.0008 - val_accuracy: 0.6477 - val_loss: 1.1028 - learning_rate: 2.4010e-06
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.6984 - val_accuracy: 0.6486 - val_loss: 1.0930 - learning_rate: 2.4010e-06
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6356 - loss: 0.9972 - val_accuracy: 0.6503 - val_loss: 1.0886 - learning_rate: 2.4010e-06
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.9001 - val_accuracy: 0.6496 - val_loss: 1.0848 - learning_rate: 2.4010e-06
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6451 - loss: 0.9886 - val_accuracy: 0.6483 - val_loss: 1.1294 - learning_rate: 2.4010e-06
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.9261 - val_accuracy: 0.6480 - val_loss: 1.1292 - learning_rate: 2.4010e-06
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6451 - loss: 0.9914
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.6806998928586836e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6451 - loss: 0.9914 - val_accuracy: 0.6499 - val_loss: 1.1211 - learning_rate: 2.4010e-06
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.1314 - val_accuracy: 0.6486 - val_loss: 1.1232 - learning_rate: 1.6807e-06
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6408 - loss: 0.9803 - val_accuracy: 0.6558 - val_loss: 1.1154 - learning_rate: 1.6807e-06
# Epoch 54/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.6562 - loss: 0.9406
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.176489956833393e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6562 - loss: 0.9406 - val_accuracy: 0.6548 - val_loss: 1.1198 - learning_rate: 1.6807e-06
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6521 - loss: 0.9721 - val_accuracy: 0.6551 - val_loss: 1.1317 - learning_rate: 1.1765e-06
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 0.9555 - val_accuracy: 0.6565 - val_loss: 1.1290 - learning_rate: 1.1765e-06
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6507 - loss: 0.9772
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6507 - loss: 0.9772 - val_accuracy: 0.6545 - val_loss: 1.1474 - learning_rate: 1.1765e-06
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 0.9468 - val_accuracy: 0.6548 - val_loss: 1.1424 - learning_rate: 1.0000e-06
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6505 - loss: 0.9735 - val_accuracy: 0.6571 - val_loss: 1.1310 - learning_rate: 1.0000e-06
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7188 - loss: 0.9603 - val_accuracy: 0.6574 - val_loss: 1.1310 - learning_rate: 1.0000e-06
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6510 - loss: 0.9769 - val_accuracy: 0.6558 - val_loss: 1.1319 - learning_rate: 1.0000e-06
# Epoch 62/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6562 - loss: 1.2270 - val_accuracy: 0.6555 - val_loss: 1.1299 - learning_rate: 1.0000e-06
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6639 - loss: 0.9551 - val_accuracy: 0.6578 - val_loss: 1.1175 - learning_rate: 1.0000e-06
# Epoch 64/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.0843 - val_accuracy: 0.6581 - val_loss: 1.1169 - learning_rate: 1.0000e-06
# Epoch 65/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6603 - loss: 0.9534 - val_accuracy: 0.6597 - val_loss: 1.1709 - learning_rate: 1.0000e-06
# Epoch 66/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7188 - loss: 0.8027 - val_accuracy: 0.6587 - val_loss: 1.1749 - learning_rate: 1.0000e-06
# Epoch 67/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6662 - loss: 0.9536 - val_accuracy: 0.6545 - val_loss: 1.1572 - learning_rate: 1.0000e-06
# Epoch 68/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.8755 - val_accuracy: 0.6535 - val_loss: 1.1531 - learning_rate: 1.0000e-06
# Epoch 69/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6639 - loss: 0.9542 - val_accuracy: 0.6542 - val_loss: 1.1613 - learning_rate: 1.0000e-06
# Epoch 70/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.8538 - val_accuracy: 0.6545 - val_loss: 1.1640 - learning_rate: 1.0000e-06
# Epoch 71/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6582 - loss: 0.9688 - val_accuracy: 0.6584 - val_loss: 1.1389 - learning_rate: 1.0000e-06
# Epoch 72/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.0439 - val_accuracy: 0.6584 - val_loss: 1.1427 - learning_rate: 1.0000e-06
# Epoch 73/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6627 - loss: 0.9366 - val_accuracy: 0.6610 - val_loss: 1.1074 - learning_rate: 1.0000e-06
# Epoch 74/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.7925 - val_accuracy: 0.6600 - val_loss: 1.0992 - learning_rate: 1.0000e-06
# Epoch 75/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6635 - loss: 0.9249 - val_accuracy: 0.6607 - val_loss: 1.1088 - learning_rate: 1.0000e-06
# Epoch 76/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.1588 - val_accuracy: 0.6604 - val_loss: 1.1100 - learning_rate: 1.0000e-06
# Epoch 77/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6545 - loss: 0.9580 - val_accuracy: 0.6620 - val_loss: 1.1495 - learning_rate: 1.0000e-06
# Epoch 78/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.7654 - val_accuracy: 0.6613 - val_loss: 1.1549 - learning_rate: 1.0000e-06
# Epoch 79/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6691 - loss: 0.9298 - val_accuracy: 0.6623 - val_loss: 1.1718 - learning_rate: 1.0000e-06
# Epoch 80/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.2018 - val_accuracy: 0.6643 - val_loss: 1.1685 - learning_rate: 1.0000e-06
# Epoch 81/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6636 - loss: 0.9367 - val_accuracy: 0.6610 - val_loss: 1.1005 - learning_rate: 1.0000e-06
# Epoch 82/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.9157 - val_accuracy: 0.6613 - val_loss: 1.1005 - learning_rate: 1.0000e-06
# Epoch 83/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6607 - loss: 0.9467 - val_accuracy: 0.6656 - val_loss: 1.1333 - learning_rate: 1.0000e-06
# Epoch 84/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.2999 - val_accuracy: 0.6662 - val_loss: 1.1385 - learning_rate: 1.0000e-06
# Epoch 85/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6668 - loss: 0.9313 - val_accuracy: 0.6643 - val_loss: 1.1076 - learning_rate: 1.0000e-06
# Epoch 86/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 0.9548 - val_accuracy: 0.6662 - val_loss: 1.1073 - learning_rate: 1.0000e-06
# Epoch 87/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6705 - loss: 0.9239 - val_accuracy: 0.6659 - val_loss: 1.1113 - learning_rate: 1.0000e-06
# Epoch 88/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.7778 - val_accuracy: 0.6649 - val_loss: 1.1110 - learning_rate: 1.0000e-06
# Epoch 89/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6632 - loss: 0.9326 - val_accuracy: 0.6656 - val_loss: 1.0986 - learning_rate: 1.0000e-06
# Epoch 90/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.7973 - val_accuracy: 0.6656 - val_loss: 1.0943 - learning_rate: 1.0000e-06
# Epoch 91/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.6751 - loss: 0.9208 - val_accuracy: 0.6669 - val_loss: 1.1595 - learning_rate: 1.0000e-06
# Epoch 92/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.2522 - val_accuracy: 0.6666 - val_loss: 1.1515 - learning_rate: 1.0000e-06
# Epoch 93/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6735 - loss: 0.9135 - val_accuracy: 0.6682 - val_loss: 1.1193 - learning_rate: 1.0000e-06
# Epoch 94/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6875 - loss: 0.7893 - val_accuracy: 0.6682 - val_loss: 1.1165 - learning_rate: 1.0000e-06
# Epoch 95/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6582 - loss: 0.9362 - val_accuracy: 0.6626 - val_loss: 1.1479 - learning_rate: 1.0000e-06
# Epoch 96/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8125 - loss: 0.6733 - val_accuracy: 0.6617 - val_loss: 1.1392 - learning_rate: 1.0000e-06
# Epoch 97/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6650 - loss: 0.9290 - val_accuracy: 0.6721 - val_loss: 1.0893 - learning_rate: 1.0000e-06
# Epoch 98/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.8083 - val_accuracy: 0.6711 - val_loss: 1.0860 - learning_rate: 1.0000e-06
# Epoch 99/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.6725 - loss: 0.9233 - val_accuracy: 0.6666 - val_loss: 1.1360 - learning_rate: 1.0000e-06
# Epoch 100/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7812 - loss: 0.7464 - val_accuracy: 0.6653 - val_loss: 1.1347 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 97.

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.309339  1.843673      0.389179  1.649055   1.000000e-05
# 1   0.343750  1.709615      0.391460  1.649418   1.000000e-05
# 2   0.390473  1.615368      0.430574  1.591518   1.000000e-05
# 3   0.437500  1.626230      0.428944  1.584473   1.000000e-05
# 4   0.427813  1.533407      0.454042  1.556295   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 95  0.812500  0.673255      0.661669  1.139168   1.000000e-06
# 96  0.672522  0.920432      0.672099  1.089346   1.000000e-06
# 97  0.750000  0.808349      0.671121  1.086045   1.000000e-06
# 98  0.668110  0.927147      0.666558  1.136024   1.000000e-06
# 99  0.781250  0.746407      0.665254  1.134728   1.000000e-06
#
# [100 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_results = model.evaluate(train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE), verbose=2)
train_loss = train_results[0]
train_acc = train_results[1]
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_results = model.evaluate(val_datagen.flow(img_arr_test, img_label_test, batch_size=BATCH_SIZE), verbose=2)
test_loss = test_results[0]
test_acc = test_results[1]
print(f"\nTest Accuracy: {test_acc}")

# Make predictions
predictions = model.predict(val_datagen.flow(img_arr_test, batch_size=BATCH_SIZE, shuffle=False))
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 384/384 - 23s - 61ms/step - accuracy: 0.6990 - loss: 1.1550
# W0000 00:00:1711473075.365043      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.6989650130271912
# 96/96 - 1s - 13ms/step - accuracy: 0.6721 - loss: 1.0875
#
# Test Accuracy: 0.6720991134643555
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.64      0.62      0.63       329
#      disgust       0.60      0.35      0.44        74
#         fear       0.52      0.53      0.52       162
#        happy       0.58      0.72      0.65       680
#      neutral       0.56      0.58      0.57       478
#          sad       0.29      0.04      0.07       160
#     surprise       0.82      0.82      0.82      1185
#
#     accuracy                           0.67      3068
#    macro avg       0.57      0.52      0.53      3068
# weighted avg       0.66      0.67      0.66      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
