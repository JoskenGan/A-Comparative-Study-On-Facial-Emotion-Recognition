# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feralignedck/feraligned+ck/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness", "Surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Surprise has 249 number of images
# Fear has 728 number of images
# Angry has 938 number of images
# Neutral has 1230 number of images
# Sadness has 1153 number of images
# Happy has 2203 number of images
#
# total images are 6501

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Surprise images to numpy arrays...
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((6501, 64, 64, 1),
#  (6501, 6),
#  {0: 'Surprise',
#   1: 'Fear',
#   2: 'Angry',
#   3: 'Neutral',
#   4: 'Sadness',
#   5: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5200, 64, 64, 1), (1301, 64, 64, 1), (5200, 6), (1301, 6))

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype(int),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)

    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1

    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=3, layers_per_block=3, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=3, layers_per_block=3, show_summary=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  in_layer (InputLayer)       [(None, 64, 64, 1)]          0         []
#
#  conv2d_0 (Conv2D)           (None, 62, 62, 12)           120       ['in_layer[0][0]']
#
#  block1_bn1 (BatchNormaliza  (None, 62, 62, 12)           48        ['conv2d_0[0][0]']
#  tion)
#
#  block1_actv1 (Activation)   (None, 62, 62, 12)           0         ['block1_bn1[0][0]']
#
#  block1_pad1 (ZeroPadding2D  (None, 64, 64, 12)           0         ['block1_actv1[0][0]']
#  )
#
#  block1_conv2d1 (Conv2D)     (None, 62, 62, 12)           1308      ['block1_pad1[0][0]']
#
#  block1_concat1 (Concatenat  (None, 62, 62, 24)           0         ['block1_conv2d1[0][0]',
#  e)                                                                  'conv2d_0[0][0]']
#
#  block1_bn2 (BatchNormaliza  (None, 62, 62, 24)           96        ['block1_concat1[0][0]']
#  tion)
#
#  block1_actv2 (Activation)   (None, 62, 62, 24)           0         ['block1_bn2[0][0]']
#
#  block1_pad2 (ZeroPadding2D  (None, 64, 64, 24)           0         ['block1_actv2[0][0]']
#  )
#
#  block1_conv2d2 (Conv2D)     (None, 62, 62, 24)           5208      ['block1_pad2[0][0]']
#
#  block1_concat2 (Concatenat  (None, 62, 62, 48)           0         ['block1_conv2d2[0][0]',
#  e)                                                                  'block1_concat1[0][0]']
#
#  block1_bn3 (BatchNormaliza  (None, 62, 62, 48)           192       ['block1_concat2[0][0]']
#  tion)
#
#  block1_actv3 (Activation)   (None, 62, 62, 48)           0         ['block1_bn3[0][0]']
#
#  block1_pad3 (ZeroPadding2D  (None, 64, 64, 48)           0         ['block1_actv3[0][0]']
#  )
#
#  block1_conv2d3 (Conv2D)     (None, 62, 62, 36)           15588     ['block1_pad3[0][0]']
#
#  block1_concat3 (Concatenat  (None, 62, 62, 84)           0         ['block1_conv2d3[0][0]',
#  e)                                                                  'block1_concat2[0][0]']
#
#  transition1_bn (BatchNorma  (None, 62, 62, 84)           336       ['block1_concat3[0][0]']
#  lization)
#
#  transition1_actv (Activati  (None, 62, 62, 84)           0         ['transition1_bn[0][0]']
#  on)
#
#  transition1_conv2d (Conv2D  (None, 62, 62, 31)           2635      ['transition1_actv[0][0]']
#  )
#
#  transition1_pool2d (Averag  (None, 31, 31, 31)           0         ['transition1_conv2d[0][0]']
#  ePooling2D)
#
#  block2_bn1 (BatchNormaliza  (None, 31, 31, 31)           124       ['transition1_pool2d[0][0]']
#  tion)
#
#  block2_actv1 (Activation)   (None, 31, 31, 31)           0         ['block2_bn1[0][0]']
#
#  block2_pad1 (ZeroPadding2D  (None, 33, 33, 31)           0         ['block2_actv1[0][0]']
#  )
#
#  block2_conv2d1 (Conv2D)     (None, 31, 31, 48)           13440     ['block2_pad1[0][0]']
#
#  block2_concat1 (Concatenat  (None, 31, 31, 79)           0         ['block2_conv2d1[0][0]',
#  e)                                                                  'transition1_pool2d[0][0]']
#
#  block2_bn2 (BatchNormaliza  (None, 31, 31, 79)           316       ['block2_concat1[0][0]']
#  tion)
#
#  block2_actv2 (Activation)   (None, 31, 31, 79)           0         ['block2_bn2[0][0]']
#
#  block2_pad2 (ZeroPadding2D  (None, 33, 33, 79)           0         ['block2_actv2[0][0]']
#  )
#
#  block2_conv2d2 (Conv2D)     (None, 31, 31, 60)           42720     ['block2_pad2[0][0]']
#
#  block2_concat2 (Concatenat  (None, 31, 31, 139)          0         ['block2_conv2d2[0][0]',
#  e)                                                                  'block2_concat1[0][0]']
#
#  block2_bn3 (BatchNormaliza  (None, 31, 31, 139)          556       ['block2_concat2[0][0]']
#  tion)
#
#  block2_actv3 (Activation)   (None, 31, 31, 139)          0         ['block2_bn3[0][0]']
#
#  block2_pad3 (ZeroPadding2D  (None, 33, 33, 139)          0         ['block2_actv3[0][0]']
#  )
#
#  block2_conv2d3 (Conv2D)     (None, 31, 31, 72)           90144     ['block2_pad3[0][0]']
#
#  block2_concat3 (Concatenat  (None, 31, 31, 211)          0         ['block2_conv2d3[0][0]',
#  e)                                                                  'block2_concat2[0][0]']
#
#  transition2_bn (BatchNorma  (None, 31, 31, 211)          844       ['block2_concat3[0][0]']
#  lization)
#
#  transition2_actv (Activati  (None, 31, 31, 211)          0         ['transition2_bn[0][0]']
#  on)
#
#  transition2_conv2d (Conv2D  (None, 31, 31, 15)           3180      ['transition2_actv[0][0]']
#  )
#
#  transition2_pool2d (Averag  (None, 15, 15, 15)           0         ['transition2_conv2d[0][0]']
#  ePooling2D)
#
#  block3_bn1 (BatchNormaliza  (None, 15, 15, 15)           60        ['transition2_pool2d[0][0]']
#  tion)
#
#  block3_actv1 (Activation)   (None, 15, 15, 15)           0         ['block3_bn1[0][0]']
#
#  block3_pad1 (ZeroPadding2D  (None, 17, 17, 15)           0         ['block3_actv1[0][0]']
#  )
#
#  block3_conv2d1 (Conv2D)     (None, 15, 15, 84)           11424     ['block3_pad1[0][0]']
#
#  block3_concat1 (Concatenat  (None, 15, 15, 99)           0         ['block3_conv2d1[0][0]',
#  e)                                                                  'transition2_pool2d[0][0]']
#
#  block3_bn2 (BatchNormaliza  (None, 15, 15, 99)           396       ['block3_concat1[0][0]']
#  tion)
#
#  block3_actv2 (Activation)   (None, 15, 15, 99)           0         ['block3_bn2[0][0]']
#
#  block3_pad2 (ZeroPadding2D  (None, 17, 17, 99)           0         ['block3_actv2[0][0]']
#  )
#
#  block3_conv2d2 (Conv2D)     (None, 15, 15, 96)           85632     ['block3_pad2[0][0]']
#
#  block3_concat2 (Concatenat  (None, 15, 15, 195)          0         ['block3_conv2d2[0][0]',
#  e)                                                                  'block3_concat1[0][0]']
#
#  block3_bn3 (BatchNormaliza  (None, 15, 15, 195)          780       ['block3_concat2[0][0]']
#  tion)
#
#  block3_actv3 (Activation)   (None, 15, 15, 195)          0         ['block3_bn3[0][0]']
#
#  block3_pad3 (ZeroPadding2D  (None, 17, 17, 195)          0         ['block3_actv3[0][0]']
#  )
#
#  block3_conv2d3 (Conv2D)     (None, 15, 15, 108)          189648    ['block3_pad3[0][0]']
#
#  block3_concat3 (Concatenat  (None, 15, 15, 303)          0         ['block3_conv2d3[0][0]',
#  e)                                                                  'block3_concat2[0][0]']
#
#  transition3_bn (BatchNorma  (None, 15, 15, 303)          1212      ['block3_concat3[0][0]']
#  lization)
#
#  transition3_actv (Activati  (None, 15, 15, 303)          0         ['transition3_bn[0][0]']
#  on)
#
#  transition3_conv2d (Conv2D  (None, 15, 15, 7)            2128      ['transition3_actv[0][0]']
#  )
#
#  transition3_pool2d (Averag  (None, 7, 7, 7)              0         ['transition3_conv2d[0][0]']
#  ePooling2D)
#
#  global_average_pooling2d (  (None, 7)                    0         ['transition3_pool2d[0][0]']
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 7)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense1 (Dense)              (None, 128)                  1024      ['flatten[0][0]']
#
#  dense1_bn (BatchNormalizat  (None, 128)                  512       ['dense1[0][0]']
#  ion)
#
#  dense1_actv (Activation)    (None, 128)                  0         ['dense1_bn[0][0]']
#
#  dense (Dense)               (None, 6)                    774       ['dense1_actv[0][0]']
#
# ==================================================================================================
# Total params: 470445 (1.79 MB)
# Trainable params: 467709 (1.78 MB)
# Non-trainable params: 2736 (10.69 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=9,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_DenseNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 162/162 [==============================] - 24s 57ms/step - loss: 1.6194 - accuracy: 0.3263 - val_loss: 1.6071 - val_accuracy: 0.3405 - lr: 0.0010
# Epoch 2/100
# 162/162 [==============================] - 7s 45ms/step - loss: 1.5396 - accuracy: 0.3712 - val_loss: 1.5978 - val_accuracy: 0.3121 - lr: 0.0010
# Epoch 3/100
# 162/162 [==============================] - 7s 45ms/step - loss: 1.3869 - accuracy: 0.4410 - val_loss: 1.5192 - val_accuracy: 0.4297 - lr: 0.0010
# Epoch 4/100
# 162/162 [==============================] - 7s 45ms/step - loss: 1.1951 - accuracy: 0.5298 - val_loss: 1.4064 - val_accuracy: 0.4658 - lr: 0.0010
# Epoch 5/100
# 162/162 [==============================] - 7s 45ms/step - loss: 1.0665 - accuracy: 0.5775 - val_loss: 2.8809 - val_accuracy: 0.4089 - lr: 0.0010
# Epoch 6/100
# 162/162 [==============================] - 7s 45ms/step - loss: 0.9937 - accuracy: 0.6050 - val_loss: 1.0325 - val_accuracy: 0.5819 - lr: 0.0010
# Epoch 7/100
# 162/162 [==============================] - 7s 45ms/step - loss: 0.9406 - accuracy: 0.6269 - val_loss: 1.1881 - val_accuracy: 0.5442 - lr: 0.0010
# Epoch 8/100
# 162/162 [==============================] - 7s 45ms/step - loss: 0.8798 - accuracy: 0.6565 - val_loss: 1.9775 - val_accuracy: 0.4596 - lr: 0.0010
# Epoch 9/100
# 162/162 [==============================] - 7s 46ms/step - loss: 0.8395 - accuracy: 0.6785 - val_loss: 2.7137 - val_accuracy: 0.3190 - lr: 0.0010
# Epoch 10/100
# 163/162 [==============================] - ETA: 0s - loss: 0.8168 - accuracy: 0.6860
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 162/162 [==============================] - 7s 46ms/step - loss: 0.8168 - accuracy: 0.6860 - val_loss: 2.1877 - val_accuracy: 0.5211 - lr: 0.0010
# Epoch 11/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.7192 - accuracy: 0.7248 - val_loss: 0.7666 - val_accuracy: 0.7048 - lr: 1.0000e-04
# Epoch 12/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.6924 - accuracy: 0.7431 - val_loss: 0.7716 - val_accuracy: 0.7079 - lr: 1.0000e-04
# Epoch 13/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.6740 - accuracy: 0.7431 - val_loss: 0.7334 - val_accuracy: 0.7164 - lr: 1.0000e-04
# Epoch 14/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.6643 - accuracy: 0.7510 - val_loss: 0.7488 - val_accuracy: 0.7218 - lr: 1.0000e-04
# Epoch 15/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6618 - accuracy: 0.7565 - val_loss: 0.7571 - val_accuracy: 0.7187 - lr: 1.0000e-04
# Epoch 16/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6548 - accuracy: 0.7563 - val_loss: 0.7504 - val_accuracy: 0.7179 - lr: 1.0000e-04
# Epoch 17/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6486 - accuracy: 0.7560 - val_loss: 0.7710 - val_accuracy: 0.7079 - lr: 1.0000e-04
# Epoch 18/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6313 - accuracy: 0.7679 - val_loss: 0.7514 - val_accuracy: 0.7225 - lr: 1.0000e-04
# Epoch 19/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6241 - accuracy: 0.7765 - val_loss: 0.7793 - val_accuracy: 0.7118 - lr: 1.0000e-04
# Epoch 20/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6203 - accuracy: 0.7738 - val_loss: 0.7635 - val_accuracy: 0.7164 - lr: 1.0000e-04
# Epoch 21/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6118 - accuracy: 0.7692 - val_loss: 0.7976 - val_accuracy: 0.7056 - lr: 1.0000e-04
# Epoch 22/100
# 162/162 [============================>.] - ETA: 0s - loss: 0.6043 - accuracy: 0.7775
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 162/162 [==============================] - 8s 46ms/step - loss: 0.6054 - accuracy: 0.7771 - val_loss: 0.7967 - val_accuracy: 0.7041 - lr: 1.0000e-04
# Epoch 23/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5822 - accuracy: 0.7827 - val_loss: 0.7273 - val_accuracy: 0.7356 - lr: 1.0000e-05
# Epoch 24/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5917 - accuracy: 0.7802 - val_loss: 0.7260 - val_accuracy: 0.7387 - lr: 1.0000e-05
# Epoch 25/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5857 - accuracy: 0.7844 - val_loss: 0.7229 - val_accuracy: 0.7417 - lr: 1.0000e-05
# Epoch 26/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5851 - accuracy: 0.7877 - val_loss: 0.7244 - val_accuracy: 0.7394 - lr: 1.0000e-05
# Epoch 27/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5851 - accuracy: 0.7842 - val_loss: 0.7196 - val_accuracy: 0.7371 - lr: 1.0000e-05
# Epoch 28/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5820 - accuracy: 0.7815 - val_loss: 0.7182 - val_accuracy: 0.7402 - lr: 1.0000e-05
# Epoch 29/100
# 163/162 [==============================] - ETA: 0s - loss: 0.5776 - accuracy: 0.7871
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5776 - accuracy: 0.7871 - val_loss: 0.7225 - val_accuracy: 0.7417 - lr: 1.0000e-05
# Epoch 30/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5819 - accuracy: 0.7838 - val_loss: 0.7222 - val_accuracy: 0.7402 - lr: 1.0000e-06
# Epoch 31/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5789 - accuracy: 0.7865 - val_loss: 0.7219 - val_accuracy: 0.7417 - lr: 1.0000e-06
# Epoch 32/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5848 - accuracy: 0.7788 - val_loss: 0.7219 - val_accuracy: 0.7410 - lr: 1.0000e-06
# Epoch 33/100
# 163/162 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.7956
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5833 - accuracy: 0.7956 - val_loss: 0.7217 - val_accuracy: 0.7402 - lr: 1.0000e-06
# Epoch 34/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5769 - accuracy: 0.7892 - val_loss: 0.7217 - val_accuracy: 0.7425 - lr: 1.0000e-07
# Epoch 35/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5851 - accuracy: 0.7812 - val_loss: 0.7222 - val_accuracy: 0.7402 - lr: 1.0000e-07
# Epoch 36/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5805 - accuracy: 0.7888 - val_loss: 0.7225 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 37/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5785 - accuracy: 0.7888 - val_loss: 0.7220 - val_accuracy: 0.7402 - lr: 1.0000e-07
# Epoch 38/100
# 163/162 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.7858
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-07.
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5847 - accuracy: 0.7858 - val_loss: 0.7214 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 39/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5794 - accuracy: 0.7865 - val_loss: 0.7222 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 40/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5908 - accuracy: 0.7856 - val_loss: 0.7218 - val_accuracy: 0.7433 - lr: 1.0000e-07
# Epoch 41/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5880 - accuracy: 0.7817 - val_loss: 0.7215 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 42/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5829 - accuracy: 0.7879 - val_loss: 0.7218 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 43/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5816 - accuracy: 0.7840 - val_loss: 0.7219 - val_accuracy: 0.7433 - lr: 1.0000e-07
# Epoch 44/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5733 - accuracy: 0.7863 - val_loss: 0.7221 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 45/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5765 - accuracy: 0.7871 - val_loss: 0.7224 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 46/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5805 - accuracy: 0.7852 - val_loss: 0.7232 - val_accuracy: 0.7402 - lr: 1.0000e-07
# Epoch 47/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5751 - accuracy: 0.7877 - val_loss: 0.7221 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 48/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5791 - accuracy: 0.7898 - val_loss: 0.7221 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 49/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5782 - accuracy: 0.7885 - val_loss: 0.7226 - val_accuracy: 0.7425 - lr: 1.0000e-07
# Epoch 50/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5810 - accuracy: 0.7890 - val_loss: 0.7228 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 51/100
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5741 - accuracy: 0.7856 - val_loss: 0.7218 - val_accuracy: 0.7440 - lr: 1.0000e-07
# Epoch 52/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5740 - accuracy: 0.7883 - val_loss: 0.7225 - val_accuracy: 0.7394 - lr: 1.0000e-07
# Epoch 53/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5781 - accuracy: 0.7871 - val_loss: 0.7221 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 54/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5779 - accuracy: 0.7867 - val_loss: 0.7220 - val_accuracy: 0.7425 - lr: 1.0000e-07
# Epoch 55/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5693 - accuracy: 0.7892 - val_loss: 0.7228 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 56/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5834 - accuracy: 0.7846 - val_loss: 0.7216 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 57/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5770 - accuracy: 0.7898 - val_loss: 0.7219 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 58/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5835 - accuracy: 0.7896 - val_loss: 0.7225 - val_accuracy: 0.7417 - lr: 1.0000e-07
# Epoch 59/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5777 - accuracy: 0.7906 - val_loss: 0.7223 - val_accuracy: 0.7410 - lr: 1.0000e-07
# Epoch 60/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5777 - accuracy: 0.7860 - val_loss: 0.7216 - val_accuracy: 0.7402 - lr: 1.0000e-07
# Epoch 61/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5789 - accuracy: 0.7865 - val_loss: 0.7225 - val_accuracy: 0.7394 - lr: 1.0000e-07
# Epoch 62/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5689 - accuracy: 0.7933 - val_loss: 0.7231 - val_accuracy: 0.7394 - lr: 1.0000e-07
# Epoch 63/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5840 - accuracy: 0.7840 - val_loss: 0.7221 - val_accuracy: 0.7433 - lr: 1.0000e-07
# Epoch 64/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5761 - accuracy: 0.7917 - val_loss: 0.7218 - val_accuracy: 0.7425 - lr: 1.0000e-07
# Epoch 65/100
# 162/162 [==============================] - 8s 46ms/step - loss: 0.5765 - accuracy: 0.7867 - val_loss: 0.7218 - val_accuracy: 0.7433 - lr: 1.0000e-07
# Epoch 66/100
# 163/162 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.7925Epoch 65: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 50.
# 162/162 [==============================] - 8s 47ms/step - loss: 0.5785 - accuracy: 0.7925 - val_loss: 0.7223 - val_accuracy: 0.7410 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_DenseNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.619353  0.326346  1.607149      0.340507  1.000000e-03
# 1   1.539612  0.371154  1.597848      0.312068  1.000000e-03
# 2   1.386950  0.440962  1.519158      0.429669  1.000000e-03
# 3   1.195108  0.529808  1.406428      0.465796  1.000000e-03
# 4   1.066483  0.577500  2.880858      0.408916  1.000000e-03
# ..       ...       ...       ...           ...           ...
# 61  0.568950  0.793269  0.723134      0.739431  1.000000e-07
# 62  0.584049  0.784038  0.722133      0.743274  1.000000e-07
# 63  0.576054  0.791731  0.721830      0.742506  1.000000e-07
# 64  0.576451  0.786731  0.721762      0.743274  1.000000e-07
# 65  0.578526  0.792500  0.722329      0.740968  1.000000e-07
#
# [66 rows x 5 columns]

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['accuracy'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['loss'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Neutral', 4: 'Sadness', 5: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 163/163 - 2s - loss: 0.5265 - accuracy: 0.8079 - 2s/epoch - 13ms/step
#
# train Accuracy: 0.8078846335411072
# 41/41 - 1s - loss: 0.7218 - accuracy: 0.7440 - 549ms/epoch - 13ms/step
#
# Test Accuracy: 0.7440430521965027
# 41/41 [==============================] - 1s 12ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00        50
#         Fear       0.69      0.57      0.63       145
#        Happy       0.71      0.74      0.73       188
#      Neutral       0.60      0.70      0.65       246
#      Sadness       0.60      0.55      0.57       231
#     Surprise       0.91      0.90      0.91       441
#
#     accuracy                           0.74      1301
#    macro avg       0.75      0.74      0.75      1301
# weighted avg       0.75      0.74      0.74      1301

# %%
# Visualize some predictions
pyplot.figure(figsize=(10, 10))
for i in range(9):
    ax = pyplot.subplot(3, 3, i + 1)
    pyplot.imshow(X_test[i])
    pyplot.title(label_to_text[predicted_labels[i]])
    pyplot.axis("off")

pyplot.show()

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Obtaining dependency information for visualkeras from https://files.pythonhosted.org/packages/a5/93/abd375b37add77d58a8c48a506ae39bb77c4380e2507ea444325ff1b9971/visualkeras-0.0.2-py3-none-any.whl.metadata
#   Downloading visualkeras-0.0.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (10.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Obtaining dependency information for aggdraw>=1.3.11 from https://files.pythonhosted.org/packages/e4/57/59b42e145ff12941c5c63d59dc48369912a9e29d69966ff630e6f0f815ac/aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 18.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2041x378>
