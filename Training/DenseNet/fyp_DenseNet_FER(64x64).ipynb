# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feraligned/feraligned/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Fear has 552 number of images
# Angry has 633 number of images
# Neutral has 863 number of images
# Sadness has 904 number of images
# Happy has 1577 number of images
#
# total images are 4529

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((4529, 64, 64, 1),
#  (4529, 5),
#  {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3623, 64, 64, 1), (906, 64, 64, 1), (3623, 5), (906, 5))

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype(int),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)

    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1

    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=3, layers_per_block=3, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=3, layers_per_block=3, show_summary=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  in_layer (InputLayer)       [(None, 64, 64, 1)]          0         []
#
#  conv2d_0 (Conv2D)           (None, 62, 62, 12)           120       ['in_layer[0][0]']
#
#  block1_bn1 (BatchNormaliza  (None, 62, 62, 12)           48        ['conv2d_0[0][0]']
#  tion)
#
#  block1_actv1 (Activation)   (None, 62, 62, 12)           0         ['block1_bn1[0][0]']
#
#  block1_pad1 (ZeroPadding2D  (None, 64, 64, 12)           0         ['block1_actv1[0][0]']
#  )
#
#  block1_conv2d1 (Conv2D)     (None, 62, 62, 12)           1308      ['block1_pad1[0][0]']
#
#  block1_concat1 (Concatenat  (None, 62, 62, 24)           0         ['block1_conv2d1[0][0]',
#  e)                                                                  'conv2d_0[0][0]']
#
#  block1_bn2 (BatchNormaliza  (None, 62, 62, 24)           96        ['block1_concat1[0][0]']
#  tion)
#
#  block1_actv2 (Activation)   (None, 62, 62, 24)           0         ['block1_bn2[0][0]']
#
#  block1_pad2 (ZeroPadding2D  (None, 64, 64, 24)           0         ['block1_actv2[0][0]']
#  )
#
#  block1_conv2d2 (Conv2D)     (None, 62, 62, 24)           5208      ['block1_pad2[0][0]']
#
#  block1_concat2 (Concatenat  (None, 62, 62, 48)           0         ['block1_conv2d2[0][0]',
#  e)                                                                  'block1_concat1[0][0]']
#
#  block1_bn3 (BatchNormaliza  (None, 62, 62, 48)           192       ['block1_concat2[0][0]']
#  tion)
#
#  block1_actv3 (Activation)   (None, 62, 62, 48)           0         ['block1_bn3[0][0]']
#
#  block1_pad3 (ZeroPadding2D  (None, 64, 64, 48)           0         ['block1_actv3[0][0]']
#  )
#
#  block1_conv2d3 (Conv2D)     (None, 62, 62, 36)           15588     ['block1_pad3[0][0]']
#
#  block1_concat3 (Concatenat  (None, 62, 62, 84)           0         ['block1_conv2d3[0][0]',
#  e)                                                                  'block1_concat2[0][0]']
#
#  transition1_bn (BatchNorma  (None, 62, 62, 84)           336       ['block1_concat3[0][0]']
#  lization)
#
#  transition1_actv (Activati  (None, 62, 62, 84)           0         ['transition1_bn[0][0]']
#  on)
#
#  transition1_conv2d (Conv2D  (None, 62, 62, 31)           2635      ['transition1_actv[0][0]']
#  )
#
#  transition1_pool2d (Averag  (None, 31, 31, 31)           0         ['transition1_conv2d[0][0]']
#  ePooling2D)
#
#  block2_bn1 (BatchNormaliza  (None, 31, 31, 31)           124       ['transition1_pool2d[0][0]']
#  tion)
#
#  block2_actv1 (Activation)   (None, 31, 31, 31)           0         ['block2_bn1[0][0]']
#
#  block2_pad1 (ZeroPadding2D  (None, 33, 33, 31)           0         ['block2_actv1[0][0]']
#  )
#
#  block2_conv2d1 (Conv2D)     (None, 31, 31, 48)           13440     ['block2_pad1[0][0]']
#
#  block2_concat1 (Concatenat  (None, 31, 31, 79)           0         ['block2_conv2d1[0][0]',
#  e)                                                                  'transition1_pool2d[0][0]']
#
#  block2_bn2 (BatchNormaliza  (None, 31, 31, 79)           316       ['block2_concat1[0][0]']
#  tion)
#
#  block2_actv2 (Activation)   (None, 31, 31, 79)           0         ['block2_bn2[0][0]']
#
#  block2_pad2 (ZeroPadding2D  (None, 33, 33, 79)           0         ['block2_actv2[0][0]']
#  )
#
#  block2_conv2d2 (Conv2D)     (None, 31, 31, 60)           42720     ['block2_pad2[0][0]']
#
#  block2_concat2 (Concatenat  (None, 31, 31, 139)          0         ['block2_conv2d2[0][0]',
#  e)                                                                  'block2_concat1[0][0]']
#
#  block2_bn3 (BatchNormaliza  (None, 31, 31, 139)          556       ['block2_concat2[0][0]']
#  tion)
#
#  block2_actv3 (Activation)   (None, 31, 31, 139)          0         ['block2_bn3[0][0]']
#
#  block2_pad3 (ZeroPadding2D  (None, 33, 33, 139)          0         ['block2_actv3[0][0]']
#  )
#
#  block2_conv2d3 (Conv2D)     (None, 31, 31, 72)           90144     ['block2_pad3[0][0]']
#
#  block2_concat3 (Concatenat  (None, 31, 31, 211)          0         ['block2_conv2d3[0][0]',
#  e)                                                                  'block2_concat2[0][0]']
#
#  transition2_bn (BatchNorma  (None, 31, 31, 211)          844       ['block2_concat3[0][0]']
#  lization)
#
#  transition2_actv (Activati  (None, 31, 31, 211)          0         ['transition2_bn[0][0]']
#  on)
#
#  transition2_conv2d (Conv2D  (None, 31, 31, 15)           3180      ['transition2_actv[0][0]']
#  )
#
#  transition2_pool2d (Averag  (None, 15, 15, 15)           0         ['transition2_conv2d[0][0]']
#  ePooling2D)
#
#  block3_bn1 (BatchNormaliza  (None, 15, 15, 15)           60        ['transition2_pool2d[0][0]']
#  tion)
#
#  block3_actv1 (Activation)   (None, 15, 15, 15)           0         ['block3_bn1[0][0]']
#
#  block3_pad1 (ZeroPadding2D  (None, 17, 17, 15)           0         ['block3_actv1[0][0]']
#  )
#
#  block3_conv2d1 (Conv2D)     (None, 15, 15, 84)           11424     ['block3_pad1[0][0]']
#
#  block3_concat1 (Concatenat  (None, 15, 15, 99)           0         ['block3_conv2d1[0][0]',
#  e)                                                                  'transition2_pool2d[0][0]']
#
#  block3_bn2 (BatchNormaliza  (None, 15, 15, 99)           396       ['block3_concat1[0][0]']
#  tion)
#
#  block3_actv2 (Activation)   (None, 15, 15, 99)           0         ['block3_bn2[0][0]']
#
#  block3_pad2 (ZeroPadding2D  (None, 17, 17, 99)           0         ['block3_actv2[0][0]']
#  )
#
#  block3_conv2d2 (Conv2D)     (None, 15, 15, 96)           85632     ['block3_pad2[0][0]']
#
#  block3_concat2 (Concatenat  (None, 15, 15, 195)          0         ['block3_conv2d2[0][0]',
#  e)                                                                  'block3_concat1[0][0]']
#
#  block3_bn3 (BatchNormaliza  (None, 15, 15, 195)          780       ['block3_concat2[0][0]']
#  tion)
#
#  block3_actv3 (Activation)   (None, 15, 15, 195)          0         ['block3_bn3[0][0]']
#
#  block3_pad3 (ZeroPadding2D  (None, 17, 17, 195)          0         ['block3_actv3[0][0]']
#  )
#
#  block3_conv2d3 (Conv2D)     (None, 15, 15, 108)          189648    ['block3_pad3[0][0]']
#
#  block3_concat3 (Concatenat  (None, 15, 15, 303)          0         ['block3_conv2d3[0][0]',
#  e)                                                                  'block3_concat2[0][0]']
#
#  transition3_bn (BatchNorma  (None, 15, 15, 303)          1212      ['block3_concat3[0][0]']
#  lization)
#
#  transition3_actv (Activati  (None, 15, 15, 303)          0         ['transition3_bn[0][0]']
#  on)
#
#  transition3_conv2d (Conv2D  (None, 15, 15, 7)            2128      ['transition3_actv[0][0]']
#  )
#
#  transition3_pool2d (Averag  (None, 7, 7, 7)              0         ['transition3_conv2d[0][0]']
#  ePooling2D)
#
#  global_average_pooling2d_1  (None, 7)                    0         ['transition3_pool2d[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 7)                    0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense1 (Dense)              (None, 128)                  1024      ['flatten_1[0][0]']
#
#  dense1_bn (BatchNormalizat  (None, 128)                  512       ['dense1[0][0]']
#  ion)
#
#  dense1_actv (Activation)    (None, 128)                  0         ['dense1_bn[0][0]']
#
#  dense_1 (Dense)             (None, 5)                    645       ['dense1_actv[0][0]']
#
# ==================================================================================================
# Total params: 470316 (1.79 MB)
# Trainable params: 467580 (1.78 MB)
# Non-trainable params: 2736 (10.69 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=9,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_DenseNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 16s 51ms/step - loss: 1.5734 - accuracy: 0.3307 - val_loss: 1.5735 - val_accuracy: 0.2848 - lr: 0.0010
# Epoch 2/100
# 113/113 [==============================] - 5s 47ms/step - loss: 1.5103 - accuracy: 0.3489 - val_loss: 1.6901 - val_accuracy: 0.2472 - lr: 0.0010
# Epoch 3/100
# 113/113 [==============================] - 5s 47ms/step - loss: 1.4691 - accuracy: 0.3768 - val_loss: 1.7172 - val_accuracy: 0.2141 - lr: 0.0010
# Epoch 4/100
# 113/113 [==============================] - 5s 48ms/step - loss: 1.4122 - accuracy: 0.4041 - val_loss: 2.6136 - val_accuracy: 0.3642 - lr: 0.0010
# Epoch 5/100
# 113/113 [==============================] - 5s 48ms/step - loss: 1.2653 - accuracy: 0.4767 - val_loss: 2.1241 - val_accuracy: 0.3775 - lr: 0.0010
# Epoch 6/100
# 113/113 [==============================] - 5s 48ms/step - loss: 1.1807 - accuracy: 0.5167 - val_loss: 1.4653 - val_accuracy: 0.4481 - lr: 0.0010
# Epoch 7/100
# 113/113 [==============================] - 6s 48ms/step - loss: 1.1105 - accuracy: 0.5504 - val_loss: 1.4189 - val_accuracy: 0.4547 - lr: 0.0010
# Epoch 8/100
# 113/113 [==============================] - 5s 47ms/step - loss: 1.0810 - accuracy: 0.5603 - val_loss: 1.4709 - val_accuracy: 0.4305 - lr: 0.0010
# Epoch 9/100
# 113/113 [==============================] - 5s 47ms/step - loss: 1.0145 - accuracy: 0.5984 - val_loss: 1.4121 - val_accuracy: 0.4570 - lr: 0.0010
# Epoch 10/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.9933 - accuracy: 0.6083 - val_loss: 1.1707 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 11/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.9684 - accuracy: 0.6205 - val_loss: 1.2839 - val_accuracy: 0.4956 - lr: 0.0010
# Epoch 12/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.9311 - accuracy: 0.6395 - val_loss: 1.1304 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 13/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.9182 - accuracy: 0.6404 - val_loss: 1.3496 - val_accuracy: 0.5419 - lr: 0.0010
# Epoch 14/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.8745 - accuracy: 0.6588 - val_loss: 1.3990 - val_accuracy: 0.4978 - lr: 0.0010
# Epoch 15/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.8582 - accuracy: 0.6635 - val_loss: 1.2034 - val_accuracy: 0.5353 - lr: 0.0010
# Epoch 16/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.8470 - accuracy: 0.6779 - val_loss: 1.0660 - val_accuracy: 0.5817 - lr: 0.0010
# Epoch 17/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.8095 - accuracy: 0.6826 - val_loss: 1.2681 - val_accuracy: 0.5276 - lr: 0.0010
# Epoch 18/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.8028 - accuracy: 0.6939 - val_loss: 1.1959 - val_accuracy: 0.5574 - lr: 0.0010
# Epoch 19/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.7877 - accuracy: 0.7058 - val_loss: 2.3157 - val_accuracy: 0.2903 - lr: 0.0010
# Epoch 20/100
# 113/113 [============================>.] - ETA: 0s - loss: 0.7693 - accuracy: 0.7070
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 113/113 [==============================] - 5s 47ms/step - loss: 0.7710 - accuracy: 0.7058 - val_loss: 1.5965 - val_accuracy: 0.5033 - lr: 0.0010
# Epoch 21/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.7051 - accuracy: 0.7378 - val_loss: 0.8634 - val_accuracy: 0.6799 - lr: 1.0000e-04
# Epoch 22/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.6627 - accuracy: 0.7530 - val_loss: 0.8481 - val_accuracy: 0.6766 - lr: 1.0000e-04
# Epoch 23/100
# 113/113 [==============================] - 6s 49ms/step - loss: 0.6448 - accuracy: 0.7657 - val_loss: 0.8942 - val_accuracy: 0.6744 - lr: 1.0000e-04
# Epoch 24/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.6378 - accuracy: 0.7599 - val_loss: 0.8714 - val_accuracy: 0.6755 - lr: 1.0000e-04
# Epoch 25/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.6262 - accuracy: 0.7706 - val_loss: 0.8566 - val_accuracy: 0.6854 - lr: 1.0000e-04
# Epoch 26/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.6141 - accuracy: 0.7698 - val_loss: 0.8576 - val_accuracy: 0.6766 - lr: 1.0000e-04
# Epoch 27/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.6062 - accuracy: 0.7695 - val_loss: 0.9081 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 28/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.6036 - accuracy: 0.7847 - val_loss: 0.8911 - val_accuracy: 0.6733 - lr: 1.0000e-04
# Epoch 29/100
# 113/113 [============================>.] - ETA: 0s - loss: 0.6013 - accuracy: 0.7775
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5994 - accuracy: 0.7781 - val_loss: 0.9305 - val_accuracy: 0.6766 - lr: 1.0000e-04
# Epoch 30/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5822 - accuracy: 0.7883 - val_loss: 0.8828 - val_accuracy: 0.6876 - lr: 1.0000e-05
# Epoch 31/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5838 - accuracy: 0.7869 - val_loss: 0.8723 - val_accuracy: 0.6943 - lr: 1.0000e-05
# Epoch 32/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5812 - accuracy: 0.7853 - val_loss: 0.8706 - val_accuracy: 0.6932 - lr: 1.0000e-05
# Epoch 33/100
# 113/113 [==============================] - 6s 48ms/step - loss: 0.5735 - accuracy: 0.7902 - val_loss: 0.8729 - val_accuracy: 0.6887 - lr: 1.0000e-05
# Epoch 34/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5711 - accuracy: 0.7894 - val_loss: 0.8722 - val_accuracy: 0.6943 - lr: 1.0000e-05
# Epoch 35/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5863 - accuracy: 0.7869 - val_loss: 0.8726 - val_accuracy: 0.6965 - lr: 1.0000e-05
# Epoch 36/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5839 - accuracy: 0.7855 - val_loss: 0.8752 - val_accuracy: 0.6954 - lr: 1.0000e-05
# Epoch 37/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5706 - accuracy: 0.7869 - val_loss: 0.8709 - val_accuracy: 0.6887 - lr: 1.0000e-05
# Epoch 38/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5666 - accuracy: 0.7952 - val_loss: 0.8779 - val_accuracy: 0.6932 - lr: 1.0000e-05
# Epoch 39/100
# 114/113 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.7935
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5708 - accuracy: 0.7935 - val_loss: 0.8730 - val_accuracy: 0.6921 - lr: 1.0000e-05
# Epoch 40/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5630 - accuracy: 0.7946 - val_loss: 0.8740 - val_accuracy: 0.6943 - lr: 1.0000e-06
# Epoch 41/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5715 - accuracy: 0.7902 - val_loss: 0.8766 - val_accuracy: 0.6954 - lr: 1.0000e-06
# Epoch 42/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5825 - accuracy: 0.7817 - val_loss: 0.8758 - val_accuracy: 0.6954 - lr: 1.0000e-06
# Epoch 43/100
# 113/113 [============================>.] - ETA: 0s - loss: 0.5722 - accuracy: 0.7856
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5700 - accuracy: 0.7864 - val_loss: 0.8769 - val_accuracy: 0.6954 - lr: 1.0000e-06
# Epoch 44/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5583 - accuracy: 0.7924 - val_loss: 0.8757 - val_accuracy: 0.6954 - lr: 1.0000e-07
# Epoch 45/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5796 - accuracy: 0.7886 - val_loss: 0.8771 - val_accuracy: 0.6932 - lr: 1.0000e-07
# Epoch 46/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5766 - accuracy: 0.7902 - val_loss: 0.8774 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 47/100
# 113/113 [============================>.] - ETA: 0s - loss: 0.5658 - accuracy: 0.7898
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5656 - accuracy: 0.7900 - val_loss: 0.8769 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 48/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5747 - accuracy: 0.7927 - val_loss: 0.8771 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 49/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5751 - accuracy: 0.7905 - val_loss: 0.8770 - val_accuracy: 0.6976 - lr: 1.0000e-07
# Epoch 50/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5684 - accuracy: 0.7969 - val_loss: 0.8753 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 51/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5665 - accuracy: 0.7933 - val_loss: 0.8762 - val_accuracy: 0.6976 - lr: 1.0000e-07
# Epoch 52/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5638 - accuracy: 0.7963 - val_loss: 0.8752 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 53/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5745 - accuracy: 0.7916 - val_loss: 0.8773 - val_accuracy: 0.6932 - lr: 1.0000e-07
# Epoch 54/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5607 - accuracy: 0.7985 - val_loss: 0.8768 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 55/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5696 - accuracy: 0.7886 - val_loss: 0.8760 - val_accuracy: 0.6954 - lr: 1.0000e-07
# Epoch 56/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5809 - accuracy: 0.7902 - val_loss: 0.8762 - val_accuracy: 0.6954 - lr: 1.0000e-07
# Epoch 57/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5790 - accuracy: 0.7894 - val_loss: 0.8769 - val_accuracy: 0.6932 - lr: 1.0000e-07
# Epoch 58/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5681 - accuracy: 0.7922 - val_loss: 0.8773 - val_accuracy: 0.6954 - lr: 1.0000e-07
# Epoch 59/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5710 - accuracy: 0.7946 - val_loss: 0.8765 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 60/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5688 - accuracy: 0.7905 - val_loss: 0.8760 - val_accuracy: 0.6932 - lr: 1.0000e-07
# Epoch 61/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5722 - accuracy: 0.7875 - val_loss: 0.8774 - val_accuracy: 0.6932 - lr: 1.0000e-07
# Epoch 62/100
# 113/113 [==============================] - 5s 47ms/step - loss: 0.5692 - accuracy: 0.7847 - val_loss: 0.8771 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 63/100
# 113/113 [==============================] - 5s 48ms/step - loss: 0.5649 - accuracy: 0.7985 - val_loss: 0.8760 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 64/100
# 113/113 [============================>.] - ETA: 0s - loss: 0.5711 - accuracy: 0.7867Epoch 63: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 48.
# 113/113 [==============================] - 6s 49ms/step - loss: 0.5701 - accuracy: 0.7869 - val_loss: 0.8744 - val_accuracy: 0.6932 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_DenseNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.573363  0.330665  1.573532      0.284768  1.000000e-03
# 1   1.510289  0.348882  1.690137      0.247241  1.000000e-03
# 2   1.469057  0.376760  1.717232      0.214128  1.000000e-03
# 3   1.412237  0.404085  2.613642      0.364238  1.000000e-03
# 4   1.265258  0.476677  2.124054      0.377483  1.000000e-03
# ..       ...       ...       ...           ...           ...
# 59  0.568784  0.790505  0.875964      0.693157  1.000000e-07
# 60  0.572198  0.787469  0.877394      0.693157  1.000000e-07
# 61  0.569246  0.784709  0.877100      0.694260  1.000000e-07
# 62  0.564934  0.798510  0.875985      0.694260  1.000000e-07
# 63  0.570111  0.786917  0.874447      0.693157  1.000000e-07
#
# [64 rows x 5 columns]

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['accuracy'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['loss'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 114/114 - 2s - loss: 0.5111 - accuracy: 0.8159 - 2s/epoch - 14ms/step
#
# train Accuracy: 0.8158984184265137
# 29/29 - 0s - loss: 0.8770 - accuracy: 0.6976 - 414ms/epoch - 14ms/step
#
# Test Accuracy: 0.6975717544555664
# 29/29 [==============================] - 1s 13ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       0.65      0.66      0.65       110
#         Fear       0.62      0.65      0.64       127
#        Happy       0.55      0.64      0.59       173
#      Neutral       0.57      0.51      0.54       181
#      Sadness       0.91      0.87      0.89       315
#
#     accuracy                           0.70       906
#    macro avg       0.66      0.67      0.66       906
# weighted avg       0.70      0.70      0.70       906

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(X_test), size=num_images_to_visualize, replace=False)

pyplot.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    pyplot.subplot(2, 5, i + 1)
    pyplot.imshow(X_test[idx])
    pyplot.title(f"True: {label_to_text[true_labels[idx]]}\nPredicted: {label_to_text[predicted_labels[idx]]}")
    pyplot.axis('off')
pyplot.tight_layout()
pyplot.show()

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /opt/conda/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Requirement already satisfied: aggdraw>=1.3.11 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.3.18.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2041x378>
