# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Add
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/AffectNet/"
TOP_EMOTIONS = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (128,128,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# surprise has 1851 number of images
# fear has 1839 number of images
# neutral has 1880 number of images
# sad has 1821 number of images
# disgust has 1740 number of images
# contempt has 1833 number of images
# happy has 1862 number of images
# anger has 1822 number of images
#
# total images are 14648

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, 0)
            img = cv2.resize(img, (128, 128))  # Resize the image to (128, 128)
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1,1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded contempt images to numpy arrays...
# loaded happy images to numpy arrays...
# loaded anger images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((14648, 128, 128, 1),
#  (14648, 8),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'neutral',
#   3: 'sad',
#   4: 'disgust',
#   5: 'contempt',
#   6: 'happy',
#   7: 'anger'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(128, 128), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11718, 128, 128, 1), (2930, 128, 128, 1), (11718, 8), (2930, 8))

# %%
def identity_block(X, kernel: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'idblock_conv_' +  str(stage) + f'_{block_id}'
    bn_name = 'idblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "idblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters = filters[0],
        kernel_size = (1, 1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters = filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters = filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_c',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def convolutional_block(X, kernel: tuple, stride: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'convblock_conv_' + str(stage) + f'_{block_id}'
    bn_name = 'convblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "convblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters[0],
        kernel_size = (1, 1),
        strides = stride,
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_c',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X_shortcut = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = stride,
        padding = 'valid',
        name = conv_name + '_sc1',
        kernel_initializer=glorot_uniform(seed =0)
    )(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name + '_sc1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def CNN_with_SkipConnections(input_shape, classes, show_summary=False):
    model_in = Input(input_shape)

    X = Conv2D(
        filters = 32,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(model_in)
    X = BatchNormalization(axis = 3, name = 'bn_0_a')(X)
    X = Activation('relu', name="actv_0_a")(X)

    X = Conv2D(
        filters = 64,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_b',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = 'bn_0_b')(X)
    X = Activation('relu', name="actv_0_b")(X)

    # Block 0
    X = convolutional_block(model_in, (3,3), stride=(1,1), filters = [32, 32, 64], stage=0, block_id='a')
    X = identity_block(X, (3,3), [32, 32, 64], stage=0, block_id='a')

    # Block 1
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [64, 64, 128], stage=1, block_id='a')
    X = identity_block(X, (3,3), [64, 64, 128], stage=1, block_id='a')

    # Block 2
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [128,128,256], stage=2, block_id='a')
    X = identity_block(X, (2,2), [128,128,256], stage=2, block_id='a')

    X = AveragePooling2D(pool_size=(2, 2))(X)

    X = Flatten()(X)
    X = Dense(
        128,
        kernel_initializer = glorot_uniform(seed=0),
        name = 'dense_1',
    )(X)
    X = BatchNormalization(name = 'bn_3')(X)
    X = Activation('relu', name="actv_3")(X)

    model_out = Dense(classes, activation='softmax', name="out_layer")(X)

    model = Model(inputs = model_in, outputs = model_out, name='CNN_with_SkipConnections')

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = CNN_with_SkipConnections(INPUT_SHAPE, NUM_CLASSES, show_summary=True)

plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)
# Out:
# Model: "CNN_with_SkipConnections"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 128, 128,  │         64 │ input_layer_1[0]… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_a  │ (None, 128, 128,  │        128 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 128, 128,  │          0 │ convblock_bn_0_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 128, 128,  │      9,248 │ convblock_actv_0… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_b  │ (None, 128, 128,  │        128 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 128, 128,  │          0 │ convblock_bn_0_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 128, 128,  │      2,112 │ convblock_actv_0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 128, 128,  │        128 │ input_layer_1[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_c  │ (None, 128, 128,  │        256 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_s… │ (None, 128, 128,  │        256 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128,  │          0 │ convblock_bn_0_a… │
# │                     │ 64)               │            │ convblock_bn_0_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 128, 128,  │          0 │ add_6[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_a  │ (None, 128, 128,  │      2,080 │ convblock_actv_0… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_a    │ (None, 128, 128,  │        128 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_a  │ (None, 128, 128,  │          0 │ idblock_bn_0_a_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_b  │ (None, 128, 128,  │      9,248 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_b    │ (None, 128, 128,  │        128 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_b  │ (None, 128, 128,  │          0 │ idblock_bn_0_a_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_c  │ (None, 128, 128,  │      2,112 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_c    │ (None, 128, 128,  │        256 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 128, 128,  │          0 │ idblock_bn_0_a_c… │
# │                     │ 64)               │            │ convblock_actv_0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_c  │ (None, 128, 128,  │          0 │ add_7[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 64, 64,    │      4,160 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_a  │ (None, 64, 64,    │        256 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 64, 64,    │          0 │ convblock_bn_1_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 64, 64,    │     36,928 │ convblock_actv_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_b  │ (None, 64, 64,    │        256 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 64, 64,    │          0 │ convblock_bn_1_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 64, 64,    │      8,320 │ convblock_actv_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 64, 64,    │      8,320 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_c  │ (None, 64, 64,    │        512 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_s… │ (None, 64, 64,    │        512 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 64, 64,    │          0 │ convblock_bn_1_a… │
# │                     │ 128)              │            │ convblock_bn_1_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 64, 64,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_a  │ (None, 64, 64,    │      8,256 │ convblock_actv_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_a    │ (None, 64, 64,    │        256 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_a  │ (None, 64, 64,    │          0 │ idblock_bn_1_a_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_b  │ (None, 64, 64,    │     36,928 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_b    │ (None, 64, 64,    │        256 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_b  │ (None, 64, 64,    │          0 │ idblock_bn_1_a_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_c  │ (None, 64, 64,    │      8,320 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_c    │ (None, 64, 64,    │        512 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 64,    │          0 │ idblock_bn_1_a_c… │
# │                     │ 128)              │            │ convblock_actv_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_c  │ (None, 64, 64,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 32, 32,    │     16,512 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_a  │ (None, 32, 32,    │        512 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 32, 32,    │          0 │ convblock_bn_2_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 32, 32,    │    147,584 │ convblock_actv_2… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_b  │ (None, 32, 32,    │        512 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 32, 32,    │          0 │ convblock_bn_2_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 32, 32,    │     33,024 │ convblock_actv_2… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 32, 32,    │     33,024 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_c  │ (None, 32, 32,    │      1,024 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_s… │ (None, 32, 32,    │      1,024 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 32, 32,    │          0 │ convblock_bn_2_a… │
# │                     │ 256)              │            │ convblock_bn_2_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 32, 32,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_a  │ (None, 32, 32,    │     32,896 │ convblock_actv_2… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_a    │ (None, 32, 32,    │        512 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_a  │ (None, 32, 32,    │          0 │ idblock_bn_2_a_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_b  │ (None, 32, 32,    │     65,664 │ idblock_actv_2_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_b    │ (None, 32, 32,    │        512 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_b  │ (None, 32, 32,    │          0 │ idblock_bn_2_a_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_c  │ (None, 32, 32,    │     33,024 │ idblock_actv_2_a… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_c    │ (None, 32, 32,    │      1,024 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 32, 32,    │          0 │ idblock_bn_2_a_c… │
# │                     │ 256)              │            │ convblock_actv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_c  │ (None, 32, 32,    │          0 │ add_11[0][0]      │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 16, 16,    │          0 │ idblock_actv_2_a… │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 65536)     │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │  8,388,736 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_3                │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ actv_3 (Activation) │ (None, 128)       │          0 │ bn_3[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_layer (Dense)   │ (None, 8)         │      1,032 │ actv_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,897,192 (33.94 MB)
#  Trainable params: 8,892,456 (33.92 MB)
#  Non-trainable params: 4,736 (18.50 KB)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(learning_rate=0.0001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy']
)

train_datagen.fit(X_train)

# Increase the number of epochs and use the custom early stopping callback
custom_early_stopping = CustomEarlyStopping(patience=15)
history_ResNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / batch_size),
    epochs=epochs,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 119s 216ms/step - accuracy: 0.2047 - loss: 2.1229 - val_accuracy: 0.1823 - val_loss: 2.0746 - learning_rate: 1.0000e-04
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 50s 139ms/step - accuracy: 0.2188 - loss: 2.1402
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2188 - loss: 2.1402 - val_accuracy: 0.1853 - val_loss: 2.0708 - learning_rate: 1.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 55s 151ms/step - accuracy: 0.2957 - loss: 1.8282 - val_accuracy: 0.3048 - val_loss: 1.8194 - learning_rate: 1.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4375 - loss: 1.6496 - val_accuracy: 0.3007 - val_loss: 1.8195 - learning_rate: 1.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.3402 - loss: 1.7321 - val_accuracy: 0.3672 - val_loss: 1.6777 - learning_rate: 1.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4688 - loss: 1.4690 - val_accuracy: 0.3710 - val_loss: 1.6730 - learning_rate: 1.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.3782 - loss: 1.6083 - val_accuracy: 0.3870 - val_loss: 1.6153 - learning_rate: 1.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3750 - loss: 1.5841 - val_accuracy: 0.3922 - val_loss: 1.6137 - learning_rate: 1.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.4217 - loss: 1.5224 - val_accuracy: 0.4014 - val_loss: 1.6489 - learning_rate: 1.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.2188 - loss: 1.6260 - val_accuracy: 0.4014 - val_loss: 1.6512 - learning_rate: 1.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.4402 - loss: 1.4711 - val_accuracy: 0.4352 - val_loss: 1.5194 - learning_rate: 1.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5000 - loss: 1.4636 - val_accuracy: 0.4304 - val_loss: 1.5375 - learning_rate: 1.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.4627 - loss: 1.4088 - val_accuracy: 0.4621 - val_loss: 1.4449 - learning_rate: 1.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5000 - loss: 1.2927 - val_accuracy: 0.4608 - val_loss: 1.4486 - learning_rate: 1.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.4879 - loss: 1.3688 - val_accuracy: 0.4280 - val_loss: 1.5189 - learning_rate: 1.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.3125 - loss: 1.4671 - val_accuracy: 0.4270 - val_loss: 1.5266 - learning_rate: 1.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4984 - loss: 1.3378
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.4984 - loss: 1.3378 - val_accuracy: 0.4526 - val_loss: 1.4739 - learning_rate: 1.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5312 - loss: 1.2293 - val_accuracy: 0.4529 - val_loss: 1.4719 - learning_rate: 1.0000e-05
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5242 - loss: 1.2702 - val_accuracy: 0.5089 - val_loss: 1.3119 - learning_rate: 1.0000e-05
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6875 - loss: 1.0716 - val_accuracy: 0.5106 - val_loss: 1.3119 - learning_rate: 1.0000e-05
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 58s 157ms/step - accuracy: 0.5489 - loss: 1.2361 - val_accuracy: 0.5218 - val_loss: 1.2992 - learning_rate: 1.0000e-05
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4375 - loss: 1.3063 - val_accuracy: 0.5208 - val_loss: 1.2992 - learning_rate: 1.0000e-05
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5481 - loss: 1.2279 - val_accuracy: 0.5229 - val_loss: 1.2956 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5000 - loss: 1.1233 - val_accuracy: 0.5232 - val_loss: 1.2956 - learning_rate: 1.0000e-05
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5396 - loss: 1.2298 - val_accuracy: 0.5212 - val_loss: 1.2957 - learning_rate: 1.0000e-05
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5938 - loss: 1.0718 - val_accuracy: 0.5218 - val_loss: 1.2955 - learning_rate: 1.0000e-05
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5585 - loss: 1.1963 - val_accuracy: 0.5280 - val_loss: 1.2914 - learning_rate: 1.0000e-05
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4375 - loss: 1.4016 - val_accuracy: 0.5270 - val_loss: 1.2916 - learning_rate: 1.0000e-05
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5575 - loss: 1.1923 - val_accuracy: 0.5314 - val_loss: 1.2845 - learning_rate: 1.0000e-05
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5312 - loss: 1.1803 - val_accuracy: 0.5314 - val_loss: 1.2846 - learning_rate: 1.0000e-05
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5734 - loss: 1.1794 - val_accuracy: 0.5294 - val_loss: 1.2940 - learning_rate: 1.0000e-05
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5312 - loss: 1.2668 - val_accuracy: 0.5287 - val_loss: 1.2937 - learning_rate: 1.0000e-05
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5714 - loss: 1.1761
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5714 - loss: 1.1761 - val_accuracy: 0.5287 - val_loss: 1.2815 - learning_rate: 1.0000e-05
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5000 - loss: 1.1872 - val_accuracy: 0.5290 - val_loss: 1.2815 - learning_rate: 1.0000e-06
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5814 - loss: 1.1536 - val_accuracy: 0.5362 - val_loss: 1.2799 - learning_rate: 1.0000e-06
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5000 - loss: 1.3068 - val_accuracy: 0.5358 - val_loss: 1.2800 - learning_rate: 1.0000e-06
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5778 - loss: 1.1603 - val_accuracy: 0.5372 - val_loss: 1.2798 - learning_rate: 1.0000e-06
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6562 - loss: 1.1870 - val_accuracy: 0.5379 - val_loss: 1.2799 - learning_rate: 1.0000e-06
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5874 - loss: 1.1512 - val_accuracy: 0.5369 - val_loss: 1.2792 - learning_rate: 1.0000e-06
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6250 - loss: 1.2243 - val_accuracy: 0.5379 - val_loss: 1.2791 - learning_rate: 1.0000e-06
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5826 - loss: 1.1500 - val_accuracy: 0.5369 - val_loss: 1.2806 - learning_rate: 1.0000e-06
# Epoch 42/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 50s 139ms/step - accuracy: 0.4688 - loss: 1.2699
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4688 - loss: 1.2699 - val_accuracy: 0.5358 - val_loss: 1.2808 - learning_rate: 1.0000e-06
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5921 - loss: 1.1359 - val_accuracy: 0.5358 - val_loss: 1.2789 - learning_rate: 1.0000e-07
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5625 - loss: 1.0858 - val_accuracy: 0.5348 - val_loss: 1.2786 - learning_rate: 1.0000e-07
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5738 - loss: 1.1598 - val_accuracy: 0.5341 - val_loss: 1.2795 - learning_rate: 1.0000e-07
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6250 - loss: 1.0316 - val_accuracy: 0.5345 - val_loss: 1.2795 - learning_rate: 1.0000e-07
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5782 - loss: 1.1461 - val_accuracy: 0.5334 - val_loss: 1.2795 - learning_rate: 1.0000e-07
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5625 - loss: 1.1105 - val_accuracy: 0.5341 - val_loss: 1.2795 - learning_rate: 1.0000e-07
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5773 - loss: 1.1566 - val_accuracy: 0.5365 - val_loss: 1.2786 - learning_rate: 1.0000e-07
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5312 - loss: 1.1768 - val_accuracy: 0.5372 - val_loss: 1.2786 - learning_rate: 1.0000e-07
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5781 - loss: 1.1573 - val_accuracy: 0.5352 - val_loss: 1.2800 - learning_rate: 1.0000e-07
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6250 - loss: 1.1912 - val_accuracy: 0.5345 - val_loss: 1.2800 - learning_rate: 1.0000e-07
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5781 - loss: 1.1608Epoch 52: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 37.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 56s 151ms/step - accuracy: 0.5781 - loss: 1.1607 - val_accuracy: 0.5362 - val_loss: 1.2792 - learning_rate: 1.0000e-07

# %%
history = pd.DataFrame(history_ResNet.history)
history
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.234982  1.999471      0.182253  2.074641   1.000000e-04
# 1   0.218750  2.140246      0.185324  2.070832   1.000000e-04
# 2   0.299846  1.814074      0.304778  1.819356   1.000000e-04
# 3   0.437500  1.649556      0.300683  1.819490   1.000000e-04
# 4   0.346569  1.712112      0.367235  1.677748   1.000000e-04
# 5   0.468750  1.469004      0.370990  1.672964   1.000000e-04
# 6   0.382081  1.607143      0.387031  1.615262   1.000000e-04
# 7   0.375000  1.584149      0.392150  1.613685   1.000000e-04
# 8   0.425295  1.513379      0.401365  1.648888   1.000000e-04
# 9   0.218750  1.625955      0.401365  1.651150   1.000000e-04
# 10  0.440784  1.466861      0.435154  1.519422   1.000000e-04
# 11  0.500000  1.463598      0.430375  1.537544   1.000000e-04
# 12  0.466627  1.409970      0.462116  1.444865   1.000000e-04
# 13  0.500000  1.292685      0.460751  1.448564   1.000000e-04
# 14  0.483827  1.371246      0.427986  1.518946   1.000000e-04
# 15  0.312500  1.467064      0.426962  1.526563   1.000000e-04
# 16  0.497091  1.340745      0.452560  1.473916   1.000000e-04
# 17  0.531250  1.229321      0.452901  1.471947   1.000000e-05
# 18  0.537566  1.254297      0.508874  1.311902   1.000000e-05
# 19  0.687500  1.071639      0.510580  1.311927   1.000000e-05
# 20  0.547407  1.234239      0.521843  1.299184   1.000000e-05
# 21  0.437500  1.306267      0.520819  1.299229   1.000000e-05
# 22  0.558959  1.214946      0.522867  1.295611   1.000000e-05
# 23  0.500000  1.123252      0.523208  1.295606   1.000000e-05
# 24  0.550402  1.210592      0.521160  1.295690   1.000000e-05
# 25  0.593750  1.071795      0.521843  1.295474   1.000000e-05
# 26  0.565035  1.196020      0.527986  1.291379   1.000000e-05
# 27  0.437500  1.401633      0.526962  1.291643   1.000000e-05
# 28  0.561869  1.187128      0.531399  1.284546   1.000000e-05
# 29  0.531250  1.180349      0.531399  1.284633   1.000000e-05
# 30  0.570597  1.181342      0.529352  1.294021   1.000000e-05
# 31  0.531250  1.266830      0.528669  1.293705   1.000000e-05
# 32  0.571025  1.173133      0.528669  1.281492   1.000000e-05
# 33  0.500000  1.187231      0.529010  1.281514   1.000000e-06
# 34  0.576331  1.158170      0.536177  1.279927   1.000000e-06
# 35  0.500000  1.306816      0.535836  1.280020   1.000000e-06
# 36  0.581208  1.161778      0.537201  1.279839   1.000000e-06
# 37  0.656250  1.187015      0.537884  1.279927   1.000000e-06
# 38  0.586856  1.154819      0.536860  1.279248   1.000000e-06
# 39  0.625000  1.224270      0.537884  1.279137   1.000000e-06
# 40  0.580267  1.156409      0.536860  1.280599   1.000000e-06
# 41  0.468750  1.269866      0.535836  1.280768   1.000000e-06
# 42  0.586856  1.145937      0.535836  1.278898   1.000000e-07
# 43  0.562500  1.085759      0.534812  1.278647   1.000000e-07
# 44  0.577871  1.160318      0.534130  1.279471   1.000000e-07
# 45  0.625000  1.031593      0.534471  1.279485   1.000000e-07
# 46  0.575047  1.158528      0.533447  1.279469   1.000000e-07
# 47  0.562500  1.110534      0.534130  1.279511   1.000000e-07
# 48  0.584802  1.152623      0.536519  1.278562   1.000000e-07
# 49  0.531250  1.176849      0.537201  1.278595   1.000000e-07
# 50  0.581037  1.147283      0.535154  1.280036   1.000000e-07
# 51  0.625000  1.191222      0.534471  1.279959   1.000000e-07
# 52  0.579069  1.159469      0.536177  1.279175   1.000000e-07

# %%
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['accuracy'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['loss'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 367/367 - 13s - 35ms/step - accuracy: 0.6481 - loss: 0.9975
#
# train Accuracy: 0.6480628252029419
# 92/92 - 3s - 32ms/step - accuracy: 0.5379 - loss: 1.2799
#
# Test Accuracy: 0.5378839373588562
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.45      0.39      0.42       370
#     contempt       0.42      0.44      0.43       368
#      disgust       0.75      0.82      0.78       376
#         fear       0.40      0.41      0.40       364
#        happy       0.45      0.41      0.43       348
#      neutral       0.52      0.58      0.55       367
#          sad       0.84      0.86      0.85       373
#     surprise       0.42      0.39      0.40       364
#
#     accuracy                           0.54      2930
#    macro avg       0.53      0.54      0.53      2930
# weighted avg       0.53      0.54      0.53      2930

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(X_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])
    plt.title(f"True: {label_to_text[true_labels[idx]]}\nPredicted: {label_to_text[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
