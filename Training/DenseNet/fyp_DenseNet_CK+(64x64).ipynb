# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/ck/ck/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Sadness", "Surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Surprise has 249 number of images
# Fear has 75 number of images
# Angry has 135 number of images
# Sadness has 84 number of images
# Happy has 207 number of images
#
# total images are 750

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Surprise images to numpy arrays...
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((750, 64, 64, 1),
#  (750, 5),
#  {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Sadness', 4: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((600, 64, 64, 1), (150, 64, 64, 1), (600, 5), (150, 5))

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype(int),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)

    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1

    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=3, layers_per_block=3, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=3, layers_per_block=3, growth_rate=16, show_summary=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  in_layer (InputLayer)       [(None, 64, 64, 1)]          0         []
#
#  conv2d_0 (Conv2D)           (None, 62, 62, 12)           120       ['in_layer[0][0]']
#
#  block1_bn1 (BatchNormaliza  (None, 62, 62, 12)           48        ['conv2d_0[0][0]']
#  tion)
#
#  block1_actv1 (Activation)   (None, 62, 62, 12)           0         ['block1_bn1[0][0]']
#
#  block1_pad1 (ZeroPadding2D  (None, 64, 64, 12)           0         ['block1_actv1[0][0]']
#  )
#
#  block1_conv2d1 (Conv2D)     (None, 62, 62, 12)           1308      ['block1_pad1[0][0]']
#
#  block1_concat1 (Concatenat  (None, 62, 62, 24)           0         ['block1_conv2d1[0][0]',
#  e)                                                                  'conv2d_0[0][0]']
#
#  block1_bn2 (BatchNormaliza  (None, 62, 62, 24)           96        ['block1_concat1[0][0]']
#  tion)
#
#  block1_actv2 (Activation)   (None, 62, 62, 24)           0         ['block1_bn2[0][0]']
#
#  block1_pad2 (ZeroPadding2D  (None, 64, 64, 24)           0         ['block1_actv2[0][0]']
#  )
#
#  block1_conv2d2 (Conv2D)     (None, 62, 62, 28)           6076      ['block1_pad2[0][0]']
#
#  block1_concat2 (Concatenat  (None, 62, 62, 52)           0         ['block1_conv2d2[0][0]',
#  e)                                                                  'block1_concat1[0][0]']
#
#  block1_bn3 (BatchNormaliza  (None, 62, 62, 52)           208       ['block1_concat2[0][0]']
#  tion)
#
#  block1_actv3 (Activation)   (None, 62, 62, 52)           0         ['block1_bn3[0][0]']
#
#  block1_pad3 (ZeroPadding2D  (None, 64, 64, 52)           0         ['block1_actv3[0][0]']
#  )
#
#  block1_conv2d3 (Conv2D)     (None, 62, 62, 44)           20636     ['block1_pad3[0][0]']
#
#  block1_concat3 (Concatenat  (None, 62, 62, 96)           0         ['block1_conv2d3[0][0]',
#  e)                                                                  'block1_concat2[0][0]']
#
#  transition1_bn (BatchNorma  (None, 62, 62, 96)           384       ['block1_concat3[0][0]']
#  lization)
#
#  transition1_actv (Activati  (None, 62, 62, 96)           0         ['transition1_bn[0][0]']
#  on)
#
#  transition1_conv2d (Conv2D  (None, 62, 62, 31)           3007      ['transition1_actv[0][0]']
#  )
#
#  transition1_pool2d (Averag  (None, 31, 31, 31)           0         ['transition1_conv2d[0][0]']
#  ePooling2D)
#
#  block2_bn1 (BatchNormaliza  (None, 31, 31, 31)           124       ['transition1_pool2d[0][0]']
#  tion)
#
#  block2_actv1 (Activation)   (None, 31, 31, 31)           0         ['block2_bn1[0][0]']
#
#  block2_pad1 (ZeroPadding2D  (None, 33, 33, 31)           0         ['block2_actv1[0][0]']
#  )
#
#  block2_conv2d1 (Conv2D)     (None, 31, 31, 60)           16800     ['block2_pad1[0][0]']
#
#  block2_concat1 (Concatenat  (None, 31, 31, 91)           0         ['block2_conv2d1[0][0]',
#  e)                                                                  'transition1_pool2d[0][0]']
#
#  block2_bn2 (BatchNormaliza  (None, 31, 31, 91)           364       ['block2_concat1[0][0]']
#  tion)
#
#  block2_actv2 (Activation)   (None, 31, 31, 91)           0         ['block2_bn2[0][0]']
#
#  block2_pad2 (ZeroPadding2D  (None, 33, 33, 91)           0         ['block2_actv2[0][0]']
#  )
#
#  block2_conv2d2 (Conv2D)     (None, 31, 31, 76)           62320     ['block2_pad2[0][0]']
#
#  block2_concat2 (Concatenat  (None, 31, 31, 167)          0         ['block2_conv2d2[0][0]',
#  e)                                                                  'block2_concat1[0][0]']
#
#  block2_bn3 (BatchNormaliza  (None, 31, 31, 167)          668       ['block2_concat2[0][0]']
#  tion)
#
#  block2_actv3 (Activation)   (None, 31, 31, 167)          0         ['block2_bn3[0][0]']
#
#  block2_pad3 (ZeroPadding2D  (None, 33, 33, 167)          0         ['block2_actv3[0][0]']
#  )
#
#  block2_conv2d3 (Conv2D)     (None, 31, 31, 92)           138368    ['block2_pad3[0][0]']
#
#  block2_concat3 (Concatenat  (None, 31, 31, 259)          0         ['block2_conv2d3[0][0]',
#  e)                                                                  'block2_concat2[0][0]']
#
#  transition2_bn (BatchNorma  (None, 31, 31, 259)          1036      ['block2_concat3[0][0]']
#  lization)
#
#  transition2_actv (Activati  (None, 31, 31, 259)          0         ['transition2_bn[0][0]']
#  on)
#
#  transition2_conv2d (Conv2D  (None, 31, 31, 15)           3900      ['transition2_actv[0][0]']
#  )
#
#  transition2_pool2d (Averag  (None, 15, 15, 15)           0         ['transition2_conv2d[0][0]']
#  ePooling2D)
#
#  block3_bn1 (BatchNormaliza  (None, 15, 15, 15)           60        ['transition2_pool2d[0][0]']
#  tion)
#
#  block3_actv1 (Activation)   (None, 15, 15, 15)           0         ['block3_bn1[0][0]']
#
#  block3_pad1 (ZeroPadding2D  (None, 17, 17, 15)           0         ['block3_actv1[0][0]']
#  )
#
#  block3_conv2d1 (Conv2D)     (None, 15, 15, 108)          14688     ['block3_pad1[0][0]']
#
#  block3_concat1 (Concatenat  (None, 15, 15, 123)          0         ['block3_conv2d1[0][0]',
#  e)                                                                  'transition2_pool2d[0][0]']
#
#  block3_bn2 (BatchNormaliza  (None, 15, 15, 123)          492       ['block3_concat1[0][0]']
#  tion)
#
#  block3_actv2 (Activation)   (None, 15, 15, 123)          0         ['block3_bn2[0][0]']
#
#  block3_pad2 (ZeroPadding2D  (None, 17, 17, 123)          0         ['block3_actv2[0][0]']
#  )
#
#  block3_conv2d2 (Conv2D)     (None, 15, 15, 124)          137392    ['block3_pad2[0][0]']
#
#  block3_concat2 (Concatenat  (None, 15, 15, 247)          0         ['block3_conv2d2[0][0]',
#  e)                                                                  'block3_concat1[0][0]']
#
#  block3_bn3 (BatchNormaliza  (None, 15, 15, 247)          988       ['block3_concat2[0][0]']
#  tion)
#
#  block3_actv3 (Activation)   (None, 15, 15, 247)          0         ['block3_bn3[0][0]']
#
#  block3_pad3 (ZeroPadding2D  (None, 17, 17, 247)          0         ['block3_actv3[0][0]']
#  )
#
#  block3_conv2d3 (Conv2D)     (None, 15, 15, 140)          311360    ['block3_pad3[0][0]']
#
#  block3_concat3 (Concatenat  (None, 15, 15, 387)          0         ['block3_conv2d3[0][0]',
#  e)                                                                  'block3_concat2[0][0]']
#
#  transition3_bn (BatchNorma  (None, 15, 15, 387)          1548      ['block3_concat3[0][0]']
#  lization)
#
#  transition3_actv (Activati  (None, 15, 15, 387)          0         ['transition3_bn[0][0]']
#  on)
#
#  transition3_conv2d (Conv2D  (None, 15, 15, 7)            2716      ['transition3_actv[0][0]']
#  )
#
#  transition3_pool2d (Averag  (None, 7, 7, 7)              0         ['transition3_conv2d[0][0]']
#  ePooling2D)
#
#  global_average_pooling2d (  (None, 7)                    0         ['transition3_pool2d[0][0]']
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 7)                    0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense1 (Dense)              (None, 128)                  1024      ['flatten[0][0]']
#
#  dense1_bn (BatchNormalizat  (None, 128)                  512       ['dense1[0][0]']
#  ion)
#
#  dense1_actv (Activation)    (None, 128)                  0         ['dense1_bn[0][0]']
#
#  dense (Dense)               (None, 5)                    645       ['dense1_actv[0][0]']
#
# ==================================================================================================
# Total params: 726888 (2.77 MB)
# Trainable params: 723624 (2.76 MB)
# Non-trainable params: 3264 (12.75 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=9,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_DenseNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 19s 178ms/step - loss: 1.5268 - accuracy: 0.3717 - val_loss: 3.1429 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 1s 53ms/step - loss: 1.1135 - accuracy: 0.6133 - val_loss: 2.1712 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.9629 - accuracy: 0.6567 - val_loss: 1.6846 - val_accuracy: 0.1667 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.8222 - accuracy: 0.6867 - val_loss: 1.9089 - val_accuracy: 0.1800 - lr: 0.0010
# Epoch 5/100
# 19/18 [==============================] - ETA: 0s - loss: 0.6749 - accuracy: 0.7367
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 18/18 [==============================] - 1s 52ms/step - loss: 0.6749 - accuracy: 0.7367 - val_loss: 2.0028 - val_accuracy: 0.1800 - lr: 0.0010
# Epoch 6/100
# 18/18 [==============================] - 1s 52ms/step - loss: 0.5564 - accuracy: 0.7900 - val_loss: 2.0015 - val_accuracy: 0.1800 - lr: 1.0000e-04
# Epoch 7/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.5412 - accuracy: 0.7933 - val_loss: 2.0782 - val_accuracy: 0.1800 - lr: 1.0000e-04
# Epoch 8/100
# 18/18 [==============================] - 1s 52ms/step - loss: 0.4661 - accuracy: 0.8233 - val_loss: 2.1692 - val_accuracy: 0.3200 - lr: 1.0000e-04
# Epoch 9/100
# 19/18 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8167
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 18/18 [==============================] - 1s 52ms/step - loss: 0.4654 - accuracy: 0.8167 - val_loss: 2.2226 - val_accuracy: 0.3200 - lr: 1.0000e-04
# Epoch 10/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4968 - accuracy: 0.8200 - val_loss: 2.2745 - val_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 11/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4359 - accuracy: 0.8333 - val_loss: 2.3056 - val_accuracy: 0.3667 - lr: 1.0000e-05
# Epoch 12/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4374 - accuracy: 0.8383 - val_loss: 2.2822 - val_accuracy: 0.4267 - lr: 1.0000e-05
# Epoch 13/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4461 - accuracy: 0.8250 - val_loss: 2.2231 - val_accuracy: 0.4333 - lr: 1.0000e-05
# Epoch 14/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4389 - accuracy: 0.8383 - val_loss: 2.1221 - val_accuracy: 0.4267 - lr: 1.0000e-05
# Epoch 15/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4187 - accuracy: 0.8500 - val_loss: 2.0041 - val_accuracy: 0.4467 - lr: 1.0000e-05
# Epoch 16/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4250 - accuracy: 0.8433 - val_loss: 1.8697 - val_accuracy: 0.4400 - lr: 1.0000e-05
# Epoch 17/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4234 - accuracy: 0.8400 - val_loss: 1.7050 - val_accuracy: 0.4533 - lr: 1.0000e-05
# Epoch 18/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4408 - accuracy: 0.8350 - val_loss: 1.5344 - val_accuracy: 0.4667 - lr: 1.0000e-05
# Epoch 19/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4112 - accuracy: 0.8483 - val_loss: 1.3378 - val_accuracy: 0.5267 - lr: 1.0000e-05
# Epoch 20/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4258 - accuracy: 0.8417 - val_loss: 1.1672 - val_accuracy: 0.6000 - lr: 1.0000e-05
# Epoch 21/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4170 - accuracy: 0.8583 - val_loss: 1.0037 - val_accuracy: 0.6600 - lr: 1.0000e-05
# Epoch 22/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4194 - accuracy: 0.8300 - val_loss: 0.8703 - val_accuracy: 0.7133 - lr: 1.0000e-05
# Epoch 23/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4062 - accuracy: 0.8550 - val_loss: 0.7618 - val_accuracy: 0.7400 - lr: 1.0000e-05
# Epoch 24/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.4021 - accuracy: 0.8600 - val_loss: 0.6856 - val_accuracy: 0.7600 - lr: 1.0000e-05
# Epoch 25/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3996 - accuracy: 0.8567 - val_loss: 0.6176 - val_accuracy: 0.7933 - lr: 1.0000e-05
# Epoch 26/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4068 - accuracy: 0.8500 - val_loss: 0.5595 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 27/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4024 - accuracy: 0.8517 - val_loss: 0.5270 - val_accuracy: 0.7800 - lr: 1.0000e-05
# Epoch 28/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3858 - accuracy: 0.8650 - val_loss: 0.4934 - val_accuracy: 0.7933 - lr: 1.0000e-05
# Epoch 29/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3965 - accuracy: 0.8583 - val_loss: 0.4727 - val_accuracy: 0.8067 - lr: 1.0000e-05
# Epoch 30/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3873 - accuracy: 0.8617 - val_loss: 0.4572 - val_accuracy: 0.7933 - lr: 1.0000e-05
# Epoch 31/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.4298 - accuracy: 0.8283 - val_loss: 0.4398 - val_accuracy: 0.8000 - lr: 1.0000e-05
# Epoch 32/100
# 18/18 [==============================] - 1s 57ms/step - loss: 0.3971 - accuracy: 0.8617 - val_loss: 0.4290 - val_accuracy: 0.8067 - lr: 1.0000e-05
# Epoch 33/100
# 18/18 [==============================] - 1s 55ms/step - loss: 0.3898 - accuracy: 0.8467 - val_loss: 0.4132 - val_accuracy: 0.8133 - lr: 1.0000e-05
# Epoch 34/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3977 - accuracy: 0.8517 - val_loss: 0.4081 - val_accuracy: 0.8267 - lr: 1.0000e-05
# Epoch 35/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3799 - accuracy: 0.8667 - val_loss: 0.4041 - val_accuracy: 0.8267 - lr: 1.0000e-05
# Epoch 36/100
# 18/18 [==============================] - 1s 55ms/step - loss: 0.3824 - accuracy: 0.8650 - val_loss: 0.3983 - val_accuracy: 0.8400 - lr: 1.0000e-05
# Epoch 37/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3693 - accuracy: 0.8767 - val_loss: 0.3957 - val_accuracy: 0.8467 - lr: 1.0000e-05
# Epoch 38/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3770 - accuracy: 0.8700 - val_loss: 0.3961 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 39/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3645 - accuracy: 0.8833 - val_loss: 0.3884 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 40/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3723 - accuracy: 0.8867 - val_loss: 0.3907 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 41/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3519 - accuracy: 0.8833 - val_loss: 0.3894 - val_accuracy: 0.8733 - lr: 1.0000e-05
# Epoch 42/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3710 - accuracy: 0.8767 - val_loss: 0.3952 - val_accuracy: 0.8733 - lr: 1.0000e-05
# Epoch 43/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3749 - accuracy: 0.8617 - val_loss: 0.3939 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 44/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3478 - accuracy: 0.8617 - val_loss: 0.3894 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 45/100
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3657 - accuracy: 0.8783 - val_loss: 0.3863 - val_accuracy: 0.8867 - lr: 1.0000e-05
# Epoch 46/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3527 - accuracy: 0.8833 - val_loss: 0.3833 - val_accuracy: 0.8733 - lr: 1.0000e-05
# Epoch 47/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3434 - accuracy: 0.9017 - val_loss: 0.3807 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 48/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3616 - accuracy: 0.8733 - val_loss: 0.3792 - val_accuracy: 0.8867 - lr: 1.0000e-05
# Epoch 49/100
# 19/18 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.9033
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3370 - accuracy: 0.9033 - val_loss: 0.3705 - val_accuracy: 0.8800 - lr: 1.0000e-05
# Epoch 50/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3419 - accuracy: 0.8817 - val_loss: 0.3729 - val_accuracy: 0.8733 - lr: 1.0000e-06
# Epoch 51/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3374 - accuracy: 0.9000 - val_loss: 0.3749 - val_accuracy: 0.8733 - lr: 1.0000e-06
# Epoch 52/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3299 - accuracy: 0.9133 - val_loss: 0.3762 - val_accuracy: 0.8733 - lr: 1.0000e-06
# Epoch 53/100
# 19/18 [==============================] - ETA: 0s - loss: 0.3461 - accuracy: 0.8800
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 18/18 [==============================] - 1s 54ms/step - loss: 0.3461 - accuracy: 0.8800 - val_loss: 0.3788 - val_accuracy: 0.8667 - lr: 1.0000e-06
# Epoch 54/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3460 - accuracy: 0.8850 - val_loss: 0.3808 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 55/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3325 - accuracy: 0.9017 - val_loss: 0.3835 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 56/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3315 - accuracy: 0.9017 - val_loss: 0.3858 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 57/100
# 19/18 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.8800
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-07.
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3535 - accuracy: 0.8800 - val_loss: 0.3875 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 58/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3406 - accuracy: 0.8833 - val_loss: 0.3890 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 59/100
# 18/18 [==============================] - 1s 53ms/step - loss: 0.3679 - accuracy: 0.8767 - val_loss: 0.3903 - val_accuracy: 0.8600 - lr: 1.0000e-07
# Epoch 60/100
# 19/18 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8967Epoch 59: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 44.
# 18/18 [==============================] - 1s 57ms/step - loss: 0.3413 - accuracy: 0.8967 - val_loss: 0.3914 - val_accuracy: 0.8600 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_DenseNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.526758  0.371667  3.142867      0.340000  1.000000e-03
# 1   1.113466  0.613333  2.171154      0.300000  1.000000e-03
# 2   0.962928  0.656667  1.684611      0.166667  1.000000e-03
# 3   0.822207  0.686667  1.908929      0.180000  1.000000e-03
# 4   0.674945  0.736667  2.002776      0.180000  1.000000e-03
# 5   0.556433  0.790000  2.001481      0.180000  1.000000e-04
# 6   0.541167  0.793333  2.078212      0.180000  1.000000e-04
# 7   0.466143  0.823333  2.169175      0.320000  1.000000e-04
# 8   0.465442  0.816667  2.222553      0.320000  1.000000e-04
# 9   0.496827  0.820000  2.274475      0.333333  1.000000e-05
# 10  0.435896  0.833333  2.305580      0.366667  1.000000e-05
# 11  0.437395  0.838333  2.282177      0.426667  1.000000e-05
# 12  0.446138  0.825000  2.223079      0.433333  1.000000e-05
# 13  0.438875  0.838333  2.122133      0.426667  1.000000e-05
# 14  0.418672  0.850000  2.004136      0.446667  1.000000e-05
# 15  0.424972  0.843333  1.869660      0.440000  1.000000e-05
# 16  0.423357  0.840000  1.705035      0.453333  1.000000e-05
# 17  0.440796  0.835000  1.534371      0.466667  1.000000e-05
# 18  0.411192  0.848333  1.337792      0.526667  1.000000e-05
# 19  0.425753  0.841667  1.167163      0.600000  1.000000e-05
# 20  0.417023  0.858333  1.003724      0.660000  1.000000e-05
# 21  0.419412  0.830000  0.870320      0.713333  1.000000e-05
# 22  0.406178  0.855000  0.761781      0.740000  1.000000e-05
# 23  0.402058  0.860000  0.685618      0.760000  1.000000e-05
# 24  0.399584  0.856667  0.617552      0.793333  1.000000e-05
# 25  0.406761  0.850000  0.559455      0.780000  1.000000e-05
# 26  0.402396  0.851667  0.527007      0.780000  1.000000e-05
# 27  0.385798  0.865000  0.493380      0.793333  1.000000e-05
# 28  0.396536  0.858333  0.472675      0.806667  1.000000e-05
# 29  0.387261  0.861667  0.457246      0.793333  1.000000e-05
# 30  0.429750  0.828333  0.439806      0.800000  1.000000e-05
# 31  0.397057  0.861667  0.429033      0.806667  1.000000e-05
# 32  0.389806  0.846667  0.413186      0.813333  1.000000e-05
# 33  0.397695  0.851667  0.408119      0.826667  1.000000e-05
# 34  0.379931  0.866667  0.404052      0.826667  1.000000e-05
# 35  0.382442  0.865000  0.398326      0.840000  1.000000e-05
# 36  0.369266  0.876667  0.395660      0.846667  1.000000e-05
# 37  0.376989  0.870000  0.396110      0.866667  1.000000e-05
# 38  0.364536  0.883333  0.388439      0.866667  1.000000e-05
# 39  0.372331  0.886667  0.390712      0.866667  1.000000e-05
# 40  0.351891  0.883333  0.389417      0.873333  1.000000e-05
# 41  0.371040  0.876667  0.395200      0.873333  1.000000e-05
# 42  0.374933  0.861667  0.393860      0.866667  1.000000e-05
# 43  0.347820  0.861667  0.389379      0.866667  1.000000e-05
# 44  0.365677  0.878333  0.386286      0.886667  1.000000e-05
# 45  0.352716  0.883333  0.383303      0.873333  1.000000e-05
# 46  0.343394  0.901667  0.380694      0.880000  1.000000e-05
# 47  0.361611  0.873333  0.379169      0.886667  1.000000e-05
# 48  0.336962  0.903333  0.370530      0.880000  1.000000e-05
# 49  0.341912  0.881667  0.372863      0.873333  1.000000e-06
# 50  0.337363  0.900000  0.374905      0.873333  1.000000e-06
# 51  0.329888  0.913333  0.376246      0.873333  1.000000e-06
# 52  0.346108  0.880000  0.378845      0.866667  1.000000e-06
# 53  0.345978  0.885000  0.380840      0.860000  1.000000e-07
# 54  0.332489  0.901667  0.383533      0.860000  1.000000e-07
# 55  0.331542  0.901667  0.385752      0.860000  1.000000e-07
# 56  0.353549  0.880000  0.387464      0.860000  1.000000e-07
# 57  0.340649  0.883333  0.388958      0.860000  1.000000e-07
# 58  0.367909  0.876667  0.390342      0.860000  1.000000e-07
# 59  0.341301  0.896667  0.391414      0.860000  1.000000e-07

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['accuracy'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['loss'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Sadness', 4: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 19/19 - 0s - loss: 0.3193 - accuracy: 0.9283 - 289ms/epoch - 15ms/step
#
# train Accuracy: 0.9283333420753479
# 5/5 - 0s - loss: 0.3863 - accuracy: 0.8867 - 87ms/epoch - 17ms/step
#
# Test Accuracy: 0.8866666555404663
# 5/5 [==============================] - 0s 13ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       0.98      0.98      0.98        50
#         Fear       0.70      0.47      0.56        15
#        Happy       0.84      1.00      0.92        27
#      Sadness       0.82      0.53      0.64        17
#     Surprise       0.87      1.00      0.93        41
#
#     accuracy                           0.89       150
#    macro avg       0.84      0.80      0.81       150
# weighted avg       0.88      0.89      0.87       150

# %%
# Visualize some predictions
pyplot.figure(figsize=(10, 10))
for i in range(9):
    ax = pyplot.subplot(3, 3, i + 1)
    pyplot.imshow(X_test[i])
    pyplot.title(label_to_text[predicted_labels[i]])
    pyplot.axis("off")

pyplot.show()
