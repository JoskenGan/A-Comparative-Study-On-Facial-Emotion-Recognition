# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-02 14:07:54.991526: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 14:07:54.991642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 14:07:55.171269: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (75, 75))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (75,75,3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 64
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 75, 75, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
# https://www.tensorflow.org/guide/keras/transfer_learning#train_the_top_layer

# Load pre-trained DenseNet121 model
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build model on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 2, 2, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,333,703 (27.98 MB)
#  Trainable params: 296,199 (1.13 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=15)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 1:47:02 34s/step - accuracy: 0.0781 - loss: 17.7590
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712067059.992019      91 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712067060.064984      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  37/191 ━━━━━━━━━━━━━━━━━━━━ 1:25 555ms/step - accuracy: 0.2380 - loss: 8.2600
# W0000 00:00:1712067079.883379      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.2908 - loss: 4.2027
# W0000 00:00:1712067112.771707      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1712067126.223741      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 100s 349ms/step - accuracy: 0.2911 - loss: 4.1937 - val_accuracy: 0.3990 - val_loss: 1.6171 - learning_rate: 0.0010
# Epoch 2/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.2656 - loss: 1.8645
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2656 - loss: 1.8645 - val_accuracy: 0.4016 - val_loss: 1.6144 - learning_rate: 0.0010
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.3802 - loss: 1.6538 - val_accuracy: 0.3993 - val_loss: 1.5985 - learning_rate: 0.0010
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4531 - loss: 1.7815 - val_accuracy: 0.3993 - val_loss: 1.5997 - learning_rate: 0.0010
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.3919 - loss: 1.6193 - val_accuracy: 0.4162 - val_loss: 1.5676 - learning_rate: 0.0010
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4062 - loss: 1.7064 - val_accuracy: 0.4162 - val_loss: 1.5647 - learning_rate: 0.0010
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4176 - loss: 1.5586 - val_accuracy: 0.4071 - val_loss: 1.5382 - learning_rate: 0.0010
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3594 - loss: 1.6199 - val_accuracy: 0.4058 - val_loss: 1.5381 - learning_rate: 0.0010
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - accuracy: 0.4109 - loss: 1.5589 - val_accuracy: 0.4267 - val_loss: 1.5178 - learning_rate: 0.0010
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5312 - loss: 1.2233 - val_accuracy: 0.4280 - val_loss: 1.5174 - learning_rate: 0.0010
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.4190 - loss: 1.5425 - val_accuracy: 0.4133 - val_loss: 1.5406 - learning_rate: 0.0010
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4844 - loss: 1.4448 - val_accuracy: 0.4172 - val_loss: 1.5367 - learning_rate: 0.0010
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - accuracy: 0.4125 - loss: 1.5464 - val_accuracy: 0.4250 - val_loss: 1.5111 - learning_rate: 0.0010
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4375 - loss: 1.5808 - val_accuracy: 0.4293 - val_loss: 1.5122 - learning_rate: 0.0010
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.4281 - loss: 1.5179 - val_accuracy: 0.4449 - val_loss: 1.4909 - learning_rate: 0.0010
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.4688 - loss: 1.4671 - val_accuracy: 0.4495 - val_loss: 1.4898 - learning_rate: 0.0010
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4170 - loss: 1.5386 - val_accuracy: 0.4348 - val_loss: 1.4935 - learning_rate: 0.0010
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4531 - loss: 1.5435 - val_accuracy: 0.4312 - val_loss: 1.4927 - learning_rate: 0.0010
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4385 - loss: 1.4989 - val_accuracy: 0.4478 - val_loss: 1.4669 - learning_rate: 0.0010
# Epoch 20/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.4688 - loss: 1.5039
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4688 - loss: 1.5039 - val_accuracy: 0.4488 - val_loss: 1.4661 - learning_rate: 0.0010
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 111ms/step - accuracy: 0.4477 - loss: 1.4630 - val_accuracy: 0.4619 - val_loss: 1.4529 - learning_rate: 1.0000e-04
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4844 - loss: 1.5496 - val_accuracy: 0.4619 - val_loss: 1.4526 - learning_rate: 1.0000e-04
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.4559 - loss: 1.4499 - val_accuracy: 0.4560 - val_loss: 1.4471 - learning_rate: 1.0000e-04
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5156 - loss: 1.3499 - val_accuracy: 0.4573 - val_loss: 1.4471 - learning_rate: 1.0000e-04
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4545 - loss: 1.4555
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.4545 - loss: 1.4555 - val_accuracy: 0.4612 - val_loss: 1.4451 - learning_rate: 1.0000e-04
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5156 - loss: 1.3755 - val_accuracy: 0.4615 - val_loss: 1.4451 - learning_rate: 1.0000e-05
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4556 - loss: 1.4383 - val_accuracy: 0.4651 - val_loss: 1.4446 - learning_rate: 1.0000e-05
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3281 - loss: 1.6059 - val_accuracy: 0.4651 - val_loss: 1.4446 - learning_rate: 1.0000e-05
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4516 - loss: 1.4611 - val_accuracy: 0.4658 - val_loss: 1.4439 - learning_rate: 1.0000e-05
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4531 - loss: 1.4227 - val_accuracy: 0.4658 - val_loss: 1.4438 - learning_rate: 1.0000e-05
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - accuracy: 0.4643 - loss: 1.4434 - val_accuracy: 0.4641 - val_loss: 1.4434 - learning_rate: 1.0000e-05
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5469 - loss: 1.2863 - val_accuracy: 0.4641 - val_loss: 1.4434 - learning_rate: 1.0000e-05
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4604 - loss: 1.4508
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.4604 - loss: 1.4507 - val_accuracy: 0.4658 - val_loss: 1.4430 - learning_rate: 1.0000e-05
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4062 - loss: 1.5992 - val_accuracy: 0.4658 - val_loss: 1.4430 - learning_rate: 1.0000e-06
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - accuracy: 0.4578 - loss: 1.4447 - val_accuracy: 0.4654 - val_loss: 1.4431 - learning_rate: 1.0000e-06
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4375 - loss: 1.4522 - val_accuracy: 0.4654 - val_loss: 1.4431 - learning_rate: 1.0000e-06
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4601 - loss: 1.4266
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - accuracy: 0.4600 - loss: 1.4267 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-06
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4062 - loss: 1.4517 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-07
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 23s 117ms/step - accuracy: 0.4579 - loss: 1.4437 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-07
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4688 - loss: 1.3490 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-07
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4587 - loss: 1.4410
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.4587 - loss: 1.4410 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-07
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4062 - loss: 1.5298 - val_accuracy: 0.4651 - val_loss: 1.4430 - learning_rate: 1.0000e-07
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.4629 - loss: 1.4366 - val_accuracy: 0.4654 - val_loss: 1.4429 - learning_rate: 1.0000e-07
# Epoch 44/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.5000 - loss: 1.3546Epoch 43: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 28.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5000 - loss: 1.3546 - val_accuracy: 0.4654 - val_loss: 1.4429 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.336692  2.474202      0.398957  1.617067   1.000000e-03
# 1   0.265625  1.864505      0.401565  1.614404   1.000000e-03
# 2   0.385353  1.639398      0.399283  1.598524   1.000000e-03
# 3   0.453125  1.781481      0.399283  1.599728   1.000000e-03
# 4   0.396576  1.606045      0.416232  1.567551   1.000000e-03
# 5   0.406250  1.706364      0.416232  1.564704   1.000000e-03
# 6   0.407717  1.571400      0.407106  1.538246   1.000000e-03
# 7   0.359375  1.619878      0.405802  1.538103   1.000000e-03
# 8   0.414025  1.559315      0.426662  1.517814   1.000000e-03
# 9   0.531250  1.223260      0.427966  1.517386   1.000000e-03
# 10  0.417302  1.539805      0.413299  1.540648   1.000000e-03
# 11  0.484375  1.444775      0.417210  1.536717   1.000000e-03
# 12  0.417711  1.535702      0.425033  1.511149   1.000000e-03
# 13  0.437500  1.580781      0.429270  1.512241   1.000000e-03
# 14  0.428688  1.515603      0.444915  1.490852   1.000000e-03
# 15  0.468750  1.467064      0.449478  1.489762   1.000000e-03
# 16  0.424838  1.517375      0.434811  1.493468   1.000000e-03
# 17  0.453125  1.543543      0.431226  1.492731   1.000000e-03
# 18  0.431228  1.504476      0.447849  1.466910   1.000000e-03
# 19  0.468750  1.503941      0.448827  1.466134   1.000000e-03
# 20  0.446301  1.472674      0.461864  1.452859   1.000000e-04
# 21  0.484375  1.549580      0.461864  1.452620   1.000000e-04
# 22  0.452773  1.460237      0.455997  1.447052   1.000000e-04
# 23  0.515625  1.349946      0.457301  1.447084   1.000000e-04
# 24  0.455968  1.454989      0.461213  1.445082   1.000000e-04
# 25  0.515625  1.375483      0.461538  1.445111   1.000000e-05
# 26  0.451380  1.449914      0.465124  1.444565   1.000000e-05
# 27  0.328125  1.605868      0.465124  1.444577   1.000000e-05
# 28  0.455394  1.449896      0.465776  1.443858   1.000000e-05
# 29  0.453125  1.422749      0.465776  1.443828   1.000000e-05
# 30  0.458671  1.447207      0.464146  1.443398   1.000000e-05
# 31  0.546875  1.286285      0.464146  1.443393   1.000000e-05
# 32  0.457606  1.446004      0.465776  1.443028   1.000000e-05
# 33  0.406250  1.599151      0.465776  1.443025   1.000000e-06
# 34  0.456623  1.449581      0.465450  1.443115   1.000000e-06
# 35  0.437500  1.452180      0.465450  1.443114   1.000000e-06
# 36  0.452445  1.447641      0.465124  1.442971   1.000000e-06
# 37  0.406250  1.451680      0.465124  1.442972   1.000000e-07
# 38  0.456377  1.447554      0.465124  1.442961   1.000000e-07
# 39  0.468750  1.349030      0.465124  1.442960   1.000000e-07
# 40  0.455149  1.444502      0.465124  1.442971   1.000000e-07
# 41  0.406250  1.529762      0.465124  1.442971   1.000000e-07
# 42  0.463996  1.445730      0.465450  1.442947   1.000000e-07
# 43  0.500000  1.354612      0.465450  1.442946   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 2, 2, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,333,703 (27.98 MB)
#  Trainable params: 7,250,055 (27.66 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 7:24:12 140s/step - accuracy: 0.3594 - loss: 1.6408
# W0000 00:00:1712067763.002783      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 154/191 ━━━━━━━━━━━━━━━━━━━━ 25s 682ms/step - accuracy: 0.4213 - loss: 1.5569
# W0000 00:00:1712067867.434248      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.4378 - loss: 1.5189
# W0000 00:00:1712067881.745825      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 266s 662ms/step - accuracy: 0.4382 - loss: 1.5179 - val_accuracy: 0.6389 - val_loss: 1.0463 - learning_rate: 1.0000e-04
# Epoch 2/100
# W0000 00:00:1712067888.743842      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 26s 138ms/step - accuracy: 0.6562 - loss: 1.0143
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6562 - loss: 1.0143 - val_accuracy: 0.6444 - val_loss: 1.0460 - learning_rate: 1.0000e-04
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.6676 - loss: 0.9605 - val_accuracy: 0.6845 - val_loss: 0.8882 - learning_rate: 1.0000e-04
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6719 - loss: 0.8405 - val_accuracy: 0.6855 - val_loss: 0.8841 - learning_rate: 1.0000e-04
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - accuracy: 0.7461 - loss: 0.7451 - val_accuracy: 0.7298 - val_loss: 0.7557 - learning_rate: 1.0000e-04
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7031 - loss: 0.9704 - val_accuracy: 0.7262 - val_loss: 0.7636 - learning_rate: 1.0000e-04
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 24s 122ms/step - accuracy: 0.7830 - loss: 0.6190 - val_accuracy: 0.7696 - val_loss: 0.6671 - learning_rate: 1.0000e-04
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7812 - loss: 0.6217 - val_accuracy: 0.7692 - val_loss: 0.6716 - learning_rate: 1.0000e-04
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.8282 - loss: 0.5051 - val_accuracy: 0.7686 - val_loss: 0.6854 - learning_rate: 1.0000e-04
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8750 - loss: 0.4175 - val_accuracy: 0.7669 - val_loss: 0.6884 - learning_rate: 1.0000e-04
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 24s 124ms/step - accuracy: 0.8361 - loss: 0.4773 - val_accuracy: 0.7999 - val_loss: 0.6091 - learning_rate: 1.0000e-04
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7812 - loss: 0.5947 - val_accuracy: 0.8025 - val_loss: 0.6056 - learning_rate: 1.0000e-04
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 24s 123ms/step - accuracy: 0.8615 - loss: 0.4009 - val_accuracy: 0.7878 - val_loss: 0.6293 - learning_rate: 1.0000e-04
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.2865 - val_accuracy: 0.7914 - val_loss: 0.6255 - learning_rate: 1.0000e-04
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 125ms/step - accuracy: 0.8765 - loss: 0.3505 - val_accuracy: 0.7855 - val_loss: 0.6749 - learning_rate: 1.0000e-04
# Epoch 16/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.8594 - loss: 0.4655
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.4655 - val_accuracy: 0.7803 - val_loss: 0.6802 - learning_rate: 1.0000e-04
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - accuracy: 0.9020 - loss: 0.2927 - val_accuracy: 0.8123 - val_loss: 0.5729 - learning_rate: 1.0000e-05
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9219 - loss: 0.2288 - val_accuracy: 0.8132 - val_loss: 0.5736 - learning_rate: 1.0000e-05
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.9140 - loss: 0.2492 - val_accuracy: 0.8201 - val_loss: 0.5711 - learning_rate: 1.0000e-05
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.2434 - val_accuracy: 0.8198 - val_loss: 0.5717 - learning_rate: 1.0000e-05
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.9233 - loss: 0.2232 - val_accuracy: 0.8149 - val_loss: 0.5829 - learning_rate: 1.0000e-05
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9219 - loss: 0.2918 - val_accuracy: 0.8142 - val_loss: 0.5831 - learning_rate: 1.0000e-05
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9248 - loss: 0.2152
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.9248 - loss: 0.2152 - val_accuracy: 0.8191 - val_loss: 0.5862 - learning_rate: 1.0000e-05
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9688 - loss: 0.0930 - val_accuracy: 0.8191 - val_loss: 0.5864 - learning_rate: 1.0000e-06
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 24s 123ms/step - accuracy: 0.9319 - loss: 0.2040 - val_accuracy: 0.8152 - val_loss: 0.5931 - learning_rate: 1.0000e-06
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9531 - loss: 0.1651 - val_accuracy: 0.8149 - val_loss: 0.5936 - learning_rate: 1.0000e-06
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9319 - loss: 0.2045
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 124ms/step - accuracy: 0.9319 - loss: 0.2045 - val_accuracy: 0.8145 - val_loss: 0.5906 - learning_rate: 1.0000e-06
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 0.0736 - val_accuracy: 0.8155 - val_loss: 0.5903 - learning_rate: 1.0000e-07
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 129ms/step - accuracy: 0.9336 - loss: 0.2071 - val_accuracy: 0.8149 - val_loss: 0.5894 - learning_rate: 1.0000e-07
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9531 - loss: 0.1332 - val_accuracy: 0.8152 - val_loss: 0.5895 - learning_rate: 1.0000e-07
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.9340 - loss: 0.2036 - val_accuracy: 0.8158 - val_loss: 0.5911 - learning_rate: 1.0000e-07
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.2496 - val_accuracy: 0.8152 - val_loss: 0.5909 - learning_rate: 1.0000e-07
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 25s 126ms/step - accuracy: 0.9377 - loss: 0.1817 - val_accuracy: 0.8152 - val_loss: 0.5912 - learning_rate: 1.0000e-07
# Epoch 34/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.9688 - loss: 0.0944Epoch 33: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 18.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9688 - loss: 0.0944 - val_accuracy: 0.8155 - val_loss: 0.5915 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.517900  1.334899      0.638853  1.046275   1.000000e-04
# 1   0.656250  1.014325      0.644394  1.046029   1.000000e-04
# 2   0.684935  0.917632      0.684485  0.888181   1.000000e-04
# 3   0.671875  0.840519      0.685463  0.884086   1.000000e-04
# 4   0.754157  0.723396      0.729791  0.755702   1.000000e-04
# 5   0.703125  0.970446      0.726206  0.763618   1.000000e-04
# 6   0.786926  0.617174      0.769557  0.667102   1.000000e-04
# 7   0.781250  0.621660      0.769231  0.671596   1.000000e-04
# 8   0.820185  0.530457      0.768579  0.685405   1.000000e-04
# 9   0.875000  0.417520      0.766949  0.688443   1.000000e-04
# 10  0.838535  0.472238      0.799870  0.609052   1.000000e-04
# 11  0.781250  0.594660      0.802477  0.605620   1.000000e-04
# 12  0.857705  0.410168      0.787810  0.629251   1.000000e-04
# 13  0.859375  0.286493      0.791395  0.625549   1.000000e-04
# 14  0.873351  0.363508      0.785528  0.674914   1.000000e-04
# 15  0.859375  0.465488      0.780313  0.680162   1.000000e-04
# 16  0.905300  0.278209      0.812256  0.572852   1.000000e-05
# 17  0.921875  0.228789      0.813233  0.573586   1.000000e-05
# 18  0.915540  0.251254      0.820078  0.571093   1.000000e-05
# 19  0.890625  0.243415      0.819752  0.571730   1.000000e-05
# 20  0.925780  0.218818      0.814863  0.582875   1.000000e-05
# 21  0.921875  0.291768      0.814211  0.583136   1.000000e-05
# 22  0.925944  0.217310      0.819100  0.586212   1.000000e-05
# 23  0.968750  0.093001      0.819100  0.586399   1.000000e-06
# 24  0.932088  0.203052      0.815189  0.593117   1.000000e-06
# 25  0.953125  0.165054      0.814863  0.593598   1.000000e-06
# 26  0.932334  0.200490      0.814537  0.590558   1.000000e-06
# 27  1.000000  0.073636      0.815515  0.590293   1.000000e-07
# 28  0.933481  0.201812      0.814863  0.589417   1.000000e-07
# 29  0.953125  0.133155      0.815189  0.589462   1.000000e-07
# 30  0.935447  0.200265      0.815841  0.591099   1.000000e-07
# 31  0.890625  0.249583      0.815189  0.590888   1.000000e-07
# 32  0.934464  0.192372      0.815189  0.591235   1.000000e-07
# 33  0.968750  0.094360      0.815515  0.591470   1.000000e-07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 18s - 48ms/step - accuracy: 0.9480 - loss: 0.1618
# W0000 00:00:1712068335.189200      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.9480075240135193
# 96/96 - 2s - 18ms/step - accuracy: 0.8201 - loss: 0.5711
#
# Test Accuracy: 0.8200782537460327
#  7/96 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# W0000 00:00:1712068347.832147      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 22s 124ms/step
# W0000 00:00:1712068359.640939      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.86      0.81      0.84       329
#      disgust       0.59      0.58      0.59        74
#         fear       0.74      0.77      0.75       162
#        happy       0.79      0.76      0.78       680
#      neutral       0.72      0.85      0.78       478
#          sad       0.56      0.39      0.46       160
#     surprise       0.92      0.92      0.92      1185
#
#     accuracy                           0.82      3068
#    macro avg       0.74      0.73      0.73      3068
# weighted avg       0.82      0.82      0.82      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
