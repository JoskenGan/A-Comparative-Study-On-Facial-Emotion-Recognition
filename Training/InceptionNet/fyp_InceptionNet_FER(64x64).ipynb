# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, MaxPool2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feraligned/feraligned/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Fear has 552 number of images
# Angry has 633 number of images
# Neutral has 863 number of images
# Sadness has 904 number of images
# Happy has 1577 number of images
#
# total images are 4529

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((4529, 64, 64, 1),
#  (4529, 5),
#  {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3623, 64, 64, 1), (906, 64, 64, 1), (3623, 5), (906, 5))

# %%
def inception_block(X,
                    filters_1x1: int,
                    filters_3x3_reduce: int,
                    filters_3x3: int,
                    filters_5x5_reduce: int,
                    filters_5x5: int,
                    filters_pool_proj: int,
                    block_name: str):

    conv_1x1 = Conv2D(
            filters=filters_1x1,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_1x1",
        )(X)

    conv_3x3_reduce = Conv2D(
            filters=filters_3x3_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3_reduce",
        )(X)
    conv_3x3 = Conv2D(
            filters=filters_3x3,
            kernel_size=(3,3),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3",
        )(conv_3x3_reduce)

    conv_5x5_reduce = Conv2D(
            filters=filters_5x5_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5_reduce",
        )(X)
    conv_5x5 = Conv2D(
            filters=filters_5x5,
            kernel_size=(5,5),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5",
        )(conv_5x5_reduce)

    pool_proj = MaxPool2D(
        pool_size=(3, 3),
        strides=(1, 1),
        padding='same',
        name=f"incepblock{block_name}_maxpool",
    )(X)
    conv_after_pool = Conv2D(
            filters=filters_pool_proj,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_afterpool",
        )(pool_proj)

    concated = concatenate([conv_1x1, conv_3x3, conv_5x5, conv_after_pool], axis=3, name=f"incepblock{block_name}_concat")
    return concated

# %%
def auxiliary_block(X, out_shape: int, block_id: int):
    X = AveragePooling2D(
        pool_size=(3,3),
        strides=(1,1),
        padding='valid',
        name=f"auxblock{block_id}_avgpool",
    )(X)

    X = Conv2D(
            filters=128,
            kernel_size=(1,1),
            strides=(1,1),
            padding='same',
            activation='relu',
            name=f"auxblock{block_id}_conv2d",
    )(X)

    X = Flatten(name=f"auxblock{block_id}_flatten",)(X)

    X = Dense(units=128, activation='relu', name=f"auxblock{block_id}_dense1",)(X)

    X = Dropout(0.25, name=f"auxblock{block_id}_dropout",)(X)

    X = Dense(units=out_shape, activation='softmax', name=f"auxblock{block_id}_outlayer",)(X)
    return X

# %%
def InceptionNet(in_shape, out_shape, show_summary=False):
    "shallow inception-net without auxiliary layers"

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
            filters=32,
            kernel_size=(3,3),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(model_in)
    X = Conv2D(
            filters=64,
            kernel_size=(1,1),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(X)

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(X,
            filters_1x1=64,
            filters_3x3_reduce=96,
            filters_3x3=128,
            filters_5x5_reduce=16,
            filters_5x5=32,
            filters_pool_proj=32,
            block_name='1a'
    )
    X = inception_block(X,
            filters_1x1=128,
            filters_3x3_reduce=128,
            filters_3x3=192,
            filters_5x5_reduce=32,
            filters_5x5=96,
            filters_pool_proj=64,
            block_name='1b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=192,
        filters_3x3_reduce=96,
        filters_3x3=208,
        filters_5x5_reduce=16,
        filters_5x5=48,
        filters_pool_proj=64,
        block_name='2a'
    )
    X = inception_block(
        X,
        filters_1x1=160,
        filters_3x3_reduce=112,
        filters_3x3=224,
        filters_5x5_reduce=24,
        filters_5x5=64,
        filters_pool_proj=64,
        block_name='2b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=256,
        filters_3x3_reduce=160,
        filters_3x3=320,
        filters_5x5_reduce=32,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3a'
    )
    X = inception_block(
        X,
        filters_1x1=384,
        filters_3x3_reduce=192,
        filters_3x3=384,
        filters_5x5_reduce=48,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3b'
    )

    X = GlobalAveragePooling2D()(X)

    X = Dense(128, activation='relu')(X)
    X = Dropout(0.25)(X)

    model_out = Dense(out_shape, activation="softmax", name="out_layer")(X)

    model = Model(model_in, model_out, name="InceptionNet")

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = InceptionNet(INPUT_SHAPE, NUM_CLASSES, show_summary=True)
# Out:
# Model: "InceptionNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  in_layer (InputLayer)       [(None, 64, 64, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 32)           320       ['in_layer[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)           2112      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 64)           0         ['conv2d_1[0][0]']
#  D)
#
#  incepblock1a_conv_3x3_redu  (None, 32, 32, 96)           6240      ['max_pooling2d[0][0]']
#  ce (Conv2D)
#
#  incepblock1a_conv_5x5_redu  (None, 32, 32, 16)           1040      ['max_pooling2d[0][0]']
#  ce (Conv2D)
#
#  incepblock1a_maxpool (MaxP  (None, 32, 32, 64)           0         ['max_pooling2d[0][0]']
#  ooling2D)
#
#  incepblock1a_conv_1x1 (Con  (None, 32, 32, 64)           4160      ['max_pooling2d[0][0]']
#  v2D)
#
#  incepblock1a_conv_3x3 (Con  (None, 32, 32, 128)          110720    ['incepblock1a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1a_conv_5x5 (Con  (None, 32, 32, 32)           12832     ['incepblock1a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1a_conv_afterpoo  (None, 32, 32, 32)           2080      ['incepblock1a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock1a_concat (Conca  (None, 32, 32, 256)          0         ['incepblock1a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock1a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock1a_conv_5x5[0][0]'
#                                                                     , 'incepblock1a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock1b_conv_3x3_redu  (None, 32, 32, 128)          32896     ['incepblock1a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock1b_conv_5x5_redu  (None, 32, 32, 32)           8224      ['incepblock1a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock1b_maxpool (MaxP  (None, 32, 32, 256)          0         ['incepblock1a_concat[0][0]']
#  ooling2D)
#
#  incepblock1b_conv_1x1 (Con  (None, 32, 32, 128)          32896     ['incepblock1a_concat[0][0]']
#  v2D)
#
#  incepblock1b_conv_3x3 (Con  (None, 32, 32, 192)          221376    ['incepblock1b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1b_conv_5x5 (Con  (None, 32, 32, 96)           76896     ['incepblock1b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1b_conv_afterpoo  (None, 32, 32, 64)           16448     ['incepblock1b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock1b_concat (Conca  (None, 32, 32, 480)          0         ['incepblock1b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock1b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock1b_conv_5x5[0][0]'
#                                                                     , 'incepblock1b_conv_afterpool
#                                                                     [0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 480)          0         ['incepblock1b_concat[0][0]']
#  g2D)
#
#  incepblock2a_conv_3x3_redu  (None, 16, 16, 96)           46176     ['max_pooling2d_1[0][0]']
#  ce (Conv2D)
#
#  incepblock2a_conv_5x5_redu  (None, 16, 16, 16)           7696      ['max_pooling2d_1[0][0]']
#  ce (Conv2D)
#
#  incepblock2a_maxpool (MaxP  (None, 16, 16, 480)          0         ['max_pooling2d_1[0][0]']
#  ooling2D)
#
#  incepblock2a_conv_1x1 (Con  (None, 16, 16, 192)          92352     ['max_pooling2d_1[0][0]']
#  v2D)
#
#  incepblock2a_conv_3x3 (Con  (None, 16, 16, 208)          179920    ['incepblock2a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2a_conv_5x5 (Con  (None, 16, 16, 48)           19248     ['incepblock2a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2a_conv_afterpoo  (None, 16, 16, 64)           30784     ['incepblock2a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock2a_concat (Conca  (None, 16, 16, 512)          0         ['incepblock2a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock2a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock2a_conv_5x5[0][0]'
#                                                                     , 'incepblock2a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock2b_conv_3x3_redu  (None, 16, 16, 112)          57456     ['incepblock2a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock2b_conv_5x5_redu  (None, 16, 16, 24)           12312     ['incepblock2a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock2b_maxpool (MaxP  (None, 16, 16, 512)          0         ['incepblock2a_concat[0][0]']
#  ooling2D)
#
#  incepblock2b_conv_1x1 (Con  (None, 16, 16, 160)          82080     ['incepblock2a_concat[0][0]']
#  v2D)
#
#  incepblock2b_conv_3x3 (Con  (None, 16, 16, 224)          226016    ['incepblock2b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2b_conv_5x5 (Con  (None, 16, 16, 64)           38464     ['incepblock2b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2b_conv_afterpoo  (None, 16, 16, 64)           32832     ['incepblock2b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock2b_concat (Conca  (None, 16, 16, 512)          0         ['incepblock2b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock2b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock2b_conv_5x5[0][0]'
#                                                                     , 'incepblock2b_conv_afterpool
#                                                                     [0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 512)            0         ['incepblock2b_concat[0][0]']
#  g2D)
#
#  incepblock3a_conv_3x3_redu  (None, 8, 8, 160)            82080     ['max_pooling2d_2[0][0]']
#  ce (Conv2D)
#
#  incepblock3a_conv_5x5_redu  (None, 8, 8, 32)             16416     ['max_pooling2d_2[0][0]']
#  ce (Conv2D)
#
#  incepblock3a_maxpool (MaxP  (None, 8, 8, 512)            0         ['max_pooling2d_2[0][0]']
#  ooling2D)
#
#  incepblock3a_conv_1x1 (Con  (None, 8, 8, 256)            131328    ['max_pooling2d_2[0][0]']
#  v2D)
#
#  incepblock3a_conv_3x3 (Con  (None, 8, 8, 320)            461120    ['incepblock3a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3a_conv_5x5 (Con  (None, 8, 8, 128)            102528    ['incepblock3a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3a_conv_afterpoo  (None, 8, 8, 128)            65664     ['incepblock3a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock3a_concat (Conca  (None, 8, 8, 832)            0         ['incepblock3a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock3a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock3a_conv_5x5[0][0]'
#                                                                     , 'incepblock3a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock3b_conv_3x3_redu  (None, 8, 8, 192)            159936    ['incepblock3a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock3b_conv_5x5_redu  (None, 8, 8, 48)             39984     ['incepblock3a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock3b_maxpool (MaxP  (None, 8, 8, 832)            0         ['incepblock3a_concat[0][0]']
#  ooling2D)
#
#  incepblock3b_conv_1x1 (Con  (None, 8, 8, 384)            319872    ['incepblock3a_concat[0][0]']
#  v2D)
#
#  incepblock3b_conv_3x3 (Con  (None, 8, 8, 384)            663936    ['incepblock3b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3b_conv_5x5 (Con  (None, 8, 8, 128)            153728    ['incepblock3b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3b_conv_afterpoo  (None, 8, 8, 128)            106624    ['incepblock3b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock3b_concat (Conca  (None, 8, 8, 1024)           0         ['incepblock3b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock3b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock3b_conv_5x5[0][0]'
#                                                                     , 'incepblock3b_conv_afterpool
#                                                                     [0][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['incepblock3b_concat[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  131200    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  out_layer (Dense)           (None, 5)                    645       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 3788637 (14.45 MB)
# Trainable params: 3788637 (14.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=13,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_InceptionNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 30s 89ms/step - loss: 1.6070 - accuracy: 0.3403 - val_loss: 1.5425 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 2/100
# 113/113 [==============================] - 7s 60ms/step - loss: 1.5470 - accuracy: 0.3486 - val_loss: 1.5359 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 3/100
# 113/113 [==============================] - 7s 60ms/step - loss: 1.5413 - accuracy: 0.3489 - val_loss: 1.5303 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 4/100
# 113/113 [==============================] - 7s 61ms/step - loss: 1.5423 - accuracy: 0.3464 - val_loss: 1.5241 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 5/100
# 113/113 [==============================] - 7s 61ms/step - loss: 1.5334 - accuracy: 0.3497 - val_loss: 1.5320 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 6/100
# 113/113 [==============================] - 7s 61ms/step - loss: 1.5258 - accuracy: 0.3450 - val_loss: 1.5054 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 7/100
# 113/113 [==============================] - 7s 62ms/step - loss: 1.5244 - accuracy: 0.3486 - val_loss: 1.5138 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 8/100
# 113/113 [==============================] - 7s 62ms/step - loss: 1.5054 - accuracy: 0.3489 - val_loss: 1.4711 - val_accuracy: 0.3631 - lr: 0.0010
# Epoch 9/100
# 113/113 [==============================] - 7s 63ms/step - loss: 1.4743 - accuracy: 0.3654 - val_loss: 1.5021 - val_accuracy: 0.3422 - lr: 0.0010
# Epoch 10/100
# 113/113 [==============================] - 7s 63ms/step - loss: 1.4483 - accuracy: 0.3743 - val_loss: 1.4128 - val_accuracy: 0.3819 - lr: 0.0010
# Epoch 11/100
# 113/113 [==============================] - 7s 64ms/step - loss: 1.3896 - accuracy: 0.3872 - val_loss: 1.2962 - val_accuracy: 0.4018 - lr: 0.0010
# Epoch 12/100
# 113/113 [==============================] - 7s 64ms/step - loss: 1.2936 - accuracy: 0.4510 - val_loss: 1.3131 - val_accuracy: 0.4536 - lr: 0.0010
# Epoch 13/100
# 113/113 [==============================] - 7s 65ms/step - loss: 1.2228 - accuracy: 0.4861 - val_loss: 1.1907 - val_accuracy: 0.5110 - lr: 0.0010
# Epoch 14/100
# 113/113 [==============================] - 7s 65ms/step - loss: 1.1651 - accuracy: 0.5131 - val_loss: 1.2262 - val_accuracy: 0.4735 - lr: 0.0010
# Epoch 15/100
# 113/113 [==============================] - 7s 64ms/step - loss: 1.1250 - accuracy: 0.5117 - val_loss: 1.1336 - val_accuracy: 0.5221 - lr: 0.0010
# Epoch 16/100
# 113/113 [==============================] - 7s 64ms/step - loss: 1.0853 - accuracy: 0.5449 - val_loss: 1.0596 - val_accuracy: 0.5287 - lr: 0.0010
# Epoch 17/100
# 113/113 [==============================] - 7s 64ms/step - loss: 1.0581 - accuracy: 0.5628 - val_loss: 1.0950 - val_accuracy: 0.5530 - lr: 0.0010
# Epoch 18/100
# 113/113 [==============================] - 7s 63ms/step - loss: 1.0579 - accuracy: 0.5675 - val_loss: 1.0387 - val_accuracy: 0.5905 - lr: 0.0010
# Epoch 19/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.9983 - accuracy: 0.5821 - val_loss: 1.0174 - val_accuracy: 0.5949 - lr: 0.0010
# Epoch 20/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.9980 - accuracy: 0.5929 - val_loss: 0.9875 - val_accuracy: 0.6093 - lr: 0.0010
# Epoch 21/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.9438 - accuracy: 0.6254 - val_loss: 0.9858 - val_accuracy: 0.5916 - lr: 0.0010
# Epoch 22/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.9283 - accuracy: 0.6224 - val_loss: 0.9928 - val_accuracy: 0.6236 - lr: 0.0010
# Epoch 23/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.9232 - accuracy: 0.6268 - val_loss: 0.9540 - val_accuracy: 0.6115 - lr: 0.0010
# Epoch 24/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.8993 - accuracy: 0.6390 - val_loss: 0.9570 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 25/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.8648 - accuracy: 0.6591 - val_loss: 1.0085 - val_accuracy: 0.6402 - lr: 0.0010
# Epoch 26/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.8559 - accuracy: 0.6547 - val_loss: 0.9461 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 27/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.8407 - accuracy: 0.6671 - val_loss: 0.9638 - val_accuracy: 0.6336 - lr: 0.0010
# Epoch 28/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.8238 - accuracy: 0.6738 - val_loss: 0.9686 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 29/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.8145 - accuracy: 0.6831 - val_loss: 1.1628 - val_accuracy: 0.5640 - lr: 0.0010
# Epoch 30/100
# 114/113 [==============================] - ETA: 0s - loss: 0.8185 - accuracy: 0.6834
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 113/113 [==============================] - 7s 63ms/step - loss: 0.8185 - accuracy: 0.6834 - val_loss: 1.0034 - val_accuracy: 0.6302 - lr: 0.0010
# Epoch 31/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.7341 - accuracy: 0.7094 - val_loss: 0.9035 - val_accuracy: 0.6645 - lr: 1.0000e-04
# Epoch 32/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.7039 - accuracy: 0.7240 - val_loss: 0.9239 - val_accuracy: 0.6689 - lr: 1.0000e-04
# Epoch 33/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6895 - accuracy: 0.7276 - val_loss: 0.9279 - val_accuracy: 0.6645 - lr: 1.0000e-04
# Epoch 34/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6770 - accuracy: 0.7292 - val_loss: 0.9109 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 35/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.7397
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6662 - accuracy: 0.7397 - val_loss: 0.9263 - val_accuracy: 0.6689 - lr: 1.0000e-04
# Epoch 36/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6520 - accuracy: 0.7444 - val_loss: 0.9279 - val_accuracy: 0.6689 - lr: 1.0000e-05
# Epoch 37/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6432 - accuracy: 0.7499 - val_loss: 0.9320 - val_accuracy: 0.6656 - lr: 1.0000e-05
# Epoch 38/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6591 - accuracy: 0.7422 - val_loss: 0.9310 - val_accuracy: 0.6678 - lr: 1.0000e-05
# Epoch 39/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.7436
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6501 - accuracy: 0.7436 - val_loss: 0.9319 - val_accuracy: 0.6689 - lr: 1.0000e-05
# Epoch 40/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6455 - accuracy: 0.7439 - val_loss: 0.9310 - val_accuracy: 0.6700 - lr: 1.0000e-06
# Epoch 41/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6438 - accuracy: 0.7491 - val_loss: 0.9303 - val_accuracy: 0.6700 - lr: 1.0000e-06
# Epoch 42/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6489 - accuracy: 0.7488 - val_loss: 0.9301 - val_accuracy: 0.6722 - lr: 1.0000e-06
# Epoch 43/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.7463
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6479 - accuracy: 0.7463 - val_loss: 0.9297 - val_accuracy: 0.6711 - lr: 1.0000e-06
# Epoch 44/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6436 - accuracy: 0.7436 - val_loss: 0.9297 - val_accuracy: 0.6700 - lr: 1.0000e-07
# Epoch 45/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6494 - accuracy: 0.7439 - val_loss: 0.9297 - val_accuracy: 0.6700 - lr: 1.0000e-07
# Epoch 46/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6472 - accuracy: 0.7458 - val_loss: 0.9297 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 47/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.7474
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6487 - accuracy: 0.7474 - val_loss: 0.9298 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 48/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6487 - accuracy: 0.7477 - val_loss: 0.9297 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 49/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6488 - accuracy: 0.7444 - val_loss: 0.9298 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 50/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6468 - accuracy: 0.7486 - val_loss: 0.9298 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 51/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6489 - accuracy: 0.7469 - val_loss: 0.9298 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 52/100
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6489 - accuracy: 0.7452 - val_loss: 0.9298 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 53/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6423 - accuracy: 0.7521 - val_loss: 0.9299 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 54/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6411 - accuracy: 0.7502 - val_loss: 0.9299 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 55/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6435 - accuracy: 0.7519 - val_loss: 0.9299 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 56/100
# 113/113 [==============================] - 7s 63ms/step - loss: 0.6473 - accuracy: 0.7483 - val_loss: 0.9300 - val_accuracy: 0.6711 - lr: 1.0000e-07
# Epoch 57/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7466Epoch 56: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 41.
# 113/113 [==============================] - 7s 64ms/step - loss: 0.6480 - accuracy: 0.7466 - val_loss: 0.9300 - val_accuracy: 0.6711 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_InceptionNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.606951  0.340326  1.542534      0.347682  1.000000e-03
# 1   1.546951  0.348606  1.535903      0.347682  1.000000e-03
# 2   1.541271  0.348882  1.530302      0.347682  1.000000e-03
# 3   1.542343  0.346398  1.524130      0.347682  1.000000e-03
# 4   1.533414  0.349710  1.531986      0.347682  1.000000e-03
# 5   1.525805  0.345018  1.505404      0.347682  1.000000e-03
# 6   1.524449  0.348606  1.513819      0.347682  1.000000e-03
# 7   1.505365  0.348882  1.471119      0.363135  1.000000e-03
# 8   1.474346  0.365443  1.502147      0.342163  1.000000e-03
# 9   1.448329  0.374275  1.412781      0.381898  1.000000e-03
# 10  1.389554  0.387248  1.296190      0.401766  1.000000e-03
# 11  1.293608  0.451007  1.313131      0.453642  1.000000e-03
# 12  1.222824  0.486061  1.190699      0.511038  1.000000e-03
# 13  1.165053  0.513111  1.226207      0.473510  1.000000e-03
# 14  1.125009  0.511731  1.133627      0.522075  1.000000e-03
# 15  1.085325  0.544852  1.059624      0.528698  1.000000e-03
# 16  1.058068  0.562793  1.094987      0.552980  1.000000e-03
# 17  1.057921  0.567486  1.038715      0.590508  1.000000e-03
# 18  0.998318  0.582114  1.017388      0.594923  1.000000e-03
# 19  0.998045  0.592879  0.987544      0.609272  1.000000e-03
# 20  0.943796  0.625449  0.985802      0.591612  1.000000e-03
# 21  0.928337  0.622412  0.992750      0.623620  1.000000e-03
# 22  0.923221  0.626829  0.954017      0.611479  1.000000e-03
# 23  0.899345  0.638973  0.956964      0.624724  1.000000e-03
# 24  0.864847  0.659122  1.008542      0.640177  1.000000e-03
# 25  0.855887  0.654706  0.946146      0.631347  1.000000e-03
# 26  0.840704  0.667127  0.963753      0.633554  1.000000e-03
# 27  0.823847  0.673751  0.968618      0.651214  1.000000e-03
# 28  0.814499  0.683136  1.162798      0.564018  1.000000e-03
# 29  0.818510  0.683412  1.003403      0.630243  1.000000e-03
# 30  0.734120  0.709357  0.903508      0.664459  1.000000e-04
# 31  0.703888  0.723986  0.923946      0.668874  1.000000e-04
# 32  0.689452  0.727574  0.927921      0.664459  1.000000e-04
# 33  0.676989  0.729230  0.910887      0.666667  1.000000e-04
# 34  0.666193  0.739718  0.926284      0.668874  1.000000e-04
# 35  0.651998  0.744411  0.927908      0.668874  1.000000e-05
# 36  0.643216  0.749931  0.931983      0.665563  1.000000e-05
# 37  0.659061  0.742203  0.931003      0.667770  1.000000e-05
# 38  0.650078  0.743583  0.931938      0.668874  1.000000e-05
# 39  0.645515  0.743859  0.931039      0.669978  1.000000e-06
# 40  0.643770  0.749103  0.930268      0.669978  1.000000e-06
# 41  0.648942  0.748827  0.930092      0.672185  1.000000e-06
# 42  0.647871  0.746343  0.929696      0.671082  1.000000e-06
# 43  0.643606  0.743583  0.929707      0.669978  1.000000e-07
# 44  0.649371  0.743859  0.929695      0.669978  1.000000e-07
# 45  0.647155  0.745791  0.929745      0.671082  1.000000e-07
# 46  0.648739  0.747447  0.929762      0.671082  1.000000e-07
# 47  0.648676  0.747723  0.929740      0.671082  1.000000e-07
# 48  0.648803  0.744411  0.929785      0.671082  1.000000e-07
# 49  0.646829  0.748551  0.929846      0.671082  1.000000e-07
# 50  0.648884  0.746895  0.929841      0.671082  1.000000e-07
# 51  0.648927  0.745239  0.929819      0.671082  1.000000e-07
# 52  0.642334  0.752139  0.929853      0.671082  1.000000e-07
# 53  0.641112  0.750207  0.929913      0.671082  1.000000e-07
# 54  0.643467  0.751863  0.929944      0.671082  1.000000e-07
# 55  0.647340  0.748275  0.929982      0.671082  1.000000e-07
# 56  0.647987  0.746619  0.930043      0.671082  1.000000e-07

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['accuracy'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['loss'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 114/114 - 2s - loss: 0.6048 - accuracy: 0.7635 - 2s/epoch - 19ms/step
#
# train Accuracy: 0.7634556889533997
# 29/29 - 1s - loss: 0.9301 - accuracy: 0.6722 - 548ms/epoch - 19ms/step
#
# Test Accuracy: 0.6721854209899902
# 29/29 [==============================] - 1s 18ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       0.70      0.55      0.61       110
#         Fear       0.62      0.73      0.67       127
#        Happy       0.53      0.55      0.54       173
#      Neutral       0.50      0.54      0.52       181
#      Sadness       0.89      0.83      0.86       315
#
#     accuracy                           0.67       906
#    macro avg       0.65      0.64      0.64       906
# weighted avg       0.68      0.67      0.68       906

# %%
# Visualize some predictions
pyplot.figure(figsize=(10, 10))
for i in range(9):
    ax = pyplot.subplot(3, 3, i + 1)
    pyplot.imshow(X_test[i])
    pyplot.title(label_to_text[predicted_labels[i]])
    pyplot.axis("off")

pyplot.show()

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Obtaining dependency information for visualkeras from https://files.pythonhosted.org/packages/a5/93/abd375b37add77d58a8c48a506ae39bb77c4380e2507ea444325ff1b9971/visualkeras-0.0.2-py3-none-any.whl.metadata
#   Downloading visualkeras-0.0.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Obtaining dependency information for aggdraw>=1.3.11 from https://files.pythonhosted.org/packages/e4/57/59b42e145ff12941c5c63d59dc48369912a9e29d69966ff630e6f0f815ac/aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 4.7 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2396x378>
