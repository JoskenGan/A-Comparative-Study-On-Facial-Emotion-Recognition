# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-24 09:59:21.891711: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 09:59:21.891818: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 09:59:22.180324: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (71, 71))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (71, 71, 3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 32
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 71, 71, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 263,175 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/383 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.1927 - loss: 14.8929
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711274525.467269      92 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711274525.497957      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 266/383 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - accuracy: 0.3031 - loss: 5.5149
# W0000 00:00:1711274541.881407      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 381/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3121 - loss: 4.7363
# W0000 00:00:1711274550.618122      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - accuracy: 0.3123 - loss: 4.7206 - val_accuracy: 0.3921 - val_loss: 1.6382 - learning_rate: 0.0010
# Epoch 2/100
# W0000 00:00:1711274556.498243      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3750 - loss: 1.6399
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3750 - loss: 1.6399 - val_accuracy: 0.3915 - val_loss: 1.6380 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.3948 - loss: 1.6701 - val_accuracy: 0.3921 - val_loss: 1.6118 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3125 - loss: 1.7487 - val_accuracy: 0.3924 - val_loss: 1.6159 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.3985 - loss: 1.5861 - val_accuracy: 0.3872 - val_loss: 1.5540 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.5299 - val_accuracy: 0.3872 - val_loss: 1.5569 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - accuracy: 0.3894 - loss: 1.5771 - val_accuracy: 0.3882 - val_loss: 1.5664 - learning_rate: 0.0010
# Epoch 8/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5000 - loss: 1.4575
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.4575 - val_accuracy: 0.3882 - val_loss: 1.5647 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.3956 - loss: 1.5604 - val_accuracy: 0.3954 - val_loss: 1.5249 - learning_rate: 1.0000e-04
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.4651 - val_accuracy: 0.3950 - val_loss: 1.5256 - learning_rate: 1.0000e-04
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4069 - loss: 1.5342 - val_accuracy: 0.4009 - val_loss: 1.5761 - learning_rate: 1.0000e-04
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.5647 - val_accuracy: 0.4009 - val_loss: 1.5762 - learning_rate: 1.0000e-04
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.4086 - loss: 1.5409 - val_accuracy: 0.4306 - val_loss: 1.5100 - learning_rate: 1.0000e-04
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.6134 - val_accuracy: 0.4296 - val_loss: 1.5081 - learning_rate: 1.0000e-04
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.4219 - loss: 1.5211 - val_accuracy: 0.4244 - val_loss: 1.5060 - learning_rate: 1.0000e-04
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.5836 - val_accuracy: 0.4237 - val_loss: 1.5048 - learning_rate: 1.0000e-04
# Epoch 17/100
# 381/383 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4229 - loss: 1.5154
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4229 - loss: 1.5154 - val_accuracy: 0.4198 - val_loss: 1.4882 - learning_rate: 1.0000e-04
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.5969 - val_accuracy: 0.4201 - val_loss: 1.4882 - learning_rate: 1.0000e-05
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - accuracy: 0.4256 - loss: 1.5079 - val_accuracy: 0.4198 - val_loss: 1.4877 - learning_rate: 1.0000e-05
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.2665 - val_accuracy: 0.4198 - val_loss: 1.4880 - learning_rate: 1.0000e-05
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4270 - loss: 1.5109
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4270 - loss: 1.5109 - val_accuracy: 0.4237 - val_loss: 1.4909 - learning_rate: 1.0000e-05
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.5022 - val_accuracy: 0.4237 - val_loss: 1.4909 - learning_rate: 1.0000e-06
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.4319 - loss: 1.5026 - val_accuracy: 0.4244 - val_loss: 1.4881 - learning_rate: 1.0000e-06
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.6883 - val_accuracy: 0.4244 - val_loss: 1.4881 - learning_rate: 1.0000e-06
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4333 - loss: 1.5022
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4333 - loss: 1.5022 - val_accuracy: 0.4244 - val_loss: 1.4874 - learning_rate: 1.0000e-06
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.5256 - val_accuracy: 0.4244 - val_loss: 1.4874 - learning_rate: 1.0000e-07
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4273 - loss: 1.5298 - val_accuracy: 0.4244 - val_loss: 1.4874 - learning_rate: 1.0000e-07
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.3358 - val_accuracy: 0.4244 - val_loss: 1.4874 - learning_rate: 1.0000e-07
# Epoch 29/100
# 381/383 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4248 - loss: 1.5136
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4248 - loss: 1.5137 - val_accuracy: 0.4244 - val_loss: 1.4873 - learning_rate: 1.0000e-07
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.3747 - val_accuracy: 0.4244 - val_loss: 1.4873 - learning_rate: 1.0000e-07
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4275 - loss: 1.5103 - val_accuracy: 0.4247 - val_loss: 1.4873 - learning_rate: 1.0000e-07
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.5756 - val_accuracy: 0.4247 - val_loss: 1.4873 - learning_rate: 1.0000e-07
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.4293 - loss: 1.5079 - val_accuracy: 0.4250 - val_loss: 1.4872 - learning_rate: 1.0000e-07
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.6024 - val_accuracy: 0.4250 - val_loss: 1.4872 - learning_rate: 1.0000e-07
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4226 - loss: 1.5132 - val_accuracy: 0.4247 - val_loss: 1.4872 - learning_rate: 1.0000e-07
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.1907 - val_accuracy: 0.4247 - val_loss: 1.4872 - learning_rate: 1.0000e-07
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.4264 - loss: 1.5002 - val_accuracy: 0.4247 - val_loss: 1.4872 - learning_rate: 1.0000e-07
# Epoch 38/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.3750 - loss: 1.4966Epoch 37: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 12.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3750 - loss: 1.4966 - val_accuracy: 0.4247 - val_loss: 1.4872 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.341368  2.732954      0.392112  1.638225   1.000000e-03
# 1   0.375000  1.639896      0.391460  1.638012   1.000000e-03
# 2   0.395866  1.643385      0.392112  1.611784   1.000000e-03
# 3   0.312500  1.748678      0.392438  1.615899   1.000000e-03
# 4   0.392761  1.595984      0.387223  1.554018   1.000000e-03
# 5   0.406250  1.529863      0.387223  1.556925   1.000000e-03
# 6   0.392352  1.581089      0.388201  1.566430   1.000000e-03
# 7   0.500000  1.457470      0.388201  1.564737   1.000000e-03
# 8   0.395784  1.556364      0.395372  1.524940   1.000000e-04
# 9   0.468750  1.465078      0.395046  1.525602   1.000000e-04
# 10  0.407305  1.536383      0.400913  1.576064   1.000000e-04
# 11  0.406250  1.564662      0.400913  1.576225   1.000000e-04
# 12  0.413514  1.532334      0.430574  1.510029   1.000000e-04
# 13  0.500000  1.613374      0.429596  1.508112   1.000000e-04
# 14  0.424136  1.521888      0.424381  1.506037   1.000000e-04
# 15  0.343750  1.583556      0.423729  1.504837   1.000000e-04
# 16  0.424136  1.516472      0.419817  1.488215   1.000000e-04
# 17  0.500000  1.596879      0.420143  1.488224   1.000000e-05
# 18  0.424054  1.506762      0.419817  1.487652   1.000000e-05
# 19  0.562500  1.266521      0.419817  1.487989   1.000000e-05
# 20  0.427241  1.511261      0.423729  1.490898   1.000000e-05
# 21  0.437500  1.502196      0.423729  1.490888   1.000000e-06
# 22  0.433124  1.507412      0.424381  1.488090   1.000000e-06
# 23  0.343750  1.688337      0.424381  1.488099   1.000000e-06
# 24  0.430918  1.510104      0.424381  1.487416   1.000000e-06
# 25  0.406250  1.525580      0.424381  1.487416   1.000000e-07
# 26  0.429774  1.513320      0.424381  1.487397   1.000000e-07
# 27  0.500000  1.335778      0.424381  1.487398   1.000000e-07
# 28  0.423809  1.517209      0.424381  1.487336   1.000000e-07
# 29  0.468750  1.374660      0.424381  1.487335   1.000000e-07
# 30  0.429283  1.509128      0.424707  1.487336   1.000000e-07
# 31  0.468750  1.575577      0.424707  1.487336   1.000000e-07
# 32  0.429529  1.507431      0.425033  1.487231   1.000000e-07
# 33  0.468750  1.602424      0.425033  1.487230   1.000000e-07
# 34  0.422420  1.513765      0.424707  1.487199   1.000000e-07
# 35  0.562500  1.190654      0.424707  1.487199   1.000000e-07
# 36  0.426669  1.507035      0.424707  1.487187   1.000000e-07
# 37  0.375000  1.496564      0.424707  1.487185   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 71, 71, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 21,070,127 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/383 ━━━━━━━━━━━━━━━━━━━━ 39s 105ms/step - accuracy: 0.3906 - loss: 1.8345
# W0000 00:00:1711274976.996950      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 182/383 ━━━━━━━━━━━━━━━━━━━━ 36s 183ms/step - accuracy: 0.3313 - loss: 1.8295
# W0000 00:00:1711275010.051478      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3395 - loss: 1.8147
# W0000 00:00:1711275027.682746      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 98s 141ms/step - accuracy: 0.3396 - loss: 1.8146 - val_accuracy: 0.4042 - val_loss: 1.6673 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 24s 64ms/step - accuracy: 0.5938 - loss: 1.5173
# W0000 00:00:1711275030.949410      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.5173 - val_accuracy: 0.4045 - val_loss: 1.6662 - learning_rate: 1.0000e-05
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.4157 - loss: 1.5873 - val_accuracy: 0.4384 - val_loss: 1.4075 - learning_rate: 1.0000e-05
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5312 - loss: 1.2935 - val_accuracy: 0.4397 - val_loss: 1.4074 - learning_rate: 1.0000e-05
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.4677 - loss: 1.3686 - val_accuracy: 0.5378 - val_loss: 1.2755 - learning_rate: 1.0000e-05
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6250 - loss: 1.1186 - val_accuracy: 0.5381 - val_loss: 1.2757 - learning_rate: 1.0000e-05
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.5348 - loss: 1.2468 - val_accuracy: 0.5707 - val_loss: 1.2174 - learning_rate: 1.0000e-05
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 1.2160 - val_accuracy: 0.5701 - val_loss: 1.2175 - learning_rate: 1.0000e-05
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.5719 - loss: 1.1822 - val_accuracy: 0.6105 - val_loss: 1.1801 - learning_rate: 1.0000e-05
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5625 - loss: 1.1099 - val_accuracy: 0.6108 - val_loss: 1.1788 - learning_rate: 1.0000e-05
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.6025 - loss: 1.0996 - val_accuracy: 0.6340 - val_loss: 1.1274 - learning_rate: 1.0000e-05
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.6851 - val_accuracy: 0.6336 - val_loss: 1.1281 - learning_rate: 1.0000e-05
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.6282 - loss: 1.0213 - val_accuracy: 0.6480 - val_loss: 1.1190 - learning_rate: 1.0000e-05
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5938 - loss: 1.1122 - val_accuracy: 0.6486 - val_loss: 1.1217 - learning_rate: 1.0000e-05
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.6531 - loss: 0.9656 - val_accuracy: 0.6688 - val_loss: 1.0715 - learning_rate: 1.0000e-05
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6250 - loss: 1.0610 - val_accuracy: 0.6692 - val_loss: 1.0789 - learning_rate: 1.0000e-05
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.6770 - loss: 0.9138 - val_accuracy: 0.6786 - val_loss: 1.0237 - learning_rate: 1.0000e-05
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6875 - loss: 1.0805 - val_accuracy: 0.6789 - val_loss: 1.0195 - learning_rate: 1.0000e-05
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.6904 - loss: 0.8778 - val_accuracy: 0.6887 - val_loss: 0.9979 - learning_rate: 1.0000e-05
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6875 - loss: 0.8664 - val_accuracy: 0.6881 - val_loss: 0.9979 - learning_rate: 1.0000e-05
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7091 - loss: 0.8223 - val_accuracy: 0.6913 - val_loss: 0.9706 - learning_rate: 1.0000e-05
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7500 - loss: 0.7933 - val_accuracy: 0.6917 - val_loss: 0.9723 - learning_rate: 1.0000e-05
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 39s 76ms/step - accuracy: 0.7150 - loss: 0.7993 - val_accuracy: 0.6949 - val_loss: 0.9711 - learning_rate: 1.0000e-05
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.5484 - val_accuracy: 0.6943 - val_loss: 0.9677 - learning_rate: 1.0000e-05
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.7237 - loss: 0.7744 - val_accuracy: 0.7005 - val_loss: 0.9491 - learning_rate: 1.0000e-05
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7188 - loss: 0.7031 - val_accuracy: 0.7014 - val_loss: 0.9498 - learning_rate: 1.0000e-05
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7365 - loss: 0.7348 - val_accuracy: 0.7115 - val_loss: 0.9922 - learning_rate: 1.0000e-05
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.6962 - val_accuracy: 0.7106 - val_loss: 1.0009 - learning_rate: 1.0000e-05
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7519 - loss: 0.7080 - val_accuracy: 0.7125 - val_loss: 0.9884 - learning_rate: 1.0000e-05
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.5167 - val_accuracy: 0.7125 - val_loss: 0.9855 - learning_rate: 1.0000e-05
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7588 - loss: 0.6839 - val_accuracy: 0.7226 - val_loss: 0.9307 - learning_rate: 1.0000e-05
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8125 - loss: 0.5853 - val_accuracy: 0.7226 - val_loss: 0.9332 - learning_rate: 1.0000e-05
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7643 - loss: 0.6698 - val_accuracy: 0.7275 - val_loss: 0.9272 - learning_rate: 1.0000e-05
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.6799 - val_accuracy: 0.7275 - val_loss: 0.9293 - learning_rate: 1.0000e-05
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7727 - loss: 0.6478 - val_accuracy: 0.7301 - val_loss: 0.8762 - learning_rate: 1.0000e-05
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.3622 - val_accuracy: 0.7298 - val_loss: 0.8705 - learning_rate: 1.0000e-05
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7868 - loss: 0.6023 - val_accuracy: 0.7321 - val_loss: 0.8751 - learning_rate: 1.0000e-05
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.6937 - val_accuracy: 0.7321 - val_loss: 0.8799 - learning_rate: 1.0000e-05
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7926 - loss: 0.5851 - val_accuracy: 0.7324 - val_loss: 0.8521 - learning_rate: 1.0000e-05
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.8254 - val_accuracy: 0.7321 - val_loss: 0.8494 - learning_rate: 1.0000e-05
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8039 - loss: 0.5607 - val_accuracy: 0.7392 - val_loss: 0.9626 - learning_rate: 1.0000e-05
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.6128 - val_accuracy: 0.7392 - val_loss: 0.9683 - learning_rate: 1.0000e-05
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8076 - loss: 0.5443 - val_accuracy: 0.7477 - val_loss: 0.9130 - learning_rate: 1.0000e-05
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.6025 - val_accuracy: 0.7474 - val_loss: 0.9111 - learning_rate: 1.0000e-05
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8197 - loss: 0.5181 - val_accuracy: 0.7438 - val_loss: 0.8893 - learning_rate: 1.0000e-05
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8750 - loss: 0.3586 - val_accuracy: 0.7432 - val_loss: 0.8886 - learning_rate: 1.0000e-05
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8212 - loss: 0.5021
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8212 - loss: 0.5021 - val_accuracy: 0.7379 - val_loss: 0.9751 - learning_rate: 1.0000e-05
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8125 - loss: 0.4592 - val_accuracy: 0.7383 - val_loss: 0.9707 - learning_rate: 1.0000e-06
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.8316 - loss: 0.4874 - val_accuracy: 0.7419 - val_loss: 0.9322 - learning_rate: 1.0000e-06
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 0.2347 - val_accuracy: 0.7432 - val_loss: 0.9399 - learning_rate: 1.0000e-06
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8355 - loss: 0.4651
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8355 - loss: 0.4651 - val_accuracy: 0.7419 - val_loss: 0.9627 - learning_rate: 1.0000e-06
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8750 - loss: 0.4648 - val_accuracy: 0.7415 - val_loss: 0.9653 - learning_rate: 1.0000e-07
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8280 - loss: 0.4778 - val_accuracy: 0.7454 - val_loss: 0.9207 - learning_rate: 1.0000e-07
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8750 - loss: 0.3625 - val_accuracy: 0.7458 - val_loss: 0.9157 - learning_rate: 1.0000e-07
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8351 - loss: 0.4716 - val_accuracy: 0.7474 - val_loss: 0.8956 - learning_rate: 1.0000e-07
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9375 - loss: 0.3129 - val_accuracy: 0.7477 - val_loss: 0.8974 - learning_rate: 1.0000e-07
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8355 - loss: 0.4792 - val_accuracy: 0.7422 - val_loss: 0.9104 - learning_rate: 1.0000e-07
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.7614 - val_accuracy: 0.7425 - val_loss: 0.9057 - learning_rate: 1.0000e-07
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8370 - loss: 0.4783 - val_accuracy: 0.7454 - val_loss: 0.9167 - learning_rate: 1.0000e-07
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8438 - loss: 0.5254 - val_accuracy: 0.7454 - val_loss: 0.9200 - learning_rate: 1.0000e-07
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8264 - loss: 0.4865 - val_accuracy: 0.7461 - val_loss: 0.9138 - learning_rate: 1.0000e-07
# Epoch 62/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9062 - loss: 0.4027 - val_accuracy: 0.7461 - val_loss: 0.9184 - learning_rate: 1.0000e-07
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8350 - loss: 0.4733 - val_accuracy: 0.7477 - val_loss: 0.9028 - learning_rate: 1.0000e-07
# Epoch 64/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9062 - loss: 0.3371 - val_accuracy: 0.7471 - val_loss: 0.9032 - learning_rate: 1.0000e-07
# Epoch 65/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8353 - loss: 0.4688 - val_accuracy: 0.7412 - val_loss: 0.9481 - learning_rate: 1.0000e-07
# Epoch 66/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9062 - loss: 0.3810 - val_accuracy: 0.7415 - val_loss: 0.9480 - learning_rate: 1.0000e-07
# Epoch 67/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.8323 - loss: 0.4771 - val_accuracy: 0.7438 - val_loss: 0.9466 - learning_rate: 1.0000e-07
# Epoch 68/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 25s 67ms/step - accuracy: 0.8750 - loss: 0.3738Epoch 67: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 42.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8750 - loss: 0.3738 - val_accuracy: 0.7435 - val_loss: 0.9419 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.360242  1.778389      0.404172  1.667259   1.000000e-05
# 1   0.593750  1.517293      0.404498  1.666190   1.000000e-05
# 2   0.423646  1.521159      0.438396  1.407511   1.000000e-05
# 3   0.531250  1.293519      0.439700  1.407391   1.000000e-05
# 4   0.482066  1.347625      0.537810  1.275457   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 63  0.906250  0.337056      0.747066  0.903203   1.000000e-07
# 64  0.835689  0.468287      0.741199  0.948069   1.000000e-07
# 65  0.906250  0.381032      0.741525  0.948039   1.000000e-07
# 66  0.833728  0.469112      0.743807  0.946567   1.000000e-07
# 67  0.875000  0.373799      0.743481  0.941918   1.000000e-07
#
# [68 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 8s - 22ms/step - accuracy: 0.8616 - loss: 0.5893
# W0000 00:00:1711276092.055196      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.8616249561309814
# 96/96 - 2s - 18ms/step - accuracy: 0.7477 - loss: 0.9130
#
# Test Accuracy: 0.7477183938026428
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.74      0.72      0.73       329
#      disgust       0.58      0.38      0.46        74
#         fear       0.63      0.60      0.62       162
#        happy       0.67      0.78      0.72       680
#      neutral       0.67      0.71      0.68       478
#          sad       0.46      0.27      0.34       160
#     surprise       0.89      0.86      0.87      1185
#
#     accuracy                           0.75      3068
#    macro avg       0.66      0.62      0.63      3068
# weighted avg       0.74      0.75      0.74      3068

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rgb_img = cv2.cvtColor(img_arr_test[i], cv2.COLOR_BGR2RGB)
    plt.imshow(rgb_img)
    plt.title(label_to_text_test[predicted_labels[i]])
    plt.axis("off")

plt.show()
