# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Add
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-01 07:47:19.222888: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-01 07:47:19.222986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-01 07:47:19.398118: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(os.path.join(data_dir, dir_)):
                img = cv2.imread(os.path.join(data_dir, dir_, f), 0)
                img = cv2.resize(img, (64, 64))  # Resize image to 64x64
                img_arr.append(np.expand_dims(img, axis=2))
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(target_names)
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
def identity_block(X, kernel: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'idblock_conv_' +  str(stage) + f'_{block_id}'
    bn_name = 'idblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "idblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters = filters[0],
        kernel_size = (1, 1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters = filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters = filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_c',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def convolutional_block(X, kernel: tuple, stride: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'convblock_conv_' + str(stage) + f'_{block_id}'
    bn_name = 'convblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "convblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters[0],
        kernel_size = (1, 1),
        strides = stride,
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_c',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X_shortcut = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = stride,
        padding = 'valid',
        name = conv_name + '_sc1',
        kernel_initializer=glorot_uniform(seed =0)
    )(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name + '_sc1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def CNN_with_SkipConnections(input_shape, classes, show_summary=False):
    model_in = Input(input_shape)

    X = Conv2D(
        filters = 32,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(model_in)
    X = BatchNormalization(axis = 3, name = 'bn_0_a')(X)
    X = Activation('relu', name="actv_0_a")(X)

    X = Conv2D(
        filters = 64,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_b',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = 'bn_0_b')(X)
    X = Activation('relu', name="actv_0_b")(X)

    # Block 0
    X = convolutional_block(model_in, (3,3), stride=(1,1), filters = [32, 32, 64], stage=0, block_id='a')
    X = identity_block(X, (3,3), [32, 32, 64], stage=0, block_id='a')

    # Block 1
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [64, 64, 128], stage=1, block_id='a')
    X = identity_block(X, (3,3), [64, 64, 128], stage=1, block_id='a')

    # Block 2
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [128,128,256], stage=2, block_id='a')
    X = identity_block(X, (2,2), [128,128,256], stage=2, block_id='a')

    X = AveragePooling2D(pool_size=(2, 2))(X)

    X = Flatten()(X)
    X = Dense(
        128,
        kernel_initializer = glorot_uniform(seed=0),
        name = 'dense_1',
    )(X)
    X = BatchNormalization(name = 'bn_3')(X)
    X = Activation('relu', name="actv_3")(X)

    model_out = Dense(classes, activation='softmax', name="out_layer")(X)

    model = Model(inputs = model_in, outputs = model_out, name='CNN_with_SkipConnections')

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = CNN_with_SkipConnections(INPUT_SHAPE, NUM_CLASSES, show_summary=True)

plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)
# Out:
# Model: "CNN_with_SkipConnections"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 64, 64,    │         64 │ input_layer[0][0] │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_a  │ (None, 64, 64,    │        128 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 64, 64,    │          0 │ convblock_bn_0_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 64, 64,    │      9,248 │ convblock_actv_0… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_b  │ (None, 64, 64,    │        128 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 64, 64,    │          0 │ convblock_bn_0_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 64, 64,    │      2,112 │ convblock_actv_0… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_0_a… │ (None, 64, 64,    │        128 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_c  │ (None, 64, 64,    │        256 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_0_a_s… │ (None, 64, 64,    │        256 │ convblock_conv_0… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ convblock_bn_0_a… │
# │                     │ 64)               │            │ convblock_bn_0_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_0_a… │ (None, 64, 64,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_a  │ (None, 64, 64,    │      2,080 │ convblock_actv_0… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_a    │ (None, 64, 64,    │        128 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_a  │ (None, 64, 64,    │          0 │ idblock_bn_0_a_a… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_b  │ (None, 64, 64,    │      9,248 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_b    │ (None, 64, 64,    │        128 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_b  │ (None, 64, 64,    │          0 │ idblock_bn_0_a_b… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_0_a_c  │ (None, 64, 64,    │      2,112 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_0_a_c    │ (None, 64, 64,    │        256 │ idblock_conv_0_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ idblock_bn_0_a_c… │
# │                     │ 64)               │            │ convblock_actv_0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_0_a_c  │ (None, 64, 64,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 32, 32,    │      4,160 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_a  │ (None, 32, 32,    │        256 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 32, 32,    │          0 │ convblock_bn_1_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 32, 32,    │     36,928 │ convblock_actv_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_b  │ (None, 32, 32,    │        256 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 32, 32,    │          0 │ convblock_bn_1_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 32, 32,    │      8,320 │ convblock_actv_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_1_a… │ (None, 32, 32,    │      8,320 │ idblock_actv_0_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_c  │ (None, 32, 32,    │        512 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_1_a_s… │ (None, 32, 32,    │        512 │ convblock_conv_1… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ convblock_bn_1_a… │
# │                     │ 128)              │            │ convblock_bn_1_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_1_a… │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_a  │ (None, 32, 32,    │      8,256 │ convblock_actv_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_a    │ (None, 32, 32,    │        256 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_a  │ (None, 32, 32,    │          0 │ idblock_bn_1_a_a… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_b  │ (None, 32, 32,    │     36,928 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_b    │ (None, 32, 32,    │        256 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_b  │ (None, 32, 32,    │          0 │ idblock_bn_1_a_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_1_a_c  │ (None, 32, 32,    │      8,320 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_1_a_c    │ (None, 32, 32,    │        512 │ idblock_conv_1_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 32, 32,    │          0 │ idblock_bn_1_a_c… │
# │                     │ 128)              │            │ convblock_actv_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_1_a_c  │ (None, 32, 32,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 16, 16,    │     16,512 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_a  │ (None, 16, 16,    │        512 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 16, 16,    │          0 │ convblock_bn_2_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 16, 16,    │    147,584 │ convblock_actv_2… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_b  │ (None, 16, 16,    │        512 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 16, 16,    │          0 │ convblock_bn_2_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 16, 16,    │     33,024 │ convblock_actv_2… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_conv_2_a… │ (None, 16, 16,    │     33,024 │ idblock_actv_1_a… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_c  │ (None, 16, 16,    │      1,024 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_bn_2_a_s… │ (None, 16, 16,    │      1,024 │ convblock_conv_2… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ convblock_bn_2_a… │
# │                     │ 256)              │            │ convblock_bn_2_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convblock_actv_2_a… │ (None, 16, 16,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_a  │ (None, 16, 16,    │     32,896 │ convblock_actv_2… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_a    │ (None, 16, 16,    │        512 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_a  │ (None, 16, 16,    │          0 │ idblock_bn_2_a_a… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_b  │ (None, 16, 16,    │     65,664 │ idblock_actv_2_a… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_b    │ (None, 16, 16,    │        512 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_b  │ (None, 16, 16,    │          0 │ idblock_bn_2_a_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_conv_2_a_c  │ (None, 16, 16,    │     33,024 │ idblock_actv_2_a… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_bn_2_a_c    │ (None, 16, 16,    │      1,024 │ idblock_conv_2_a… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 16,    │          0 │ idblock_bn_2_a_c… │
# │                     │ 256)              │            │ convblock_actv_2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ idblock_actv_2_a_c  │ (None, 16, 16,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 8, 8, 256) │          0 │ idblock_actv_2_a… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 16384)     │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │  2,097,280 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_3                │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ actv_3 (Activation) │ (None, 128)       │          0 │ bn_3[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_layer (Dense)   │ (None, 7)         │        903 │ actv_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,605,607 (9.94 MB)
#  Trainable params: 2,600,871 (9.92 MB)
#  Non-trainable params: 4,736 (18.50 KB)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.2,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=7,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(img_arr_train)

# Training the model
custom_early_stopping = CustomEarlyStopping(patience=15)
history_ResNet = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=batch_size),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / batch_size),
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/383 ━━━━━━━━━━━━━━━━━━━━ 23s 62ms/step - accuracy: 0.1328 - loss: 2.2634
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711957784.244347     111 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711957784.295390     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 146/383 ━━━━━━━━━━━━━━━━━━━━ 30s 127ms/step - accuracy: 0.3809 - loss: 1.7507
# W0000 00:00:1711957802.595082     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 382/383 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.4291 - loss: 1.5843
# W0000 00:00:1711957813.663341     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 63s 87ms/step - accuracy: 0.4294 - loss: 1.5834 - val_accuracy: 0.5447 - val_loss: 1.2556 - learning_rate: 0.0010
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - accuracy: 0.5312 - loss: 1.1315
# W0000 00:00:1711957817.591605     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5312 - loss: 1.1315 - val_accuracy: 0.5336 - val_loss: 1.2810 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.5867 - loss: 1.1261 - val_accuracy: 0.6010 - val_loss: 1.1122 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6250 - loss: 1.0852 - val_accuracy: 0.5975 - val_loss: 1.1243 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.6569 - loss: 0.9543 - val_accuracy: 0.6571 - val_loss: 0.9131 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6250 - loss: 1.1405 - val_accuracy: 0.6574 - val_loss: 0.9080 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.6845 - loss: 0.8704 - val_accuracy: 0.7014 - val_loss: 0.8578 - learning_rate: 0.0010
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6250 - loss: 1.0090 - val_accuracy: 0.7021 - val_loss: 0.8510 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.7084 - loss: 0.8071 - val_accuracy: 0.7314 - val_loss: 0.7502 - learning_rate: 0.0010
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5625 - loss: 1.0106 - val_accuracy: 0.7291 - val_loss: 0.7545 - learning_rate: 0.0010
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.7288 - loss: 0.7539 - val_accuracy: 0.6754 - val_loss: 0.8716 - learning_rate: 0.0010
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.6771 - val_accuracy: 0.6705 - val_loss: 0.8768 - learning_rate: 0.0010
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7458 - loss: 0.7205
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.7457 - loss: 0.7205 - val_accuracy: 0.6578 - val_loss: 0.9546 - learning_rate: 0.0010
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.7736 - val_accuracy: 0.6591 - val_loss: 0.9485 - learning_rate: 2.0000e-04
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.7730 - loss: 0.6446 - val_accuracy: 0.7878 - val_loss: 0.5799 - learning_rate: 2.0000e-04
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.7102 - val_accuracy: 0.7878 - val_loss: 0.5798 - learning_rate: 2.0000e-04
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.7793 - loss: 0.6051 - val_accuracy: 0.7937 - val_loss: 0.5723 - learning_rate: 2.0000e-04
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.6824 - val_accuracy: 0.7937 - val_loss: 0.5716 - learning_rate: 2.0000e-04
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.7928 - loss: 0.5851 - val_accuracy: 0.7999 - val_loss: 0.5604 - learning_rate: 2.0000e-04
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.5544 - val_accuracy: 0.7995 - val_loss: 0.5600 - learning_rate: 2.0000e-04
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8023 - loss: 0.5641 - val_accuracy: 0.7976 - val_loss: 0.5481 - learning_rate: 2.0000e-04
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6562 - loss: 0.9592 - val_accuracy: 0.7960 - val_loss: 0.5481 - learning_rate: 2.0000e-04
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8048 - loss: 0.5512 - val_accuracy: 0.8083 - val_loss: 0.5481 - learning_rate: 2.0000e-04
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.6012 - val_accuracy: 0.8090 - val_loss: 0.5489 - learning_rate: 2.0000e-04
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8161 - loss: 0.5199 - val_accuracy: 0.8035 - val_loss: 0.5405 - learning_rate: 2.0000e-04
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8750 - loss: 0.3699 - val_accuracy: 0.8038 - val_loss: 0.5401 - learning_rate: 2.0000e-04
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8126 - loss: 0.5295 - val_accuracy: 0.8083 - val_loss: 0.5420 - learning_rate: 2.0000e-04
# Epoch 28/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.8438 - loss: 0.4386
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.4386 - val_accuracy: 0.8080 - val_loss: 0.5407 - learning_rate: 2.0000e-04
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8246 - loss: 0.5014 - val_accuracy: 0.8165 - val_loss: 0.5150 - learning_rate: 4.0000e-05
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.3425 - val_accuracy: 0.8162 - val_loss: 0.5149 - learning_rate: 4.0000e-05
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8372 - loss: 0.4730 - val_accuracy: 0.8175 - val_loss: 0.5115 - learning_rate: 4.0000e-05
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.4160 - val_accuracy: 0.8175 - val_loss: 0.5121 - learning_rate: 4.0000e-05
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8371 - loss: 0.4790 - val_accuracy: 0.8171 - val_loss: 0.5195 - learning_rate: 4.0000e-05
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.4651 - val_accuracy: 0.8178 - val_loss: 0.5193 - learning_rate: 4.0000e-05
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8378 - loss: 0.4664 - val_accuracy: 0.8184 - val_loss: 0.5117 - learning_rate: 4.0000e-05
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6562 - loss: 0.8485 - val_accuracy: 0.8181 - val_loss: 0.5114 - learning_rate: 4.0000e-05
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8379 - loss: 0.4617 - val_accuracy: 0.8194 - val_loss: 0.5094 - learning_rate: 4.0000e-05
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.5844 - val_accuracy: 0.8188 - val_loss: 0.5097 - learning_rate: 4.0000e-05
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8385 - loss: 0.4672 - val_accuracy: 0.8194 - val_loss: 0.5081 - learning_rate: 4.0000e-05
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9375 - loss: 0.3229 - val_accuracy: 0.8201 - val_loss: 0.5084 - learning_rate: 4.0000e-05
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8391 - loss: 0.4640 - val_accuracy: 0.8220 - val_loss: 0.5055 - learning_rate: 4.0000e-05
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.4940 - val_accuracy: 0.8220 - val_loss: 0.5053 - learning_rate: 4.0000e-05
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8358 - loss: 0.4613 - val_accuracy: 0.8224 - val_loss: 0.5058 - learning_rate: 4.0000e-05
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9688 - loss: 0.1960 - val_accuracy: 0.8224 - val_loss: 0.5057 - learning_rate: 4.0000e-05
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8376 - loss: 0.4643 - val_accuracy: 0.8227 - val_loss: 0.5030 - learning_rate: 4.0000e-05
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8750 - loss: 0.3363 - val_accuracy: 0.8224 - val_loss: 0.5030 - learning_rate: 4.0000e-05
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8402 - loss: 0.4524 - val_accuracy: 0.8158 - val_loss: 0.5138 - learning_rate: 4.0000e-05
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.5404 - val_accuracy: 0.8165 - val_loss: 0.5137 - learning_rate: 4.0000e-05
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8425 - loss: 0.4606
# Epoch 49: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8425 - loss: 0.4606 - val_accuracy: 0.8214 - val_loss: 0.5014 - learning_rate: 4.0000e-05
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9688 - loss: 0.2991 - val_accuracy: 0.8211 - val_loss: 0.5014 - learning_rate: 8.0000e-06
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8446 - loss: 0.4430 - val_accuracy: 0.8207 - val_loss: 0.5041 - learning_rate: 8.0000e-06
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.2707 - val_accuracy: 0.8204 - val_loss: 0.5040 - learning_rate: 8.0000e-06
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8512 - loss: 0.4328
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8512 - loss: 0.4328 - val_accuracy: 0.8224 - val_loss: 0.5037 - learning_rate: 8.0000e-06
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8125 - loss: 0.4721 - val_accuracy: 0.8224 - val_loss: 0.5039 - learning_rate: 1.6000e-06
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8455 - loss: 0.4352 - val_accuracy: 0.8227 - val_loss: 0.5029 - learning_rate: 1.6000e-06
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8438 - loss: 0.5422 - val_accuracy: 0.8227 - val_loss: 0.5027 - learning_rate: 1.6000e-06
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8522 - loss: 0.4209
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.8522 - loss: 0.4209 - val_accuracy: 0.8220 - val_loss: 0.5031 - learning_rate: 1.6000e-06
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8750 - loss: 0.3893 - val_accuracy: 0.8220 - val_loss: 0.5031 - learning_rate: 3.2000e-07
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.8445 - loss: 0.4389 - val_accuracy: 0.8224 - val_loss: 0.5043 - learning_rate: 3.2000e-07
# Epoch 60/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.8438 - loss: 0.4351Epoch 59: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 44.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8438 - loss: 0.4351 - val_accuracy: 0.8227 - val_loss: 0.5040 - learning_rate: 3.2000e-07

# %%
history = pd.DataFrame(history_ResNet.history)
history
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.482556  1.411772      0.544654  1.255555   1.000000e-03
# 1   0.531250  1.131485      0.533572  1.280986   1.000000e-03
# 2   0.599232  1.096312      0.601043  1.112237   1.000000e-03
# 3   0.625000  1.085230      0.597458  1.124257   1.000000e-03
# 4   0.661574  0.945637      0.657106  0.913141   1.000000e-03
# 5   0.625000  1.140479      0.657432  0.907985   1.000000e-03
# 6   0.687638  0.865981      0.701434  0.857785   1.000000e-03
# 7   0.625000  1.008976      0.702086  0.851017   1.000000e-03
# 8   0.704551  0.816026      0.731421  0.750188   1.000000e-03
# 9   0.562500  1.010620      0.729140  0.754468   1.000000e-03
# 10  0.725713  0.766158      0.675359  0.871637   1.000000e-03
# 11  0.718750  0.677128      0.670469  0.876847   1.000000e-03
# 12  0.743933  0.723464      0.657758  0.954584   1.000000e-03
# 13  0.718750  0.773570      0.659061  0.948489   2.000000e-04
# 14  0.773756  0.641204      0.787810  0.579871   2.000000e-04
# 15  0.781250  0.710231      0.787810  0.579764   2.000000e-04
# 16  0.784460  0.597712      0.793677  0.572332   2.000000e-04
# 17  0.718750  0.682373      0.793677  0.571649   2.000000e-04
# 18  0.791976  0.580879      0.799870  0.560414   2.000000e-04
# 19  0.812500  0.554371      0.799544  0.559986   2.000000e-04
# 20  0.799330  0.571679      0.797588  0.548117   2.000000e-04
# 21  0.656250  0.959191      0.795958  0.548140   2.000000e-04
# 22  0.802598  0.552635      0.808344  0.548111   2.000000e-04
# 23  0.718750  0.601249      0.808996  0.548907   2.000000e-04
# 24  0.809952  0.535843      0.803455  0.540535   2.000000e-04
# 25  0.875000  0.369894      0.803781  0.540084   2.000000e-04
# 26  0.813792  0.527656      0.808344  0.542000   2.000000e-04
# 27  0.843750  0.438650      0.808018  0.540726   2.000000e-04
# 28  0.827600  0.491432      0.816493  0.514967   4.000000e-05
# 29  0.906250  0.342509      0.816167  0.514889   4.000000e-05
# 30  0.830051  0.484275      0.817471  0.511461   4.000000e-05
# 31  0.843750  0.415966      0.817471  0.512084   4.000000e-05
# 32  0.835117  0.480186      0.817145  0.519528   4.000000e-05
# 33  0.906250  0.465148      0.817797  0.519269   4.000000e-05
# 34  0.837568  0.466051      0.818448  0.511660   4.000000e-05
# 35  0.656250  0.848521      0.818123  0.511432   4.000000e-05
# 36  0.836996  0.461998      0.819426  0.509439   4.000000e-05
# 37  0.781250  0.584383      0.818774  0.509744   4.000000e-05
# 38  0.838631  0.463069      0.819426  0.508133   4.000000e-05
# 39  0.937500  0.322886      0.820078  0.508387   4.000000e-05
# 40  0.839039  0.459494      0.822034  0.505509   4.000000e-05
# 41  0.812500  0.493956      0.822034  0.505344   4.000000e-05
# 42  0.838631  0.455588      0.822360  0.505781   4.000000e-05
# 43  0.968750  0.196046      0.822360  0.505742   4.000000e-05
# 44  0.841245  0.455373      0.822686  0.502966   4.000000e-05
# 45  0.875000  0.336287      0.822360  0.502958   4.000000e-05
# 46  0.839774  0.449055      0.815841  0.513808   4.000000e-05
# 47  0.843750  0.540430      0.816493  0.513703   4.000000e-05
# 48  0.842307  0.450572      0.821382  0.501437   4.000000e-05
# 49  0.968750  0.299085      0.821056  0.501350   8.000001e-06
# 50  0.845249  0.435802      0.820730  0.504056   8.000001e-06
# 51  0.906250  0.270739      0.820404  0.503997   8.000001e-06
# 52  0.848027  0.435790      0.822360  0.503743   8.000001e-06
# 53  0.812500  0.472137      0.822360  0.503927   1.600000e-06
# 54  0.842552  0.435008      0.822686  0.502888   1.600000e-06
# 55  0.843750  0.542242      0.822686  0.502727   1.600000e-06
# 56  0.850069  0.429232      0.822034  0.503128   1.600000e-06
# 57  0.875000  0.389326      0.822034  0.503115   3.200000e-07
# 58  0.846474  0.434935      0.822360  0.504319   3.200000e-07
# 59  0.843750  0.435115      0.822686  0.504011   3.200000e-07

# %%
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['accuracy'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['loss'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 5s - 12ms/step - accuracy: 0.8919 - loss: 0.3226
# W0000 00:00:1711958314.752649     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.8918588757514954
# 96/96 - 1s - 9ms/step - accuracy: 0.8227 - loss: 0.5030
#
# Test Accuracy: 0.8226857781410217
# 20/96 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# W0000 00:00:1711958317.419539     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step
# W0000 00:00:1711958319.808650     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.83      0.82      0.83       329
#      disgust       0.72      0.55      0.63        74
#         fear       0.69      0.79      0.74       162
#        happy       0.77      0.80      0.79       680
#      neutral       0.75      0.80      0.78       478
#          sad       0.55      0.39      0.46       160
#     surprise       0.93      0.93      0.93      1185
#
#     accuracy                           0.82      3068
#    macro avg       0.75      0.73      0.73      3068
# weighted avg       0.82      0.82      0.82      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
