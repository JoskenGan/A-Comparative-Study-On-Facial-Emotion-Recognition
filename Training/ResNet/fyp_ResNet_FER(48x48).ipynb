# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Add
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feraligned/feraligned/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (48,48,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Fear has 552 number of images
# Angry has 633 number of images
# Neutral has 863 number of images
# Sadness has 904 number of images
# Happy has 1577 number of images
#
# total images are 4529

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img_arr.append(np.expand_dims(cv2.imread(DATA_PATH + dir_ + "/" + f, 0), axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1,1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((4529, 48, 48, 1),
#  (4529, 5),
#  {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(48, 48), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3623, 48, 48, 1), (906, 48, 48, 1), (3623, 5), (906, 5))

# %%
def identity_block(X, kernel: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'idblock_conv_' +  str(stage) + f'_{block_id}'
    bn_name = 'idblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "idblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters = filters[0],
        kernel_size = (1, 1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters = filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters = filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_c',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def convolutional_block(X, kernel: tuple, stride: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'convblock_conv_' + str(stage) + f'_{block_id}'
    bn_name = 'convblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "convblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters[0],
        kernel_size = (1, 1),
        strides = stride,
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_c',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X_shortcut = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = stride,
        padding = 'valid',
        name = conv_name + '_sc1',
        kernel_initializer=glorot_uniform(seed =0)
    )(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name + '_sc1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def CNN_with_SkipConnections(input_shape, classes, show_summary=False):
    model_in = Input(input_shape)

    X = Conv2D(
        filters = 32,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(model_in)
    X = BatchNormalization(axis = 3, name = 'bn_0_a')(X)
    X = Activation('relu', name="actv_0_a")(X)

    X = Conv2D(
        filters = 64,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_b',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = 'bn_0_b')(X)
    X = Activation('relu', name="actv_0_b")(X)

    # Block 0
    X = convolutional_block(model_in, (3,3), stride=(1,1), filters = [32, 32, 64], stage=0, block_id='a')
    X = identity_block(X, (3,3), [32, 32, 64], stage=0, block_id='a')

    # Block 1
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [64, 64, 128], stage=1, block_id='a')
    X = identity_block(X, (3,3), [64, 64, 128], stage=1, block_id='a')

    # Block 2
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [128,128,256], stage=2, block_id='a')
    X = identity_block(X, (2,2), [128,128,256], stage=2, block_id='a')

    X = AveragePooling2D()(X)

    X = Flatten()(X)
    X = Dense(
        128,
        kernel_initializer = glorot_uniform(seed=0),
        name = 'dense_1',
    )(X)
    X = BatchNormalization(name = 'bn_3')(X)
    X = Activation('relu', name="actv_3")(X)

    model_out = Dense(classes, activation='softmax', name="out_layer")(X)

    model = Model(inputs = model_in, outputs = model_out, name='CNN_with_SkipConnections')

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = CNN_with_SkipConnections(INPUT_SHAPE, NUM_CLASSES, show_summary=True)
# Out:
# Model: "CNN_with_SkipConnections"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  convblock_conv_0_a_a (Conv  (None, 48, 48, 32)           64        ['input_2[0][0]']
#  2D)
#
#  convblock_bn_0_a_a (BatchN  (None, 48, 48, 32)           128       ['convblock_conv_0_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_0_a_a (Acti  (None, 48, 48, 32)           0         ['convblock_bn_0_a_a[0][0]']
#  vation)
#
#  convblock_conv_0_a_b (Conv  (None, 48, 48, 32)           9248      ['convblock_actv_0_a_a[0][0]']
#  2D)
#
#  convblock_bn_0_a_b (BatchN  (None, 48, 48, 32)           128       ['convblock_conv_0_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_0_a_b (Acti  (None, 48, 48, 32)           0         ['convblock_bn_0_a_b[0][0]']
#  vation)
#
#  convblock_conv_0_a_c (Conv  (None, 48, 48, 64)           2112      ['convblock_actv_0_a_b[0][0]']
#  2D)
#
#  convblock_conv_0_a_sc1 (Co  (None, 48, 48, 64)           128       ['input_2[0][0]']
#  nv2D)
#
#  convblock_bn_0_a_c (BatchN  (None, 48, 48, 64)           256       ['convblock_conv_0_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_0_a_sc1 (Batc  (None, 48, 48, 64)           256       ['convblock_conv_0_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add_6 (Add)                 (None, 48, 48, 64)           0         ['convblock_bn_0_a_c[0][0]',
#                                                                      'convblock_bn_0_a_sc1[0][0]']
#
#  convblock_actv_0_a_c (Acti  (None, 48, 48, 64)           0         ['add_6[0][0]']
#  vation)
#
#  idblock_conv_0_a_a (Conv2D  (None, 48, 48, 32)           2080      ['convblock_actv_0_a_c[0][0]']
#  )
#
#  idblock_bn_0_a_a (BatchNor  (None, 48, 48, 32)           128       ['idblock_conv_0_a_a[0][0]']
#  malization)
#
#  idblock_actv_0_a_a (Activa  (None, 48, 48, 32)           0         ['idblock_bn_0_a_a[0][0]']
#  tion)
#
#  idblock_conv_0_a_b (Conv2D  (None, 48, 48, 32)           9248      ['idblock_actv_0_a_a[0][0]']
#  )
#
#  idblock_bn_0_a_b (BatchNor  (None, 48, 48, 32)           128       ['idblock_conv_0_a_b[0][0]']
#  malization)
#
#  idblock_actv_0_a_b (Activa  (None, 48, 48, 32)           0         ['idblock_bn_0_a_b[0][0]']
#  tion)
#
#  idblock_conv_0_a_c (Conv2D  (None, 48, 48, 64)           2112      ['idblock_actv_0_a_b[0][0]']
#  )
#
#  idblock_bn_0_a_c (BatchNor  (None, 48, 48, 64)           256       ['idblock_conv_0_a_c[0][0]']
#  malization)
#
#  add_7 (Add)                 (None, 48, 48, 64)           0         ['idblock_bn_0_a_c[0][0]',
#                                                                      'convblock_actv_0_a_c[0][0]']
#
#  idblock_actv_0_a_c (Activa  (None, 48, 48, 64)           0         ['add_7[0][0]']
#  tion)
#
#  convblock_conv_1_a_a (Conv  (None, 24, 24, 64)           4160      ['idblock_actv_0_a_c[0][0]']
#  2D)
#
#  convblock_bn_1_a_a (BatchN  (None, 24, 24, 64)           256       ['convblock_conv_1_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_1_a_a (Acti  (None, 24, 24, 64)           0         ['convblock_bn_1_a_a[0][0]']
#  vation)
#
#  convblock_conv_1_a_b (Conv  (None, 24, 24, 64)           36928     ['convblock_actv_1_a_a[0][0]']
#  2D)
#
#  convblock_bn_1_a_b (BatchN  (None, 24, 24, 64)           256       ['convblock_conv_1_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_1_a_b (Acti  (None, 24, 24, 64)           0         ['convblock_bn_1_a_b[0][0]']
#  vation)
#
#  convblock_conv_1_a_c (Conv  (None, 24, 24, 128)          8320      ['convblock_actv_1_a_b[0][0]']
#  2D)
#
#  convblock_conv_1_a_sc1 (Co  (None, 24, 24, 128)          8320      ['idblock_actv_0_a_c[0][0]']
#  nv2D)
#
#  convblock_bn_1_a_c (BatchN  (None, 24, 24, 128)          512       ['convblock_conv_1_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_1_a_sc1 (Batc  (None, 24, 24, 128)          512       ['convblock_conv_1_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add_8 (Add)                 (None, 24, 24, 128)          0         ['convblock_bn_1_a_c[0][0]',
#                                                                      'convblock_bn_1_a_sc1[0][0]']
#
#  convblock_actv_1_a_c (Acti  (None, 24, 24, 128)          0         ['add_8[0][0]']
#  vation)
#
#  idblock_conv_1_a_a (Conv2D  (None, 24, 24, 64)           8256      ['convblock_actv_1_a_c[0][0]']
#  )
#
#  idblock_bn_1_a_a (BatchNor  (None, 24, 24, 64)           256       ['idblock_conv_1_a_a[0][0]']
#  malization)
#
#  idblock_actv_1_a_a (Activa  (None, 24, 24, 64)           0         ['idblock_bn_1_a_a[0][0]']
#  tion)
#
#  idblock_conv_1_a_b (Conv2D  (None, 24, 24, 64)           36928     ['idblock_actv_1_a_a[0][0]']
#  )
#
#  idblock_bn_1_a_b (BatchNor  (None, 24, 24, 64)           256       ['idblock_conv_1_a_b[0][0]']
#  malization)
#
#  idblock_actv_1_a_b (Activa  (None, 24, 24, 64)           0         ['idblock_bn_1_a_b[0][0]']
#  tion)
#
#  idblock_conv_1_a_c (Conv2D  (None, 24, 24, 128)          8320      ['idblock_actv_1_a_b[0][0]']
#  )
#
#  idblock_bn_1_a_c (BatchNor  (None, 24, 24, 128)          512       ['idblock_conv_1_a_c[0][0]']
#  malization)
#
#  add_9 (Add)                 (None, 24, 24, 128)          0         ['idblock_bn_1_a_c[0][0]',
#                                                                      'convblock_actv_1_a_c[0][0]']
#
#  idblock_actv_1_a_c (Activa  (None, 24, 24, 128)          0         ['add_9[0][0]']
#  tion)
#
#  convblock_conv_2_a_a (Conv  (None, 12, 12, 128)          16512     ['idblock_actv_1_a_c[0][0]']
#  2D)
#
#  convblock_bn_2_a_a (BatchN  (None, 12, 12, 128)          512       ['convblock_conv_2_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_2_a_a (Acti  (None, 12, 12, 128)          0         ['convblock_bn_2_a_a[0][0]']
#  vation)
#
#  convblock_conv_2_a_b (Conv  (None, 12, 12, 128)          147584    ['convblock_actv_2_a_a[0][0]']
#  2D)
#
#  convblock_bn_2_a_b (BatchN  (None, 12, 12, 128)          512       ['convblock_conv_2_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_2_a_b (Acti  (None, 12, 12, 128)          0         ['convblock_bn_2_a_b[0][0]']
#  vation)
#
#  convblock_conv_2_a_c (Conv  (None, 12, 12, 256)          33024     ['convblock_actv_2_a_b[0][0]']
#  2D)
#
#  convblock_conv_2_a_sc1 (Co  (None, 12, 12, 256)          33024     ['idblock_actv_1_a_c[0][0]']
#  nv2D)
#
#  convblock_bn_2_a_c (BatchN  (None, 12, 12, 256)          1024      ['convblock_conv_2_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_2_a_sc1 (Batc  (None, 12, 12, 256)          1024      ['convblock_conv_2_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add_10 (Add)                (None, 12, 12, 256)          0         ['convblock_bn_2_a_c[0][0]',
#                                                                      'convblock_bn_2_a_sc1[0][0]']
#
#  convblock_actv_2_a_c (Acti  (None, 12, 12, 256)          0         ['add_10[0][0]']
#  vation)
#
#  idblock_conv_2_a_a (Conv2D  (None, 12, 12, 128)          32896     ['convblock_actv_2_a_c[0][0]']
#  )
#
#  idblock_bn_2_a_a (BatchNor  (None, 12, 12, 128)          512       ['idblock_conv_2_a_a[0][0]']
#  malization)
#
#  idblock_actv_2_a_a (Activa  (None, 12, 12, 128)          0         ['idblock_bn_2_a_a[0][0]']
#  tion)
#
#  idblock_conv_2_a_b (Conv2D  (None, 12, 12, 128)          65664     ['idblock_actv_2_a_a[0][0]']
#  )
#
#  idblock_bn_2_a_b (BatchNor  (None, 12, 12, 128)          512       ['idblock_conv_2_a_b[0][0]']
#  malization)
#
#  idblock_actv_2_a_b (Activa  (None, 12, 12, 128)          0         ['idblock_bn_2_a_b[0][0]']
#  tion)
#
#  idblock_conv_2_a_c (Conv2D  (None, 12, 12, 256)          33024     ['idblock_actv_2_a_b[0][0]']
#  )
#
#  idblock_bn_2_a_c (BatchNor  (None, 12, 12, 256)          1024      ['idblock_conv_2_a_c[0][0]']
#  malization)
#
#  add_11 (Add)                (None, 12, 12, 256)          0         ['idblock_bn_2_a_c[0][0]',
#                                                                      'convblock_actv_2_a_c[0][0]']
#
#  idblock_actv_2_a_c (Activa  (None, 12, 12, 256)          0         ['add_11[0][0]']
#  tion)
#
#  average_pooling2d_1 (Avera  (None, 6, 6, 256)            0         ['idblock_actv_2_a_c[0][0]']
#  gePooling2D)
#
#  flatten_1 (Flatten)         (None, 9216)                 0         ['average_pooling2d_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  1179776   ['flatten_1[0][0]']
#
#  bn_3 (BatchNormalization)   (None, 128)                  512       ['dense_1[0][0]']
#
#  actv_3 (Activation)         (None, 128)                  0         ['bn_3[0][0]']
#
#  out_layer (Dense)           (None, 5)                    645       ['actv_3[0][0]']
#
# ==================================================================================================
# Total params: 1687845 (6.44 MB)
# Trainable params: 1683109 (6.42 MB)
# Non-trainable params: 4736 (18.50 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=9,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_ResNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 113/113 [==============================] - 20s 42ms/step - loss: 1.5648 - accuracy: 0.3516 - val_loss: 1.7200 - val_accuracy: 0.3499 - lr: 0.0010
# Epoch 2/100
# 113/113 [==============================] - 4s 36ms/step - loss: 1.3289 - accuracy: 0.4590 - val_loss: 2.1718 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 3/100
# 113/113 [==============================] - 4s 37ms/step - loss: 1.2311 - accuracy: 0.5029 - val_loss: 1.4854 - val_accuracy: 0.4404 - lr: 0.0010
# Epoch 4/100
# 113/113 [==============================] - 4s 36ms/step - loss: 1.1147 - accuracy: 0.5537 - val_loss: 1.1871 - val_accuracy: 0.5121 - lr: 0.0010
# Epoch 5/100
# 113/113 [==============================] - 4s 36ms/step - loss: 1.0503 - accuracy: 0.5863 - val_loss: 1.1702 - val_accuracy: 0.5464 - lr: 0.0010
# Epoch 6/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.9978 - accuracy: 0.6020 - val_loss: 1.2629 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 7/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.9575 - accuracy: 0.6257 - val_loss: 1.1895 - val_accuracy: 0.5453 - lr: 0.0010
# Epoch 8/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.9113 - accuracy: 0.6390 - val_loss: 0.9712 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 9/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.8896 - accuracy: 0.6508 - val_loss: 1.1821 - val_accuracy: 0.5364 - lr: 0.0010
# Epoch 10/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.8627 - accuracy: 0.6553 - val_loss: 1.3197 - val_accuracy: 0.5077 - lr: 0.0010
# Epoch 11/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.8360 - accuracy: 0.6704 - val_loss: 1.0394 - val_accuracy: 0.6280 - lr: 0.0010
# Epoch 12/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.8080 - accuracy: 0.6878 - val_loss: 1.1023 - val_accuracy: 0.5916 - lr: 0.0010
# Epoch 13/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.7913 - accuracy: 0.7036 - val_loss: 1.0137 - val_accuracy: 0.6280 - lr: 0.0010
# Epoch 14/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.7725 - accuracy: 0.7071 - val_loss: 0.9435 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 15/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.7498 - accuracy: 0.7160 - val_loss: 1.0416 - val_accuracy: 0.6269 - lr: 0.0010
# Epoch 16/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.7267 - accuracy: 0.7212 - val_loss: 0.9759 - val_accuracy: 0.6391 - lr: 0.0010
# Epoch 17/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.7254 - accuracy: 0.7226 - val_loss: 1.0170 - val_accuracy: 0.6247 - lr: 0.0010
# Epoch 18/100
# 114/113 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.7394
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 113/113 [==============================] - 4s 36ms/step - loss: 0.6934 - accuracy: 0.7394 - val_loss: 1.1085 - val_accuracy: 0.5872 - lr: 0.0010
# Epoch 19/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.6451 - accuracy: 0.7599 - val_loss: 0.8464 - val_accuracy: 0.6766 - lr: 1.0000e-04
# Epoch 20/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5914 - accuracy: 0.7803 - val_loss: 0.8284 - val_accuracy: 0.6876 - lr: 1.0000e-04
# Epoch 21/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.6007 - accuracy: 0.7770 - val_loss: 0.8255 - val_accuracy: 0.6965 - lr: 1.0000e-04
# Epoch 22/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.5611 - accuracy: 0.7902 - val_loss: 0.8288 - val_accuracy: 0.6987 - lr: 1.0000e-04
# Epoch 23/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.5581 - accuracy: 0.7875 - val_loss: 0.8225 - val_accuracy: 0.6976 - lr: 1.0000e-04
# Epoch 24/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5395 - accuracy: 0.8015 - val_loss: 0.8237 - val_accuracy: 0.6976 - lr: 1.0000e-04
# Epoch 25/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.5310 - accuracy: 0.8079 - val_loss: 0.8222 - val_accuracy: 0.6987 - lr: 1.0000e-04
# Epoch 26/100
# 114/113 [==============================] - ETA: 0s - loss: 0.5237 - accuracy: 0.8101
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5237 - accuracy: 0.8101 - val_loss: 0.8390 - val_accuracy: 0.6921 - lr: 1.0000e-04
# Epoch 27/100
# 113/113 [==============================] - 4s 35ms/step - loss: 0.5220 - accuracy: 0.8137 - val_loss: 0.8373 - val_accuracy: 0.6932 - lr: 1.0000e-05
# Epoch 28/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5175 - accuracy: 0.8109 - val_loss: 0.8382 - val_accuracy: 0.6954 - lr: 1.0000e-05
# Epoch 29/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5111 - accuracy: 0.8165 - val_loss: 0.8360 - val_accuracy: 0.6965 - lr: 1.0000e-05
# Epoch 30/100
# 114/113 [==============================] - ETA: 0s - loss: 0.5020 - accuracy: 0.8156
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 113/113 [==============================] - 4s 35ms/step - loss: 0.5020 - accuracy: 0.8156 - val_loss: 0.8375 - val_accuracy: 0.6965 - lr: 1.0000e-05
# Epoch 31/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5088 - accuracy: 0.8073 - val_loss: 0.8378 - val_accuracy: 0.6965 - lr: 1.0000e-06
# Epoch 32/100
# 113/113 [==============================] - 4s 37ms/step - loss: 0.5118 - accuracy: 0.8195 - val_loss: 0.8375 - val_accuracy: 0.6976 - lr: 1.0000e-06
# Epoch 33/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5146 - accuracy: 0.8093 - val_loss: 0.8373 - val_accuracy: 0.6965 - lr: 1.0000e-06
# Epoch 34/100
# 114/113 [==============================] - ETA: 0s - loss: 0.5150 - accuracy: 0.8151
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5150 - accuracy: 0.8151 - val_loss: 0.8371 - val_accuracy: 0.6932 - lr: 1.0000e-06
# Epoch 35/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5067 - accuracy: 0.8162 - val_loss: 0.8372 - val_accuracy: 0.6943 - lr: 1.0000e-07
# Epoch 36/100
# 113/113 [==============================] - 4s 36ms/step - loss: 0.5085 - accuracy: 0.8159 - val_loss: 0.8367 - val_accuracy: 0.6965 - lr: 1.0000e-07
# Epoch 37/100
# 114/113 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.8200Epoch 36: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 21.
# 113/113 [==============================] - 4s 36ms/step - loss: 0.4993 - accuracy: 0.8200 - val_loss: 0.8370 - val_accuracy: 0.6976 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_ResNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.564762  0.351642  1.719968      0.349890  1.000000e-03
# 1   1.328923  0.459012  2.171752      0.347682  1.000000e-03
# 2   1.231113  0.502898  1.485385      0.440397  1.000000e-03
# 3   1.114656  0.553685  1.187124      0.512141  1.000000e-03
# 4   1.050337  0.586254  1.170218      0.546358  1.000000e-03
# 5   0.997826  0.601987  1.262939      0.500000  1.000000e-03
# 6   0.957548  0.625725  1.189540      0.545254  1.000000e-03
# 7   0.911342  0.638973  0.971178      0.624724  1.000000e-03
# 8   0.889565  0.650842  1.182086      0.536424  1.000000e-03
# 9   0.862668  0.655258  1.319677      0.507726  1.000000e-03
# 10  0.836014  0.670439  1.039415      0.628035  1.000000e-03
# 11  0.807976  0.687828  1.102277      0.591612  1.000000e-03
# 12  0.791266  0.703561  1.013739      0.628035  1.000000e-03
# 13  0.772504  0.707149  0.943513      0.651214  1.000000e-03
# 14  0.749793  0.715981  1.041605      0.626932  1.000000e-03
# 15  0.726735  0.721226  0.975897      0.639073  1.000000e-03
# 16  0.725417  0.722606  1.017035      0.624724  1.000000e-03
# 17  0.693372  0.739442  1.108472      0.587196  1.000000e-03
# 18  0.645137  0.759867  0.846370      0.676600  1.000000e-04
# 19  0.591384  0.780293  0.828389      0.687638  1.000000e-04
# 20  0.600708  0.776980  0.825548      0.696468  1.000000e-04
# 21  0.561091  0.790229  0.828820      0.698676  1.000000e-04
# 22  0.558092  0.787469  0.822487      0.697572  1.000000e-04
# 23  0.539460  0.801546  0.823732      0.697572  1.000000e-04
# 24  0.530955  0.807894  0.822203      0.698676  1.000000e-04
# 25  0.523735  0.810102  0.839043      0.692053  1.000000e-04
# 26  0.521981  0.813690  0.837253      0.693157  1.000000e-05
# 27  0.517498  0.810930  0.838237      0.695364  1.000000e-05
# 28  0.511095  0.816450  0.836038      0.696468  1.000000e-05
# 29  0.501970  0.815622  0.837506      0.696468  1.000000e-05
# 30  0.508814  0.807342  0.837760      0.696468  1.000000e-06
# 31  0.511779  0.819487  0.837466      0.697572  1.000000e-06
# 32  0.514621  0.809274  0.837313      0.696468  1.000000e-06
# 33  0.515021  0.815070  0.837144      0.693157  1.000000e-06
# 34  0.506664  0.816174  0.837162      0.694260  1.000000e-07
# 35  0.508508  0.815898  0.836698      0.696468  1.000000e-07
# 36  0.499295  0.820039  0.837031      0.697572  1.000000e-07

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['accuracy'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['loss'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 114/114 - 1s - loss: 0.4494 - accuracy: 0.8418 - 1s/epoch - 9ms/step
#
# train Accuracy: 0.8418437838554382
# 29/29 - 0s - loss: 0.8288 - accuracy: 0.6987 - 273ms/epoch - 9ms/step
#
# Test Accuracy: 0.6986755132675171
# 29/29 [==============================] - 1s 8ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       0.61      0.60      0.60       110
#         Fear       0.70      0.69      0.69       127
#        Happy       0.60      0.63      0.61       173
#      Neutral       0.53      0.54      0.54       181
#      Sadness       0.89      0.87      0.88       315
#
#     accuracy                           0.70       906
#    macro avg       0.67      0.66      0.66       906
# weighted avg       0.70      0.70      0.70       906

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(X_test), size=num_images_to_visualize, replace=False)

pyplot.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    pyplot.subplot(2, 5, i + 1)
    pyplot.imshow(X_test[idx])
    pyplot.title(f"True: {label_to_text[true_labels[idx]]}\nPredicted: {label_to_text[predicted_labels[idx]]}")
    pyplot.axis('off')
pyplot.tight_layout()
pyplot.show()

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /opt/conda/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Requirement already satisfied: aggdraw>=1.3.11 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.3.18.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2677x292>
