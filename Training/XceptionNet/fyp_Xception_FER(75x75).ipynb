# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-03 15:55:43.604762: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 15:55:43.604866: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 15:55:43.770339: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feraligned/feraligned/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness"]

# Define constants
TRAIN_SIZE = 0.80
INPUT_SHAPE = (75, 75, 3) # input size must 75 x 75
NUM_CLASSES = len(TOP_EMOTIONS)
BATCH_SIZE = 32
EPOCHS = 100

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Fear has 552 number of images
# Angry has 633 number of images
# Neutral has 863 number of images
# Sadness has 904 number of images
# Happy has 1577 number of images
#
# total images are 4529

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f)
            img = cv2.resize(img, (75, 75))

            # Convert image to RGB format if it's grayscale
            if img.shape[-1] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

            img_arr.append(img)
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((4529, 75, 75, 3),
#  (4529, 5),
#  {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'})

# %%
# Memory cleanup
del img
del dir_
del f

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols * 2, num_emotions * 2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3623, 75, 75, 3), (906, 75, 75, 3), (3623, 5), (906, 5))

# %%
# Memory cleanup
del img_arr
del img_label

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(X_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,397 (80.58 MB)
#  Trainable params: 262,917 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   4/113 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.3770 - loss: 1.6350
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712159811.784343      88 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712159811.813745      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  28/113 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.3487 - loss: 1.6298
# W0000 00:00:1712159817.118290      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3555 - loss: 1.5593
# W0000 00:00:1712159824.575771      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 29s 152ms/step - accuracy: 0.3556 - loss: 1.5588 - val_accuracy: 0.4161 - val_loss: 1.4190 - learning_rate: 0.0010
# Epoch 2/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4062 - loss: 1.4003
# W0000 00:00:1712159828.648614      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.4003 - val_accuracy: 0.4150 - val_loss: 1.4168 - learning_rate: 0.0010
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.4270 - loss: 1.3884 - val_accuracy: 0.4492 - val_loss: 1.3583 - learning_rate: 0.0010
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2500 - loss: 1.6327 - val_accuracy: 0.4470 - val_loss: 1.3495 - learning_rate: 0.0010
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.4600 - loss: 1.3303 - val_accuracy: 0.4801 - val_loss: 1.3091 - learning_rate: 0.0010
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.1935 - val_accuracy: 0.4702 - val_loss: 1.3118 - learning_rate: 0.0010
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.4825 - loss: 1.2750 - val_accuracy: 0.4790 - val_loss: 1.2879 - learning_rate: 0.0010
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4375 - loss: 1.2475 - val_accuracy: 0.4790 - val_loss: 1.2910 - learning_rate: 0.0010
# Epoch 9/100
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4831 - loss: 1.2790
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.4832 - loss: 1.2788 - val_accuracy: 0.4581 - val_loss: 1.3513 - learning_rate: 0.0010
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4688 - loss: 1.2654 - val_accuracy: 0.4570 - val_loss: 1.3494 - learning_rate: 1.0000e-04
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5212 - loss: 1.2102 - val_accuracy: 0.4956 - val_loss: 1.2894 - learning_rate: 1.0000e-04
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.3480 - val_accuracy: 0.4956 - val_loss: 1.2887 - learning_rate: 1.0000e-04
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5301 - loss: 1.1782 - val_accuracy: 0.4967 - val_loss: 1.2891 - learning_rate: 1.0000e-04
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4062 - loss: 1.2848 - val_accuracy: 0.4956 - val_loss: 1.2886 - learning_rate: 1.0000e-04
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5194 - loss: 1.2075 - val_accuracy: 0.5022 - val_loss: 1.2805 - learning_rate: 1.0000e-04
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6562 - loss: 0.9687 - val_accuracy: 0.5011 - val_loss: 1.2807 - learning_rate: 1.0000e-04
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5257 - loss: 1.1813 - val_accuracy: 0.5022 - val_loss: 1.2874 - learning_rate: 1.0000e-04
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 1.0739 - val_accuracy: 0.5033 - val_loss: 1.2884 - learning_rate: 1.0000e-04
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5368 - loss: 1.1772 - val_accuracy: 0.4945 - val_loss: 1.2817 - learning_rate: 1.0000e-04
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3750 - loss: 1.3716 - val_accuracy: 0.4945 - val_loss: 1.2823 - learning_rate: 1.0000e-04
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5326 - loss: 1.1887 - val_accuracy: 0.5011 - val_loss: 1.2758 - learning_rate: 1.0000e-04
# Epoch 22/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5625 - loss: 1.1703
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.1703 - val_accuracy: 0.5022 - val_loss: 1.2762 - learning_rate: 1.0000e-04
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5549 - loss: 1.1339 - val_accuracy: 0.4989 - val_loss: 1.2759 - learning_rate: 1.0000e-05
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.5439 - val_accuracy: 0.4989 - val_loss: 1.2760 - learning_rate: 1.0000e-05
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5470 - loss: 1.1599 - val_accuracy: 0.5033 - val_loss: 1.2758 - learning_rate: 1.0000e-05
# Epoch 26/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6250 - loss: 1.2295
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6250 - loss: 1.2295 - val_accuracy: 0.5033 - val_loss: 1.2757 - learning_rate: 1.0000e-05
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5308 - loss: 1.1863 - val_accuracy: 0.5033 - val_loss: 1.2755 - learning_rate: 1.0000e-06
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5312 - loss: 1.0982 - val_accuracy: 0.5033 - val_loss: 1.2755 - learning_rate: 1.0000e-06
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5477 - loss: 1.1461 - val_accuracy: 0.5044 - val_loss: 1.2756 - learning_rate: 1.0000e-06
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4375 - loss: 1.1926 - val_accuracy: 0.5044 - val_loss: 1.2755 - learning_rate: 1.0000e-06
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5516 - loss: 1.1432 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-06
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4688 - loss: 1.2411 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-06
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5592 - loss: 1.1469
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5591 - loss: 1.1470 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-06
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4688 - loss: 1.0051 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.5438 - loss: 1.1518 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.0874 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5278 - loss: 1.1654
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5278 - loss: 1.1654 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5938 - loss: 1.0670 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5504 - loss: 1.1689 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4688 - loss: 1.2216 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5374 - loss: 1.1664 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4688 - loss: 1.1723 - val_accuracy: 0.5044 - val_loss: 1.2754 - learning_rate: 1.0000e-07
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5320 - loss: 1.1481 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5312 - loss: 1.1958 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5393 - loss: 1.1774 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5625 - loss: 1.0868 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5513 - loss: 1.1768 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.1851 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.5303 - loss: 1.1597 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 1.1547 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.5556 - loss: 1.1473 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 52/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.1297 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5240 - loss: 1.1771 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07
# Epoch 54/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5625 - loss: 1.2162Epoch 53: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 28.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5625 - loss: 1.2162 - val_accuracy: 0.5044 - val_loss: 1.2753 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.369256  1.504539      0.416115  1.419043   1.000000e-03
# 1   0.406250  1.400252      0.415011  1.416755   1.000000e-03
# 2   0.422167  1.392750      0.449227  1.358318   1.000000e-03
# 3   0.250000  1.632674      0.447020  1.349521   1.000000e-03
# 4   0.454191  1.335442      0.480132  1.309064   1.000000e-03
# 5   0.562500  1.193466      0.470199  1.311835   1.000000e-03
# 6   0.477026  1.299892      0.479029  1.287897   1.000000e-03
# 7   0.437500  1.247538      0.479029  1.291048   1.000000e-03
# 8   0.489000  1.274142      0.458057  1.351333   1.000000e-03
# 9   0.468750  1.265411      0.456954  1.349368   1.000000e-04
# 10  0.520189  1.212692      0.495585  1.289425   1.000000e-04
# 11  0.406250  1.348049      0.495585  1.288697   1.000000e-04
# 12  0.518797  1.194366      0.496689  1.289126   1.000000e-04
# 13  0.406250  1.284807      0.495585  1.288596   1.000000e-04
# 14  0.527430  1.197697      0.502208  1.280495   1.000000e-04
# 15  0.656250  0.968689      0.501104  1.280735   1.000000e-04
# 16  0.527430  1.190228      0.502208  1.287421   1.000000e-04
# 17  0.593750  1.073875      0.503311  1.288436   1.000000e-04
# 18  0.524923  1.185963      0.494481  1.281659   1.000000e-04
# 19  0.375000  1.371627      0.494481  1.282343   1.000000e-04
# 20  0.532721  1.180113      0.501104  1.275800   1.000000e-04
# 21  0.562500  1.170308      0.502208  1.276209   1.000000e-04
# 22  0.544138  1.157995      0.498896  1.275884   1.000000e-05
# 23  0.406250  1.543920      0.498896  1.275952   1.000000e-05
# 24  0.545809  1.162388      0.503311  1.275796   1.000000e-05
# 25  0.625000  1.229509      0.503311  1.275746   1.000000e-05
# 26  0.538012  1.170272      0.503311  1.275531   1.000000e-06
# 27  0.531250  1.098186      0.503311  1.275535   1.000000e-06
# 28  0.544417  1.162858      0.504415  1.275552   1.000000e-06
# 29  0.437500  1.192637      0.504415  1.275549   1.000000e-06
# 30  0.542467  1.165703      0.504415  1.275333   1.000000e-06
# 31  0.468750  1.241117      0.504415  1.275338   1.000000e-06
# 32  0.545530  1.162035      0.504415  1.275425   1.000000e-06
# 33  0.468750  1.005125      0.504415  1.275425   1.000000e-07
# 34  0.537176  1.163804      0.504415  1.275399   1.000000e-07
# 35  0.562500  1.087394      0.504415  1.275400   1.000000e-07
# 36  0.531050  1.168163      0.504415  1.275389   1.000000e-07
# 37  0.593750  1.067004      0.504415  1.275388   1.000000e-07
# 38  0.540796  1.169950      0.504415  1.275374   1.000000e-07
# 39  0.468750  1.221612      0.504415  1.275375   1.000000e-07
# 40  0.536619  1.167789      0.504415  1.275358   1.000000e-07
# 41  0.468750  1.172293      0.504415  1.275357   1.000000e-07
# 42  0.532999  1.158752      0.504415  1.275346   1.000000e-07
# 43  0.531250  1.195845      0.504415  1.275345   1.000000e-07
# 44  0.546087  1.165160      0.504415  1.275333   1.000000e-07
# 45  0.562500  1.086775      0.504415  1.275334   1.000000e-07
# 46  0.545809  1.168709      0.504415  1.275336   1.000000e-07
# 47  0.500000  1.185146      0.504415  1.275335   1.000000e-07
# 48  0.531328  1.163693      0.504415  1.275313   1.000000e-07
# 49  0.625000  1.154650      0.504415  1.275313   1.000000e-07
# 50  0.542189  1.161877      0.504415  1.275295   1.000000e-07
# 51  0.562500  1.129696      0.504415  1.275295   1.000000e-07
# 52  0.538847  1.160464      0.504415  1.275280   1.000000e-07
# 53  0.562500  1.216152      0.504415  1.275279   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,397 (80.58 MB)
#  Trainable params: 21,069,869 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1:23:07 45s/step - accuracy: 0.1562 - loss: 1.6799
# W0000 00:00:1712160055.140041      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  13/113 ━━━━━━━━━━━━━━━━━━━━ 2:59 2s/step - accuracy: 0.2478 - loss: 1.6254
# W0000 00:00:1712160076.674508      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.2756 - loss: 1.5885
# W0000 00:00:1712160086.944552      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 78s 301ms/step - accuracy: 0.2759 - loss: 1.5883 - val_accuracy: 0.3720 - val_loss: 1.4876 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.4688 - loss: 1.4612
# W0000 00:00:1712160088.962532      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4688 - loss: 1.4612 - val_accuracy: 0.3720 - val_loss: 1.4879 - learning_rate: 1.0000e-05
# Epoch 3/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.3855 - loss: 1.4889 - val_accuracy: 0.3985 - val_loss: 1.4601 - learning_rate: 1.0000e-05
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4688 - loss: 1.3646 - val_accuracy: 0.3996 - val_loss: 1.4591 - learning_rate: 1.0000e-05
# Epoch 5/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.4158 - loss: 1.4255 - val_accuracy: 0.4172 - val_loss: 1.4228 - learning_rate: 1.0000e-05
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.4313 - val_accuracy: 0.4161 - val_loss: 1.4233 - learning_rate: 1.0000e-05
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.4609 - loss: 1.3411 - val_accuracy: 0.4227 - val_loss: 1.3839 - learning_rate: 1.0000e-05
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 1.2689 - val_accuracy: 0.4260 - val_loss: 1.3842 - learning_rate: 1.0000e-05
# Epoch 9/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.4771 - loss: 1.2918 - val_accuracy: 0.4437 - val_loss: 1.3737 - learning_rate: 1.0000e-05
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.3095 - val_accuracy: 0.4459 - val_loss: 1.3760 - learning_rate: 1.0000e-05
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.5278 - loss: 1.2152 - val_accuracy: 0.4978 - val_loss: 1.2312 - learning_rate: 1.0000e-05
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 1.0317 - val_accuracy: 0.5000 - val_loss: 1.2327 - learning_rate: 1.0000e-05
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.5388 - loss: 1.1828 - val_accuracy: 0.5309 - val_loss: 1.1949 - learning_rate: 1.0000e-05
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5000 - loss: 1.0994 - val_accuracy: 0.5331 - val_loss: 1.1946 - learning_rate: 1.0000e-05
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.5647 - loss: 1.1313 - val_accuracy: 0.5541 - val_loss: 1.1913 - learning_rate: 1.0000e-05
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.0712 - val_accuracy: 0.5530 - val_loss: 1.1927 - learning_rate: 1.0000e-05
# Epoch 17/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.5867 - loss: 1.0709 - val_accuracy: 0.5618 - val_loss: 1.1783 - learning_rate: 1.0000e-05
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5312 - loss: 1.1461 - val_accuracy: 0.5629 - val_loss: 1.1813 - learning_rate: 1.0000e-05
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.5959 - loss: 1.0346 - val_accuracy: 0.5717 - val_loss: 1.1840 - learning_rate: 1.0000e-05
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.8584 - val_accuracy: 0.5728 - val_loss: 1.1787 - learning_rate: 1.0000e-05
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6171 - loss: 1.0159 - val_accuracy: 0.5828 - val_loss: 1.0984 - learning_rate: 1.0000e-05
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5938 - loss: 1.0516 - val_accuracy: 0.5828 - val_loss: 1.0993 - learning_rate: 1.0000e-05
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6166 - loss: 0.9828 - val_accuracy: 0.5894 - val_loss: 1.0866 - learning_rate: 1.0000e-05
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.7880 - val_accuracy: 0.5894 - val_loss: 1.0868 - learning_rate: 1.0000e-05
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6110 - loss: 0.9798 - val_accuracy: 0.5927 - val_loss: 1.1262 - learning_rate: 1.0000e-05
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.8362 - val_accuracy: 0.5949 - val_loss: 1.1289 - learning_rate: 1.0000e-05
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6526 - loss: 0.9000 - val_accuracy: 0.6026 - val_loss: 1.1626 - learning_rate: 1.0000e-05
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 0.8699 - val_accuracy: 0.6026 - val_loss: 1.1614 - learning_rate: 1.0000e-05
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6463 - loss: 0.9080 - val_accuracy: 0.6071 - val_loss: 1.1352 - learning_rate: 1.0000e-05
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5312 - loss: 1.1622 - val_accuracy: 0.6049 - val_loss: 1.1371 - learning_rate: 1.0000e-05
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6763 - loss: 0.8370 - val_accuracy: 0.6104 - val_loss: 1.1152 - learning_rate: 1.0000e-05
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.5964 - val_accuracy: 0.6093 - val_loss: 1.1095 - learning_rate: 1.0000e-05
# Epoch 33/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.6482 - loss: 0.8863 - val_accuracy: 0.6093 - val_loss: 1.1199 - learning_rate: 1.0000e-05
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.8291 - val_accuracy: 0.6104 - val_loss: 1.1223 - learning_rate: 1.0000e-05
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6690 - loss: 0.8392 - val_accuracy: 0.6236 - val_loss: 1.1044 - learning_rate: 1.0000e-05
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.8740 - val_accuracy: 0.6236 - val_loss: 1.1067 - learning_rate: 1.0000e-05
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7003 - loss: 0.8089 - val_accuracy: 0.6280 - val_loss: 1.0963 - learning_rate: 1.0000e-05
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.9093 - val_accuracy: 0.6269 - val_loss: 1.0987 - learning_rate: 1.0000e-05
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.7010 - loss: 0.7921 - val_accuracy: 0.6336 - val_loss: 1.0800 - learning_rate: 1.0000e-05
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.7721 - val_accuracy: 0.6336 - val_loss: 1.0822 - learning_rate: 1.0000e-05
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.7117 - loss: 0.7519 - val_accuracy: 0.6358 - val_loss: 1.1967 - learning_rate: 1.0000e-05
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9375 - loss: 0.4180 - val_accuracy: 0.6369 - val_loss: 1.2043 - learning_rate: 1.0000e-05
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.7149 - loss: 0.7551 - val_accuracy: 0.6402 - val_loss: 1.0866 - learning_rate: 1.0000e-05
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.6310 - val_accuracy: 0.6402 - val_loss: 1.0890 - learning_rate: 1.0000e-05
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7160 - loss: 0.7405 - val_accuracy: 0.6380 - val_loss: 1.1181 - learning_rate: 1.0000e-05
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9062 - loss: 0.4583 - val_accuracy: 0.6380 - val_loss: 1.1113 - learning_rate: 1.0000e-05
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7269 - loss: 0.7044
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7270 - loss: 0.7044 - val_accuracy: 0.6391 - val_loss: 1.1139 - learning_rate: 1.0000e-05
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7812 - loss: 0.7651 - val_accuracy: 0.6413 - val_loss: 1.1150 - learning_rate: 1.0000e-06
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7586 - loss: 0.6663 - val_accuracy: 0.6391 - val_loss: 1.1066 - learning_rate: 1.0000e-06
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.7232 - val_accuracy: 0.6380 - val_loss: 1.1082 - learning_rate: 1.0000e-06
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7508 - loss: 0.6783 - val_accuracy: 0.6391 - val_loss: 1.0999 - learning_rate: 1.0000e-06
# Epoch 52/100
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.8125 - loss: 0.5595
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-07.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.5595 - val_accuracy: 0.6391 - val_loss: 1.1004 - learning_rate: 1.0000e-06
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7458 - loss: 0.7016 - val_accuracy: 0.6413 - val_loss: 1.0920 - learning_rate: 1.0000e-07
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6743 - val_accuracy: 0.6413 - val_loss: 1.0947 - learning_rate: 1.0000e-07
# Epoch 55/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7440 - loss: 0.6739 - val_accuracy: 0.6369 - val_loss: 1.0884 - learning_rate: 1.0000e-07
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.7286 - val_accuracy: 0.6380 - val_loss: 1.0881 - learning_rate: 1.0000e-07
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7624 - loss: 0.6730 - val_accuracy: 0.6402 - val_loss: 1.0966 - learning_rate: 1.0000e-07
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.6996 - val_accuracy: 0.6413 - val_loss: 1.0971 - learning_rate: 1.0000e-07
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7328 - loss: 0.6902 - val_accuracy: 0.6402 - val_loss: 1.1097 - learning_rate: 1.0000e-07
# Epoch 60/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6024 - val_accuracy: 0.6413 - val_loss: 1.1096 - learning_rate: 1.0000e-07
# Epoch 61/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7492 - loss: 0.6551 - val_accuracy: 0.6369 - val_loss: 1.1061 - learning_rate: 1.0000e-07
# Epoch 62/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.6858 - val_accuracy: 0.6369 - val_loss: 1.1062 - learning_rate: 1.0000e-07
# Epoch 63/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7418 - loss: 0.6892 - val_accuracy: 0.6347 - val_loss: 1.1089 - learning_rate: 1.0000e-07
# Epoch 64/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7500 - loss: 0.8294 - val_accuracy: 0.6347 - val_loss: 1.1085 - learning_rate: 1.0000e-07
# Epoch 65/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7460 - loss: 0.6831 - val_accuracy: 0.6380 - val_loss: 1.0996 - learning_rate: 1.0000e-07
# Epoch 66/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.6284 - val_accuracy: 0.6380 - val_loss: 1.1001 - learning_rate: 1.0000e-07
# Epoch 67/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7481 - loss: 0.6720 - val_accuracy: 0.6347 - val_loss: 1.1266 - learning_rate: 1.0000e-07
# Epoch 68/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.5786 - val_accuracy: 0.6358 - val_loss: 1.1264 - learning_rate: 1.0000e-07
# Epoch 69/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.7433 - loss: 0.6833 - val_accuracy: 0.6380 - val_loss: 1.1074 - learning_rate: 1.0000e-07
# Epoch 70/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.5786 - val_accuracy: 0.6369 - val_loss: 1.1056 - learning_rate: 1.0000e-07
# Epoch 71/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.7331 - loss: 0.7009 - val_accuracy: 0.6391 - val_loss: 1.1123 - learning_rate: 1.0000e-07
# Epoch 72/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.6128 - val_accuracy: 0.6391 - val_loss: 1.1109 - learning_rate: 1.0000e-07
# Epoch 73/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7621 - loss: 0.6672Epoch 72: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 47.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.7620 - loss: 0.6673 - val_accuracy: 0.6380 - val_loss: 1.1270 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.305207  1.560246      0.371965  1.487591   1.000000e-05
# 1   0.468750  1.461202      0.371965  1.487887   1.000000e-05
# 2   0.397382  1.472163      0.398455  1.460133   1.000000e-05
# 3   0.468750  1.364558      0.399558  1.459140   1.000000e-05
# 4   0.429685  1.399438      0.417219  1.422827   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 68  0.744639  0.684332      0.637969  1.107406   1.000000e-07
# 69  0.875000  0.578589      0.636865  1.105558   1.000000e-07
# 70  0.745196  0.685574      0.639073  1.112298   1.000000e-07
# 71  0.718750  0.612777      0.639073  1.110869   1.000000e-07
# 72  0.751601  0.685079      0.637969  1.127041   1.000000e-07
#
# [73 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 114/114 - 4s - 34ms/step - accuracy: 0.7966 - loss: 0.7850
# W0000 00:00:1712160443.590237      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.7965773940086365
# 29/29 - 1s - 21ms/step - accuracy: 0.6413 - loss: 1.1150
#
# Test Accuracy: 0.6412803530693054
#  8/29 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# W0000 00:00:1712160447.315383      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step
# W0000 00:00:1712160450.611178      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       0.50      0.45      0.48       110
#         Fear       0.53      0.63      0.58       127
#        Happy       0.53      0.60      0.57       173
#      Neutral       0.55      0.45      0.49       181
#      Sadness       0.85      0.84      0.85       315
#
#     accuracy                           0.64       906
#    macro avg       0.59      0.60      0.59       906
# weighted avg       0.64      0.64      0.64       906

# %%
label_to_text
# Out:
# {0: 'Fear', 1: 'Angry', 2: 'Neutral', 3: 'Sadness', 4: 'Happy'}

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(X_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])
    plt.title(f"True: {label_to_text[true_labels[idx]]}\nPredicted: {label_to_text[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
