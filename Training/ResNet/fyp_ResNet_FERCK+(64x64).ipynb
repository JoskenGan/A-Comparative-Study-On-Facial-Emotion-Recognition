# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Add
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/feralignedck/feraligned+ck/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Neutral", "Sadness", "Surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Surprise has 249 number of images
# Fear has 728 number of images
# Angry has 938 number of images
# Neutral has 1230 number of images
# Sadness has 1153 number of images
# Happy has 2203 number of images
#
# total images are 6501

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Surprise images to numpy arrays...
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((6501, 64, 64, 1),
#  (6501, 6),
#  {0: 'Surprise',
#   1: 'Fear',
#   2: 'Angry',
#   3: 'Neutral',
#   4: 'Sadness',
#   5: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((5200, 64, 64, 1), (1301, 64, 64, 1), (5200, 6), (1301, 6))

# %%
def identity_block(X, kernel: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'idblock_conv_' +  str(stage) + f'_{block_id}'
    bn_name = 'idblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "idblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters = filters[0],
        kernel_size = (1, 1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters = filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters = filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_c',
        kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def convolutional_block(X, kernel: tuple, stride: tuple, filters: list, stage: int, block_id: str):
    conv_name = 'convblock_conv_' + str(stage) + f'_{block_id}'
    bn_name = 'convblock_bn_' + str(stage) + f'_{block_id}'
    actv_name = "convblock_actv_" + str(stage) + f'_{block_id}'

    X_shortcut = X

    X = Conv2D(
        filters[0],
        kernel_size = (1, 1),
        strides = stride,
        name = conv_name + '_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_a')(X)
    X = Activation('relu', name = actv_name + '_a')(X)

    X = Conv2D(
        filters[1],
        kernel_size = kernel,
        strides = (1,1),
        padding = 'same',
        name = conv_name + '_b',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_b')(X)
    X = Activation('relu', name = actv_name + '_b')(X)

    X = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = (1,1),
        padding = 'valid',
        name = conv_name + '_c',
        kernel_initializer=glorot_uniform(seed =0)
    )(X)
    X = BatchNormalization(axis = 3, name = bn_name + '_c')(X)

    X_shortcut = Conv2D(
        filters[2],
        kernel_size = (1,1),
        strides = stride,
        padding = 'valid',
        name = conv_name + '_sc1',
        kernel_initializer=glorot_uniform(seed =0)
    )(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name + '_sc1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu', name = actv_name + '_c')(X)

    return X

# %%
def CNN_with_SkipConnections(input_shape, classes, show_summary=False):
    model_in = Input(input_shape)

    X = Conv2D(
        filters = 32,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_a',
        kernel_initializer = glorot_uniform(seed=0)
    )(model_in)
    X = BatchNormalization(axis = 3, name = 'bn_0_a')(X)
    X = Activation('relu', name="actv_0_a")(X)

    X = Conv2D(
        filters = 64,
        kernel_size = (3,3),
        strides = (1,1),
        padding = 'valid',
        name = 'conv_0_b',
        kernel_initializer = glorot_uniform(seed=0)
    )(X)
    X = BatchNormalization(axis = 3, name = 'bn_0_b')(X)
    X = Activation('relu', name="actv_0_b")(X)

    # Block 0
    X = convolutional_block(model_in, (3,3), stride=(1,1), filters = [32, 32, 64], stage=0, block_id='a')
    X = identity_block(X, (3,3), [32, 32, 64], stage=0, block_id='a')

    # Block 1
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [64, 64, 128], stage=1, block_id='a')
    X = identity_block(X, (3,3), [64, 64, 128], stage=1, block_id='a')

    # Block 2
    X = convolutional_block(X, (3,3), stride=(2,2), filters = [128,128,256], stage=2, block_id='a')
    X = identity_block(X, (2,2), [128,128,256], stage=2, block_id='a')

    X = AveragePooling2D()(X)

    X = Flatten()(X)
    X = Dense(
        128,
        kernel_initializer = glorot_uniform(seed=0),
        name = 'dense_1',
    )(X)
    X = BatchNormalization(name = 'bn_3')(X)
    X = Activation('relu', name="actv_3")(X)

    model_out = Dense(classes, activation='softmax', name="out_layer")(X)

    model = Model(inputs = model_in, outputs = model_out, name='CNN_with_SkipConnections')

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = CNN_with_SkipConnections(INPUT_SHAPE, NUM_CLASSES, show_summary=True)
# Out:
# Model: "CNN_with_SkipConnections"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]          0         []
#
#  convblock_conv_0_a_a (Conv  (None, 64, 64, 32)           64        ['input_1[0][0]']
#  2D)
#
#  convblock_bn_0_a_a (BatchN  (None, 64, 64, 32)           128       ['convblock_conv_0_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_0_a_a (Acti  (None, 64, 64, 32)           0         ['convblock_bn_0_a_a[0][0]']
#  vation)
#
#  convblock_conv_0_a_b (Conv  (None, 64, 64, 32)           9248      ['convblock_actv_0_a_a[0][0]']
#  2D)
#
#  convblock_bn_0_a_b (BatchN  (None, 64, 64, 32)           128       ['convblock_conv_0_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_0_a_b (Acti  (None, 64, 64, 32)           0         ['convblock_bn_0_a_b[0][0]']
#  vation)
#
#  convblock_conv_0_a_c (Conv  (None, 64, 64, 64)           2112      ['convblock_actv_0_a_b[0][0]']
#  2D)
#
#  convblock_conv_0_a_sc1 (Co  (None, 64, 64, 64)           128       ['input_1[0][0]']
#  nv2D)
#
#  convblock_bn_0_a_c (BatchN  (None, 64, 64, 64)           256       ['convblock_conv_0_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_0_a_sc1 (Batc  (None, 64, 64, 64)           256       ['convblock_conv_0_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add (Add)                   (None, 64, 64, 64)           0         ['convblock_bn_0_a_c[0][0]',
#                                                                      'convblock_bn_0_a_sc1[0][0]']
#
#  convblock_actv_0_a_c (Acti  (None, 64, 64, 64)           0         ['add[0][0]']
#  vation)
#
#  idblock_conv_0_a_a (Conv2D  (None, 64, 64, 32)           2080      ['convblock_actv_0_a_c[0][0]']
#  )
#
#  idblock_bn_0_a_a (BatchNor  (None, 64, 64, 32)           128       ['idblock_conv_0_a_a[0][0]']
#  malization)
#
#  idblock_actv_0_a_a (Activa  (None, 64, 64, 32)           0         ['idblock_bn_0_a_a[0][0]']
#  tion)
#
#  idblock_conv_0_a_b (Conv2D  (None, 64, 64, 32)           9248      ['idblock_actv_0_a_a[0][0]']
#  )
#
#  idblock_bn_0_a_b (BatchNor  (None, 64, 64, 32)           128       ['idblock_conv_0_a_b[0][0]']
#  malization)
#
#  idblock_actv_0_a_b (Activa  (None, 64, 64, 32)           0         ['idblock_bn_0_a_b[0][0]']
#  tion)
#
#  idblock_conv_0_a_c (Conv2D  (None, 64, 64, 64)           2112      ['idblock_actv_0_a_b[0][0]']
#  )
#
#  idblock_bn_0_a_c (BatchNor  (None, 64, 64, 64)           256       ['idblock_conv_0_a_c[0][0]']
#  malization)
#
#  add_1 (Add)                 (None, 64, 64, 64)           0         ['idblock_bn_0_a_c[0][0]',
#                                                                      'convblock_actv_0_a_c[0][0]']
#
#  idblock_actv_0_a_c (Activa  (None, 64, 64, 64)           0         ['add_1[0][0]']
#  tion)
#
#  convblock_conv_1_a_a (Conv  (None, 32, 32, 64)           4160      ['idblock_actv_0_a_c[0][0]']
#  2D)
#
#  convblock_bn_1_a_a (BatchN  (None, 32, 32, 64)           256       ['convblock_conv_1_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_1_a_a (Acti  (None, 32, 32, 64)           0         ['convblock_bn_1_a_a[0][0]']
#  vation)
#
#  convblock_conv_1_a_b (Conv  (None, 32, 32, 64)           36928     ['convblock_actv_1_a_a[0][0]']
#  2D)
#
#  convblock_bn_1_a_b (BatchN  (None, 32, 32, 64)           256       ['convblock_conv_1_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_1_a_b (Acti  (None, 32, 32, 64)           0         ['convblock_bn_1_a_b[0][0]']
#  vation)
#
#  convblock_conv_1_a_c (Conv  (None, 32, 32, 128)          8320      ['convblock_actv_1_a_b[0][0]']
#  2D)
#
#  convblock_conv_1_a_sc1 (Co  (None, 32, 32, 128)          8320      ['idblock_actv_0_a_c[0][0]']
#  nv2D)
#
#  convblock_bn_1_a_c (BatchN  (None, 32, 32, 128)          512       ['convblock_conv_1_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_1_a_sc1 (Batc  (None, 32, 32, 128)          512       ['convblock_conv_1_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add_2 (Add)                 (None, 32, 32, 128)          0         ['convblock_bn_1_a_c[0][0]',
#                                                                      'convblock_bn_1_a_sc1[0][0]']
#
#  convblock_actv_1_a_c (Acti  (None, 32, 32, 128)          0         ['add_2[0][0]']
#  vation)
#
#  idblock_conv_1_a_a (Conv2D  (None, 32, 32, 64)           8256      ['convblock_actv_1_a_c[0][0]']
#  )
#
#  idblock_bn_1_a_a (BatchNor  (None, 32, 32, 64)           256       ['idblock_conv_1_a_a[0][0]']
#  malization)
#
#  idblock_actv_1_a_a (Activa  (None, 32, 32, 64)           0         ['idblock_bn_1_a_a[0][0]']
#  tion)
#
#  idblock_conv_1_a_b (Conv2D  (None, 32, 32, 64)           36928     ['idblock_actv_1_a_a[0][0]']
#  )
#
#  idblock_bn_1_a_b (BatchNor  (None, 32, 32, 64)           256       ['idblock_conv_1_a_b[0][0]']
#  malization)
#
#  idblock_actv_1_a_b (Activa  (None, 32, 32, 64)           0         ['idblock_bn_1_a_b[0][0]']
#  tion)
#
#  idblock_conv_1_a_c (Conv2D  (None, 32, 32, 128)          8320      ['idblock_actv_1_a_b[0][0]']
#  )
#
#  idblock_bn_1_a_c (BatchNor  (None, 32, 32, 128)          512       ['idblock_conv_1_a_c[0][0]']
#  malization)
#
#  add_3 (Add)                 (None, 32, 32, 128)          0         ['idblock_bn_1_a_c[0][0]',
#                                                                      'convblock_actv_1_a_c[0][0]']
#
#  idblock_actv_1_a_c (Activa  (None, 32, 32, 128)          0         ['add_3[0][0]']
#  tion)
#
#  convblock_conv_2_a_a (Conv  (None, 16, 16, 128)          16512     ['idblock_actv_1_a_c[0][0]']
#  2D)
#
#  convblock_bn_2_a_a (BatchN  (None, 16, 16, 128)          512       ['convblock_conv_2_a_a[0][0]']
#  ormalization)
#
#  convblock_actv_2_a_a (Acti  (None, 16, 16, 128)          0         ['convblock_bn_2_a_a[0][0]']
#  vation)
#
#  convblock_conv_2_a_b (Conv  (None, 16, 16, 128)          147584    ['convblock_actv_2_a_a[0][0]']
#  2D)
#
#  convblock_bn_2_a_b (BatchN  (None, 16, 16, 128)          512       ['convblock_conv_2_a_b[0][0]']
#  ormalization)
#
#  convblock_actv_2_a_b (Acti  (None, 16, 16, 128)          0         ['convblock_bn_2_a_b[0][0]']
#  vation)
#
#  convblock_conv_2_a_c (Conv  (None, 16, 16, 256)          33024     ['convblock_actv_2_a_b[0][0]']
#  2D)
#
#  convblock_conv_2_a_sc1 (Co  (None, 16, 16, 256)          33024     ['idblock_actv_1_a_c[0][0]']
#  nv2D)
#
#  convblock_bn_2_a_c (BatchN  (None, 16, 16, 256)          1024      ['convblock_conv_2_a_c[0][0]']
#  ormalization)
#
#  convblock_bn_2_a_sc1 (Batc  (None, 16, 16, 256)          1024      ['convblock_conv_2_a_sc1[0][0]
#  hNormalization)                                                    ']
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['convblock_bn_2_a_c[0][0]',
#                                                                      'convblock_bn_2_a_sc1[0][0]']
#
#  convblock_actv_2_a_c (Acti  (None, 16, 16, 256)          0         ['add_4[0][0]']
#  vation)
#
#  idblock_conv_2_a_a (Conv2D  (None, 16, 16, 128)          32896     ['convblock_actv_2_a_c[0][0]']
#  )
#
#  idblock_bn_2_a_a (BatchNor  (None, 16, 16, 128)          512       ['idblock_conv_2_a_a[0][0]']
#  malization)
#
#  idblock_actv_2_a_a (Activa  (None, 16, 16, 128)          0         ['idblock_bn_2_a_a[0][0]']
#  tion)
#
#  idblock_conv_2_a_b (Conv2D  (None, 16, 16, 128)          65664     ['idblock_actv_2_a_a[0][0]']
#  )
#
#  idblock_bn_2_a_b (BatchNor  (None, 16, 16, 128)          512       ['idblock_conv_2_a_b[0][0]']
#  malization)
#
#  idblock_actv_2_a_b (Activa  (None, 16, 16, 128)          0         ['idblock_bn_2_a_b[0][0]']
#  tion)
#
#  idblock_conv_2_a_c (Conv2D  (None, 16, 16, 256)          33024     ['idblock_actv_2_a_b[0][0]']
#  )
#
#  idblock_bn_2_a_c (BatchNor  (None, 16, 16, 256)          1024      ['idblock_conv_2_a_c[0][0]']
#  malization)
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['idblock_bn_2_a_c[0][0]',
#                                                                      'convblock_actv_2_a_c[0][0]']
#
#  idblock_actv_2_a_c (Activa  (None, 16, 16, 256)          0         ['add_5[0][0]']
#  tion)
#
#  average_pooling2d (Average  (None, 8, 8, 256)            0         ['idblock_actv_2_a_c[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 16384)                0         ['average_pooling2d[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  2097280   ['flatten[0][0]']
#
#  bn_3 (BatchNormalization)   (None, 128)                  512       ['dense_1[0][0]']
#
#  actv_3 (Activation)         (None, 128)                  0         ['bn_3[0][0]']
#
#  out_layer (Dense)           (None, 6)                    774       ['actv_3[0][0]']
#
# ==================================================================================================
# Total params: 2605478 (9.94 MB)
# Trainable params: 2600742 (9.92 MB)
# Non-trainable params: 4736 (18.50 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=9,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_ResNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 162/162 [==============================] - 29s 67ms/step - loss: 1.5021 - accuracy: 0.4065 - val_loss: 2.2216 - val_accuracy: 0.3390 - lr: 0.0010
# Epoch 2/100
# 162/162 [==============================] - 9s 55ms/step - loss: 1.2254 - accuracy: 0.5163 - val_loss: 1.5401 - val_accuracy: 0.3974 - lr: 0.0010
# Epoch 3/100
# 162/162 [==============================] - 9s 55ms/step - loss: 1.0725 - accuracy: 0.5860 - val_loss: 1.0958 - val_accuracy: 0.5757 - lr: 0.0010
# Epoch 4/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.9946 - accuracy: 0.6152 - val_loss: 0.8951 - val_accuracy: 0.6364 - lr: 0.0010
# Epoch 5/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.9141 - accuracy: 0.6413 - val_loss: 1.1114 - val_accuracy: 0.5949 - lr: 0.0010
# Epoch 6/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.8618 - accuracy: 0.6633 - val_loss: 0.8706 - val_accuracy: 0.6718 - lr: 0.0010
# Epoch 7/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.8177 - accuracy: 0.6796 - val_loss: 0.8102 - val_accuracy: 0.6887 - lr: 0.0010
# Epoch 8/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.8036 - accuracy: 0.6915 - val_loss: 0.8124 - val_accuracy: 0.6787 - lr: 0.0010
# Epoch 9/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.7665 - accuracy: 0.7071 - val_loss: 0.9776 - val_accuracy: 0.6533 - lr: 0.0010
# Epoch 10/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.7543 - accuracy: 0.7158 - val_loss: 1.0244 - val_accuracy: 0.5957 - lr: 0.0010
# Epoch 11/100
# 163/162 [==============================] - ETA: 0s - loss: 0.7268 - accuracy: 0.7246
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 162/162 [==============================] - 9s 56ms/step - loss: 0.7268 - accuracy: 0.7246 - val_loss: 1.0297 - val_accuracy: 0.6118 - lr: 0.0010
# Epoch 12/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.6498 - accuracy: 0.7550 - val_loss: 0.6923 - val_accuracy: 0.7402 - lr: 1.0000e-04
# Epoch 13/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.6122 - accuracy: 0.7690 - val_loss: 0.6757 - val_accuracy: 0.7471 - lr: 1.0000e-04
# Epoch 14/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.6013 - accuracy: 0.7815 - val_loss: 0.6768 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 15/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5817 - accuracy: 0.7862 - val_loss: 0.6723 - val_accuracy: 0.7494 - lr: 1.0000e-04
# Epoch 16/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5655 - accuracy: 0.7896 - val_loss: 0.6698 - val_accuracy: 0.7456 - lr: 1.0000e-04
# Epoch 17/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5543 - accuracy: 0.8008 - val_loss: 0.6706 - val_accuracy: 0.7502 - lr: 1.0000e-04
# Epoch 18/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5507 - accuracy: 0.8017 - val_loss: 0.6640 - val_accuracy: 0.7463 - lr: 1.0000e-04
# Epoch 19/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5521 - accuracy: 0.7935 - val_loss: 0.6637 - val_accuracy: 0.7479 - lr: 1.0000e-04
# Epoch 20/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5402 - accuracy: 0.8004 - val_loss: 0.6706 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 21/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5234 - accuracy: 0.8069 - val_loss: 0.6751 - val_accuracy: 0.7556 - lr: 1.0000e-04
# Epoch 22/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5181 - accuracy: 0.8106 - val_loss: 0.6684 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 23/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.5105 - accuracy: 0.8156 - val_loss: 0.6741 - val_accuracy: 0.7533 - lr: 1.0000e-04
# Epoch 24/100
# 163/162 [==============================] - ETA: 0s - loss: 0.5052 - accuracy: 0.8140
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 162/162 [==============================] - 9s 55ms/step - loss: 0.5052 - accuracy: 0.8140 - val_loss: 0.6872 - val_accuracy: 0.7463 - lr: 1.0000e-04
# Epoch 25/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4898 - accuracy: 0.8233 - val_loss: 0.6771 - val_accuracy: 0.7517 - lr: 1.0000e-05
# Epoch 26/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4864 - accuracy: 0.8288 - val_loss: 0.6772 - val_accuracy: 0.7510 - lr: 1.0000e-05
# Epoch 27/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.4841 - accuracy: 0.8208 - val_loss: 0.6764 - val_accuracy: 0.7517 - lr: 1.0000e-05
# Epoch 28/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4855 - accuracy: 0.8269 - val_loss: 0.6756 - val_accuracy: 0.7594 - lr: 1.0000e-05
# Epoch 29/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.4869 - accuracy: 0.8235 - val_loss: 0.6753 - val_accuracy: 0.7556 - lr: 1.0000e-05
# Epoch 30/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4832 - accuracy: 0.8256 - val_loss: 0.6757 - val_accuracy: 0.7586 - lr: 1.0000e-05
# Epoch 31/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4947 - accuracy: 0.8192 - val_loss: 0.6743 - val_accuracy: 0.7548 - lr: 1.0000e-05
# Epoch 32/100
# 163/162 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.8288
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4712 - accuracy: 0.8288 - val_loss: 0.6760 - val_accuracy: 0.7540 - lr: 1.0000e-05
# Epoch 33/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4750 - accuracy: 0.8333 - val_loss: 0.6765 - val_accuracy: 0.7548 - lr: 1.0000e-06
# Epoch 34/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4764 - accuracy: 0.8279 - val_loss: 0.6765 - val_accuracy: 0.7517 - lr: 1.0000e-06
# Epoch 35/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.4779 - accuracy: 0.8317 - val_loss: 0.6758 - val_accuracy: 0.7548 - lr: 1.0000e-06
# Epoch 36/100
# 163/162 [==============================] - ETA: 0s - loss: 0.4730 - accuracy: 0.8327
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4730 - accuracy: 0.8327 - val_loss: 0.6765 - val_accuracy: 0.7540 - lr: 1.0000e-06
# Epoch 37/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4723 - accuracy: 0.8256 - val_loss: 0.6771 - val_accuracy: 0.7548 - lr: 1.0000e-07
# Epoch 38/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4699 - accuracy: 0.8346 - val_loss: 0.6764 - val_accuracy: 0.7556 - lr: 1.0000e-07
# Epoch 39/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4681 - accuracy: 0.8333 - val_loss: 0.6761 - val_accuracy: 0.7533 - lr: 1.0000e-07
# Epoch 40/100
# 163/162 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.8246
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-07.
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4772 - accuracy: 0.8246 - val_loss: 0.6763 - val_accuracy: 0.7540 - lr: 1.0000e-07
# Epoch 41/100
# 162/162 [==============================] - 9s 55ms/step - loss: 0.4833 - accuracy: 0.8254 - val_loss: 0.6765 - val_accuracy: 0.7548 - lr: 1.0000e-07
# Epoch 42/100
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4850 - accuracy: 0.8229 - val_loss: 0.6767 - val_accuracy: 0.7540 - lr: 1.0000e-07
# Epoch 43/100
# 163/162 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.8281Epoch 42: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 27.
# 162/162 [==============================] - 9s 56ms/step - loss: 0.4722 - accuracy: 0.8281 - val_loss: 0.6762 - val_accuracy: 0.7548 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_ResNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.502051  0.406538  2.221554      0.338970  1.000000e-03
# 1   1.225365  0.516346  1.540105      0.397387  1.000000e-03
# 2   1.072531  0.585962  1.095815      0.575711  1.000000e-03
# 3   0.994570  0.615192  0.895128      0.636434  1.000000e-03
# 4   0.914111  0.641346  1.111388      0.594927  1.000000e-03
# 5   0.861798  0.663269  0.870594      0.671791  1.000000e-03
# 6   0.817746  0.679615  0.810223      0.688701  1.000000e-03
# 7   0.803627  0.691538  0.812383      0.678709  1.000000e-03
# 8   0.766509  0.707115  0.977645      0.653344  1.000000e-03
# 9   0.754310  0.715769  1.024362      0.595696  1.000000e-03
# 10  0.726813  0.724615  1.029722      0.611837  1.000000e-03
# 11  0.649830  0.755000  0.692327      0.740200  1.000000e-04
# 12  0.612224  0.769038  0.675656      0.747118  1.000000e-04
# 13  0.601346  0.781538  0.676783      0.747886  1.000000e-04
# 14  0.581679  0.786154  0.672295      0.749424  1.000000e-04
# 15  0.565496  0.789615  0.669823      0.745580  1.000000e-04
# 16  0.554335  0.800769  0.670567      0.750192  1.000000e-04
# 17  0.550689  0.801731  0.664029      0.746349  1.000000e-04
# 18  0.552107  0.793462  0.663693      0.747886  1.000000e-04
# 19  0.540242  0.800385  0.670569      0.757110  1.000000e-04
# 20  0.523427  0.806923  0.675056      0.755573  1.000000e-04
# 21  0.518056  0.810577  0.668377      0.757110  1.000000e-04
# 22  0.510490  0.815577  0.674065      0.753267  1.000000e-04
# 23  0.505194  0.814038  0.687248      0.746349  1.000000e-04
# 24  0.489840  0.823269  0.677121      0.751729  1.000000e-05
# 25  0.486418  0.828846  0.677215      0.750961  1.000000e-05
# 26  0.484078  0.820769  0.676381      0.751729  1.000000e-05
# 27  0.485523  0.826923  0.675567      0.759416  1.000000e-05
# 28  0.486930  0.823462  0.675303      0.755573  1.000000e-05
# 29  0.483198  0.825577  0.675745      0.758647  1.000000e-05
# 30  0.494655  0.819231  0.674322      0.754804  1.000000e-05
# 31  0.471160  0.828846  0.676048      0.754035  1.000000e-05
# 32  0.475009  0.833269  0.676498      0.754804  1.000000e-06
# 33  0.476399  0.827885  0.676457      0.751729  1.000000e-06
# 34  0.477912  0.831731  0.675824      0.754804  1.000000e-06
# 35  0.472954  0.832692  0.676453      0.754035  1.000000e-06
# 36  0.472307  0.825577  0.677064      0.754804  1.000000e-07
# 37  0.469914  0.834615  0.676449      0.755573  1.000000e-07
# 38  0.468127  0.833269  0.676107      0.753267  1.000000e-07
# 39  0.477231  0.824615  0.676262      0.754035  1.000000e-07
# 40  0.483324  0.825385  0.676521      0.754804  1.000000e-07
# 41  0.484981  0.822885  0.676743      0.754035  1.000000e-07
# 42  0.472163  0.828077  0.676222      0.754804  1.000000e-07

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['accuracy'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['loss'], label='train')
sns.lineplot(x=history_ResNet.epoch, y=history_ResNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Neutral', 4: 'Sadness', 5: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 163/163 - 2s - loss: 0.3681 - accuracy: 0.8690 - 2s/epoch - 14ms/step
#
# train Accuracy: 0.869038462638855
# 41/41 - 1s - loss: 0.6756 - accuracy: 0.7594 - 568ms/epoch - 14ms/step
#
# Test Accuracy: 0.7594158053398132
# 41/41 [==============================] - 1s 12ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       1.00      1.00      1.00        50
#         Fear       0.68      0.59      0.63       145
#        Happy       0.76      0.74      0.75       188
#      Neutral       0.62      0.70      0.65       246
#      Sadness       0.65      0.61      0.63       231
#     Surprise       0.90      0.91      0.90       441
#
#     accuracy                           0.76      1301
#    macro avg       0.77      0.76      0.76      1301
# weighted avg       0.76      0.76      0.76      1301

# %%
# Visualize some predictions
pyplot.figure(figsize=(10, 10))
for i in range(9):
    ax = pyplot.subplot(3, 3, i + 1)
    pyplot.imshow(X_test[i].reshape(64, 64), cmap='gray')
    pyplot.title(label_to_text[predicted_labels[i]])
    pyplot.axis("off")

pyplot.show()

# %%
! pip install visualkeras

import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# Collecting visualkeras
#   Obtaining dependency information for visualkeras from https://files.pythonhosted.org/packages/a5/93/abd375b37add77d58a8c48a506ae39bb77c4380e2507ea444325ff1b9971/visualkeras-0.0.2-py3-none-any.whl.metadata
#   Downloading visualkeras-0.0.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (10.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Obtaining dependency information for aggdraw>=1.3.11 from https://files.pythonhosted.org/packages/e4/57/59b42e145ff12941c5c63d59dc48369912a9e29d69966ff630e6f0f815ac/aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (661 bytes)
# Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Downloading aggdraw-1.3.18.post0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 31.3 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18.post0 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=2688x378>
