# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-03 13:24:33.097741: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-03 13:24:33.097851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-03 13:24:33.276250: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (75, 75))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (75, 75, 3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 32
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 75, 75, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
# Load the Xception model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 263,175 (1.00 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   4/383 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.1979 - loss: 17.5674
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712150831.735895      91 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712150831.772348      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  43/383 ━━━━━━━━━━━━━━━━━━━━ 53s 158ms/step - accuracy: 0.2676 - loss: 14.0864
# W0000 00:00:1712150838.220655      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3101 - loss: 5.2432
# W0000 00:00:1712150858.568172      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 44s 86ms/step - accuracy: 0.3102 - loss: 5.2369 - val_accuracy: 0.3960 - val_loss: 1.6484 - learning_rate: 0.0010
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.2812 - loss: 1.7713
# W0000 00:00:1712150864.474444      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2812 - loss: 1.7713 - val_accuracy: 0.3950 - val_loss: 1.6855 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.3962 - loss: 1.7112 - val_accuracy: 0.4296 - val_loss: 1.6034 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.2277 - val_accuracy: 0.4316 - val_loss: 1.5846 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4069 - loss: 1.6289 - val_accuracy: 0.4404 - val_loss: 1.5267 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.2623 - val_accuracy: 0.4371 - val_loss: 1.5262 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.4142 - loss: 1.6012 - val_accuracy: 0.4306 - val_loss: 1.5404 - learning_rate: 0.0010
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4688 - loss: 1.4516 - val_accuracy: 0.4254 - val_loss: 1.5556 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4258 - loss: 1.5724
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4258 - loss: 1.5724 - val_accuracy: 0.4228 - val_loss: 1.5666 - learning_rate: 0.0010
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5625 - loss: 1.2307 - val_accuracy: 0.4231 - val_loss: 1.5653 - learning_rate: 1.0000e-04
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.4371 - loss: 1.5186 - val_accuracy: 0.4537 - val_loss: 1.4754 - learning_rate: 1.0000e-04
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.5555 - val_accuracy: 0.4534 - val_loss: 1.4753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4371 - loss: 1.5208 - val_accuracy: 0.4452 - val_loss: 1.4919 - learning_rate: 1.0000e-04
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.5721 - val_accuracy: 0.4482 - val_loss: 1.4867 - learning_rate: 1.0000e-04
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4506 - loss: 1.4864 - val_accuracy: 0.4586 - val_loss: 1.4705 - learning_rate: 1.0000e-04
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3125 - loss: 1.5434 - val_accuracy: 0.4599 - val_loss: 1.4713 - learning_rate: 1.0000e-04
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4363 - loss: 1.5006 - val_accuracy: 0.4531 - val_loss: 1.4710 - learning_rate: 1.0000e-04
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.8345 - val_accuracy: 0.4521 - val_loss: 1.4721 - learning_rate: 1.0000e-04
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.4355 - loss: 1.5009 - val_accuracy: 0.4668 - val_loss: 1.4608 - learning_rate: 1.0000e-04
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5000 - loss: 1.3732 - val_accuracy: 0.4671 - val_loss: 1.4604 - learning_rate: 1.0000e-04
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.4553 - loss: 1.4826 - val_accuracy: 0.4593 - val_loss: 1.4688 - learning_rate: 1.0000e-04
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.3025 - val_accuracy: 0.4586 - val_loss: 1.4691 - learning_rate: 1.0000e-04
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4433 - loss: 1.5031 - val_accuracy: 0.4527 - val_loss: 1.4657 - learning_rate: 1.0000e-04
# Epoch 24/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.4375 - loss: 1.4909
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4375 - loss: 1.4909 - val_accuracy: 0.4547 - val_loss: 1.4644 - learning_rate: 1.0000e-04
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4404 - loss: 1.4944 - val_accuracy: 0.4632 - val_loss: 1.4570 - learning_rate: 1.0000e-05
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3438 - loss: 1.5578 - val_accuracy: 0.4625 - val_loss: 1.4571 - learning_rate: 1.0000e-05
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.4545 - loss: 1.4727 - val_accuracy: 0.4589 - val_loss: 1.4591 - learning_rate: 1.0000e-05
# Epoch 28/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4062 - loss: 1.5486
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.5486 - val_accuracy: 0.4589 - val_loss: 1.4590 - learning_rate: 1.0000e-05
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.4452 - loss: 1.4807 - val_accuracy: 0.4609 - val_loss: 1.4583 - learning_rate: 1.0000e-06
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.5270 - val_accuracy: 0.4609 - val_loss: 1.4583 - learning_rate: 1.0000e-06
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.4499 - loss: 1.4769 - val_accuracy: 0.4628 - val_loss: 1.4577 - learning_rate: 1.0000e-06
# Epoch 32/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5312 - loss: 1.3700
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 1.3700 - val_accuracy: 0.4632 - val_loss: 1.4577 - learning_rate: 1.0000e-06
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4527 - loss: 1.4862 - val_accuracy: 0.4625 - val_loss: 1.4577 - learning_rate: 1.0000e-07
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5000 - loss: 1.4171 - val_accuracy: 0.4625 - val_loss: 1.4577 - learning_rate: 1.0000e-07
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.4441 - loss: 1.4810 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 36/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.5312 - loss: 1.4408
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5312 - loss: 1.4408 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4452 - loss: 1.4853 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.2019 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4526 - loss: 1.4697 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.3025 - val_accuracy: 0.4622 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4391 - loss: 1.4898 - val_accuracy: 0.4615 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3125 - loss: 1.6157 - val_accuracy: 0.4615 - val_loss: 1.4578 - learning_rate: 1.0000e-07
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4520 - loss: 1.4924 - val_accuracy: 0.4615 - val_loss: 1.4577 - learning_rate: 1.0000e-07
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.6010 - val_accuracy: 0.4615 - val_loss: 1.4577 - learning_rate: 1.0000e-07
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4485 - loss: 1.4905Epoch 44: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 19.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4485 - loss: 1.4904 - val_accuracy: 0.4615 - val_loss: 1.4577 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.340714  2.824500      0.396023  1.648422   1.000000e-03
# 1   0.281250  1.771278      0.395046  1.685521   1.000000e-03
# 2   0.396519  1.696659      0.429596  1.603365   1.000000e-03
# 3   0.593750  1.227699      0.431551  1.584632   1.000000e-03
# 4   0.411962  1.608215      0.440352  1.526735   1.000000e-03
# 5   0.562500  1.262276      0.437093  1.526179   1.000000e-03
# 6   0.415884  1.586379      0.430574  1.540412   1.000000e-03
# 7   0.468750  1.451573      0.425359  1.555566   1.000000e-03
# 8   0.424136  1.571208      0.422751  1.566621   1.000000e-03
# 9   0.562500  1.230715      0.423077  1.565313   1.000000e-04
# 10  0.436882  1.515321      0.453716  1.475354   1.000000e-04
# 11  0.437500  1.555499      0.453390  1.475267   1.000000e-04
# 12  0.440804  1.508523      0.445241  1.491910   1.000000e-04
# 13  0.343750  1.572133      0.448175  1.486677   1.000000e-04
# 14  0.443010  1.501768      0.458605  1.470458   1.000000e-04
# 15  0.312500  1.543416      0.459909  1.471321   1.000000e-04
# 16  0.438598  1.499707      0.453064  1.470990   1.000000e-04
# 17  0.343750  1.834467      0.452086  1.472052   1.000000e-04
# 18  0.441703  1.497136      0.466754  1.460780   1.000000e-04
# 19  0.500000  1.373192      0.467080  1.460379   1.000000e-04
# 20  0.448811  1.494674      0.459257  1.468825   1.000000e-04
# 21  0.500000  1.302468      0.458605  1.469121   1.000000e-04
# 22  0.444971  1.493461      0.452738  1.465710   1.000000e-04
# 23  0.437500  1.490924      0.454694  1.464392   1.000000e-04
# 24  0.449628  1.482403      0.463168  1.456996   1.000000e-05
# 25  0.343750  1.557815      0.462516  1.457135   1.000000e-05
# 26  0.447749  1.485312      0.458931  1.459093   1.000000e-05
# 27  0.406250  1.548615      0.458931  1.459001   1.000000e-05
# 28  0.441784  1.487733      0.460887  1.458290   1.000000e-06
# 29  0.406250  1.526999      0.460887  1.458299   1.000000e-06
# 30  0.447504  1.480618      0.462842  1.457703   1.000000e-06
# 31  0.531250  1.369963      0.463168  1.457709   1.000000e-06
# 32  0.449873  1.482785      0.462516  1.457744   1.000000e-07
# 33  0.500000  1.417063      0.462516  1.457745   1.000000e-07
# 34  0.447095  1.483581      0.462190  1.457768   1.000000e-07
# 35  0.531250  1.440832      0.462190  1.457769   1.000000e-07
# 36  0.445788  1.488112      0.462190  1.457762   1.000000e-07
# 37  0.593750  1.201916      0.462190  1.457762   1.000000e-07
# 38  0.449056  1.483016      0.462190  1.457759   1.000000e-07
# 39  0.593750  1.302531      0.462190  1.457758   1.000000e-07
# 40  0.448811  1.480581      0.461538  1.457762   1.000000e-07
# 41  0.312500  1.615716      0.461538  1.457762   1.000000e-07
# 42  0.449301  1.482585      0.461538  1.457720   1.000000e-07
# 43  0.406250  1.600972      0.461538  1.457718   1.000000e-07
# 44  0.450282  1.482113      0.461538  1.457702   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 3, 3, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,124,655 (80.58 MB)
#  Trainable params: 21,070,127 (80.38 MB)
#  Non-trainable params: 54,528 (213.00 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/383 ━━━━━━━━━━━━━━━━━━━━ 35s 94ms/step - accuracy: 0.2266 - loss: 1.8571
# W0000 00:00:1712151412.007453      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  85/383 ━━━━━━━━━━━━━━━━━━━━ 1:33 313ms/step - accuracy: 0.2167 - loss: 1.8473
# W0000 00:00:1712151438.204778      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.2786 - loss: 1.8306
# W0000 00:00:1712151463.165591      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 99s 142ms/step - accuracy: 0.2788 - loss: 1.8305 - val_accuracy: 0.4048 - val_loss: 1.6487 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 26s 70ms/step - accuracy: 0.4062 - loss: 1.6947
# W0000 00:00:1712151466.405096      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4062 - loss: 1.6947 - val_accuracy: 0.4051 - val_loss: 1.6470 - learning_rate: 1.0000e-05
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.4212 - loss: 1.6176 - val_accuracy: 0.4749 - val_loss: 1.4669 - learning_rate: 1.0000e-05
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4062 - loss: 1.3589 - val_accuracy: 0.4759 - val_loss: 1.4610 - learning_rate: 1.0000e-05
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.4774 - loss: 1.3809 - val_accuracy: 0.5430 - val_loss: 1.3591 - learning_rate: 1.0000e-05
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.2141 - val_accuracy: 0.5430 - val_loss: 1.3586 - learning_rate: 1.0000e-05
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.5338 - loss: 1.2451 - val_accuracy: 0.5883 - val_loss: 1.1914 - learning_rate: 1.0000e-05
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5938 - loss: 1.4415 - val_accuracy: 0.5883 - val_loss: 1.1912 - learning_rate: 1.0000e-05
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.5705 - loss: 1.1696 - val_accuracy: 0.6167 - val_loss: 1.0975 - learning_rate: 1.0000e-05
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5938 - loss: 0.9585 - val_accuracy: 0.6173 - val_loss: 1.0975 - learning_rate: 1.0000e-05
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6108 - loss: 1.0874 - val_accuracy: 0.6395 - val_loss: 1.0559 - learning_rate: 1.0000e-05
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6562 - loss: 1.1203 - val_accuracy: 0.6398 - val_loss: 1.0566 - learning_rate: 1.0000e-05
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6338 - loss: 1.0249 - val_accuracy: 0.6594 - val_loss: 0.9938 - learning_rate: 1.0000e-05
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6250 - loss: 0.9825 - val_accuracy: 0.6584 - val_loss: 0.9950 - learning_rate: 1.0000e-05
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6507 - loss: 0.9763 - val_accuracy: 0.6711 - val_loss: 0.9380 - learning_rate: 1.0000e-05
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7188 - loss: 0.7724 - val_accuracy: 0.6718 - val_loss: 0.9387 - learning_rate: 1.0000e-05
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6699 - loss: 0.9197 - val_accuracy: 0.6819 - val_loss: 0.8978 - learning_rate: 1.0000e-05
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6562 - loss: 1.3269 - val_accuracy: 0.6829 - val_loss: 0.8974 - learning_rate: 1.0000e-05
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.6941 - loss: 0.8580 - val_accuracy: 0.6956 - val_loss: 0.8583 - learning_rate: 1.0000e-05
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6562 - loss: 0.9438 - val_accuracy: 0.6949 - val_loss: 0.8585 - learning_rate: 1.0000e-05
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.7112 - loss: 0.8070 - val_accuracy: 0.7093 - val_loss: 0.8291 - learning_rate: 1.0000e-05
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6875 - loss: 0.8017 - val_accuracy: 0.7096 - val_loss: 0.8293 - learning_rate: 1.0000e-05
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7239 - loss: 0.7672 - val_accuracy: 0.7112 - val_loss: 0.8831 - learning_rate: 1.0000e-05
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.7728 - val_accuracy: 0.7106 - val_loss: 0.8847 - learning_rate: 1.0000e-05
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.7342 - loss: 0.7515 - val_accuracy: 0.7145 - val_loss: 0.8994 - learning_rate: 1.0000e-05
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.8250 - val_accuracy: 0.7132 - val_loss: 0.8990 - learning_rate: 1.0000e-05
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.7507 - loss: 0.7010 - val_accuracy: 0.7164 - val_loss: 0.8293 - learning_rate: 1.0000e-05
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6250 - loss: 1.0249 - val_accuracy: 0.7171 - val_loss: 0.8306 - learning_rate: 1.0000e-05
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.7543 - loss: 0.6799 - val_accuracy: 0.7194 - val_loss: 0.9010 - learning_rate: 1.0000e-05
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8438 - loss: 0.5726 - val_accuracy: 0.7200 - val_loss: 0.9015 - learning_rate: 1.0000e-05
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.7673 - loss: 0.6573 - val_accuracy: 0.7262 - val_loss: 1.1411 - learning_rate: 1.0000e-05
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8438 - loss: 0.4834 - val_accuracy: 0.7275 - val_loss: 1.1355 - learning_rate: 1.0000e-05
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7824 - loss: 0.6131 - val_accuracy: 0.7311 - val_loss: 0.8509 - learning_rate: 1.0000e-05
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7812 - loss: 0.5401 - val_accuracy: 0.7314 - val_loss: 0.8551 - learning_rate: 1.0000e-05
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7900 - loss: 0.5975 - val_accuracy: 0.7366 - val_loss: 0.7650 - learning_rate: 1.0000e-05
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.6365 - val_accuracy: 0.7360 - val_loss: 0.7653 - learning_rate: 1.0000e-05
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7995 - loss: 0.5654 - val_accuracy: 0.7412 - val_loss: 0.7649 - learning_rate: 1.0000e-05
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.7505 - val_accuracy: 0.7402 - val_loss: 0.7655 - learning_rate: 1.0000e-05
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.8066 - loss: 0.5427 - val_accuracy: 0.7454 - val_loss: 0.7490 - learning_rate: 1.0000e-05
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.4870 - val_accuracy: 0.7454 - val_loss: 0.7490 - learning_rate: 1.0000e-05
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.8117 - loss: 0.5233 - val_accuracy: 0.7451 - val_loss: 0.7543 - learning_rate: 1.0000e-05
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9062 - loss: 0.3437 - val_accuracy: 0.7454 - val_loss: 0.7540 - learning_rate: 1.0000e-05
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8235 - loss: 0.5043
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.8235 - loss: 0.5043 - val_accuracy: 0.7419 - val_loss: 0.7647 - learning_rate: 1.0000e-05
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9375 - loss: 0.3072 - val_accuracy: 0.7422 - val_loss: 0.7648 - learning_rate: 1.0000e-06
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8287 - loss: 0.4808 - val_accuracy: 0.7451 - val_loss: 0.7664 - learning_rate: 1.0000e-06
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8125 - loss: 0.7203 - val_accuracy: 0.7445 - val_loss: 0.7663 - learning_rate: 1.0000e-06
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8378 - loss: 0.4603
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8378 - loss: 0.4603 - val_accuracy: 0.7448 - val_loss: 0.7663 - learning_rate: 1.0000e-06
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.5927 - val_accuracy: 0.7451 - val_loss: 0.7663 - learning_rate: 1.0000e-07
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8322 - loss: 0.4793 - val_accuracy: 0.7445 - val_loss: 0.7642 - learning_rate: 1.0000e-07
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7500 - loss: 0.5328 - val_accuracy: 0.7448 - val_loss: 0.7641 - learning_rate: 1.0000e-07
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8406 - loss: 0.4640 - val_accuracy: 0.7441 - val_loss: 0.7666 - learning_rate: 1.0000e-07
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9375 - loss: 0.2885 - val_accuracy: 0.7445 - val_loss: 0.7665 - learning_rate: 1.0000e-07
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.8345 - loss: 0.4632 - val_accuracy: 0.7435 - val_loss: 0.7615 - learning_rate: 1.0000e-07
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.5779 - val_accuracy: 0.7432 - val_loss: 0.7621 - learning_rate: 1.0000e-07
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8369 - loss: 0.4767 - val_accuracy: 0.7454 - val_loss: 0.7655 - learning_rate: 1.0000e-07
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7188 - loss: 0.5426 - val_accuracy: 0.7454 - val_loss: 0.7652 - learning_rate: 1.0000e-07
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8331 - loss: 0.4687 - val_accuracy: 0.7438 - val_loss: 0.7697 - learning_rate: 1.0000e-07
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8125 - loss: 0.4680 - val_accuracy: 0.7422 - val_loss: 0.7696 - learning_rate: 1.0000e-07
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8366 - loss: 0.4605 - val_accuracy: 0.7448 - val_loss: 0.7732 - learning_rate: 1.0000e-07
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.5156 - val_accuracy: 0.7448 - val_loss: 0.7736 - learning_rate: 1.0000e-07
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8333 - loss: 0.4620 - val_accuracy: 0.7454 - val_loss: 0.7666 - learning_rate: 1.0000e-07
# Epoch 62/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7812 - loss: 0.5551 - val_accuracy: 0.7448 - val_loss: 0.7674 - learning_rate: 1.0000e-07
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.8409 - loss: 0.4647 - val_accuracy: 0.7438 - val_loss: 0.7670 - learning_rate: 1.0000e-07
# Epoch 64/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 0.8750 - loss: 0.4296Epoch 63: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 38.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8750 - loss: 0.4296 - val_accuracy: 0.7428 - val_loss: 0.7671 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.339897  1.799506      0.404824  1.648677   1.000000e-05
# 1   0.406250  1.694666      0.405150  1.646964   1.000000e-05
# 2   0.435166  1.536725      0.474902  1.466913   1.000000e-05
# 3   0.406250  1.358896      0.475880  1.461011   1.000000e-05
# 4   0.496364  1.336295      0.543025  1.359058   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 59  0.781250  0.515588      0.744785  0.773586   1.000000e-07
# 60  0.832584  0.467659      0.745437  0.766570   1.000000e-07
# 61  0.781250  0.555098      0.744785  0.767443   1.000000e-07
# 62  0.838794  0.465270      0.743807  0.766956   1.000000e-07
# 63  0.875000  0.429588      0.742829  0.767092   1.000000e-07
#
# [64 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 9s - 22ms/step - accuracy: 0.8692 - loss: 1.4289
# W0000 00:00:1712152461.722771      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.8692038059234619
# 96/96 - 2s - 18ms/step - accuracy: 0.7454 - loss: 0.7490
#
# Test Accuracy: 0.7454367876052856
#  7/96 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# W0000 00:00:1712152466.510705      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step
# W0000 00:00:1712152470.860406      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.73      0.68      0.70       329
#      disgust       0.69      0.36      0.48        74
#         fear       0.59      0.63      0.61       162
#        happy       0.66      0.76      0.71       680
#      neutral       0.67      0.68      0.68       478
#          sad       0.43      0.26      0.32       160
#     surprise       0.88      0.88      0.88      1185
#
#     accuracy                           0.75      3068
#    macro avg       0.67      0.61      0.63      3068
# weighted avg       0.74      0.75      0.74      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
