# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-18 17:18:59.171442: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 17:18:59.171541: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 17:18:59.341484: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/AffectNet/"
TOP_EMOTIONS = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (128,128,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# surprise has 1851 number of images
# fear has 1839 number of images
# neutral has 1880 number of images
# sad has 1821 number of images
# disgust has 1740 number of images
# contempt has 1833 number of images
# happy has 1862 number of images
# anger has 1822 number of images
#
# total images are 14648

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, 0)
            img = cv2.resize(img, (128, 128))
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1,1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded contempt images to numpy arrays...
# loaded happy images to numpy arrays...
# loaded anger images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((14648, 128, 128, 1),
#  (14648, 8),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'neutral',
#   3: 'sad',
#   4: 'disgust',
#   5: 'contempt',
#   6: 'happy',
#   7: 'anger'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(128, 128), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11718, 128, 128, 1), (2930, 128, 128, 1), (11718, 8), (2930, 8))

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype(int),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)

    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1

    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=4, layers_per_block=4, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=4, layers_per_block=4, growth_rate=16, show_summary=True)

plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ in_layer            │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_0 (Conv2D)   │ (None, 126, 126,  │        120 │ in_layer[0][0]    │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn1          │ (None, 126, 126,  │         48 │ conv2d_0[0][0]    │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv1        │ (None, 126, 126,  │          0 │ block1_bn1[0][0]  │
# │ (Activation)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad1         │ (None, 128, 128,  │          0 │ block1_actv1[0][… │
# │ (ZeroPadding2D)     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d1      │ (None, 126, 126,  │      1,308 │ block1_pad1[0][0] │
# │ (Conv2D)            │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat1      │ (None, 126, 126,  │          0 │ block1_conv2d1[0… │
# │ (Concatenate)       │ 24)               │            │ conv2d_0[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn2          │ (None, 126, 126,  │         96 │ block1_concat1[0… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv2        │ (None, 126, 126,  │          0 │ block1_bn2[0][0]  │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad2         │ (None, 128, 128,  │          0 │ block1_actv2[0][… │
# │ (ZeroPadding2D)     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d2      │ (None, 126, 126,  │      6,076 │ block1_pad2[0][0] │
# │ (Conv2D)            │ 28)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat2      │ (None, 126, 126,  │          0 │ block1_conv2d2[0… │
# │ (Concatenate)       │ 52)               │            │ block1_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn3          │ (None, 126, 126,  │        208 │ block1_concat2[0… │
# │ (BatchNormalizatio… │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv3        │ (None, 126, 126,  │          0 │ block1_bn3[0][0]  │
# │ (Activation)        │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad3         │ (None, 128, 128,  │          0 │ block1_actv3[0][… │
# │ (ZeroPadding2D)     │ 52)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d3      │ (None, 126, 126,  │     20,636 │ block1_pad3[0][0] │
# │ (Conv2D)            │ 44)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat3      │ (None, 126, 126,  │          0 │ block1_conv2d3[0… │
# │ (Concatenate)       │ 96)               │            │ block1_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_bn4          │ (None, 126, 126,  │        384 │ block1_concat3[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_actv4        │ (None, 126, 126,  │          0 │ block1_bn4[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pad4         │ (None, 128, 128,  │          0 │ block1_actv4[0][… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2d4      │ (None, 126, 126,  │     51,900 │ block1_pad4[0][0] │
# │ (Conv2D)            │ 60)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_concat4      │ (None, 126, 126,  │          0 │ block1_conv2d4[0… │
# │ (Concatenate)       │ 156)              │            │ block1_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_bn      │ (None, 126, 126,  │        624 │ block1_concat4[0… │
# │ (BatchNormalizatio… │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_actv    │ (None, 126, 126,  │          0 │ transition1_bn[0… │
# │ (Activation)        │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_conv2d  │ (None, 126, 126,  │      9,891 │ transition1_actv… │
# │ (Conv2D)            │ 63)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition1_pool2d  │ (None, 63, 63,    │          0 │ transition1_conv… │
# │ (AveragePooling2D)  │ 63)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn1          │ (None, 63, 63,    │        252 │ transition1_pool… │
# │ (BatchNormalizatio… │ 63)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv1        │ (None, 63, 63,    │          0 │ block2_bn1[0][0]  │
# │ (Activation)        │ 63)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad1         │ (None, 65, 65,    │          0 │ block2_actv1[0][… │
# │ (ZeroPadding2D)     │ 63)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d1      │ (None, 63, 63,    │     43,168 │ block2_pad1[0][0] │
# │ (Conv2D)            │ 76)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat1      │ (None, 63, 63,    │          0 │ block2_conv2d1[0… │
# │ (Concatenate)       │ 139)              │            │ transition1_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn2          │ (None, 63, 63,    │        556 │ block2_concat1[0… │
# │ (BatchNormalizatio… │ 139)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv2        │ (None, 63, 63,    │          0 │ block2_bn2[0][0]  │
# │ (Activation)        │ 139)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad2         │ (None, 65, 65,    │          0 │ block2_actv2[0][… │
# │ (ZeroPadding2D)     │ 139)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d2      │ (None, 63, 63,    │    115,184 │ block2_pad2[0][0] │
# │ (Conv2D)            │ 92)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat2      │ (None, 63, 63,    │          0 │ block2_conv2d2[0… │
# │ (Concatenate)       │ 231)              │            │ block2_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn3          │ (None, 63, 63,    │        924 │ block2_concat2[0… │
# │ (BatchNormalizatio… │ 231)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv3        │ (None, 63, 63,    │          0 │ block2_bn3[0][0]  │
# │ (Activation)        │ 231)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad3         │ (None, 65, 65,    │          0 │ block2_actv3[0][… │
# │ (ZeroPadding2D)     │ 231)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d3      │ (None, 63, 63,    │    224,640 │ block2_pad3[0][0] │
# │ (Conv2D)            │ 108)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat3      │ (None, 63, 63,    │          0 │ block2_conv2d3[0… │
# │ (Concatenate)       │ 339)              │            │ block2_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_bn4          │ (None, 63, 63,    │      1,356 │ block2_concat3[0… │
# │ (BatchNormalizatio… │ 339)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_actv4        │ (None, 63, 63,    │          0 │ block2_bn4[0][0]  │
# │ (Activation)        │ 339)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pad4         │ (None, 65, 65,    │          0 │ block2_actv4[0][… │
# │ (ZeroPadding2D)     │ 339)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2d4      │ (None, 63, 63,    │    378,448 │ block2_pad4[0][0] │
# │ (Conv2D)            │ 124)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_concat4      │ (None, 63, 63,    │          0 │ block2_conv2d4[0… │
# │ (Concatenate)       │ 463)              │            │ block2_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_bn      │ (None, 63, 63,    │      1,852 │ block2_concat4[0… │
# │ (BatchNormalizatio… │ 463)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_actv    │ (None, 63, 63,    │          0 │ transition2_bn[0… │
# │ (Activation)        │ 463)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_conv2d  │ (None, 63, 63,    │     14,384 │ transition2_actv… │
# │ (Conv2D)            │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition2_pool2d  │ (None, 31, 31,    │          0 │ transition2_conv… │
# │ (AveragePooling2D)  │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn1          │ (None, 31, 31,    │        124 │ transition2_pool… │
# │ (BatchNormalizatio… │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv1        │ (None, 31, 31,    │          0 │ block3_bn1[0][0]  │
# │ (Activation)        │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad1         │ (None, 33, 33,    │          0 │ block3_actv1[0][… │
# │ (ZeroPadding2D)     │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d1      │ (None, 31, 31,    │     39,200 │ block3_pad1[0][0] │
# │ (Conv2D)            │ 140)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat1      │ (None, 31, 31,    │          0 │ block3_conv2d1[0… │
# │ (Concatenate)       │ 171)              │            │ transition2_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn2          │ (None, 31, 31,    │        684 │ block3_concat1[0… │
# │ (BatchNormalizatio… │ 171)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv2        │ (None, 31, 31,    │          0 │ block3_bn2[0][0]  │
# │ (Activation)        │ 171)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad2         │ (None, 33, 33,    │          0 │ block3_actv2[0][… │
# │ (ZeroPadding2D)     │ 171)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d2      │ (None, 31, 31,    │    240,240 │ block3_pad2[0][0] │
# │ (Conv2D)            │ 156)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat2      │ (None, 31, 31,    │          0 │ block3_conv2d2[0… │
# │ (Concatenate)       │ 327)              │            │ block3_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn3          │ (None, 31, 31,    │      1,308 │ block3_concat2[0… │
# │ (BatchNormalizatio… │ 327)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv3        │ (None, 31, 31,    │          0 │ block3_bn3[0][0]  │
# │ (Activation)        │ 327)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad3         │ (None, 33, 33,    │          0 │ block3_actv3[0][… │
# │ (ZeroPadding2D)     │ 327)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d3      │ (None, 31, 31,    │    506,368 │ block3_pad3[0][0] │
# │ (Conv2D)            │ 172)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat3      │ (None, 31, 31,    │          0 │ block3_conv2d3[0… │
# │ (Concatenate)       │ 499)              │            │ block3_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_bn4          │ (None, 31, 31,    │      1,996 │ block3_concat3[0… │
# │ (BatchNormalizatio… │ 499)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_actv4        │ (None, 31, 31,    │          0 │ block3_bn4[0][0]  │
# │ (Activation)        │ 499)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pad4         │ (None, 33, 33,    │          0 │ block3_actv4[0][… │
# │ (ZeroPadding2D)     │ 499)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2d4      │ (None, 31, 31,    │    844,496 │ block3_pad4[0][0] │
# │ (Conv2D)            │ 188)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_concat4      │ (None, 31, 31,    │          0 │ block3_conv2d4[0… │
# │ (Concatenate)       │ 687)              │            │ block3_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_bn      │ (None, 31, 31,    │      2,748 │ block3_concat4[0… │
# │ (BatchNormalizatio… │ 687)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_actv    │ (None, 31, 31,    │          0 │ transition3_bn[0… │
# │ (Activation)        │ 687)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_conv2d  │ (None, 31, 31,    │     10,320 │ transition3_actv… │
# │ (Conv2D)            │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition3_pool2d  │ (None, 15, 15,    │          0 │ transition3_conv… │
# │ (AveragePooling2D)  │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn1          │ (None, 15, 15,    │         60 │ transition3_pool… │
# │ (BatchNormalizatio… │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv1        │ (None, 15, 15,    │          0 │ block4_bn1[0][0]  │
# │ (Activation)        │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad1         │ (None, 17, 17,    │          0 │ block4_actv1[0][… │
# │ (ZeroPadding2D)     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d1      │ (None, 15, 15,    │     27,744 │ block4_pad1[0][0] │
# │ (Conv2D)            │ 204)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat1      │ (None, 15, 15,    │          0 │ block4_conv2d1[0… │
# │ (Concatenate)       │ 219)              │            │ transition3_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn2          │ (None, 15, 15,    │        876 │ block4_concat1[0… │
# │ (BatchNormalizatio… │ 219)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv2        │ (None, 15, 15,    │          0 │ block4_bn2[0][0]  │
# │ (Activation)        │ 219)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad2         │ (None, 17, 17,    │          0 │ block4_actv2[0][… │
# │ (ZeroPadding2D)     │ 219)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d2      │ (None, 15, 15,    │    433,840 │ block4_pad2[0][0] │
# │ (Conv2D)            │ 220)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat2      │ (None, 15, 15,    │          0 │ block4_conv2d2[0… │
# │ (Concatenate)       │ 439)              │            │ block4_concat1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn3          │ (None, 15, 15,    │      1,756 │ block4_concat2[0… │
# │ (BatchNormalizatio… │ 439)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv3        │ (None, 15, 15,    │          0 │ block4_bn3[0][0]  │
# │ (Activation)        │ 439)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad3         │ (None, 17, 17,    │          0 │ block4_actv3[0][… │
# │ (ZeroPadding2D)     │ 439)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d3      │ (None, 15, 15,    │    932,672 │ block4_pad3[0][0] │
# │ (Conv2D)            │ 236)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat3      │ (None, 15, 15,    │          0 │ block4_conv2d3[0… │
# │ (Concatenate)       │ 675)              │            │ block4_concat2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_bn4          │ (None, 15, 15,    │      2,700 │ block4_concat3[0… │
# │ (BatchNormalizatio… │ 675)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_actv4        │ (None, 15, 15,    │          0 │ block4_bn4[0][0]  │
# │ (Activation)        │ 675)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pad4         │ (None, 17, 17,    │          0 │ block4_actv4[0][… │
# │ (ZeroPadding2D)     │ 675)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2d4      │ (None, 15, 15,    │  1,531,152 │ block4_pad4[0][0] │
# │ (Conv2D)            │ 252)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_concat4      │ (None, 15, 15,    │          0 │ block4_conv2d4[0… │
# │ (Concatenate)       │ 927)              │            │ block4_concat3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_bn      │ (None, 15, 15,    │      3,708 │ block4_concat4[0… │
# │ (BatchNormalizatio… │ 927)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_actv    │ (None, 15, 15,    │          0 │ transition4_bn[0… │
# │ (Activation)        │ 927)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_conv2d  │ (None, 15, 15, 7) │      6,496 │ transition4_actv… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition4_pool2d  │ (None, 7, 7, 7)   │          0 │ transition4_conv… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 7)         │          0 │ transition4_pool… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 7)         │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 128)       │      1,024 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1_bn           │ (None, 128)       │        512 │ dense1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1_actv         │ (None, 128)       │          0 │ dense1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │      1,032 │ dense1_actv[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,463,111 (20.84 MB)
#  Trainable params: 5,451,725 (20.80 MB)
#  Non-trainable params: 11,386 (44.48 KB)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(learning_rate=0.0001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

# Increase the number of epochs and use the custom early stopping callback
custom_early_stopping = CustomEarlyStopping(patience=15)
history_DenseNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / batch_size),
    epochs=epochs,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710782885.883667     117 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 322s 597ms/step - accuracy: 0.1474 - loss: 2.1838 - val_accuracy: 0.1457 - val_loss: 2.1116 - learning_rate: 1.0000e-04
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 2:17 377ms/step - accuracy: 0.1875 - loss: 1.9904
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.1875 - loss: 1.9904 - val_accuracy: 0.1444 - val_loss: 2.1367 - learning_rate: 1.0000e-04
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.2211 - loss: 1.9750 - val_accuracy: 0.1505 - val_loss: 2.5664 - learning_rate: 1.0000e-04
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.1875 - loss: 1.8883 - val_accuracy: 0.1406 - val_loss: 2.8522 - learning_rate: 1.0000e-04
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.2656 - loss: 1.8237 - val_accuracy: 0.2986 - val_loss: 1.7252 - learning_rate: 1.0000e-04
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5000 - loss: 1.3462 - val_accuracy: 0.3007 - val_loss: 1.7258 - learning_rate: 1.0000e-04
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.3417 - loss: 1.6848 - val_accuracy: 0.3573 - val_loss: 1.6594 - learning_rate: 1.0000e-04
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.4062 - loss: 1.3823 - val_accuracy: 0.3365 - val_loss: 1.6892 - learning_rate: 1.0000e-04
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.4131 - loss: 1.5187 - val_accuracy: 0.3352 - val_loss: 1.7876 - learning_rate: 1.0000e-04
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6562 - loss: 1.1363 - val_accuracy: 0.3290 - val_loss: 1.8220 - learning_rate: 1.0000e-04
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.4448 - loss: 1.4273 - val_accuracy: 0.3887 - val_loss: 1.7576 - learning_rate: 1.0000e-04
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5312 - loss: 1.2583 - val_accuracy: 0.3870 - val_loss: 1.7928 - learning_rate: 1.0000e-04
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.4742 - loss: 1.3469 - val_accuracy: 0.3437 - val_loss: 1.9656 - learning_rate: 1.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.3438 - loss: 1.4670 - val_accuracy: 0.3471 - val_loss: 1.9211 - learning_rate: 1.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.4887 - loss: 1.3144 - val_accuracy: 0.4358 - val_loss: 1.4673 - learning_rate: 1.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.4062 - loss: 1.2510 - val_accuracy: 0.4498 - val_loss: 1.4289 - learning_rate: 1.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.4977 - loss: 1.2823 - val_accuracy: 0.3635 - val_loss: 1.7600 - learning_rate: 1.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5312 - loss: 1.3174 - val_accuracy: 0.3628 - val_loss: 1.7503 - learning_rate: 1.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.5186 - loss: 1.2565 - val_accuracy: 0.3631 - val_loss: 1.8829 - learning_rate: 1.0000e-04
# Epoch 20/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 2:18 380ms/step - accuracy: 0.5312 - loss: 1.1640
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5312 - loss: 1.1640 - val_accuracy: 0.3751 - val_loss: 1.8346 - learning_rate: 1.0000e-04
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5346 - loss: 1.2199 - val_accuracy: 0.5113 - val_loss: 1.2749 - learning_rate: 1.0000e-05
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.3750 - loss: 1.5226 - val_accuracy: 0.5096 - val_loss: 1.2784 - learning_rate: 1.0000e-05
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5567 - loss: 1.1548 - val_accuracy: 0.5106 - val_loss: 1.2707 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5938 - loss: 1.1699 - val_accuracy: 0.5123 - val_loss: 1.2691 - learning_rate: 1.0000e-05
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5547 - loss: 1.1584 - val_accuracy: 0.5266 - val_loss: 1.2266 - learning_rate: 1.0000e-05
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5938 - loss: 1.1246 - val_accuracy: 0.5270 - val_loss: 1.2262 - learning_rate: 1.0000e-05
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5669 - loss: 1.1282 - val_accuracy: 0.5188 - val_loss: 1.2415 - learning_rate: 1.0000e-05
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5312 - loss: 1.0745 - val_accuracy: 0.5177 - val_loss: 1.2426 - learning_rate: 1.0000e-05
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5717 - loss: 1.1221 - val_accuracy: 0.5184 - val_loss: 1.2645 - learning_rate: 1.0000e-05
# Epoch 30/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 2:20 385ms/step - accuracy: 0.5000 - loss: 1.3748
# Epoch 30: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5000 - loss: 1.3748 - val_accuracy: 0.5191 - val_loss: 1.2636 - learning_rate: 1.0000e-05
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5845 - loss: 1.1031 - val_accuracy: 0.5290 - val_loss: 1.2277 - learning_rate: 1.0000e-06
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6250 - loss: 0.9945 - val_accuracy: 0.5294 - val_loss: 1.2279 - learning_rate: 1.0000e-06
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5822 - loss: 1.1047 - val_accuracy: 0.5273 - val_loss: 1.2245 - learning_rate: 1.0000e-06
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6250 - loss: 1.0513 - val_accuracy: 0.5270 - val_loss: 1.2244 - learning_rate: 1.0000e-06
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5779 - loss: 1.1240 - val_accuracy: 0.5324 - val_loss: 1.2283 - learning_rate: 1.0000e-06
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6250 - loss: 0.9032 - val_accuracy: 0.5324 - val_loss: 1.2283 - learning_rate: 1.0000e-06
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5734 - loss: 1.1121 - val_accuracy: 0.5328 - val_loss: 1.2244 - learning_rate: 1.0000e-06
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5000 - loss: 1.3617 - val_accuracy: 0.5328 - val_loss: 1.2245 - learning_rate: 1.0000e-06
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5762 - loss: 1.0979 - val_accuracy: 0.5328 - val_loss: 1.2263 - learning_rate: 1.0000e-06
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.2500 - loss: 1.8732 - val_accuracy: 0.5321 - val_loss: 1.2265 - learning_rate: 1.0000e-06
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5861 - loss: 1.0937 - val_accuracy: 0.5334 - val_loss: 1.2264 - learning_rate: 1.0000e-06
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6875 - loss: 1.0144 - val_accuracy: 0.5328 - val_loss: 1.2263 - learning_rate: 1.0000e-06
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5792 - loss: 1.1049 - val_accuracy: 0.5338 - val_loss: 1.2293 - learning_rate: 1.0000e-06
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5625 - loss: 1.0811 - val_accuracy: 0.5334 - val_loss: 1.2293 - learning_rate: 1.0000e-06
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5729 - loss: 1.1122 - val_accuracy: 0.5290 - val_loss: 1.2240 - learning_rate: 1.0000e-06
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6250 - loss: 1.1468 - val_accuracy: 0.5287 - val_loss: 1.2240 - learning_rate: 1.0000e-06
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.5878 - loss: 1.1000
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.5878 - loss: 1.1000 - val_accuracy: 0.5317 - val_loss: 1.2224 - learning_rate: 1.0000e-06
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.7812 - loss: 0.8761 - val_accuracy: 0.5324 - val_loss: 1.2223 - learning_rate: 1.0000e-07
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 413ms/step - accuracy: 0.5817 - loss: 1.0958 - val_accuracy: 0.5290 - val_loss: 1.2249 - learning_rate: 1.0000e-07
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.7188 - loss: 0.8395 - val_accuracy: 0.5294 - val_loss: 1.2249 - learning_rate: 1.0000e-07
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.5780 - loss: 1.1182 - val_accuracy: 0.5297 - val_loss: 1.2242 - learning_rate: 1.0000e-07
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5312 - loss: 1.2902 - val_accuracy: 0.5300 - val_loss: 1.2243 - learning_rate: 1.0000e-07
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5830 - loss: 1.0946 - val_accuracy: 0.5324 - val_loss: 1.2254 - learning_rate: 1.0000e-07
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.6875 - loss: 1.0630 - val_accuracy: 0.5311 - val_loss: 1.2253 - learning_rate: 1.0000e-07
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 151s 413ms/step - accuracy: 0.5845 - loss: 1.1008 - val_accuracy: 0.5338 - val_loss: 1.2234 - learning_rate: 1.0000e-07
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.5625 - loss: 1.0962 - val_accuracy: 0.5328 - val_loss: 1.2235 - learning_rate: 1.0000e-07
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 152s 414ms/step - accuracy: 0.5869 - loss: 1.0933 - val_accuracy: 0.5297 - val_loss: 1.2250 - learning_rate: 1.0000e-07
# Epoch 58/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 2:17 378ms/step - accuracy: 0.5312 - loss: 1.0179Epoch 57: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 42.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.5312 - loss: 1.0179 - val_accuracy: 0.5300 - val_loss: 1.2250 - learning_rate: 1.0000e-07

# %%
history = pd.DataFrame(history_DenseNet.history)
history
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.165583  2.105273      0.145734  2.111621   1.000000e-04
# 1   0.187500  1.990390      0.144369  2.136748   1.000000e-04
# 2   0.226339  1.931238      0.150512  2.566377   1.000000e-04
# 3   0.187500  1.888264      0.140614  2.852219   1.000000e-04
# 4   0.281619  1.787393      0.298635  1.725216   1.000000e-04
# 5   0.500000  1.346186      0.300683  1.725816   1.000000e-04
# 6   0.356923  1.645120      0.357338  1.659382   1.000000e-04
# 7   0.406250  1.382344      0.336519  1.689211   1.000000e-04
# 8   0.421444  1.493644      0.335154  1.787602   1.000000e-04
# 9   0.656250  1.136315      0.329010  1.822015   1.000000e-04
# 10  0.446517  1.416209      0.388737  1.757590   1.000000e-04
# 11  0.531250  1.258339      0.387031  1.792842   1.000000e-04
# 12  0.473216  1.358862      0.343686  1.965552   1.000000e-04
# 13  0.343750  1.466981      0.347099  1.921133   1.000000e-04
# 14  0.487250  1.318418      0.435836  1.467274   1.000000e-04
# 15  0.406250  1.251001      0.449829  1.428893   1.000000e-04
# 16  0.495379  1.293002      0.363481  1.760047   1.000000e-04
# 17  0.531250  1.317400      0.362799  1.750326   1.000000e-04
# 18  0.516601  1.254569      0.363140  1.882886   1.000000e-04
# 19  0.531250  1.164008      0.375085  1.834560   1.000000e-04
# 20  0.545182  1.192894      0.511263  1.274895   1.000000e-05
# 21  0.375000  1.522560      0.509556  1.278448   1.000000e-05
# 22  0.558959  1.157042      0.510580  1.270727   1.000000e-05
# 23  0.593750  1.169918      0.512287  1.269140   1.000000e-05
# 24  0.559387  1.145416      0.526621  1.226568   1.000000e-05
# 25  0.593750  1.124570      0.526962  1.226152   1.000000e-05
# 26  0.565121  1.138031      0.518771  1.241452   1.000000e-05
# 27  0.531250  1.074503      0.517747  1.242617   1.000000e-05
# 28  0.572993  1.121045      0.518430  1.264457   1.000000e-05
# 29  0.500000  1.374846      0.519113  1.263592   1.000000e-05
# 30  0.578812  1.110798      0.529010  1.227729   1.000000e-06
# 31  0.625000  0.994482      0.529352  1.227870   1.000000e-06
# 32  0.577614  1.110142      0.527304  1.224542   1.000000e-06
# 33  0.625000  1.051264      0.526962  1.224419   1.000000e-06
# 34  0.580353  1.109233      0.532423  1.228285   1.000000e-06
# 35  0.625000  0.903177      0.532423  1.228295   1.000000e-06
# 36  0.579754  1.106080      0.532764  1.224367   1.000000e-06
# 37  0.500000  1.361695      0.532764  1.224460   1.000000e-06
# 38  0.580010  1.108230      0.532764  1.226273   1.000000e-06
# 39  0.250000  1.873235      0.532082  1.226511   1.000000e-06
# 40  0.585145  1.093032      0.533447  1.226363   1.000000e-06
# 41  0.687500  1.014439      0.532764  1.226304   1.000000e-06
# 42  0.581636  1.103732      0.533788  1.229292   1.000000e-06
# 43  0.562500  1.081081      0.533447  1.229318   1.000000e-06
# 44  0.577957  1.102017      0.529010  1.224046   1.000000e-06
# 45  0.625000  1.146825      0.528669  1.224049   1.000000e-06
# 46  0.585915  1.099542      0.531741  1.222364   1.000000e-06
# 47  0.781250  0.876100      0.532423  1.222347   1.000000e-07
# 48  0.580609  1.102172      0.529010  1.224943   1.000000e-07
# 49  0.718750  0.839452      0.529352  1.224920   1.000000e-07
# 50  0.586000  1.096364      0.529693  1.224195   1.000000e-07
# 51  0.531250  1.290207      0.530034  1.224283   1.000000e-07
# 52  0.582749  1.097977      0.532423  1.225423   1.000000e-07
# 53  0.687500  1.062962      0.531058  1.225271   1.000000e-07
# 54  0.586514  1.096136      0.533788  1.223390   1.000000e-07
# 55  0.562500  1.096162      0.532764  1.223512   1.000000e-07
# 56  0.583947  1.096307      0.529693  1.224968   1.000000e-07
# 57  0.531250  1.017875      0.530034  1.225025   1.000000e-07

# %%
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['accuracy'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['loss'], label='train')
sns.lineplot(x=history_DenseNet.epoch, y=history_DenseNet.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 367/367 - 42s - 115ms/step - accuracy: 0.5847 - loss: 1.0873
#
# train Accuracy: 0.5847414135932922
# 92/92 - 10s - 111ms/step - accuracy: 0.5338 - loss: 1.2293
#
# Test Accuracy: 0.5337883830070496
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.44      0.44      0.44       370
#     contempt       0.39      0.35      0.37       368
#      disgust       0.73      0.87      0.80       376
#         fear       0.37      0.35      0.36       364
#        happy       0.50      0.36      0.42       348
#      neutral       0.50      0.62      0.56       367
#          sad       0.84      0.88      0.86       373
#     surprise       0.40      0.37      0.38       364
#
#     accuracy                           0.53      2930
#    macro avg       0.52      0.53      0.52      2930
# weighted avg       0.52      0.53      0.52      2930

# %%
# Visualize some predictions
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_test[i])
    plt.title(label_to_text[predicted_labels[i]])
    plt.axis("off")

plt.show()
