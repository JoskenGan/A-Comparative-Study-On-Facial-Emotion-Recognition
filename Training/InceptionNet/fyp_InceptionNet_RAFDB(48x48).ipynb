# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, MaxPool2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
# Out:
# 2024-03-26 07:29:15.149765: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 07:29:15.149895: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 07:29:15.316765: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(os.path.join(data_dir, dir_)):
                img = cv2.imread(os.path.join(data_dir, dir_, f), 0)
                img = cv2.resize(img, (48, 48))  # Resize image to 48x48
                img_arr.append(np.expand_dims(img, axis=2))
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (48,48,1)
NUM_CLASSES = len(target_names)
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(48, 48), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
def inception_block(X,
                    filters_1x1: int,
                    filters_3x3_reduce: int,
                    filters_3x3: int,
                    filters_5x5_reduce: int,
                    filters_5x5: int,
                    filters_pool_proj: int,
                    block_name: str):

    conv_1x1 = Conv2D(
            filters=filters_1x1,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_1x1",
        )(X)

    conv_3x3_reduce = Conv2D(
            filters=filters_3x3_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3_reduce",
        )(X)
    conv_3x3 = Conv2D(
            filters=filters_3x3,
            kernel_size=(3,3),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3",
        )(conv_3x3_reduce)

    conv_5x5_reduce = Conv2D(
            filters=filters_5x5_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5_reduce",
        )(X)
    conv_5x5 = Conv2D(
            filters=filters_5x5,
            kernel_size=(5,5),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5",
        )(conv_5x5_reduce)

    pool_proj = MaxPool2D(
        pool_size=(3, 3),
        strides=(1, 1),
        padding='same',
        name=f"incepblock{block_name}_maxpool",
    )(X)
    conv_after_pool = Conv2D(
            filters=filters_pool_proj,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_afterpool",
        )(pool_proj)

    concated = concatenate([conv_1x1, conv_3x3, conv_5x5, conv_after_pool], axis=3, name=f"incepblock{block_name}_concat")
    return concated

# %%
def auxiliary_block(X, out_shape: int, block_id: int):
    X = AveragePooling2D(
        pool_size=(3,3),
        strides=(1,1),
        padding='valid',
        name=f"auxblock{block_id}_avgpool",
    )(X)

    X = Conv2D(
            filters=128,
            kernel_size=(1,1),
            strides=(1,1),
            padding='same',
            activation='relu',
            name=f"auxblock{block_id}_conv2d",
    )(X)

    X = Flatten(name=f"auxblock{block_id}_flatten",)(X)

    X = Dense(units=128, activation='relu', name=f"auxblock{block_id}_dense1",)(X)

    X = Dropout(0.25, name=f"auxblock{block_id}_dropout",)(X)

    X = Dense(units=out_shape, activation='softmax', name=f"auxblock{block_id}_outlayer",)(X)
    return X

# %%
def InceptionNet(in_shape, out_shape, show_summary=False):
    "shallow inception-net without auxiliary layers"

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
            filters=32,
            kernel_size=(3,3),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(model_in)
    X = Conv2D(
            filters=64,
            kernel_size=(1,1),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(X)

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(X,
            filters_1x1=64,
            filters_3x3_reduce=96,
            filters_3x3=128,
            filters_5x5_reduce=16,
            filters_5x5=32,
            filters_pool_proj=32,
            block_name='1a'
    )
    X = inception_block(X,
            filters_1x1=128,
            filters_3x3_reduce=128,
            filters_3x3=192,
            filters_5x5_reduce=32,
            filters_5x5=96,
            filters_pool_proj=64,
            block_name='1b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=192,
        filters_3x3_reduce=96,
        filters_3x3=208,
        filters_5x5_reduce=16,
        filters_5x5=48,
        filters_pool_proj=64,
        block_name='2a'
    )
    X = inception_block(
        X,
        filters_1x1=160,
        filters_3x3_reduce=112,
        filters_3x3=224,
        filters_5x5_reduce=24,
        filters_5x5=64,
        filters_pool_proj=64,
        block_name='2b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=256,
        filters_3x3_reduce=160,
        filters_3x3=320,
        filters_5x5_reduce=32,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3a'
    )
    X = inception_block(
        X,
        filters_1x1=384,
        filters_3x3_reduce=192,
        filters_3x3=384,
        filters_5x5_reduce=48,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3b'
    )

    X = GlobalAveragePooling2D()(X)

    X = Dense(128, activation='relu')(X)
    X = Dropout(0.25)(X)

    model_out = Dense(out_shape, activation="softmax", name="out_layer")(X)

    model = Model(model_in, model_out, name="InceptionNet")

    if show_summary:
        model.summary()

    return model

# %%
model = InceptionNet(INPUT_SHAPE, NUM_CLASSES, show_summary=True)

plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)
# Out:
# Model: "InceptionNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ in_layer            │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 48, 48,    │        320 │ in_layer[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 48, 48,    │      2,112 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 24, 24,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │      6,240 │ max_pooling2d[0]… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │      1,040 │ max_pooling2d[0]… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_maxpo… │ (None, 24, 24,    │          0 │ max_pooling2d[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │      4,160 │ max_pooling2d[0]… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │    110,720 │ incepblock1a_con… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │     12,832 │ incepblock1a_con… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_conv_… │ (None, 24, 24,    │      2,080 │ incepblock1a_max… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1a_concat │ (None, 24, 24,    │          0 │ incepblock1a_con… │
# │ (Concatenate)       │ 256)              │            │ incepblock1a_con… │
# │                     │                   │            │ incepblock1a_con… │
# │                     │                   │            │ incepblock1a_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │     32,896 │ incepblock1a_con… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │      8,224 │ incepblock1a_con… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_maxpo… │ (None, 24, 24,    │          0 │ incepblock1a_con… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │     32,896 │ incepblock1a_con… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │    221,376 │ incepblock1b_con… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │     76,896 │ incepblock1b_con… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_conv_… │ (None, 24, 24,    │     16,448 │ incepblock1b_max… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock1b_concat │ (None, 24, 24,    │          0 │ incepblock1b_con… │
# │ (Concatenate)       │ 480)              │            │ incepblock1b_con… │
# │                     │                   │            │ incepblock1b_con… │
# │                     │                   │            │ incepblock1b_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 12, 12,    │          0 │ incepblock1b_con… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │     46,176 │ max_pooling2d_1[… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │      7,696 │ max_pooling2d_1[… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_maxpo… │ (None, 12, 12,    │          0 │ max_pooling2d_1[… │
# │ (MaxPooling2D)      │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │     92,352 │ max_pooling2d_1[… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │    179,920 │ incepblock2a_con… │
# │ (Conv2D)            │ 208)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │     19,248 │ incepblock2a_con… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_conv_… │ (None, 12, 12,    │     30,784 │ incepblock2a_max… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2a_concat │ (None, 12, 12,    │          0 │ incepblock2a_con… │
# │ (Concatenate)       │ 512)              │            │ incepblock2a_con… │
# │                     │                   │            │ incepblock2a_con… │
# │                     │                   │            │ incepblock2a_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │     57,456 │ incepblock2a_con… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │     12,312 │ incepblock2a_con… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_maxpo… │ (None, 12, 12,    │          0 │ incepblock2a_con… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │     82,080 │ incepblock2a_con… │
# │ (Conv2D)            │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │    226,016 │ incepblock2b_con… │
# │ (Conv2D)            │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │     38,464 │ incepblock2b_con… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_conv_… │ (None, 12, 12,    │     32,832 │ incepblock2b_max… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock2b_concat │ (None, 12, 12,    │          0 │ incepblock2b_con… │
# │ (Concatenate)       │ 512)              │            │ incepblock2b_con… │
# │                     │                   │            │ incepblock2b_con… │
# │                     │                   │            │ incepblock2b_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 6, 6, 512) │          0 │ incepblock2b_con… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 160) │     82,080 │ max_pooling2d_2[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 32)  │     16,416 │ max_pooling2d_2[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_maxpo… │ (None, 6, 6, 512) │          0 │ max_pooling2d_2[… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 256) │    131,328 │ max_pooling2d_2[… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 320) │    461,120 │ incepblock3a_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 128) │    102,528 │ incepblock3a_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_conv_… │ (None, 6, 6, 128) │     65,664 │ incepblock3a_max… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3a_concat │ (None, 6, 6, 832) │          0 │ incepblock3a_con… │
# │ (Concatenate)       │                   │            │ incepblock3a_con… │
# │                     │                   │            │ incepblock3a_con… │
# │                     │                   │            │ incepblock3a_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 192) │    159,936 │ incepblock3a_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 48)  │     39,984 │ incepblock3a_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_maxpo… │ (None, 6, 6, 832) │          0 │ incepblock3a_con… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 384) │    319,872 │ incepblock3a_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 384) │    663,936 │ incepblock3b_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 128) │    153,728 │ incepblock3b_con… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_conv_… │ (None, 6, 6, 128) │    106,624 │ incepblock3b_max… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ incepblock3b_concat │ (None, 6, 6,      │          0 │ incepblock3b_con… │
# │ (Concatenate)       │ 1024)             │            │ incepblock3b_con… │
# │                     │                   │            │ incepblock3b_con… │
# │                     │                   │            │ incepblock3b_con… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ incepblock3b_con… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    131,200 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_layer (Dense)   │ (None, 7)         │        903 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,788,895 (14.45 MB)
#  Trainable params: 3,788,895 (14.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
    rescale=1./255  # Normalization
)

val_datagen = ImageDataGenerator(rescale=1./255)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    min_delta=0.0001,
    factor=0.7,
    patience=3,
    min_lr=1e-6,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=20,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
# Applying data augmentation to the images

train_generator = train_datagen.flow_from_directory(
        data_dir_train,
        target_size=(48, 48),
        color_mode='grayscale',  # Convert images to grayscale
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True

)
val_generator = val_datagen.flow_from_directory(
        data_dir_test,
        target_size=(48, 48),
        color_mode='grayscale',
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
)
# Out:
# Found 12271 images belonging to 7 classes.
# Found 3068 images belonging to 7 classes.

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

# train_datagen.fit(img_arr_train)

# Fit the data generator on validation data
# val_datagen.fit(img_arr_test)

# Training the model

history_InceptionNet = model.fit(x = train_generator,
                                 steps_per_epoch=int(len(img_arr_train) / batch_size),
                                 epochs = epochs,
                                 validation_data = val_generator,
                                 callbacks = [lr_scheduler, early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/383 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.2578 - loss: 2.5838
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711438558.903311      92 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1711438558.950678      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.3734 - loss: 1.7294
# W0000 00:00:1711438617.676661      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 106s 186ms/step - accuracy: 0.3734 - loss: 1.7292 - val_accuracy: 0.4159 - val_loss: 1.5371 - learning_rate: 0.0010
# Epoch 2/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.4688 - loss: 1.4089
# W0000 00:00:1711438629.931160      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.4688 - loss: 1.4089 - val_accuracy: 0.4104 - val_loss: 1.5477 - learning_rate: 0.0010
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 34s 88ms/step - accuracy: 0.4249 - loss: 1.5391 - val_accuracy: 0.4938 - val_loss: 1.4413 - learning_rate: 0.0010
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.4062 - loss: 1.6912 - val_accuracy: 0.4850 - val_loss: 1.5034 - learning_rate: 0.0010
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.4850 - loss: 1.3898 - val_accuracy: 0.5261 - val_loss: 1.2803 - learning_rate: 0.0010
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - loss: 1.2799 - val_accuracy: 0.5398 - val_loss: 1.2561 - learning_rate: 0.0010
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.5363 - loss: 1.2754 - val_accuracy: 0.5114 - val_loss: 1.3065 - learning_rate: 0.0010
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.6250 - loss: 1.2542 - val_accuracy: 0.4739 - val_loss: 1.3791 - learning_rate: 0.0010
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.5623 - loss: 1.1857 - val_accuracy: 0.6219 - val_loss: 1.0351 - learning_rate: 0.0010
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6875 - loss: 0.9119 - val_accuracy: 0.6252 - val_loss: 1.0423 - learning_rate: 0.0010
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.5946 - loss: 1.1115 - val_accuracy: 0.6463 - val_loss: 0.9986 - learning_rate: 0.0010
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.5938 - loss: 0.9194 - val_accuracy: 0.6516 - val_loss: 0.9829 - learning_rate: 0.0010
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 70ms/step - accuracy: 0.6346 - loss: 1.0294 - val_accuracy: 0.6522 - val_loss: 0.9545 - learning_rate: 0.0010
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.7095 - val_accuracy: 0.6607 - val_loss: 0.9451 - learning_rate: 0.0010
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.6542 - loss: 0.9532 - val_accuracy: 0.6793 - val_loss: 0.8951 - learning_rate: 0.0010
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.6875 - loss: 0.9171 - val_accuracy: 0.6780 - val_loss: 0.9069 - learning_rate: 0.0010
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.6695 - loss: 0.9258 - val_accuracy: 0.7076 - val_loss: 0.8225 - learning_rate: 0.0010
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.5938 - loss: 1.1124 - val_accuracy: 0.7034 - val_loss: 0.8219 - learning_rate: 0.0010
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.6908 - loss: 0.8658 - val_accuracy: 0.6705 - val_loss: 0.8724 - learning_rate: 0.0010
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6250 - loss: 1.0233 - val_accuracy: 0.6848 - val_loss: 0.8408 - learning_rate: 0.0010
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.7116 - loss: 0.8100 - val_accuracy: 0.7194 - val_loss: 0.7815 - learning_rate: 0.0010
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7812 - loss: 0.6522 - val_accuracy: 0.7262 - val_loss: 0.7739 - learning_rate: 0.0010
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - accuracy: 0.7179 - loss: 0.7882 - val_accuracy: 0.7099 - val_loss: 0.7917 - learning_rate: 0.0010
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - loss: 1.0128 - val_accuracy: 0.7171 - val_loss: 0.7776 - learning_rate: 0.0010
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7200 - loss: 0.7785
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.7200 - loss: 0.7785 - val_accuracy: 0.6597 - val_loss: 0.8867 - learning_rate: 0.0010
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 1.0316 - val_accuracy: 0.6578 - val_loss: 0.8872 - learning_rate: 7.0000e-04
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.7454 - loss: 0.7247 - val_accuracy: 0.7285 - val_loss: 0.7562 - learning_rate: 7.0000e-04
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.8837 - val_accuracy: 0.7285 - val_loss: 0.7549 - learning_rate: 7.0000e-04
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.7585 - loss: 0.6747 - val_accuracy: 0.7497 - val_loss: 0.7124 - learning_rate: 7.0000e-04
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7500 - loss: 0.5916 - val_accuracy: 0.7474 - val_loss: 0.7253 - learning_rate: 7.0000e-04
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.7676 - loss: 0.6512 - val_accuracy: 0.7581 - val_loss: 0.7057 - learning_rate: 7.0000e-04
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.6944 - val_accuracy: 0.7595 - val_loss: 0.6983 - learning_rate: 7.0000e-04
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.7718 - loss: 0.6376 - val_accuracy: 0.7669 - val_loss: 0.6772 - learning_rate: 7.0000e-04
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7500 - loss: 0.4711 - val_accuracy: 0.7604 - val_loss: 0.6727 - learning_rate: 7.0000e-04
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.7775 - loss: 0.6217 - val_accuracy: 0.7679 - val_loss: 0.6959 - learning_rate: 7.0000e-04
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7812 - loss: 0.5792 - val_accuracy: 0.7588 - val_loss: 0.7090 - learning_rate: 7.0000e-04
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7867 - loss: 0.5912
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.7867 - loss: 0.5912 - val_accuracy: 0.7555 - val_loss: 0.6976 - learning_rate: 7.0000e-04
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7500 - loss: 0.6068 - val_accuracy: 0.7523 - val_loss: 0.6962 - learning_rate: 4.9000e-04
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.7992 - loss: 0.5606 - val_accuracy: 0.7477 - val_loss: 0.7373 - learning_rate: 4.9000e-04
# Epoch 40/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7500 - loss: 0.4833
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7500 - loss: 0.4833 - val_accuracy: 0.7516 - val_loss: 0.7305 - learning_rate: 4.9000e-04
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.8174 - loss: 0.5127 - val_accuracy: 0.7888 - val_loss: 0.6459 - learning_rate: 3.4300e-04
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7500 - loss: 0.5574 - val_accuracy: 0.7855 - val_loss: 0.6468 - learning_rate: 3.4300e-04
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8224 - loss: 0.4919 - val_accuracy: 0.7702 - val_loss: 0.6647 - learning_rate: 3.4300e-04
# Epoch 44/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9062 - loss: 0.4132
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9062 - loss: 0.4132 - val_accuracy: 0.7696 - val_loss: 0.6603 - learning_rate: 3.4300e-04
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8279 - loss: 0.4784 - val_accuracy: 0.7914 - val_loss: 0.6582 - learning_rate: 2.4010e-04
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.6586 - val_accuracy: 0.7920 - val_loss: 0.6629 - learning_rate: 2.4010e-04
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8342 - loss: 0.4539
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8342 - loss: 0.4539 - val_accuracy: 0.7725 - val_loss: 0.7032 - learning_rate: 2.4010e-04
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.4475 - val_accuracy: 0.7741 - val_loss: 0.6984 - learning_rate: 1.6807e-04
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8391 - loss: 0.4373 - val_accuracy: 0.7891 - val_loss: 0.6525 - learning_rate: 1.6807e-04
# Epoch 50/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.8750 - loss: 0.3205
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8750 - loss: 0.3205 - val_accuracy: 0.7891 - val_loss: 0.6528 - learning_rate: 1.6807e-04
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.8573 - loss: 0.3990 - val_accuracy: 0.7911 - val_loss: 0.6613 - learning_rate: 1.1765e-04
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8125 - loss: 0.6819 - val_accuracy: 0.7917 - val_loss: 0.6614 - learning_rate: 1.1765e-04
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8569 - loss: 0.3915
# Epoch 53: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8569 - loss: 0.3915 - val_accuracy: 0.7849 - val_loss: 0.6711 - learning_rate: 1.1765e-04
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9062 - loss: 0.3079 - val_accuracy: 0.7852 - val_loss: 0.6706 - learning_rate: 8.2354e-05
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.8564 - loss: 0.3888 - val_accuracy: 0.7846 - val_loss: 0.7022 - learning_rate: 8.2354e-05
# Epoch 56/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.8750 - loss: 0.3349
# Epoch 56: ReduceLROnPlateau reducing learning rate to 5.76480058953166e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8750 - loss: 0.3349 - val_accuracy: 0.7846 - val_loss: 0.7021 - learning_rate: 8.2354e-05
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8702 - loss: 0.3632 - val_accuracy: 0.7891 - val_loss: 0.6858 - learning_rate: 5.7648e-05
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9062 - loss: 0.3248 - val_accuracy: 0.7888 - val_loss: 0.6862 - learning_rate: 5.7648e-05
# Epoch 59/100
# 382/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8670 - loss: 0.3639
# Epoch 59: ReduceLROnPlateau reducing learning rate to 4.0353603617404586e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8670 - loss: 0.3639 - val_accuracy: 0.7800 - val_loss: 0.7020 - learning_rate: 5.7648e-05
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8438 - loss: 0.3204 - val_accuracy: 0.7793 - val_loss: 0.7022 - learning_rate: 4.0354e-05
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.8735 - loss: 0.3580 - val_accuracy: 0.7940 - val_loss: 0.6878 - learning_rate: 4.0354e-05
# Epoch 62/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.9062 - loss: 0.3674
# Epoch 62: ReduceLROnPlateau reducing learning rate to 2.8247522277524694e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9062 - loss: 0.3674 - val_accuracy: 0.7950 - val_loss: 0.6877 - learning_rate: 4.0354e-05
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8752 - loss: 0.3401 - val_accuracy: 0.7865 - val_loss: 0.6985 - learning_rate: 2.8248e-05
# Epoch 64/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8125 - loss: 0.5830 - val_accuracy: 0.7865 - val_loss: 0.6983 - learning_rate: 2.8248e-05
# Epoch 65/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8748 - loss: 0.3532
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.977326610358432e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8748 - loss: 0.3532 - val_accuracy: 0.7901 - val_loss: 0.6924 - learning_rate: 2.8248e-05
# Epoch 66/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8438 - loss: 0.3497 - val_accuracy: 0.7898 - val_loss: 0.6922 - learning_rate: 1.9773e-05
# Epoch 67/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8731 - loss: 0.3513 - val_accuracy: 0.7914 - val_loss: 0.6946 - learning_rate: 1.9773e-05
# Epoch 68/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 43ms/step - accuracy: 0.8125 - loss: 0.3636
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.3841286272509023e-05.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8125 - loss: 0.3636 - val_accuracy: 0.7911 - val_loss: 0.6945 - learning_rate: 1.9773e-05
# Epoch 69/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8823 - loss: 0.3313 - val_accuracy: 0.7907 - val_loss: 0.6976 - learning_rate: 1.3841e-05
# Epoch 70/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.2914 - val_accuracy: 0.7911 - val_loss: 0.6972 - learning_rate: 1.3841e-05
# Epoch 71/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8704 - loss: 0.3562
# Epoch 71: ReduceLROnPlateau reducing learning rate to 9.688900263427058e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.8704 - loss: 0.3561 - val_accuracy: 0.7911 - val_loss: 0.7041 - learning_rate: 1.3841e-05
# Epoch 72/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.2772 - val_accuracy: 0.7911 - val_loss: 0.7042 - learning_rate: 9.6889e-06
# Epoch 73/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8740 - loss: 0.3505 - val_accuracy: 0.7901 - val_loss: 0.7021 - learning_rate: 9.6889e-06
# Epoch 74/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 43ms/step - accuracy: 0.8438 - loss: 0.4366
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.782229866075795e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8438 - loss: 0.4366 - val_accuracy: 0.7901 - val_loss: 0.7021 - learning_rate: 9.6889e-06
# Epoch 75/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - accuracy: 0.8701 - loss: 0.3488 - val_accuracy: 0.7904 - val_loss: 0.7021 - learning_rate: 6.7822e-06
# Epoch 76/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9688 - loss: 0.1767 - val_accuracy: 0.7904 - val_loss: 0.7020 - learning_rate: 6.7822e-06
# Epoch 77/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8862 - loss: 0.3303
# Epoch 77: ReduceLROnPlateau reducing learning rate to 4.747560842588427e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8861 - loss: 0.3304 - val_accuracy: 0.7930 - val_loss: 0.7054 - learning_rate: 6.7822e-06
# Epoch 78/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9375 - loss: 0.2082 - val_accuracy: 0.7930 - val_loss: 0.7053 - learning_rate: 4.7476e-06
# Epoch 79/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.8844 - loss: 0.3267 - val_accuracy: 0.7927 - val_loss: 0.7060 - learning_rate: 4.7476e-06
# Epoch 80/100
#   1/383 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.9062 - loss: 0.2109
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.3232926853088427e-06.
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9062 - loss: 0.2109 - val_accuracy: 0.7927 - val_loss: 0.7061 - learning_rate: 4.7476e-06
# Epoch 81/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8834 - loss: 0.3251 - val_accuracy: 0.7943 - val_loss: 0.7046 - learning_rate: 3.3233e-06
# Epoch 82/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6875 - loss: 0.7107 - val_accuracy: 0.7937 - val_loss: 0.7046 - learning_rate: 3.3233e-06
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 62.

# %%
history = pd.DataFrame(history_InceptionNet.history)
history
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.388185  1.650456      0.415906  1.537110       0.001000
# 1   0.468750  1.408939      0.410365  1.547675       0.001000
# 2   0.434022  1.514199      0.493807  1.441346       0.001000
# 3   0.406250  1.691202      0.485007  1.503386       0.001000
# 4   0.504943  1.350669      0.526076  1.280344       0.001000
# ..       ...       ...           ...       ...            ...
# 77  0.937500  0.208240      0.793025  0.705340       0.000005
# 78  0.881608  0.333766      0.792699  0.706049       0.000005
# 79  0.906250  0.210912      0.792699  0.706129       0.000005
# 80  0.883406  0.330164      0.794329  0.704560       0.000003
# 81  0.687500  0.710733      0.793677  0.704560       0.000003
#
# [82 rows x 5 columns]

# %%
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['accuracy'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['loss'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_loss'], label='valid')
plt.title('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
train_loss, train_acc = model.evaluate(train_generator, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

test_loss, test_acc = model.evaluate(val_generator, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Make predictions
predictions = model.predict(val_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = val_generator.classes
class_labels = list(val_generator.class_indices.keys())

# Generate classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print("Classification Report:\n", report)

# Generate confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.8819 - loss: 0.3278
#
# train Accuracy: 0.8780865669250488
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7649 - loss: 0.8279
#
# Test Accuracy: 0.7949804663658142
#  6/96 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# W0000 00:00:1711439894.896114      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step
# W0000 00:00:1711439900.637453      92 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.61      0.74      0.67       162
#      disgust       0.44      0.39      0.41       160
#         fear       0.70      0.51      0.59        74
#        happy       0.92      0.90      0.91      1185
#      neutral       0.74      0.81      0.77       680
#          sad       0.72      0.74      0.73       478
#     surprise       0.86      0.78      0.82       329
#
#     accuracy                           0.79      3068
#    macro avg       0.72      0.69      0.70      3068
# weighted avg       0.80      0.79      0.79      3068

# %%
import random

# Visualize random predictions
num_samples_to_show = 9
sample_images, sample_labels = next(val_generator)
random_indices = random.sample(range(len(sample_images)), num_samples_to_show)

plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(3, 3, i + 1)
    plt.imshow(sample_images[idx].reshape(64, 64), cmap='gray')
    plt.title(f"True: {class_labels[np.argmax(sample_labels[idx])]}, Predicted: {class_labels[predicted_classes_sample[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
