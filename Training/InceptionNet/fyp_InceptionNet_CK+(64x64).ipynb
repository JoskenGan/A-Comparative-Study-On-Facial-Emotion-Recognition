# %%
! pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (3.7.4)
# Requirement already satisfied: scikit-learn>=0.18 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /opt/conda/lib/python3.10/site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, MaxPool2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/ck/ck/"
TOP_EMOTIONS = ["Angry", "Fear", "Happy", "Sadness", "Surprise"]

TRAIN_SIZE = 0.80
INPUT_SHAPE = (64,64,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Surprise has 249 number of images
# Fear has 75 number of images
# Angry has 135 number of images
# Sadness has 84 number of images
# Happy has 207 number of images
#
# total images are 750

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (64, 64))  # Resize the image to 64x64
            img_arr.append(np.expand_dims(img, axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Surprise images to numpy arrays...
# loaded Fear images to numpy arrays...
# loaded Angry images to numpy arrays...
# loaded Sadness images to numpy arrays...
# loaded Happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((750, 64, 64, 1),
#  (750, 5),
#  {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Sadness', 4: 'Happy'})

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = pyplot.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        ax.imshow(img.reshape(64, 64), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

pyplot.tight_layout()
pyplot.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((600, 64, 64, 1), (150, 64, 64, 1), (600, 5), (150, 5))

# %%
def inception_block(X,
                    filters_1x1: int,
                    filters_3x3_reduce: int,
                    filters_3x3: int,
                    filters_5x5_reduce: int,
                    filters_5x5: int,
                    filters_pool_proj: int,
                    block_name: str):

    conv_1x1 = Conv2D(
            filters=filters_1x1,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_1x1",
        )(X)

    conv_3x3_reduce = Conv2D(
            filters=filters_3x3_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3_reduce",
        )(X)
    conv_3x3 = Conv2D(
            filters=filters_3x3,
            kernel_size=(3,3),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_3x3",
        )(conv_3x3_reduce)

    conv_5x5_reduce = Conv2D(
            filters=filters_5x5_reduce,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5_reduce",
        )(X)
    conv_5x5 = Conv2D(
            filters=filters_5x5,
            kernel_size=(5,5),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_5x5",
        )(conv_5x5_reduce)

    pool_proj = MaxPool2D(
        pool_size=(3, 3),
        strides=(1, 1),
        padding='same',
        name=f"incepblock{block_name}_maxpool",
    )(X)
    conv_after_pool = Conv2D(
            filters=filters_pool_proj,
            kernel_size=(1, 1),
            padding='same',
            activation='relu',
            kernel_initializer=he_normal(seed=42),
            name=f"incepblock{block_name}_conv_afterpool",
        )(pool_proj)

    concated = concatenate([conv_1x1, conv_3x3, conv_5x5, conv_after_pool], axis=3, name=f"incepblock{block_name}_concat")
    return concated

# %%
def auxiliary_block(X, out_shape: int, block_id: int):
    X = AveragePooling2D(
        pool_size=(3,3),
        strides=(1,1),
        padding='valid',
        name=f"auxblock{block_id}_avgpool",
    )(X)

    X = Conv2D(
            filters=128,
            kernel_size=(1,1),
            strides=(1,1),
            padding='same',
            activation='relu',
            name=f"auxblock{block_id}_conv2d",
    )(X)

    X = Flatten(name=f"auxblock{block_id}_flatten",)(X)

    X = Dense(units=128, activation='relu', name=f"auxblock{block_id}_dense1",)(X)

    X = Dropout(0.25, name=f"auxblock{block_id}_dropout",)(X)

    X = Dense(units=out_shape, activation='softmax', name=f"auxblock{block_id}_outlayer",)(X)
    return X

# %%
def InceptionNet(in_shape, out_shape, show_summary=False):
    "shallow inception-net without auxiliary layers"

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
            filters=32,
            kernel_size=(3,3),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(model_in)
    X = Conv2D(
            filters=64,
            kernel_size=(1,1),
            padding='same',
            strides=(1,1),
            activation='relu',
            kernel_initializer=he_normal(seed=42)
        )(X)

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(X,
            filters_1x1=64,
            filters_3x3_reduce=96,
            filters_3x3=128,
            filters_5x5_reduce=16,
            filters_5x5=32,
            filters_pool_proj=32,
            block_name='1a'
    )
    X = inception_block(X,
            filters_1x1=128,
            filters_3x3_reduce=128,
            filters_3x3=192,
            filters_5x5_reduce=32,
            filters_5x5=96,
            filters_pool_proj=64,
            block_name='1b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=192,
        filters_3x3_reduce=96,
        filters_3x3=208,
        filters_5x5_reduce=16,
        filters_5x5=48,
        filters_pool_proj=64,
        block_name='2a'
    )
    X = inception_block(
        X,
        filters_1x1=160,
        filters_3x3_reduce=112,
        filters_3x3=224,
        filters_5x5_reduce=24,
        filters_5x5=64,
        filters_pool_proj=64,
        block_name='2b'
    )

    X = MaxPool2D(
        (3, 3),
        padding='same',
        strides=(2, 2),
        )(X)

    X = inception_block(
        X,
        filters_1x1=256,
        filters_3x3_reduce=160,
        filters_3x3=320,
        filters_5x5_reduce=32,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3a'
    )
    X = inception_block(
        X,
        filters_1x1=384,
        filters_3x3_reduce=192,
        filters_3x3=384,
        filters_5x5_reduce=48,
        filters_5x5=128,
        filters_pool_proj=128,
        block_name='3b'
    )

    X = GlobalAveragePooling2D()(X)

    X = Dense(128, activation='relu')(X)
    X = Dropout(0.25)(X)

    model_out = Dense(out_shape, activation="softmax", name="out_layer")(X)

    model = Model(model_in, model_out, name="InceptionNet")

    if show_summary:
        model.summary()

    return model

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
model = InceptionNet(INPUT_SHAPE, NUM_CLASSES, show_summary=True)
# Out:
# Model: "InceptionNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  in_layer (InputLayer)       [(None, 64, 64, 1)]          0         []
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)           320       ['in_layer[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           2112      ['conv2d_4[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  incepblock1a_conv_3x3_redu  (None, 32, 32, 96)           6240      ['max_pooling2d_6[0][0]']
#  ce (Conv2D)
#
#  incepblock1a_conv_5x5_redu  (None, 32, 32, 16)           1040      ['max_pooling2d_6[0][0]']
#  ce (Conv2D)
#
#  incepblock1a_maxpool (MaxP  (None, 32, 32, 64)           0         ['max_pooling2d_6[0][0]']
#  ooling2D)
#
#  incepblock1a_conv_1x1 (Con  (None, 32, 32, 64)           4160      ['max_pooling2d_6[0][0]']
#  v2D)
#
#  incepblock1a_conv_3x3 (Con  (None, 32, 32, 128)          110720    ['incepblock1a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1a_conv_5x5 (Con  (None, 32, 32, 32)           12832     ['incepblock1a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1a_conv_afterpoo  (None, 32, 32, 32)           2080      ['incepblock1a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock1a_concat (Conca  (None, 32, 32, 256)          0         ['incepblock1a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock1a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock1a_conv_5x5[0][0]'
#                                                                     , 'incepblock1a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock1b_conv_3x3_redu  (None, 32, 32, 128)          32896     ['incepblock1a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock1b_conv_5x5_redu  (None, 32, 32, 32)           8224      ['incepblock1a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock1b_maxpool (MaxP  (None, 32, 32, 256)          0         ['incepblock1a_concat[0][0]']
#  ooling2D)
#
#  incepblock1b_conv_1x1 (Con  (None, 32, 32, 128)          32896     ['incepblock1a_concat[0][0]']
#  v2D)
#
#  incepblock1b_conv_3x3 (Con  (None, 32, 32, 192)          221376    ['incepblock1b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1b_conv_5x5 (Con  (None, 32, 32, 96)           76896     ['incepblock1b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock1b_conv_afterpoo  (None, 32, 32, 64)           16448     ['incepblock1b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock1b_concat (Conca  (None, 32, 32, 480)          0         ['incepblock1b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock1b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock1b_conv_5x5[0][0]'
#                                                                     , 'incepblock1b_conv_afterpool
#                                                                     [0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 480)          0         ['incepblock1b_concat[0][0]']
#  g2D)
#
#  incepblock2a_conv_3x3_redu  (None, 16, 16, 96)           46176     ['max_pooling2d_7[0][0]']
#  ce (Conv2D)
#
#  incepblock2a_conv_5x5_redu  (None, 16, 16, 16)           7696      ['max_pooling2d_7[0][0]']
#  ce (Conv2D)
#
#  incepblock2a_maxpool (MaxP  (None, 16, 16, 480)          0         ['max_pooling2d_7[0][0]']
#  ooling2D)
#
#  incepblock2a_conv_1x1 (Con  (None, 16, 16, 192)          92352     ['max_pooling2d_7[0][0]']
#  v2D)
#
#  incepblock2a_conv_3x3 (Con  (None, 16, 16, 208)          179920    ['incepblock2a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2a_conv_5x5 (Con  (None, 16, 16, 48)           19248     ['incepblock2a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2a_conv_afterpoo  (None, 16, 16, 64)           30784     ['incepblock2a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock2a_concat (Conca  (None, 16, 16, 512)          0         ['incepblock2a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock2a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock2a_conv_5x5[0][0]'
#                                                                     , 'incepblock2a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock2b_conv_3x3_redu  (None, 16, 16, 112)          57456     ['incepblock2a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock2b_conv_5x5_redu  (None, 16, 16, 24)           12312     ['incepblock2a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock2b_maxpool (MaxP  (None, 16, 16, 512)          0         ['incepblock2a_concat[0][0]']
#  ooling2D)
#
#  incepblock2b_conv_1x1 (Con  (None, 16, 16, 160)          82080     ['incepblock2a_concat[0][0]']
#  v2D)
#
#  incepblock2b_conv_3x3 (Con  (None, 16, 16, 224)          226016    ['incepblock2b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2b_conv_5x5 (Con  (None, 16, 16, 64)           38464     ['incepblock2b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock2b_conv_afterpoo  (None, 16, 16, 64)           32832     ['incepblock2b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock2b_concat (Conca  (None, 16, 16, 512)          0         ['incepblock2b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock2b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock2b_conv_5x5[0][0]'
#                                                                     , 'incepblock2b_conv_afterpool
#                                                                     [0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 8, 8, 512)            0         ['incepblock2b_concat[0][0]']
#  g2D)
#
#  incepblock3a_conv_3x3_redu  (None, 8, 8, 160)            82080     ['max_pooling2d_8[0][0]']
#  ce (Conv2D)
#
#  incepblock3a_conv_5x5_redu  (None, 8, 8, 32)             16416     ['max_pooling2d_8[0][0]']
#  ce (Conv2D)
#
#  incepblock3a_maxpool (MaxP  (None, 8, 8, 512)            0         ['max_pooling2d_8[0][0]']
#  ooling2D)
#
#  incepblock3a_conv_1x1 (Con  (None, 8, 8, 256)            131328    ['max_pooling2d_8[0][0]']
#  v2D)
#
#  incepblock3a_conv_3x3 (Con  (None, 8, 8, 320)            461120    ['incepblock3a_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3a_conv_5x5 (Con  (None, 8, 8, 128)            102528    ['incepblock3a_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3a_conv_afterpoo  (None, 8, 8, 128)            65664     ['incepblock3a_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock3a_concat (Conca  (None, 8, 8, 832)            0         ['incepblock3a_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock3a_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock3a_conv_5x5[0][0]'
#                                                                     , 'incepblock3a_conv_afterpool
#                                                                     [0][0]']
#
#  incepblock3b_conv_3x3_redu  (None, 8, 8, 192)            159936    ['incepblock3a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock3b_conv_5x5_redu  (None, 8, 8, 48)             39984     ['incepblock3a_concat[0][0]']
#  ce (Conv2D)
#
#  incepblock3b_maxpool (MaxP  (None, 8, 8, 832)            0         ['incepblock3a_concat[0][0]']
#  ooling2D)
#
#  incepblock3b_conv_1x1 (Con  (None, 8, 8, 384)            319872    ['incepblock3a_concat[0][0]']
#  v2D)
#
#  incepblock3b_conv_3x3 (Con  (None, 8, 8, 384)            663936    ['incepblock3b_conv_3x3_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3b_conv_5x5 (Con  (None, 8, 8, 128)            153728    ['incepblock3b_conv_5x5_reduce
#  v2D)                                                               [0][0]']
#
#  incepblock3b_conv_afterpoo  (None, 8, 8, 128)            106624    ['incepblock3b_maxpool[0][0]']
#  l (Conv2D)
#
#  incepblock3b_concat (Conca  (None, 8, 8, 1024)           0         ['incepblock3b_conv_1x1[0][0]'
#  tenate)                                                            , 'incepblock3b_conv_3x3[0][0]
#                                                                     ',
#                                                                      'incepblock3b_conv_5x5[0][0]'
#                                                                     , 'incepblock3b_conv_afterpool
#                                                                     [0][0]']
#
#  global_average_pooling2d_2  (None, 1024)                 0         ['incepblock3b_concat[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)                  131200    ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  out_layer (Dense)           (None, 5)                    645       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 3788637 (14.45 MB)
# Trainable params: 3788637 (14.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=13,
    verbose=1,
    restore_best_weights=True,
)

# %%
batch_size = 32
loss = "categorical_crossentropy"
optim = optimizers.Adam(0.001)
epochs = 100

# %%
model.compile(
        loss=loss,
        optimizer=optim,
        metrics=['accuracy'],
)

train_datagen.fit(X_train)

custom_early_stopping = CustomEarlyStopping(patience=15)

history_InceptionNet = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data = (X_test, y_test),
    steps_per_epoch = len(X_train) / batch_size,
    epochs = epochs,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 14s 94ms/step - loss: 1.8023 - accuracy: 0.2867 - val_loss: 1.5182 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.5212 - accuracy: 0.3100 - val_loss: 1.5087 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.5118 - accuracy: 0.3217 - val_loss: 1.5083 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.5114 - accuracy: 0.3300 - val_loss: 1.5025 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.5011 - accuracy: 0.3333 - val_loss: 1.4745 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.5091 - accuracy: 0.3450 - val_loss: 1.5081 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.5085 - accuracy: 0.3033 - val_loss: 1.5068 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 8/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.5075 - accuracy: 0.3100 - val_loss: 1.5029 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.4874 - accuracy: 0.3367 - val_loss: 1.4592 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 10/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.4899 - accuracy: 0.3350 - val_loss: 1.4488 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 11/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.5023 - accuracy: 0.3250 - val_loss: 1.4864 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 12/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.5047 - accuracy: 0.3367 - val_loss: 1.4568 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 13/100
# 18/18 [==============================] - 1s 61ms/step - loss: 1.4638 - accuracy: 0.3283 - val_loss: 1.4148 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 14/100
# 18/18 [==============================] - 1s 64ms/step - loss: 1.4632 - accuracy: 0.3583 - val_loss: 1.4218 - val_accuracy: 0.4733 - lr: 0.0010
# Epoch 15/100
# 18/18 [==============================] - 1s 64ms/step - loss: 1.4347 - accuracy: 0.3717 - val_loss: 1.3643 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 16/100
# 18/18 [==============================] - 1s 63ms/step - loss: 1.3284 - accuracy: 0.4700 - val_loss: 1.1157 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 17/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.2756 - accuracy: 0.4867 - val_loss: 1.3670 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 18/100
# 18/18 [==============================] - 1s 63ms/step - loss: 1.1999 - accuracy: 0.4983 - val_loss: 0.9598 - val_accuracy: 0.6067 - lr: 0.0010
# Epoch 19/100
# 18/18 [==============================] - 1s 62ms/step - loss: 1.0372 - accuracy: 0.5900 - val_loss: 0.9891 - val_accuracy: 0.5800 - lr: 0.0010
# Epoch 20/100
# 18/18 [==============================] - 1s 64ms/step - loss: 1.0142 - accuracy: 0.5933 - val_loss: 0.9274 - val_accuracy: 0.6533 - lr: 0.0010
# Epoch 21/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.9378 - accuracy: 0.6200 - val_loss: 0.8022 - val_accuracy: 0.6600 - lr: 0.0010
# Epoch 22/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.8518 - accuracy: 0.6717 - val_loss: 0.9729 - val_accuracy: 0.6467 - lr: 0.0010
# Epoch 23/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.7622 - accuracy: 0.7000 - val_loss: 0.7017 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 24/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.6170 - accuracy: 0.7733 - val_loss: 0.5356 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 25/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.4921 - accuracy: 0.7983 - val_loss: 0.4010 - val_accuracy: 0.8933 - lr: 0.0010
# Epoch 26/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.4321 - accuracy: 0.8300 - val_loss: 0.4699 - val_accuracy: 0.8133 - lr: 0.0010
# Epoch 27/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.4654 - accuracy: 0.8267 - val_loss: 0.5836 - val_accuracy: 0.7733 - lr: 0.0010
# Epoch 28/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.4208 - accuracy: 0.8367 - val_loss: 0.4679 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 29/100
# 18/18 [==============================] - 1s 62ms/step - loss: 0.3577 - accuracy: 0.8533 - val_loss: 0.3877 - val_accuracy: 0.8133 - lr: 0.0010
# Epoch 30/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.3334 - accuracy: 0.8650 - val_loss: 0.2630 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 31/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.2756 - accuracy: 0.8883 - val_loss: 0.2381 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 32/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2238 - accuracy: 0.9300 - val_loss: 0.2835 - val_accuracy: 0.8933 - lr: 0.0010
# Epoch 33/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2218 - accuracy: 0.9150 - val_loss: 0.2533 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 34/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2234 - accuracy: 0.9250 - val_loss: 0.3329 - val_accuracy: 0.8867 - lr: 0.0010
# Epoch 35/100
# 19/18 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9150
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 18/18 [==============================] - 1s 63ms/step - loss: 0.2239 - accuracy: 0.9150 - val_loss: 0.2423 - val_accuracy: 0.9267 - lr: 0.0010
# Epoch 36/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.1961 - accuracy: 0.9433 - val_loss: 0.1251 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 37/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.1117 - accuracy: 0.9633 - val_loss: 0.1363 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 38/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0967 - accuracy: 0.9700 - val_loss: 0.1438 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 39/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0931 - accuracy: 0.9717 - val_loss: 0.1559 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 40/100
# 19/18 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9800
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0719 - accuracy: 0.9800 - val_loss: 0.1476 - val_accuracy: 0.9467 - lr: 1.0000e-04
# Epoch 41/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0906 - accuracy: 0.9683 - val_loss: 0.1354 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 42/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0875 - accuracy: 0.9833 - val_loss: 0.1350 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 43/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0826 - accuracy: 0.9767 - val_loss: 0.1334 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 44/100
# 19/18 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9800
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0701 - accuracy: 0.9800 - val_loss: 0.1291 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 45/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0637 - accuracy: 0.9817 - val_loss: 0.1293 - val_accuracy: 0.9667 - lr: 1.0000e-06
# Epoch 46/100
# 18/18 [==============================] - 1s 63ms/step - loss: 0.0804 - accuracy: 0.9750 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-06
# Epoch 47/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0690 - accuracy: 0.9783 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-06
# Epoch 48/100
# 19/18 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9733
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 18/18 [==============================] - 1s 66ms/step - loss: 0.0693 - accuracy: 0.9733 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-06
# Epoch 49/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0742 - accuracy: 0.9800 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 50/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0719 - accuracy: 0.9800 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 51/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0743 - accuracy: 0.9767 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 52/100
# 19/18 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9750
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-07.
# 18/18 [==============================] - 1s 66ms/step - loss: 0.0754 - accuracy: 0.9750 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 53/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0669 - accuracy: 0.9783 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 54/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0784 - accuracy: 0.9750 - val_loss: 0.1296 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 55/100
# 18/18 [==============================] - 1s 65ms/step - loss: 0.0640 - accuracy: 0.9817 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 56/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0719 - accuracy: 0.9800 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 57/100
# 18/18 [==============================] - 1s 64ms/step - loss: 0.0999 - accuracy: 0.9683 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-07
# Epoch 58/100
# 18/18 [===========================>..] - ETA: 0s - loss: 0.0520 - accuracy: 0.9878Epoch 57: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 42.
# 18/18 [==============================] - 1s 66ms/step - loss: 0.0677 - accuracy: 0.9850 - val_loss: 0.1295 - val_accuracy: 0.9667 - lr: 1.0000e-07

# %%
history = pd.DataFrame(history_InceptionNet.history)
history
# Out:
#         loss  accuracy  val_loss  val_accuracy            lr
# 0   1.802323  0.286667  1.518212      0.333333  1.000000e-03
# 1   1.521210  0.310000  1.508692      0.333333  1.000000e-03
# 2   1.511751  0.321667  1.508307      0.333333  1.000000e-03
# 3   1.511449  0.330000  1.502468      0.333333  1.000000e-03
# 4   1.501097  0.333333  1.474487      0.333333  1.000000e-03
# 5   1.509068  0.345000  1.508096      0.333333  1.000000e-03
# 6   1.508484  0.303333  1.506765      0.333333  1.000000e-03
# 7   1.507507  0.310000  1.502926      0.333333  1.000000e-03
# 8   1.487433  0.336667  1.459209      0.333333  1.000000e-03
# 9   1.489930  0.335000  1.448846      0.333333  1.000000e-03
# 10  1.502332  0.325000  1.486398      0.333333  1.000000e-03
# 11  1.504708  0.336667  1.456774      0.333333  1.000000e-03
# 12  1.463764  0.328333  1.414843      0.333333  1.000000e-03
# 13  1.463182  0.358333  1.421788      0.473333  1.000000e-03
# 14  1.434685  0.371667  1.364310      0.533333  1.000000e-03
# 15  1.328401  0.470000  1.115707      0.560000  1.000000e-03
# 16  1.275580  0.486667  1.367038      0.333333  1.000000e-03
# 17  1.199872  0.498333  0.959751      0.606667  1.000000e-03
# 18  1.037197  0.590000  0.989128      0.580000  1.000000e-03
# 19  1.014204  0.593333  0.927434      0.653333  1.000000e-03
# 20  0.937774  0.620000  0.802200      0.660000  1.000000e-03
# 21  0.851822  0.671667  0.972907      0.646667  1.000000e-03
# 22  0.762222  0.700000  0.701667      0.680000  1.000000e-03
# 23  0.616968  0.773333  0.535595      0.833333  1.000000e-03
# 24  0.492141  0.798333  0.400981      0.893333  1.000000e-03
# 25  0.432091  0.830000  0.469882      0.813333  1.000000e-03
# 26  0.465414  0.826667  0.583591      0.773333  1.000000e-03
# 27  0.420775  0.836667  0.467855      0.866667  1.000000e-03
# 28  0.357748  0.853333  0.387712      0.813333  1.000000e-03
# 29  0.333378  0.865000  0.263033      0.906667  1.000000e-03
# 30  0.275633  0.888333  0.238143      0.933333  1.000000e-03
# 31  0.223761  0.930000  0.283538      0.893333  1.000000e-03
# 32  0.221826  0.915000  0.253330      0.933333  1.000000e-03
# 33  0.223376  0.925000  0.332921      0.886667  1.000000e-03
# 34  0.223859  0.915000  0.242296      0.926667  1.000000e-03
# 35  0.196148  0.943333  0.125113      0.960000  1.000000e-04
# 36  0.111699  0.963333  0.136299      0.960000  1.000000e-04
# 37  0.096706  0.970000  0.143756      0.960000  1.000000e-04
# 38  0.093129  0.971667  0.155911      0.960000  1.000000e-04
# 39  0.071903  0.980000  0.147586      0.946667  1.000000e-04
# 40  0.090624  0.968333  0.135441      0.960000  1.000000e-05
# 41  0.087530  0.983333  0.135001      0.960000  1.000000e-05
# 42  0.082606  0.976667  0.133384      0.966667  1.000000e-05
# 43  0.070090  0.980000  0.129098      0.966667  1.000000e-05
# 44  0.063745  0.981667  0.129302      0.966667  1.000000e-06
# 45  0.080381  0.975000  0.129503      0.966667  1.000000e-06
# 46  0.069022  0.978333  0.129528      0.966667  1.000000e-06
# 47  0.069342  0.973333  0.129561      0.966667  1.000000e-06
# 48  0.074163  0.980000  0.129568      0.966667  1.000000e-07
# 49  0.071896  0.980000  0.129572      0.966667  1.000000e-07
# 50  0.074329  0.976667  0.129559      0.966667  1.000000e-07
# 51  0.075350  0.975000  0.129556      0.966667  1.000000e-07
# 52  0.066907  0.978333  0.129569      0.966667  1.000000e-07
# 53  0.078379  0.975000  0.129554      0.966667  1.000000e-07
# 54  0.063981  0.981667  0.129541      0.966667  1.000000e-07
# 55  0.071922  0.980000  0.129532      0.966667  1.000000e-07
# 56  0.099940  0.968333  0.129484      0.966667  1.000000e-07
# 57  0.067704  0.985000  0.129460      0.966667  1.000000e-07

# %%
sns.set()
fig = pyplot.figure(figsize=(12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['accuracy'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['loss'], label='train')
sns.lineplot(x=history_InceptionNet.epoch, y=history_InceptionNet.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
label_to_text
# Out:
# {0: 'Surprise', 1: 'Fear', 2: 'Angry', 3: 'Sadness', 4: 'Happy'}

# %%
from sklearn.metrics import confusion_matrix

# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
pyplot.title('Confusion Matrix')
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.show()
# Out:
# 19/19 - 0s - loss: 0.0644 - accuracy: 0.9783 - 365ms/epoch - 19ms/step
#
# train Accuracy: 0.9783333539962769
# 5/5 - 0s - loss: 0.1334 - accuracy: 0.9667 - 103ms/epoch - 21ms/step
#
# Test Accuracy: 0.9666666388511658
# 5/5 [==============================] - 0s 17ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Angry       1.00      0.98      0.99        50
#         Fear       0.93      0.93      0.93        15
#        Happy       0.96      0.89      0.92        27
#      Sadness       0.85      1.00      0.92        17
#     Surprise       1.00      1.00      1.00        41
#
#     accuracy                           0.97       150
#    macro avg       0.95      0.96      0.95       150
# weighted avg       0.97      0.97      0.97       150

# %%
# Visualize some predictions
pyplot.figure(figsize=(10, 10))
for i in range(9):
    ax = pyplot.subplot(3, 3, i + 1)
    pyplot.imshow(X_test[i])
    pyplot.title(label_to_text[predicted_labels[i]])
    pyplot.axis("off")

pyplot.show()

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /opt/conda/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (9.5.0)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.24.3)
# Requirement already satisfied: aggdraw>=1.3.11 in /opt/conda/lib/python3.10/site-packages (from visualkeras) (1.3.18.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=2396x378>
