# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.utils import plot_model

# %%
DATA_PATH = "/kaggle/input/fyp-dataset/AffectNet/"
TOP_EMOTIONS = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]

# Define constants
TRAIN_SIZE = 0.80
INPUT_SHAPE = (75, 75, 3) # input size must 75 x 75
NUM_CLASSES = len(TOP_EMOTIONS)
BATCH_SIZE = 32
EPOCHS = 100

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# surprise has 1851 number of images
# fear has 1839 number of images
# neutral has 1880 number of images
# sad has 1821 number of images
# disgust has 1740 number of images
# contempt has 1833 number of images
# happy has 1862 number of images
# anger has 1822 number of images
#
# total images are 14648

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img = cv2.imread(DATA_PATH + dir_ + "/" + f)
            img = cv2.resize(img, (75, 75))

            # Convert image to RGB format if it's grayscale
            if img.shape[-1] == 1:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

            img_arr.append(img)
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded contempt images to numpy arrays...
# loaded happy images to numpy arrays...
# loaded anger images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((14648, 75, 75, 3),
#  (14648, 8),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'neutral',
#   3: 'sad',
#   4: 'disgust',
#   5: 'contempt',
#   6: 'happy',
#   7: 'anger'})

# %%
# Memory cleanup
del img
del dir_
del f

# %%
num_emotions = len(TOP_EMOTIONS)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols * 2, num_emotions * 2))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11718, 75, 75, 3), (2930, 75, 75, 3), (11718, 8), (2930, 8))

# %%
# Memory cleanup
del img_arr
del img_label

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(X_train)

# %%
# Load the InceptionV3 model
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build custom model architecture on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 1, 1, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,066,088 (84.18 MB)
#  Trainable params: 263,304 (1.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=25)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   5/366 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.1253 - loss: 3.0282
# W0000 00:00:1711465657.841718      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 270/366 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.2048 - loss: 2.1227
# W0000 00:00:1711465676.269535      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2131 - loss: 2.0835
# W0000 00:00:1711465688.064187      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 47s 95ms/step - accuracy: 0.2132 - loss: 2.0832 - val_accuracy: 0.2597 - val_loss: 1.8848 - learning_rate: 0.0010
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.2500 - loss: 1.7781
# W0000 00:00:1711465692.292815      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2500 - loss: 1.7781 - val_accuracy: 0.2710 - val_loss: 1.8682 - learning_rate: 0.0010
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.2823 - loss: 1.8437 - val_accuracy: 0.2935 - val_loss: 1.8291 - learning_rate: 0.0010
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.7409 - val_accuracy: 0.3007 - val_loss: 1.8184 - learning_rate: 0.0010
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.2893 - loss: 1.8147 - val_accuracy: 0.3058 - val_loss: 1.7859 - learning_rate: 0.0010
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1562 - loss: 2.1230 - val_accuracy: 0.3007 - val_loss: 1.7902 - learning_rate: 0.0010
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3029 - loss: 1.7908 - val_accuracy: 0.3140 - val_loss: 1.7632 - learning_rate: 0.0010
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.7276 - val_accuracy: 0.3184 - val_loss: 1.7627 - learning_rate: 0.0010
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3129 - loss: 1.7740 - val_accuracy: 0.3174 - val_loss: 1.7657 - learning_rate: 0.0010
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.7776 - val_accuracy: 0.3143 - val_loss: 1.7711 - learning_rate: 0.0010
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3046 - loss: 1.7863 - val_accuracy: 0.3119 - val_loss: 1.7512 - learning_rate: 0.0010
# Epoch 12/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.3125 - loss: 1.7505
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.7505 - val_accuracy: 0.3130 - val_loss: 1.7526 - learning_rate: 0.0010
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3355 - loss: 1.7435 - val_accuracy: 0.3225 - val_loss: 1.7362 - learning_rate: 1.0000e-04
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1562 - loss: 1.7683 - val_accuracy: 0.3246 - val_loss: 1.7360 - learning_rate: 1.0000e-04
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.3387 - loss: 1.7268 - val_accuracy: 0.3208 - val_loss: 1.7429 - learning_rate: 1.0000e-04
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 2.0793 - val_accuracy: 0.3198 - val_loss: 1.7436 - learning_rate: 1.0000e-04
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3302 - loss: 1.7377 - val_accuracy: 0.3253 - val_loss: 1.7316 - learning_rate: 1.0000e-04
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1875 - loss: 1.8573 - val_accuracy: 0.3256 - val_loss: 1.7315 - learning_rate: 1.0000e-04
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3370 - loss: 1.7274 - val_accuracy: 0.3235 - val_loss: 1.7271 - learning_rate: 1.0000e-04
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.6853 - val_accuracy: 0.3235 - val_loss: 1.7278 - learning_rate: 1.0000e-04
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3443 - loss: 1.7190 - val_accuracy: 0.3215 - val_loss: 1.7293 - learning_rate: 1.0000e-04
# Epoch 22/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.4062 - loss: 1.7766
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.7766 - val_accuracy: 0.3229 - val_loss: 1.7291 - learning_rate: 1.0000e-04
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3414 - loss: 1.7080 - val_accuracy: 0.3263 - val_loss: 1.7243 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.8837 - val_accuracy: 0.3259 - val_loss: 1.7243 - learning_rate: 1.0000e-05
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.3422 - loss: 1.7183 - val_accuracy: 0.3246 - val_loss: 1.7277 - learning_rate: 1.0000e-05
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.6978 - val_accuracy: 0.3246 - val_loss: 1.7277 - learning_rate: 1.0000e-05
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3407 - loss: 1.7177 - val_accuracy: 0.3270 - val_loss: 1.7261 - learning_rate: 1.0000e-05
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.5177 - val_accuracy: 0.3266 - val_loss: 1.7261 - learning_rate: 1.0000e-05
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3460 - loss: 1.7058 - val_accuracy: 0.3249 - val_loss: 1.7267 - learning_rate: 1.0000e-05
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.6623 - val_accuracy: 0.3249 - val_loss: 1.7267 - learning_rate: 1.0000e-05
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3523 - loss: 1.7036
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3522 - loss: 1.7036 - val_accuracy: 0.3256 - val_loss: 1.7274 - learning_rate: 1.0000e-05
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.7135 - val_accuracy: 0.3256 - val_loss: 1.7274 - learning_rate: 1.0000e-06
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3432 - loss: 1.7203 - val_accuracy: 0.3253 - val_loss: 1.7269 - learning_rate: 1.0000e-06
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.6404 - val_accuracy: 0.3253 - val_loss: 1.7269 - learning_rate: 1.0000e-06
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3522 - loss: 1.7043 - val_accuracy: 0.3273 - val_loss: 1.7264 - learning_rate: 1.0000e-06
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.9166 - val_accuracy: 0.3273 - val_loss: 1.7264 - learning_rate: 1.0000e-06
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3470 - loss: 1.7138 - val_accuracy: 0.3270 - val_loss: 1.7264 - learning_rate: 1.0000e-06
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.8399 - val_accuracy: 0.3266 - val_loss: 1.7264 - learning_rate: 1.0000e-06
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3449 - loss: 1.7137
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3449 - loss: 1.7137 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-06
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.5732 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3463 - loss: 1.7105 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.6559 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3393 - loss: 1.7180
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.3393 - loss: 1.7180 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.8640 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3400 - loss: 1.7150 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.5696 - val_accuracy: 0.3263 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.3455 - loss: 1.7061 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.6866 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.3413 - loss: 1.7137 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.5323 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - accuracy: 0.3524 - loss: 1.7113 - val_accuracy: 0.3266 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.4041 - val_accuracy: 0.3266 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.3497 - loss: 1.7059 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.6265 - val_accuracy: 0.3266 - val_loss: 1.7262 - learning_rate: 1.0000e-07
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.3498 - loss: 1.7141 - val_accuracy: 0.3266 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.6406 - val_accuracy: 0.3266 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - accuracy: 0.3547 - loss: 1.6940 - val_accuracy: 0.3263 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 58/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.6677 - val_accuracy: 0.3263 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 59/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - accuracy: 0.3397 - loss: 1.7313 - val_accuracy: 0.3259 - val_loss: 1.7261 - learning_rate: 1.0000e-07
# Epoch 60/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.4062 - loss: 1.6197Epoch 59: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 34.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4062 - loss: 1.6197 - val_accuracy: 0.3259 - val_loss: 1.7261 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.236351  1.963742      0.259727  1.884794   1.000000e-03
# 1   0.250000  1.778095      0.270990  1.868201   1.000000e-03
# 2   0.277939  1.853507      0.293515  1.829115   1.000000e-03
# 3   0.406250  1.740931      0.300683  1.818406   1.000000e-03
# 4   0.292230  1.825316      0.305802  1.785934   1.000000e-03
# 5   0.156250  2.122955      0.300683  1.790185   1.000000e-03
# 6   0.297536  1.801129      0.313993  1.763204   1.000000e-03
# 7   0.375000  1.727565      0.318430  1.762667   1.000000e-03
# 8   0.307975  1.787305      0.317406  1.765684   1.000000e-03
# 9   0.343750  1.777611      0.314334  1.771130   1.000000e-03
# 10  0.306863  1.783793      0.311945  1.751187   1.000000e-03
# 11  0.312500  1.750542      0.312969  1.752584   1.000000e-03
# 12  0.330738  1.743670      0.322526  1.736150   1.000000e-04
# 13  0.156250  1.768274      0.324573  1.735995   1.000000e-04
# 14  0.338182  1.729021      0.320819  1.742866   1.000000e-04
# 15  0.312500  2.079271      0.319795  1.743591   1.000000e-04
# 16  0.333305  1.730271      0.325256  1.731557   1.000000e-04
# 17  0.187500  1.857301      0.325597  1.731498   1.000000e-04
# 18  0.342461  1.720801      0.323549  1.727118   1.000000e-04
# 19  0.281250  1.685323      0.323549  1.727770   1.000000e-04
# 20  0.343146  1.721700      0.321502  1.729308   1.000000e-04
# 21  0.406250  1.776642      0.322867  1.729123   1.000000e-04
# 22  0.344344  1.715898      0.326280  1.724283   1.000000e-05
# 23  0.281250  1.883662      0.325939  1.724259   1.000000e-05
# 24  0.348109  1.710486      0.324573  1.727713   1.000000e-05
# 25  0.343750  1.697816      0.324573  1.727699   1.000000e-05
# 26  0.340236  1.718994      0.326962  1.726103   1.000000e-05
# 27  0.531250  1.517682      0.326621  1.726137   1.000000e-05
# 28  0.343402  1.715445      0.324915  1.726689   1.000000e-05
# 29  0.406250  1.662305      0.324915  1.726708   1.000000e-05
# 30  0.350163  1.709395      0.325597  1.727422   1.000000e-05
# 31  0.312500  1.713497      0.325597  1.727417   1.000000e-06
# 32  0.343231  1.715763      0.325256  1.726949   1.000000e-06
# 33  0.406250  1.640435      0.325256  1.726945   1.000000e-06
# 34  0.347767  1.709393      0.327304  1.726438   1.000000e-06
# 35  0.312500  1.916572      0.327304  1.726443   1.000000e-06
# 36  0.342119  1.713205      0.326962  1.726429   1.000000e-06
# 37  0.312500  1.839882      0.326621  1.726427   1.000000e-06
# 38  0.347681  1.711940      0.326280  1.726224   1.000000e-06
# 39  0.312500  1.573200      0.326280  1.726224   1.000000e-07
# 40  0.342975  1.713855      0.326280  1.726220   1.000000e-07
# 41  0.406250  1.655875      0.326280  1.726220   1.000000e-07
# 42  0.341349  1.710781      0.326280  1.726229   1.000000e-07
# 43  0.281250  1.864037      0.326280  1.726229   1.000000e-07
# 44  0.344772  1.711133      0.326280  1.726213   1.000000e-07
# 45  0.437500  1.569647      0.326280  1.726212   1.000000e-07
# 46  0.344857  1.709655      0.326621  1.726212   1.000000e-07
# 47  0.281250  1.686642      0.326621  1.726211   1.000000e-07
# 48  0.344087  1.714065      0.326621  1.726168   1.000000e-07
# 49  0.468750  1.532259      0.326621  1.726168   1.000000e-07
# 50  0.344515  1.714690      0.326621  1.726140   1.000000e-07
# 51  0.500000  1.404061      0.326621  1.726140   1.000000e-07
# 52  0.344686  1.715688      0.326621  1.726159   1.000000e-07
# 53  0.500000  1.626537      0.326621  1.726160   1.000000e-07
# 54  0.348366  1.713724      0.326621  1.726148   1.000000e-07
# 55  0.375000  1.640562      0.326621  1.726149   1.000000e-07
# 56  0.344686  1.712213      0.326280  1.726133   1.000000e-07
# 57  0.281250  1.667690      0.326280  1.726133   1.000000e-07
# 58  0.337669  1.720316      0.325939  1.726122   1.000000e-07
# 59  0.406250  1.619675      0.325939  1.726122   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 75, 75, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 1, 1, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,066,088 (84.18 MB)
#  Trainable params: 22,031,656 (84.04 MB)
#  Non-trainable params: 34,432 (134.50 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_test, y_test),
    steps_per_epoch=int(len(X_train) / BATCH_SIZE),
    epochs=EPOCHS,
    callbacks=[lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   2/366 ━━━━━━━━━━━━━━━━━━━━ 29s 80ms/step - accuracy: 0.0703 - loss: 2.5148
# W0000 00:00:1711466414.632327      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 258/366 ━━━━━━━━━━━━━━━━━━━━ 17s 159ms/step - accuracy: 0.1451 - loss: 2.1924
# W0000 00:00:1711466455.497155      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.1493 - loss: 2.1679
# W0000 00:00:1711466467.662200      88 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 122s 156ms/step - accuracy: 0.1493 - loss: 2.1677 - val_accuracy: 0.2031 - val_loss: 2.1446 - learning_rate: 1.0000e-05
# Epoch 2/100
#   1/366 ━━━━━━━━━━━━━━━━━━━━ 28s 77ms/step - accuracy: 0.1875 - loss: 2.0612
# W0000 00:00:1711466471.667038      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1875 - loss: 2.0612 - val_accuracy: 0.2027 - val_loss: 2.1472 - learning_rate: 1.0000e-05
# Epoch 3/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.1997 - loss: 2.0046 - val_accuracy: 0.2375 - val_loss: 2.2003 - learning_rate: 1.0000e-05
# Epoch 4/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0625 - loss: 1.9427 - val_accuracy: 0.2362 - val_loss: 2.1996 - learning_rate: 1.0000e-05
# Epoch 5/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.2236 - loss: 1.9462 - val_accuracy: 0.2573 - val_loss: 2.0455 - learning_rate: 1.0000e-05
# Epoch 6/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2500 - loss: 1.8350 - val_accuracy: 0.2577 - val_loss: 2.0475 - learning_rate: 1.0000e-05
# Epoch 7/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.2445 - loss: 1.8972 - val_accuracy: 0.2857 - val_loss: 1.9181 - learning_rate: 1.0000e-05
# Epoch 8/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.7433 - val_accuracy: 0.2853 - val_loss: 1.9192 - learning_rate: 1.0000e-05
# Epoch 9/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.2789 - loss: 1.8481 - val_accuracy: 0.2881 - val_loss: 1.9888 - learning_rate: 1.0000e-05
# Epoch 10/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3125 - loss: 1.8949 - val_accuracy: 0.2898 - val_loss: 1.9800 - learning_rate: 1.0000e-05
# Epoch 11/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.2914 - loss: 1.8083 - val_accuracy: 0.3150 - val_loss: 1.9714 - learning_rate: 1.0000e-05
# Epoch 12/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2500 - loss: 1.7854 - val_accuracy: 0.3157 - val_loss: 1.9681 - learning_rate: 1.0000e-05
# Epoch 13/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3115 - loss: 1.7691 - val_accuracy: 0.3365 - val_loss: 1.8198 - learning_rate: 1.0000e-05
# Epoch 14/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2500 - loss: 1.8696 - val_accuracy: 0.3372 - val_loss: 1.8203 - learning_rate: 1.0000e-05
# Epoch 15/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.3229 - loss: 1.7235 - val_accuracy: 0.3392 - val_loss: 1.7731 - learning_rate: 1.0000e-05
# Epoch 16/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1875 - loss: 2.0122 - val_accuracy: 0.3375 - val_loss: 1.7737 - learning_rate: 1.0000e-05
# Epoch 17/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3471 - loss: 1.6899 - val_accuracy: 0.3488 - val_loss: 1.7412 - learning_rate: 1.0000e-05
# Epoch 18/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.5364 - val_accuracy: 0.3495 - val_loss: 1.7425 - learning_rate: 1.0000e-05
# Epoch 19/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3539 - loss: 1.6596 - val_accuracy: 0.3741 - val_loss: 1.6834 - learning_rate: 1.0000e-05
# Epoch 20/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.5720 - val_accuracy: 0.3737 - val_loss: 1.6825 - learning_rate: 1.0000e-05
# Epoch 21/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3637 - loss: 1.6294 - val_accuracy: 0.3812 - val_loss: 1.6599 - learning_rate: 1.0000e-05
# Epoch 22/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2812 - loss: 1.9666 - val_accuracy: 0.3816 - val_loss: 1.6594 - learning_rate: 1.0000e-05
# Epoch 23/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3779 - loss: 1.5929 - val_accuracy: 0.3887 - val_loss: 1.6030 - learning_rate: 1.0000e-05
# Epoch 24/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.4989 - val_accuracy: 0.3911 - val_loss: 1.6027 - learning_rate: 1.0000e-05
# Epoch 25/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.3927 - loss: 1.5566 - val_accuracy: 0.3976 - val_loss: 1.5828 - learning_rate: 1.0000e-05
# Epoch 26/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.5486 - val_accuracy: 0.3990 - val_loss: 1.5827 - learning_rate: 1.0000e-05
# Epoch 27/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.3928 - loss: 1.5502 - val_accuracy: 0.4020 - val_loss: 1.5892 - learning_rate: 1.0000e-05
# Epoch 28/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.4709 - val_accuracy: 0.4020 - val_loss: 1.5901 - learning_rate: 1.0000e-05
# Epoch 29/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4177 - loss: 1.5136 - val_accuracy: 0.4133 - val_loss: 1.5659 - learning_rate: 1.0000e-05
# Epoch 30/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.5720 - val_accuracy: 0.4143 - val_loss: 1.5647 - learning_rate: 1.0000e-05
# Epoch 31/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4107 - loss: 1.5115 - val_accuracy: 0.4229 - val_loss: 1.5301 - learning_rate: 1.0000e-05
# Epoch 32/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.5730 - val_accuracy: 0.4222 - val_loss: 1.5311 - learning_rate: 1.0000e-05
# Epoch 33/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4278 - loss: 1.4701 - val_accuracy: 0.4311 - val_loss: 1.5127 - learning_rate: 1.0000e-05
# Epoch 34/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.5495 - val_accuracy: 0.4304 - val_loss: 1.5132 - learning_rate: 1.0000e-05
# Epoch 35/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4337 - loss: 1.4639 - val_accuracy: 0.4294 - val_loss: 1.5349 - learning_rate: 1.0000e-05
# Epoch 36/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6250 - loss: 1.2043 - val_accuracy: 0.4290 - val_loss: 1.5338 - learning_rate: 1.0000e-05
# Epoch 37/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4403 - loss: 1.4460 - val_accuracy: 0.4399 - val_loss: 1.5215 - learning_rate: 1.0000e-05
# Epoch 38/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.1301 - val_accuracy: 0.4396 - val_loss: 1.5229 - learning_rate: 1.0000e-05
# Epoch 39/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4453 - loss: 1.4124 - val_accuracy: 0.4300 - val_loss: 1.5499 - learning_rate: 1.0000e-05
# Epoch 40/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.6667 - val_accuracy: 0.4300 - val_loss: 1.5504 - learning_rate: 1.0000e-05
# Epoch 41/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4477 - loss: 1.4170
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 24s 64ms/step - accuracy: 0.4477 - loss: 1.4170 - val_accuracy: 0.4396 - val_loss: 1.5195 - learning_rate: 1.0000e-05
# Epoch 42/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5000 - loss: 1.1977 - val_accuracy: 0.4392 - val_loss: 1.5165 - learning_rate: 1.0000e-06
# Epoch 43/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 24s 66ms/step - accuracy: 0.4634 - loss: 1.4014 - val_accuracy: 0.4430 - val_loss: 1.4964 - learning_rate: 1.0000e-06
# Epoch 44/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.3665 - val_accuracy: 0.4430 - val_loss: 1.4951 - learning_rate: 1.0000e-06
# Epoch 45/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4635 - loss: 1.3795 - val_accuracy: 0.4369 - val_loss: 1.4902 - learning_rate: 1.0000e-06
# Epoch 46/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4688 - loss: 1.3268 - val_accuracy: 0.4372 - val_loss: 1.4898 - learning_rate: 1.0000e-06
# Epoch 47/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4675 - loss: 1.3816
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4675 - loss: 1.3816 - val_accuracy: 0.4430 - val_loss: 1.4849 - learning_rate: 1.0000e-06
# Epoch 48/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3438 - loss: 1.5802 - val_accuracy: 0.4433 - val_loss: 1.4852 - learning_rate: 1.0000e-07
# Epoch 49/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4659 - loss: 1.3806 - val_accuracy: 0.4413 - val_loss: 1.4843 - learning_rate: 1.0000e-07
# Epoch 50/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.3028 - val_accuracy: 0.4420 - val_loss: 1.4847 - learning_rate: 1.0000e-07
# Epoch 51/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 40s 59ms/step - accuracy: 0.4614 - loss: 1.3886 - val_accuracy: 0.4416 - val_loss: 1.4941 - learning_rate: 1.0000e-07
# Epoch 52/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.4303 - val_accuracy: 0.4410 - val_loss: 1.4948 - learning_rate: 1.0000e-07
# Epoch 53/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4679 - loss: 1.3654 - val_accuracy: 0.4420 - val_loss: 1.4892 - learning_rate: 1.0000e-07
# Epoch 54/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.2960 - val_accuracy: 0.4406 - val_loss: 1.4883 - learning_rate: 1.0000e-07
# Epoch 55/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4643 - loss: 1.3857 - val_accuracy: 0.4365 - val_loss: 1.4928 - learning_rate: 1.0000e-07
# Epoch 56/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.3685 - val_accuracy: 0.4372 - val_loss: 1.4926 - learning_rate: 1.0000e-07
# Epoch 57/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4764 - loss: 1.3820 - val_accuracy: 0.4389 - val_loss: 1.4895 - learning_rate: 1.0000e-07
# Epoch 58/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2500 - loss: 1.6537 - val_accuracy: 0.4406 - val_loss: 1.4895 - learning_rate: 1.0000e-07
# Epoch 59/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4588 - loss: 1.3839 - val_accuracy: 0.4392 - val_loss: 1.4856 - learning_rate: 1.0000e-07
# Epoch 60/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5625 - loss: 1.4283 - val_accuracy: 0.4413 - val_loss: 1.4837 - learning_rate: 1.0000e-07
# Epoch 61/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4751 - loss: 1.3681 - val_accuracy: 0.4416 - val_loss: 1.4855 - learning_rate: 1.0000e-07
# Epoch 62/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.2872 - val_accuracy: 0.4413 - val_loss: 1.4844 - learning_rate: 1.0000e-07
# Epoch 63/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4703 - loss: 1.3819 - val_accuracy: 0.4406 - val_loss: 1.4930 - learning_rate: 1.0000e-07
# Epoch 64/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.4182 - val_accuracy: 0.4403 - val_loss: 1.4923 - learning_rate: 1.0000e-07
# Epoch 65/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4701 - loss: 1.3823 - val_accuracy: 0.4433 - val_loss: 1.4916 - learning_rate: 1.0000e-07
# Epoch 66/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.2498 - val_accuracy: 0.4440 - val_loss: 1.4894 - learning_rate: 1.0000e-07
# Epoch 67/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4700 - loss: 1.3668 - val_accuracy: 0.4416 - val_loss: 1.4861 - learning_rate: 1.0000e-07
# Epoch 68/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6562 - loss: 1.1360 - val_accuracy: 0.4416 - val_loss: 1.4859 - learning_rate: 1.0000e-07
# Epoch 69/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4664 - loss: 1.3843 - val_accuracy: 0.4403 - val_loss: 1.4898 - learning_rate: 1.0000e-07
# Epoch 70/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.3235 - val_accuracy: 0.4416 - val_loss: 1.4893 - learning_rate: 1.0000e-07
# Epoch 71/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4696 - loss: 1.3840 - val_accuracy: 0.4392 - val_loss: 1.4914 - learning_rate: 1.0000e-07
# Epoch 72/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.3457 - val_accuracy: 0.4386 - val_loss: 1.4913 - learning_rate: 1.0000e-07
# Epoch 73/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4706 - loss: 1.3734 - val_accuracy: 0.4403 - val_loss: 1.4885 - learning_rate: 1.0000e-07
# Epoch 74/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.2624 - val_accuracy: 0.4410 - val_loss: 1.4882 - learning_rate: 1.0000e-07
# Epoch 75/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4721 - loss: 1.3753 - val_accuracy: 0.4406 - val_loss: 1.4903 - learning_rate: 1.0000e-07
# Epoch 76/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4062 - loss: 1.4811 - val_accuracy: 0.4399 - val_loss: 1.4907 - learning_rate: 1.0000e-07
# Epoch 77/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4714 - loss: 1.3653 - val_accuracy: 0.4413 - val_loss: 1.4814 - learning_rate: 1.0000e-07
# Epoch 78/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.3130 - val_accuracy: 0.4406 - val_loss: 1.4807 - learning_rate: 1.0000e-07
# Epoch 79/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4648 - loss: 1.3802 - val_accuracy: 0.4416 - val_loss: 1.4878 - learning_rate: 1.0000e-07
# Epoch 80/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5000 - loss: 1.5173 - val_accuracy: 0.4427 - val_loss: 1.4873 - learning_rate: 1.0000e-07
# Epoch 81/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4644 - loss: 1.3770 - val_accuracy: 0.4420 - val_loss: 1.4882 - learning_rate: 1.0000e-07
# Epoch 82/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5938 - loss: 1.2812 - val_accuracy: 0.4416 - val_loss: 1.4883 - learning_rate: 1.0000e-07
# Epoch 83/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4706 - loss: 1.3753 - val_accuracy: 0.4410 - val_loss: 1.4829 - learning_rate: 1.0000e-07
# Epoch 84/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.4720 - val_accuracy: 0.4413 - val_loss: 1.4829 - learning_rate: 1.0000e-07
# Epoch 85/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.4655 - loss: 1.3797 - val_accuracy: 0.4399 - val_loss: 1.4889 - learning_rate: 1.0000e-07
# Epoch 86/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3750 - loss: 1.3000 - val_accuracy: 0.4420 - val_loss: 1.4896 - learning_rate: 1.0000e-07
# Epoch 87/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 59ms/step - accuracy: 0.4711 - loss: 1.3621 - val_accuracy: 0.4392 - val_loss: 1.4895 - learning_rate: 1.0000e-07
# Epoch 88/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4375 - loss: 1.3624 - val_accuracy: 0.4389 - val_loss: 1.4893 - learning_rate: 1.0000e-07
# Epoch 89/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4673 - loss: 1.3856 - val_accuracy: 0.4406 - val_loss: 1.4851 - learning_rate: 1.0000e-07
# Epoch 90/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5312 - loss: 1.2491 - val_accuracy: 0.4416 - val_loss: 1.4855 - learning_rate: 1.0000e-07
# Epoch 91/100
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4744 - loss: 1.3677Epoch 90: Early stopping due to no improvement in 25 epochs.
# Restoring best weights from epoch 65.
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 22s 60ms/step - accuracy: 0.4744 - loss: 1.3677 - val_accuracy: 0.4423 - val_loss: 1.4869 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.163016  2.097777      0.203072  2.144570   1.000000e-05
# 1   0.187500  2.061248      0.202730  2.147169   1.000000e-05
# 2   0.200839  1.993485      0.237543  2.200346   1.000000e-05
# 3   0.062500  1.942724      0.236177  2.199592   1.000000e-05
# 4   0.234811  1.931386      0.257338  2.045477   1.000000e-05
# ..       ...       ...           ...       ...            ...
# 86  0.462776  1.380134      0.439249  1.489464   1.000000e-07
# 87  0.437500  1.362408      0.438908  1.489328   1.000000e-07
# 88  0.465771  1.382278      0.440614  1.485087   1.000000e-07
# 89  0.531250  1.249134      0.441638  1.485480   1.000000e-07
# 90  0.472275  1.379406      0.442321  1.486856   1.000000e-07
#
# [91 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=TOP_EMOTIONS))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=TOP_EMOTIONS, yticklabels=TOP_EMOTIONS)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 367/367 - 7s - 19ms/step - accuracy: 0.5096 - loss: 1.3123
# W0000 00:00:1711467544.362001      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.5095579624176025
# 92/92 - 1s - 13ms/step - accuracy: 0.4440 - loss: 1.4894
#
# Test Accuracy: 0.444027304649353
# 12/92 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# W0000 00:00:1711467551.986669      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step
# W0000 00:00:1711467558.128209      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.40      0.34      0.36       370
#     contempt       0.34      0.43      0.38       368
#      disgust       0.70      0.70      0.70       376
#         fear       0.27      0.16      0.20       364
#        happy       0.25      0.25      0.25       348
#      neutral       0.43      0.51      0.47       367
#          sad       0.78      0.79      0.78       373
#     surprise       0.31      0.36      0.33       364
#
#     accuracy                           0.44      2930
#    macro avg       0.44      0.44      0.44      2930
# weighted avg       0.44      0.44      0.44      2930

# %%
label_to_text
# Out:
# {0: 'surprise',
#  1: 'fear',
#  2: 'neutral',
#  3: 'sad',
#  4: 'disgust',
#  5: 'contempt',
#  6: 'happy',
#  7: 'anger'}

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(X_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])
    plt.title(f"True: {label_to_text[true_labels[idx]]}\nPredicted: {label_to_text[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
