# %%
import os
import cv2
import math
import joblib
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.utils import plot_model
# Out:
# 2024-04-02 15:14:17.498366: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-02 15:14:17.498458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-02 15:14:17.635580: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Function to load data
def load_data(data_dir, target_names):
    img_arr = []
    img_label = []
    label_to_text = {}
    label = 0

    for dir_ in os.listdir(data_dir):
        if dir_ in target_names:
            for f in os.listdir(data_dir + dir_ + "/"):
                img = cv2.imread(data_dir + dir_ + "/" + f)
                img = cv2.resize(img, (32, 32))

                # Convert image to RGB format if it's grayscale
                if img.shape[-1] == 1:
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                img_arr.append(img)
                img_label.append(label)
            print(f"loaded {dir_} images to numpy arrays...")
            label_to_text[label] = dir_
            label += 1

    img_arr = np.array(img_arr)
    img_label = np.array(img_label)
    img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1, 1))

    return img_arr, img_label, label_to_text

# %%
target_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# Load training data
data_dir_train = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/train/"
img_arr_train, img_label_train, label_to_text_train = load_data(data_dir_train, target_names)

# Load test data
data_dir_test = "/kaggle/input/fyp-dataset/RAFDB/RAFDB/test/"
img_arr_test, img_label_test, label_to_text_test = load_data(data_dir_test, target_names)

INPUT_SHAPE = (32,32,3)
NUM_CLASSES = len(target_names)
BATCH_SIZE = 64
EPOCHS = 100

img_arr_train.shape, img_label_train.shape, label_to_text_train
img_arr_test.shape, img_label_test.shape, label_to_text_test
# Out:
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# loaded surprise images to numpy arrays...
# loaded fear images to numpy arrays...
# loaded angry images to numpy arrays...
# loaded neutral images to numpy arrays...
# loaded sad images to numpy arrays...
# loaded disgust images to numpy arrays...
# loaded happy images to numpy arrays...
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ((3068, 32, 32, 3),
#  (3068, 7),
#  {0: 'surprise',
#   1: 'fear',
#   2: 'angry',
#   3: 'neutral',
#   4: 'sad',
#   5: 'disgust',
#   6: 'happy'})

# %%
total_images_train = 0
for dir_ in os.listdir(data_dir_train):
    if dir_ in target_names:
        count = 0
        for f in os.listdir(data_dir_train + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of training images")
        total_images_train += count

print(f"\ntotal training images are {total_images_train}\n")
# Out:
# surprise has 1290 number of training images
# fear has 281 number of training images
# angry has 705 number of training images
# neutral has 2524 number of training images
# sad has 1982 number of training images
# disgust has 717 number of training images
# happy has 4772 number of training images
#
# total training images are 12271

# %%
num_emotions = len(target_names)
num_cols = 4
fig, axes = plt.subplots(num_emotions, num_cols, figsize=(num_cols*2, num_emotions*2))

idx = 0
for k in label_to_text_train:
    sample_indices = np.random.choice(np.where(img_label_train[:, k] == 1)[0], size=num_cols, replace=False)
    sample_images = img_arr_train[sample_indices]

    for i, img in enumerate(sample_images):
        ax = axes[idx, i]
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax.imshow(img), plt.axis('off')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text_train[k])

    idx += 1

plt.tight_layout()
plt.show()

# %%
# Define a custom callback for early stopping based on validation accuracy
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='val_accuracy', patience=10, restore_best_weights=True):
        super(CustomEarlyStopping, self).__init__()
        self.monitor = monitor
        self.patience = patience
        self.restore_best_weights = restore_best_weights
        self.best = -np.Inf  # Initialize best to negative infinity
        self.best_epoch = 0
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        current_val_acc = logs.get(self.monitor)
        if current_val_acc > self.best:
            self.best = current_val_acc
            self.best_epoch = epoch
            self.best_weights = self.model.get_weights()  # Save the best weights
        elif epoch - self.best_epoch >= self.patience:
            print(f"Epoch {epoch}: Early stopping due to no improvement in {self.patience} epochs.")
            self.model.stop_training = True
            if self.restore_best_weights and self.best_weights is not None:
                print(f"Restoring best weights from epoch {self.best_epoch}.")
                self.model.set_weights(self.best_weights)

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

# Fit the data generator on training data
train_datagen.fit(img_arr_train)

# %%
# https://www.tensorflow.org/guide/keras/transfer_learning#train_the_top_layer

# Load pre-trained DenseNet121 model
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

# Freeze layers in the pre-trained model
for layer in base_model.layers:
    layer.trainable = False

# Build model on top of pre-trained model
inputs = Input(shape=INPUT_SHAPE)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 1, 1, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,333,703 (27.98 MB)
#  Trainable params: 296,199 (1.13 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=15,
    verbose=1,
    restore_best_weights=True,
)

# %%
custom_early_stopping = CustomEarlyStopping(patience=15)

# Train the top layer
history_top_layer = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   4/191 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.2298 - loss: 10.6226
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712071016.056374      91 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1712071016.118408      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 147/191 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.3065 - loss: 3.6969
# W0000 00:00:1712071036.706616      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 189/191 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.3175 - loss: 3.3687
# W0000 00:00:1712071053.505691      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1712071064.354910      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 78s 255ms/step - accuracy: 0.3182 - loss: 3.3496 - val_accuracy: 0.3993 - val_loss: 1.5904 - learning_rate: 0.0010
# Epoch 2/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.4844 - loss: 1.4271
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4844 - loss: 1.4271 - val_accuracy: 0.3973 - val_loss: 1.5889 - learning_rate: 0.0010
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.3915 - loss: 1.6236 - val_accuracy: 0.4051 - val_loss: 1.5578 - learning_rate: 0.0010
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3125 - loss: 1.8844 - val_accuracy: 0.4071 - val_loss: 1.5564 - learning_rate: 0.0010
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.3925 - loss: 1.5979 - val_accuracy: 0.4140 - val_loss: 1.5431 - learning_rate: 0.0010
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4688 - loss: 1.4768 - val_accuracy: 0.4153 - val_loss: 1.5445 - learning_rate: 0.0010
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4158 - loss: 1.5530 - val_accuracy: 0.4061 - val_loss: 1.5587 - learning_rate: 0.0010
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4062 - loss: 1.4686 - val_accuracy: 0.4055 - val_loss: 1.5577 - learning_rate: 0.0010
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4197 - loss: 1.5596 - val_accuracy: 0.4175 - val_loss: 1.5420 - learning_rate: 0.0010
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3906 - loss: 1.6454 - val_accuracy: 0.4218 - val_loss: 1.5444 - learning_rate: 0.0010
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.4186 - loss: 1.5416 - val_accuracy: 0.4166 - val_loss: 1.5356 - learning_rate: 0.0010
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4219 - loss: 1.5496 - val_accuracy: 0.4175 - val_loss: 1.5270 - learning_rate: 0.0010
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4114 - loss: 1.5396 - val_accuracy: 0.4179 - val_loss: 1.5134 - learning_rate: 0.0010
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4062 - loss: 1.6413 - val_accuracy: 0.4221 - val_loss: 1.5153 - learning_rate: 0.0010
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4199 - loss: 1.5239 - val_accuracy: 0.4319 - val_loss: 1.5211 - learning_rate: 0.0010
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4219 - loss: 1.4832 - val_accuracy: 0.4322 - val_loss: 1.5214 - learning_rate: 0.0010
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4363 - loss: 1.4995 - val_accuracy: 0.4260 - val_loss: 1.5104 - learning_rate: 0.0010
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3906 - loss: 1.5421 - val_accuracy: 0.4254 - val_loss: 1.5040 - learning_rate: 0.0010
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4301 - loss: 1.5061 - val_accuracy: 0.4286 - val_loss: 1.4888 - learning_rate: 0.0010
# Epoch 20/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4375 - loss: 1.3780
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.3780 - val_accuracy: 0.4276 - val_loss: 1.4914 - learning_rate: 0.0010
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.4322 - loss: 1.4815 - val_accuracy: 0.4404 - val_loss: 1.4779 - learning_rate: 1.0000e-04
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3125 - loss: 1.5232 - val_accuracy: 0.4397 - val_loss: 1.4777 - learning_rate: 1.0000e-04
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4402 - loss: 1.4672 - val_accuracy: 0.4368 - val_loss: 1.4771 - learning_rate: 1.0000e-04
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3594 - loss: 1.4993 - val_accuracy: 0.4374 - val_loss: 1.4773 - learning_rate: 1.0000e-04
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4399 - loss: 1.4741
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4399 - loss: 1.4741 - val_accuracy: 0.4384 - val_loss: 1.4778 - learning_rate: 1.0000e-04
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.5452 - val_accuracy: 0.4384 - val_loss: 1.4778 - learning_rate: 1.0000e-05
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.4480 - loss: 1.4537 - val_accuracy: 0.4407 - val_loss: 1.4750 - learning_rate: 1.0000e-05
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4062 - loss: 1.4911 - val_accuracy: 0.4407 - val_loss: 1.4751 - learning_rate: 1.0000e-05
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4354 - loss: 1.4678 - val_accuracy: 0.4423 - val_loss: 1.4736 - learning_rate: 1.0000e-05
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5000 - loss: 1.4751 - val_accuracy: 0.4426 - val_loss: 1.4735 - learning_rate: 1.0000e-05
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4386 - loss: 1.4694 - val_accuracy: 0.4426 - val_loss: 1.4714 - learning_rate: 1.0000e-05
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.3611 - val_accuracy: 0.4426 - val_loss: 1.4714 - learning_rate: 1.0000e-05
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.4342 - loss: 1.4670 - val_accuracy: 0.4404 - val_loss: 1.4724 - learning_rate: 1.0000e-05
# Epoch 34/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4375 - loss: 1.4492
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.4492 - val_accuracy: 0.4404 - val_loss: 1.4724 - learning_rate: 1.0000e-05
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4504 - loss: 1.4530 - val_accuracy: 0.4404 - val_loss: 1.4723 - learning_rate: 1.0000e-06
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5000 - loss: 1.3852 - val_accuracy: 0.4404 - val_loss: 1.4723 - learning_rate: 1.0000e-06
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.4490 - loss: 1.4594 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-06
# Epoch 38/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.4375 - loss: 1.4534
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4375 - loss: 1.4534 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-06
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4381 - loss: 1.4642 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5156 - loss: 1.3962 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.4451 - loss: 1.4769 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 42/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4844 - loss: 1.4055
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4844 - loss: 1.4055 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.4461 - loss: 1.4499 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4531 - loss: 1.3920 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07
# Epoch 45/100
# 189/191 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4513 - loss: 1.4433Epoch 44: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 29.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - accuracy: 0.4512 - loss: 1.4436 - val_accuracy: 0.4410 - val_loss: 1.4722 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for the top layer training
history_top_layer_df = pd.DataFrame(history_top_layer.history)
history_top_layer_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.359794  2.146931      0.399283  1.590354   1.000000e-03
# 1   0.484375  1.427093      0.397327  1.588932   1.000000e-03
# 2   0.396330  1.608469      0.405150  1.557789   1.000000e-03
# 3   0.312500  1.884378      0.407106  1.556367   1.000000e-03
# 4   0.401901  1.579985      0.413950  1.543149   1.000000e-03
# 5   0.468750  1.476823      0.415254  1.544466   1.000000e-03
# 6   0.405095  1.560989      0.406128  1.558684   1.000000e-03
# 7   0.406250  1.468588      0.405476  1.557744   1.000000e-03
# 8   0.408864  1.560907      0.417536  1.542016   1.000000e-03
# 9   0.390625  1.645398      0.421773  1.544445   1.000000e-03
# 10  0.417629  1.537279      0.416558  1.535609   1.000000e-03
# 11  0.421875  1.549592      0.417536  1.527008   1.000000e-03
# 12  0.419186  1.530822      0.417862  1.513358   1.000000e-03
# 13  0.406250  1.641296      0.422099  1.515285   1.000000e-03
# 14  0.414762  1.524655      0.431877  1.521101   1.000000e-03
# 15  0.421875  1.483171      0.432203  1.521433   1.000000e-03
# 16  0.426804  1.517959      0.426010  1.510388   1.000000e-03
# 17  0.390625  1.542075      0.425359  1.503953   1.000000e-03
# 18  0.420169  1.520036      0.428618  1.488839   1.000000e-03
# 19  0.437500  1.377990      0.427640  1.491369   1.000000e-03
# 20  0.437700  1.477935      0.440352  1.477851   1.000000e-04
# 21  0.312500  1.523210      0.439700  1.477747   1.000000e-04
# 22  0.439420  1.471112      0.436767  1.477114   1.000000e-04
# 23  0.359375  1.499318      0.437419  1.477319   1.000000e-04
# 24  0.439830  1.469297      0.438396  1.477838   1.000000e-04
# 25  0.437500  1.545232      0.438396  1.477831   1.000000e-05
# 26  0.445646  1.458224      0.440678  1.475035   1.000000e-05
# 27  0.406250  1.491139      0.440678  1.475056   1.000000e-05
# 28  0.441222  1.462483      0.442308  1.473563   1.000000e-05
# 29  0.500000  1.475073      0.442634  1.473524   1.000000e-05
# 30  0.446056  1.456428      0.442634  1.471364   1.000000e-05
# 31  0.500000  1.361073      0.442634  1.471380   1.000000e-05
# 32  0.438109  1.462291      0.440352  1.472436   1.000000e-05
# 33  0.437500  1.449245      0.440352  1.472439   1.000000e-05
# 34  0.444335  1.461223      0.440352  1.472340   1.000000e-06
# 35  0.500000  1.385157      0.440352  1.472339   1.000000e-06
# 36  0.445154  1.461816      0.441004  1.472167   1.000000e-06
# 37  0.437500  1.453398      0.441004  1.472165   1.000000e-06
# 38  0.438765  1.464779      0.441004  1.472171   1.000000e-07
# 39  0.515625  1.396230      0.441004  1.472170   1.000000e-07
# 40  0.446793  1.463715      0.441004  1.472152   1.000000e-07
# 41  0.484375  1.405490      0.441004  1.472153   1.000000e-07
# 42  0.442369  1.453835      0.441004  1.472156   1.000000e-07
# 43  0.453125  1.392045      0.441004  1.472156   1.000000e-07
# 44  0.444417  1.463421      0.441004  1.472179   1.000000e-07

# %%
# Fine-tuning the entire model
for layer in base_model.layers:
    layer.trainable = True

# Compile the model again
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model after fine-tuning
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 1, 1, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,333,703 (27.98 MB)
#  Trainable params: 7,250,055 (27.66 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
# Train the entire model end-to-end with a low learning rate
history_fine_tuning = model.fit(
    train_datagen.flow(img_arr_train, img_label_train, batch_size=BATCH_SIZE),
    validation_data=(img_arr_test, img_label_test),
    steps_per_epoch=int(len(img_arr_train) / BATCH_SIZE),
    epochs = EPOCHS,
    callbacks = [lr_scheduler, custom_early_stopping],
)
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/191 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - accuracy: 0.4071 - loss: 1.6431
# W0000 00:00:1712071454.143156      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#  42/191 ━━━━━━━━━━━━━━━━━━━━ 4:35 2s/step - accuracy: 0.3777 - loss: 1.6716
# W0000 00:00:1712071529.839525      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.3901 - loss: 1.6200
# W0000 00:00:1712071546.187524      89 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 236s 515ms/step - accuracy: 0.3902 - loss: 1.6197 - val_accuracy: 0.4700 - val_loss: 1.4571 - learning_rate: 1.0000e-04
# Epoch 2/100
# W0000 00:00:1712071551.828433      90 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.5469 - loss: 1.4447
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5469 - loss: 1.4447 - val_accuracy: 0.4720 - val_loss: 1.4542 - learning_rate: 1.0000e-04
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.5077 - loss: 1.3497 - val_accuracy: 0.5261 - val_loss: 1.2787 - learning_rate: 1.0000e-04
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6562 - loss: 1.0922 - val_accuracy: 0.5297 - val_loss: 1.2745 - learning_rate: 1.0000e-04
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.5665 - loss: 1.2099 - val_accuracy: 0.6037 - val_loss: 1.1191 - learning_rate: 1.0000e-04
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5469 - loss: 1.1818 - val_accuracy: 0.6053 - val_loss: 1.1188 - learning_rate: 1.0000e-04
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6028 - loss: 1.1068 - val_accuracy: 0.5557 - val_loss: 1.3367 - learning_rate: 1.0000e-04
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6094 - loss: 1.0414 - val_accuracy: 0.5603 - val_loss: 1.3144 - learning_rate: 1.0000e-04
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6500 - loss: 0.9869 - val_accuracy: 0.5984 - val_loss: 1.1219 - learning_rate: 1.0000e-04
# Epoch 10/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.6250 - loss: 1.1094
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 1.1094 - val_accuracy: 0.5978 - val_loss: 1.1310 - learning_rate: 1.0000e-04
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6755 - loss: 0.9188 - val_accuracy: 0.6255 - val_loss: 1.0365 - learning_rate: 1.0000e-05
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 1.0017 - val_accuracy: 0.6252 - val_loss: 1.0359 - learning_rate: 1.0000e-05
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.6933 - loss: 0.8996 - val_accuracy: 0.6310 - val_loss: 1.0094 - learning_rate: 1.0000e-05
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7031 - loss: 0.8685 - val_accuracy: 0.6314 - val_loss: 1.0106 - learning_rate: 1.0000e-05
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6839 - loss: 0.8941 - val_accuracy: 0.6424 - val_loss: 1.0027 - learning_rate: 1.0000e-05
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6250 - loss: 0.9642 - val_accuracy: 0.6421 - val_loss: 1.0031 - learning_rate: 1.0000e-05
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.6827 - loss: 0.8941 - val_accuracy: 0.6470 - val_loss: 0.9905 - learning_rate: 1.0000e-05
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.8745 - val_accuracy: 0.6473 - val_loss: 0.9913 - learning_rate: 1.0000e-05
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6912 - loss: 0.8771 - val_accuracy: 0.6529 - val_loss: 0.9804 - learning_rate: 1.0000e-05
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6719 - loss: 0.8643 - val_accuracy: 0.6516 - val_loss: 0.9814 - learning_rate: 1.0000e-05
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.6942 - loss: 0.8653 - val_accuracy: 0.6499 - val_loss: 0.9842 - learning_rate: 1.0000e-05
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.7959 - val_accuracy: 0.6490 - val_loss: 0.9845 - learning_rate: 1.0000e-05
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7118 - loss: 0.8140 - val_accuracy: 0.6574 - val_loss: 0.9726 - learning_rate: 1.0000e-05
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7500 - loss: 0.9271 - val_accuracy: 0.6578 - val_loss: 0.9718 - learning_rate: 1.0000e-05
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7071 - loss: 0.8387 - val_accuracy: 0.6519 - val_loss: 0.9762 - learning_rate: 1.0000e-05
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7344 - loss: 0.7189 - val_accuracy: 0.6522 - val_loss: 0.9776 - learning_rate: 1.0000e-05
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.7108 - loss: 0.8199 - val_accuracy: 0.6600 - val_loss: 0.9568 - learning_rate: 1.0000e-05
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7656 - loss: 0.8369 - val_accuracy: 0.6607 - val_loss: 0.9566 - learning_rate: 1.0000e-05
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.7241 - loss: 0.7956 - val_accuracy: 0.6695 - val_loss: 0.9371 - learning_rate: 1.0000e-05
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.6761 - val_accuracy: 0.6705 - val_loss: 0.9376 - learning_rate: 1.0000e-05
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7164 - loss: 0.8001 - val_accuracy: 0.6643 - val_loss: 0.9497 - learning_rate: 1.0000e-05
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7031 - loss: 0.8430 - val_accuracy: 0.6643 - val_loss: 0.9509 - learning_rate: 1.0000e-05
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7223 - loss: 0.7984 - val_accuracy: 0.6613 - val_loss: 0.9494 - learning_rate: 1.0000e-05
# Epoch 34/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.8281 - loss: 0.7092
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8281 - loss: 0.7092 - val_accuracy: 0.6617 - val_loss: 0.9486 - learning_rate: 1.0000e-05
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7333 - loss: 0.7611 - val_accuracy: 0.6646 - val_loss: 0.9483 - learning_rate: 1.0000e-06
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8594 - loss: 0.5729 - val_accuracy: 0.6636 - val_loss: 0.9486 - learning_rate: 1.0000e-06
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7337 - loss: 0.7538 - val_accuracy: 0.6633 - val_loss: 0.9455 - learning_rate: 1.0000e-06
# Epoch 38/100
#   1/191 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.7812 - loss: 0.6815
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-07.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6815 - val_accuracy: 0.6630 - val_loss: 0.9459 - learning_rate: 1.0000e-06
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.7322 - loss: 0.7612 - val_accuracy: 0.6623 - val_loss: 0.9470 - learning_rate: 1.0000e-07
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.8854 - val_accuracy: 0.6626 - val_loss: 0.9472 - learning_rate: 1.0000e-07
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.7329 - loss: 0.7530 - val_accuracy: 0.6620 - val_loss: 0.9483 - learning_rate: 1.0000e-07
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.6685 - val_accuracy: 0.6630 - val_loss: 0.9487 - learning_rate: 1.0000e-07
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - accuracy: 0.7297 - loss: 0.7617 - val_accuracy: 0.6636 - val_loss: 0.9502 - learning_rate: 1.0000e-07
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7031 - loss: 0.8826 - val_accuracy: 0.6636 - val_loss: 0.9504 - learning_rate: 1.0000e-07
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7316 - loss: 0.7731Epoch 44: Early stopping due to no improvement in 15 epochs.
# Restoring best weights from epoch 29.
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.7316 - loss: 0.7730 - val_accuracy: 0.6626 - val_loss: 0.9474 - learning_rate: 1.0000e-07

# %%
# Create history dataframe for fine-tuning
history_fine_tuning_df = pd.DataFrame(history_fine_tuning.history)
history_fine_tuning_df
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 0   0.407963  1.556084      0.470013  1.457063   1.000000e-04
# 1   0.546875  1.444701      0.471969  1.454237   1.000000e-04
# 2   0.518391  1.322713      0.526076  1.278731   1.000000e-04
# 3   0.656250  1.092202      0.529661  1.274460   1.000000e-04
# 4   0.578193  1.173533      0.603651  1.119120   1.000000e-04
# 5   0.546875  1.181806      0.605280  1.118837   1.000000e-04
# 6   0.615057  1.084152      0.555737  1.336684   1.000000e-04
# 7   0.609375  1.041435      0.560300  1.314364   1.000000e-04
# 8   0.643483  1.007424      0.598435  1.121881   1.000000e-04
# 9   0.625000  1.109363      0.597784  1.131025   1.000000e-04
# 10  0.673466  0.926760      0.625489  1.036481   1.000000e-05
# 11  0.625000  1.001677      0.625163  1.035853   1.000000e-05
# 12  0.683215  0.902863      0.631030  1.009434   1.000000e-05
# 13  0.703125  0.868490      0.631356  1.010557   1.000000e-05
# 14  0.683870  0.890736      0.642438  1.002674   1.000000e-05
# 15  0.625000  0.964201      0.642112  1.003097   1.000000e-05
# 16  0.687638  0.884617      0.647001  0.990535   1.000000e-05
# 17  0.718750  0.874463      0.647327  0.991298   1.000000e-05
# 18  0.697223  0.863374      0.652868  0.980354   1.000000e-05
# 19  0.671875  0.864254      0.651565  0.981445   1.000000e-05
# 20  0.700172  0.843639      0.649935  0.984190   1.000000e-05
# 21  0.718750  0.795920      0.648957  0.984528   1.000000e-05
# 22  0.703531  0.831354      0.657432  0.972628   1.000000e-05
# 23  0.750000  0.927076      0.657758  0.971759   1.000000e-05
# 24  0.709101  0.830128      0.651890  0.976171   1.000000e-05
# 25  0.734375  0.718864      0.652216  0.977608   1.000000e-05
# 26  0.709839  0.819452      0.660039  0.956798   1.000000e-05
# 27  0.765625  0.836858      0.660691  0.956604   1.000000e-05
# 28  0.717457  0.806626      0.669492  0.937072   1.000000e-05
# 29  0.812500  0.676063      0.670469  0.937564   1.000000e-05
# 30  0.721307  0.789403      0.664276  0.949730   1.000000e-05
# 31  0.703125  0.842969      0.664276  0.950931   1.000000e-05
# 32  0.726878  0.786628      0.661343  0.949400   1.000000e-05
# 33  0.828125  0.709208      0.661669  0.948588   1.000000e-05
# 34  0.726305  0.768335      0.664602  0.948255   1.000000e-06
# 35  0.859375  0.572896      0.663625  0.948591   1.000000e-06
# 36  0.729991  0.761664      0.663299  0.945549   1.000000e-06
# 37  0.781250  0.681511      0.662973  0.945944   1.000000e-06
# 38  0.735480  0.759755      0.662321  0.947019   1.000000e-07
# 39  0.656250  0.885356      0.662647  0.947183   1.000000e-07
# 40  0.732940  0.758211      0.661995  0.948251   1.000000e-07
# 41  0.781250  0.668489      0.662973  0.948676   1.000000e-07
# 42  0.728107  0.761983      0.663625  0.950194   1.000000e-07
# 43  0.703125  0.882565      0.663625  0.950382   1.000000e-07
# 44  0.732203  0.762921      0.662647  0.947442   1.000000e-07

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize training history for the top layer training
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['accuracy'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_accuracy'], label='valid')
plt.title('Top Layer Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['loss'], label='train')
sns.lineplot(x=history_top_layer_df.index, y=history_top_layer_df['val_loss'], label='valid')
plt.title('Top Layer Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()

# Visualize training history for fine-tuning
sns.set()
fig = plt.figure(figsize=(12, 4))

ax = plt.subplot(1, 2, 1)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['accuracy'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_accuracy'], label='valid')
plt.title('Fine-tuning Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.tight_layout()

ax = plt.subplot(1, 2, 2)
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['loss'], label='train')
sns.lineplot(x=history_fine_tuning_df.index, y=history_fine_tuning_df['val_loss'], label='valid')
plt.title('Fine-tuning Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.tight_layout()

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Evaluate the model
train_loss, train_acc = model.evaluate(img_arr_train, img_label_train, verbose=2)
print(f"\ntrain Accuracy: {train_acc}")

# Evaluate the model
test_loss, test_acc = model.evaluate(img_arr_test, img_label_test, verbose=2)
print(f"\nTest Accuracy: {test_acc}")

# Predictions
predictions = model.predict(img_arr_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(img_label_test, axis=1)

# Classification Report
print("\nClassification Report:\n", classification_report(true_labels, predicted_labels, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 384/384 - 13s - 34ms/step - accuracy: 0.7459 - loss: 0.7280
# W0000 00:00:1712071840.281926      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# train Accuracy: 0.7459049820899963
# 96/96 - 1s - 11ms/step - accuracy: 0.6705 - loss: 0.9376
#
# Test Accuracy: 0.670469343662262
# 16/96 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# W0000 00:00:1712071850.609653      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step
# W0000 00:00:1712071860.591732      91 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.61      0.64      0.63       329
#      disgust       0.59      0.22      0.32        74
#         fear       0.36      0.63      0.46       162
#        happy       0.63      0.66      0.64       680
#      neutral       0.53      0.57      0.55       478
#          sad       0.37      0.21      0.27       160
#     surprise       0.89      0.82      0.85      1185
#
#     accuracy                           0.67      3068
#    macro avg       0.57      0.54      0.53      3068
# weighted avg       0.68      0.67      0.67      3068

# %%
import random

# Visualize some predictions
num_images_to_visualize = 10
random_indices = np.random.choice(len(img_arr_test), size=num_images_to_visualize, replace=False)

plt.figure(figsize=(15, 8))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img_arr_test[idx])
    plt.title(f"True: {label_to_text_test[true_labels[idx]]}\nPredicted: {label_to_text_test[predicted_labels[idx]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
